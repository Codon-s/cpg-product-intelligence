# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/topo chico_from_dump.csv")
df
# Out:
#              code                                       product_name  \
# 0   0021136010374                           MINERAL WATER CARBONATED
# 1   0021136010480                                       Agua Mineral
# 2   0021136010626  Topo Chico, Sparkling Carbonatada Agua Mineral...
# 3   0021136011500                                               Soda
# 4   0021136011579             Topo Chico, Carbonated Beverage, Apple
# ..            ...                                                ...
# 76  0993350000724                                         Topo chico
# 77  0810078782193                Margarita Flavored Alcohol Beverage
# 78  0721136000480                                    Topo chico 1.5L
# 79       01219258      Raspberry with Lemon Flavored Sparkling Water
# 80  0810078782186   Margarita Flavored Alcohol Beverage Prickly Pear
#
#                    brands                                    categories_tags  \
# 0              Topo Chico                                          undefined
# 1   Cia. Topo Chico  S.A.  beverages-and-beverages-preparations, beverage...
# 2   Cia. Topo Chico  S.A.                                  beverages, waters
# 3   Cia. Topo Chico  S.A.                beverages, carbonated-drinks, sodas
# 4   Cia. Topo Chico  S.A.                beverages, carbonated-drinks, sodas
# ..                    ...                                                ...
# 76                    NaN                                                NaN
# 77             Topo Chico                                                NaN
# 78                    NaN                                                NaN
# 79     Topo Chico Sabores                                                NaN
# 80             Topo Chico                                                NaN
#
#            countries_tags                        packaging_tags stores  \
# 0           united-states  bottle-or-vial, bottle, glass-bottle    NaN
# 1   mexico, united-states                                   NaN    NaN
# 2           united-states                                   NaN    NaN
# 3           united-states                                   NaN    NaN
# 4           united-states                                   NaN    NaN
# ..                    ...                                   ...    ...
# 76                 mexico                                   NaN    NaN
# 77          united-states                                   NaN    NaN
# 78                 mexico                                   NaN    NaN
# 79          united-states                                   NaN    NaN
# 80          united-states                                   NaN    NaN
#
#    purchase_places nutriscore_grade  nova_group  ecoscore_grade  \
# 0              NaN                a         NaN             NaN
# 1              NaN                a         4.0             NaN
# 2              NaN          unknown         4.0             NaN
# 3              NaN                e         4.0  not-applicable
# 4              NaN                e         4.0  not-applicable
# ..             ...              ...         ...             ...
# 76             NaN          unknown         NaN             NaN
# 77             NaN          unknown         NaN             NaN
# 78             NaN          unknown         NaN             NaN
# 79             NaN          unknown         NaN             NaN
# 80             NaN          unknown         NaN             NaN
#
#                                      ingredients_text  nutriments.sugars_100g  \
# 0    CARBONATED MINERAL WATER BOTTLED ONLY AT SOURCE.                     NaN
# 1                   MINERAL WATER AND CARBON DIOXIDE.                     NaN
# 2                      Mineral water, carbon dioxide.                     NaN
# 3   Carbonated water, cane sugar, artificial and n...                   10.99
# 4   Carbonated water, cane sugar, citric acid, car...                   12.24
# ..                                                ...                     ...
# 76                                                NaN                     NaN
# 77                                                NaN                     NaN
# 78                                                NaN                     NaN
# 79                                                NaN                     NaN
# 80                                                NaN                     NaN
#
#     nutriments.energy-kcal_100g
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                          42.0
# 4                          49.0
# ..                          ...
# 76                          NaN
# 77                          NaN
# 78                          NaN
# 79                          NaN
# 80                          NaN
#
# [81 rows x 14 columns]

# %%
df.dtypes
# Out:
# code                             int64
# product_name                    object
# brands                          object
# categories_tags                 object
# countries_tags                  object
# packaging_tags                  object
# stores                          object
# purchase_places                 object
# nutriscore_grade                object
# nova_group                     float64
# ecoscore_grade                  object
# ingredients_text                object
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df.code.unique()
# Out:
# array(['0021136010374', '0021136010480', '0021136010626', '0021136011500',
#        '0021136011579', '0021136013504', '0021136013573', '0021136014501',
#        '0021136015508', '0021136016185', '0021136019506', '0021136019575',
#        '0021136020373', '0021136050462', '0021136110180', '0021136120448',
#        '0021136414370', '0021136616507', '0021136010541', '0021136010534',
#        '5449000294722', '5449000294746', '0021136180619', '5449000294708',
#        '0021136180657', '0021136010350', '0021136180794', '0021136016444',
#        '5000112650150', '0021136180800', '5449000300904', '0021136180817',
#        '0021136180558', '0021136180954', '0021136180701', '0021136180664',
#        '0810078780014', '2004361007713', '91055901860836515341',
#        '0021136180596', '0021136180626', '0021136010121', '0810078780045',
#        '0810078780342', '0021136180947', '0810078780021', '0021136181166',
#        '5000112650167', '0021136110449', '0810078780564', '0810078781035',
#        '7894900335040', '7894900335095', '7894900335026', '7501055379866',
#        '0628068270380', '0021136181371', '4774537447244', '0021266181371',
#        '0021136181678', '0021136181708', '03118153', '0021266010541',
#        '0021136181616', '0002113618136', '0021136181623', '0783474362125',
#        '0021136181685', '7501055387007', '0002113601054', '0810078782223',
#        '0021136181463', '0810078781356', '17386922', '0810078781370',
#        '0021136181715', '0993350000724', '0810078782193', '0721136000480',
#        '01219258', '0810078782186'], dtype=object)

# %%
df=df.astype({"code": "int64"})

# %%
df.brands.unique()
# Out:
# array(['Topo Chico', 'Cia. Topo Chico  S.A.', 'unknown',
#        'Coca-Cola Company', 'Topo Chico Sabores', 'Topo Chico Hard'],
#       dtype=object)

# %%
df.brands = df.brands.replace({
    "Topo chico": "Topo Chico",
    "topo chico": "Topo Chico",
    "TOPO CHICO": "Topo Chico",
    "Too Chico": "Topo Chico"
}, regex=True)

# %%
df.brands = df.brands.fillna("unknown")
df.brands.isnull().sum()
# Out:
# np.int64(0)

# %%
cols = [
    "categories_tags",
    "countries_tags",
    "packaging_tags",
    "stores",
    "purchase_places",
    "ecoscore_grade",
    "ingredients_text"
]

df[cols] = df[cols].fillna("Unknown")

# %%
df_clean = df.copy()

# %%
country_df = df_clean.copy()
country_df["countries_tags"] = country_df["countries_tags"].str.split(",")
country_df = country_df.explode("countries_tags")
country_df["countries_tags"] = country_df["countries_tags"].str.strip().str.lower()

# %%
pack_df = df_clean.copy()
pack_df["packaging_tags"] = pack_df["packaging_tags"].str.split(",")
pack_df = pack_df.explode("packaging_tags")
pack_df["packaging_tags"] = pack_df["packaging_tags"].str.strip().str.lower()

# %%
cat_df = df_clean.copy()
cat_df["categories_tags"] = cat_df["categories_tags"].str.split(",")
cat_df = cat_df.explode("categories_tags")
cat_df["categories_tags"] = cat_df["categories_tags"].str.strip().str.lower()

# %%
store_df = df_clean.copy()
store_df["stores"] = store_df["stores"].str.split(",")
store_df = store_df.explode("stores")
store_df["stores"] = store_df["stores"].str.strip().str.lower()

# %%
products_df = df_clean.copy()
products_df["product_name"] = products_df["product_name"].str.split(",")
products_df = products_df.explode("product_name")
products_df["product_name"] = products_df["product_name"].str.strip().str.lower()

# %%
df.brands.value_counts()
# Out:
# brands
# Topo Chico               44
# unknown                  16
# Cia. Topo Chico  S.A.    15
# Topo Chico Sabores        4
# Coca-Cola Company         1
# Topo Chico Hard           1
# Name: count, dtype: int64

# %%
country_df.value_counts("countries_tags")
# Out:
# countries_tags
# united-states    60
# spain             6
# mexico            5
# brazil            3
# germany           2
# luxembourg        2
# france            1
# italy             1
# japan             1
# saudi-arabia      1
# unknown           1
# Name: count, dtype: int64

# %%
pack_df.value_counts("packaging_tags")
# Out:
# packaging_tags
# unknown                          72
# bottle                            5
# aluminium                         3
# metal                             3
# recyclable-metals                 3
# bottle-or-vial                    1
# de:al                             1
# glass-bottle                      1
# pet-desechable-con-taparrosca     1
# Name: count, dtype: int64

# %%
cat_df.value_counts("categories_tags")
# Out:
# categories_tags
# beverages                               44
# unknown                                 34
# beverages-and-beverages-preparations    22
# waters                                  20
# carbonated-drinks                       15
# alcoholic-beverages                     13
# carbonated-waters                        8
# mineral-waters                           7
# spring-waters                            7
# sodas                                    7
# hard-seltzer                             4
# undefined                                3
# carbonated-mineral-waters                2
# vodka-based-alcoholic-beverages          2
# premixed-alcoholic-beverages             2
# hard-seltzers                            2
# de:selt                                  1
# de:wein                                  1
# de:ready-to-drink                        1
# de:premixgetränk                         1
# de:hard-seltzer                          1
# de:alkopop                               1
# de:alkoholhaltiges-mischgetränk          1
# de:alcopop                               1
# wines                                    1
# Name: count, dtype: int64

# %%
store_df.value_counts("stores")
# Out:
# stores
# unknown         77
# carrefour.fr     2
# abarrotes        1
# chedraui         1
# hagebaumarkt     1
# la plancha       1
# méxico           1
# sam's            1
# soriana          1
# walmart          1
# Name: count, dtype: int64

# %%
products_df.value_counts("product_name")
# Out:
# product_name
# topo chico                                       15
# topo chico hard seltzer                           5
# raspberry with lemon flavored sparkling water     3
# pineapple                                         3
# mineral water                                     3
#                                                  ..
# raspberry lemon                                   1
# agua mineral natural carbonatada                  1
# sengria carbonated beverage                       1
# soda                                              1
# twist of lime mineral water                       1
# Name: count, Length: 62, dtype: int64

# %%
print("Total Products :", products_df["product_name"].nunique())
# Out:
# Total Products : 62

# %%
print("Total Brands :", df["brands"].nunique())
# Out:
# Total Brands : 6

# %%
print("Total Categories :", cat_df["categories_tags"].nunique())
# Out:
# Total Categories : 25

# %%
print("Total Countries :", country_df["countries_tags"].nunique())
# Out:
# Total Countries : 11

# %%
print("Total Packaging Types :", pack_df["packaging_tags"].nunique())
# Out:
# Total Packaging Types : 9

# %%
print("Total Stores :", store_df["stores"].nunique())
# Out:
# Total Stores : 10

# %%
summary = pd.DataFrame({
    "Unique Values": df.nunique(),
    "Missing Values": df.isnull().sum(),
    "Data Type": df.dtypes
})

summary
# Out:
#                              Unique Values  Missing Values Data Type
# code                                    81               0     int64
# product_name                            65               0    object
# brands                                   6               0    object
# categories_tags                         18               0    object
# countries_tags                          13               0    object
# packaging_tags                           6               0    object
# stores                                   4               0    object
# purchase_places                          2               0    object
# nutriscore_grade                         6               0    object
# nova_group                               2              43   float64
# ecoscore_grade                           3               0    object
# ingredients_text                        39               0    object
# nutriments.sugars_100g                  19              43   float64
# nutriments.energy-kcal_100g             19              35   float64
