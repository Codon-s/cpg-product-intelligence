# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/coca-cola_from_dump.csv')

# %%
df
# Out:
#                code            product_name                      brands  \
# 0       22222084941      Coca-Cola original                   Coca-Cola
# 1       42111558865          coca cola zéro  Coca-Cola-light, coca cola
# 2       49000004632               Coca-Cola                   Coca-Cola
# 3       49000012781               Coca-Cola                   Coca-Cola
# 4       49000024685     Original Taste Soda                   Coca-Cola
# ...             ...                     ...                         ...
# 4984  5000112686692                     NaN                   Coca Cola
# 4985  6990871421605     Coca Cola Coca Cola                   Coca Cola
# 4986  5942321005454          Coke zero zero                   Coca-Cola
# 4987    49000056166  Cherry Float Coke Zero                   Coca-Cola
# 4988  7801610350652   Coca-Cola Zero Azucar                   Coca-Cola
#
#                                         categories_tags  \
# ...

# %%
df.tail()
# Out:
#                code            product_name     brands  \
# 4984  5000112686692                     NaN  Coca Cola
# 4985  6990871421605     Coca Cola Coca Cola  Coca Cola
# 4986  5942321005454          Coke zero zero  Coca-Cola
# 4987    49000056166  Cherry Float Coke Zero  Coca-Cola
# 4988  7801610350652   Coca-Cola Zero Azucar  Coca-Cola
#
#                                         categories_tags  \
# 4984  beverages-and-beverages-preparations, beverage...
# 4985                                        Dagligvarer
# 4986                                                NaN
# 4987                                                NaN
# 4988  beverages-and-beverages-preparations, beverage...
#
#                                          countries_tags packaging_tags stores  \
# 4984                                            germany            NaN    NaN
# 4985                                            denmark            NaN    NaN
# ...

# %%
df.isnull().sum()
# Out:
# code                              0
# product_name                    260
# brands                          389
# categories_tags                1954
# countries_tags                   28
# packaging_tags                 3721
# stores                         4429
# purchase_places                4449
# nutriscore_grade                  1
# nova_group                     3084
# ecoscore_grade                 4249
# ingredients_text               2741
# nutriments.sugars_100g         3990
# nutriments.energy-kcal_100g    3940
# dtype: int64

# %%
df.dtypes
# Out:
# code                            object
# product_name                       str
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                     str
# stores                             str
# purchase_places                    str
# nutriscore_grade                   str
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['code', 'product_name', 'brands', 'categories_tags', 'countries_tags',
#        'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade',
#        'nova_group', 'ecoscore_grade', 'ingredients_text',
#        'nutriments.sugars_100g', 'nutriments.energy-kcal_100g'],
#       dtype='str')

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4984    False
# 4985    False
# 4986    False
# 4987    False
# 4988    False
# Length: 4989, dtype: bool

# %%
df.code.unique()
# Out:
# array([22222084941, 42111558865, 49000004632, ..., 5942321005454,
#        49000056166, 7801610350652], shape=(4989,), dtype=object)

# %%
df.code = df.code .replace(',','',regex=True)

# %%
df.dtypes
# Out:
# code                            object
# product_name                       str
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                     str
# stores                             str
# purchase_places                    str
# nutriscore_grade                   str
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df.code = df.code.replace('shape=(4989,)','',regex=True)

# %%
df.dtypes
# Out:
# code                            object
# product_name                       str
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                     str
# stores                             str
# purchase_places                    str
# nutriscore_grade                   str
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df = df.astype({'code': 'float64'})

# %%
df.dtypes
# Out:
# code                           float64
# product_name                       str
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                     str
# stores                             str
# purchase_places                    str
# nutriscore_grade                   str
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df['nutriments.sugars_100g'].unique()
# Out:
# array([           nan, 1.10000000e+01, 1.08291032e+01, 6.76000000e+00,
#        1.00000000e+01, 9.80000000e+00, 1.16000000e+01, 8.00000000e+00,
#        0.00000000e+00, 1.06000000e+01, 7.91000000e+00, 3.59000000e+00,
#        5.50000000e+01, 1.00000000e+00, 1.13000000e+01, 6.50000000e+00,
#        9.00000000e+00, 1.07000000e+01, 3.80000000e+01, 7.50000000e+00,
#        6.00000000e+00, 3.00000000e+00, 9.39000000e+00, 9.50000000e+00,
#        1.20000000e+01, 6.30000000e+00, 1.02000000e+01, 7.90000000e+00,
#        2.16000000e+00, 7.30000000e+00, 6.40000000e+01, 5.80000000e+00,
#        5.10000000e+00, 1.18000000e+01, 4.20000000e+00, 5.83000000e+00,
#        1.30000000e+01, 1.08000000e+01, 7.00000000e+00, 6.67000000e+00,
#        5.14000000e+00, 7.70000000e+00, 1.13559322e+01, 8.60000000e+00,
#        1.05000000e+01, 4.29000000e+00, 4.40000000e+00, 6.70000000e+00,
#        1.35000000e+01, 5.00000000e-01, 5.00000000e+00, 7.80000000e+00,
# ...

# %%
df['nutriments.energy-kcal_100g'].unique()
# Out:
# array([           nan, 3.94000000e+01, 3.89170897e+01, 2.71000000e+01,
#        4.80000000e+01, 4.20000000e+01, 5.10000000e+01, 3.00000000e+00,
#        5.00000000e+01, 4.23000000e+01, 2.00000000e+00, 3.71000000e+01,
#        1.50000000e+01, 0.00000000e+00, 4.50000000e+01, 2.20000000e+02,
#        1.00000000e+00, 2.00000000e-01, 4.74000000e+01, 9.00000000e-01,
#        2.70000000e+01, 4.30000000e+01, 3.00000000e-01, 3.80000000e+01,
#        1.50000000e+02, 3.00000000e+01, 2.40000000e+01, 1.20000000e+01,
#        4.25000000e+01, 4.08000000e+01, 4.00000000e+01, 4.40000000e+01,
#        5.60000000e+01, 2.67000000e-01, 2.86000000e+01, 3.40000000e+01,
#        2.50000000e+01, 4.05000000e+01, 4.00000000e-01, 1.68000000e+01,
#        2.80000000e+01, 2.00000000e+01, 2.22000000e+01, 5.40000000e+01,
#        4.90000000e+01, 4.54000000e-01, 1.90000000e+01, 3.10000000e+01,
#        5.00000000e-01, 2.33333333e-01, 4.11864407e+01, 1.05000000e+02,
# ...

# %%
df.isnull().sum()
# Out:
# code                              0
# product_name                    260
# brands                          389
# categories_tags                1954
# countries_tags                   28
# packaging_tags                 3721
# stores                         4429
# purchase_places                4449
# nutriscore_grade                  1
# nova_group                     3084
# ecoscore_grade                 4249
# ingredients_text               2741
# nutriments.sugars_100g         3990
# nutriments.energy-kcal_100g    3940
# dtype: int64

# %%
df.product_name.unique()
# Out:
# <ArrowStringArray>
# [               'Coca-Cola original',                    'coca cola zéro',
#                          'Coca-Cola',               'Original Taste Soda',
#                                  nan,     'Coca-Cola Original Taste Soda',
#                          'Pibb Xtra',              'Coca-Cola Zero Sugar',
#          'Coca-Cola Zero Sugar Cola',       'Cherry Coca-Cola Zero Sugar',
#  ...
#                    'Cherry Floaters', 'Coca-Cola Zero Sugar cherry float',
#                       'Orange Fanta',                  'Mezzo Mix Cherry',
#             'Coca Cola (Zero Sugar)',   'Coca-Cola Zero Sugar Hương Vani',
#     'Coca Cola - White Peach Flavor',         'coca cola original tastew',
#                     'Coke zero zero',             'Coca-Cola Zero Azucar']
# Length: 2902, dtype: str

# %%
df.product_name = df.product_name.replace('-','',regex=True)

# %%
df.product_name.unique()
# Out:
# <ArrowStringArray>
# [               'CocaCola original',                   'coca cola zéro',
#                          'CocaCola',              'Original Taste Soda',
#                                 nan,     'CocaCola Original Taste Soda',
#                         'Pibb Xtra',              'CocaCola Zero Sugar',
#          'CocaCola Zero Sugar Cola',       'Cherry CocaCola Zero Sugar',
#  ...
#                   'Cherry Floaters', 'CocaCola Zero Sugar cherry float',
#                      'Orange Fanta',                 'Mezzo Mix Cherry',
#            'Coca Cola (Zero Sugar)',   'CocaCola Zero Sugar Hương Vani',
#     'Coca Cola  White Peach Flavor',        'coca cola original tastew',
#                    'Coke zero zero',             'CocaCola Zero Azucar']
# Length: 2886, dtype: str

# %%
df.product_name = df.product_name.fillna('unknown')

# %%
df.product_name.unique()
# Out:
# <ArrowStringArray>
# [               'CocaCola original',                   'coca cola zéro',
#                          'CocaCola',              'Original Taste Soda',
#                           'unknown',     'CocaCola Original Taste Soda',
#                         'Pibb Xtra',              'CocaCola Zero Sugar',
#          'CocaCola Zero Sugar Cola',       'Cherry CocaCola Zero Sugar',
#  ...
#                   'Cherry Floaters', 'CocaCola Zero Sugar cherry float',
#                      'Orange Fanta',                 'Mezzo Mix Cherry',
#            'Coca Cola (Zero Sugar)',   'CocaCola Zero Sugar Hương Vani',
#     'Coca Cola  White Peach Flavor',        'coca cola original tastew',
#                    'Coke zero zero',             'CocaCola Zero Azucar']
# Length: 2886, dtype: str

# %%
a=df.product_name[df.product_name== 'unknown'].count()
a
# Out:
# np.int64(260)

# %%
df.product_name.isnull().sum()
# Out:
# np.int64(0)

# %%
df.brands.isnull().sum()
# Out:
# np.int64(389)

# %%
df.brands = df.brands.fillna('unknown')

# %%
df.brands.isnull().sum()
# Out:
# np.int64(0)

# %%
df.categories_tags = df.categories_tags.fillna('unknown')

# %%
df.categories_tags.isnull().sum()
# Out:
# np.int64(0)

# %%
df.countries_tags = df.countries_tags.fillna('unknown')

# %%
df.countries_tags.isnull().sum()
# Out:
# np.int64(0)

# %%
df.packaging_tags = df.packaging_tags.fillna('unknown')

# %%
df.packaging_tags.isnull().sum()
# Out:
# np.int64(0)

# %%
df.stores = df.stores.fillna('unknown')

# %%
df.packaging_tags.isnull().sum()
# Out:
# np.int64(0)

# %%
df.purchase_places = df.purchase_places.fillna('unknown')
df.purchase_places.isnull().sum()
# Out:
# np.int64(0)

# %%
df.nutriscore_grade = df.nutriscore_grade.fillna('unknown')
df.nutriscore_grade.isnull().sum()
# Out:
# np.int64(0)

# %%
df.ecoscore_grade = df.ecoscore_grade.fillna('unknown')
df.ecoscore_grade.isnull().sum()
# Out:
# np.int64(0)

# %%
df.ingredients_text = df.ingredients_text.fillna('unknown')
df.ingredients_text.isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# code                              0
# product_name                      0
# brands                            0
# categories_tags                   0
# countries_tags                    0
# packaging_tags                    0
# stores                            0
# purchase_places                   0
# nutriscore_grade                  0
# nova_group                     3084
# ecoscore_grade                    0
# ingredients_text                  0
# nutriments.sugars_100g         3990
# nutriments.energy-kcal_100g    3940
# dtype: int64

# %%
df.code = df.code.replace('coca cola','Coca-Cola',regex=True)

# %%
df.code = df.code.replace('Coca-cola','Coca-Cola',regex=True)

# %%
df.code = df.code.replace('Cocacola','Coca-Cola',regex=True)

# %%
raw_products = df.product_name.str.split(',')
raw_products
# Out:
# 0            [CocaCola original]
# 1               [coca cola zéro]
# 2                     [CocaCola]
# 3                     [CocaCola]
# 4          [Original Taste Soda]
#                   ...
# 4984                   [unknown]
# 4985       [Coca Cola Coca Cola]
# 4986            [Coke zero zero]
# 4987    [Cherry Float Coke Zero]
# 4988      [CocaCola Zero Azucar]
# Name: product_name, Length: 4989, dtype: object

# %%
exploded_products = raw_products.explode()
exploded_products
# Out:
# 0            CocaCola original
# 1               coca cola zéro
# 2                     CocaCola
# 3                     CocaCola
# 4          Original Taste Soda
#                  ...
# 4984                   unknown
# 4985       Coca Cola Coca Cola
# 4986            Coke zero zero
# 4987    Cherry Float Coke Zero
# 4988      CocaCola Zero Azucar
# Name: product_name, Length: 5517, dtype: str

# %%
exploded_products.value_counts()
# Out:
# product_name
# unknown                           260
# CocaCola                          183
# Coca cola                         175
# Coca Cola                         128
#  Coca Cola                         86
#                                  ...
# CocaCola Zero Sugar Hương Vani      1
# Coca Cola  White Peach Flavor       1
# coca cola original tastew           1
# Coke zero zero                      1
# CocaCola Zero Azucar                1
# Name: count, Length: 2914, dtype: int64

# %%
raw_products = df.product_name.str.lower()
raw_products
# Out:
# 0            cocacola original
# 1               coca cola zéro
# 2                     cocacola
# 3                     cocacola
# 4          original taste soda
#                  ...
# 4984                   unknown
# 4985       coca cola coca cola
# 4986            coke zero zero
# 4987    cherry float coke zero
# 4988      cocacola zero azucar
# Name: product_name, Length: 4989, dtype: str

# %%
raw_products.unique()
# Out:
# <ArrowStringArray>
# [               'cocacola original',                   'coca cola zéro',
#                          'cocacola',              'original taste soda',
#                           'unknown',     'cocacola original taste soda',
#                         'pibb xtra',              'cocacola zero sugar',
#          'cocacola zero sugar cola',       'cherry cocacola zero sugar',
#  ...
#                              'アンバサ',           'sprite mint zero sugar',
#                   'cherry floaters', 'cocacola zero sugar cherry float',
#                      'orange fanta',                 'mezzo mix cherry',
#            'coca cola (zero sugar)',   'cocacola zero sugar hương vani',
#     'coca cola  white peach flavor',        'coca cola original tastew']
# Length: 2585, dtype: str

# %%
df.isnull().sum()
# Out:
# code                              0
# product_name                      0
# brands                            0
# categories_tags                   0
# countries_tags                    0
# packaging_tags                    0
# stores                            0
# purchase_places                   0
# nutriscore_grade                  0
# nova_group                     3084
# ecoscore_grade                    0
# ingredients_text                  0
# nutriments.sugars_100g         3990
# nutriments.energy-kcal_100g    3940
# dtype: int64

# %%
df.dtypes
# Out:
# code                           float64
# product_name                       str
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                     str
# stores                             str
# purchase_places                    str
# nutriscore_grade                   str
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df['product_name'] = df['product_name'].str.lower().str.split(',')

df['product_name'] = [
    [item.strip() for item in row]
    for row in df['product_name']
]

# %%
df.categories_tags
# Out:
# 0              beverages, carbonated-drinks, sodas, colas
# 1       beverages, carbonated-drinks, artificially-swe...
# 2       beverages-and-beverages-preparations, beverage...
# 3                                                 unknown
# 4       beverages-and-beverages-preparations, beverage...
#                               ...
# 4984    beverages-and-beverages-preparations, beverage...
# 4985                                          Dagligvarer
# 4986                                              unknown
# 4987                                              unknown
# 4988    beverages-and-beverages-preparations, beverage...
# Name: categories_tags, Length: 4989, dtype: str

# %%
df.packaging_tags
# Out:
# 0                      unknown
# 1              plastic, bottle
# 2       bottle-or-vial, bottle
# 3                      unknown
# 4                      unknown
#                  ...
# 4984                   unknown
# 4985                   unknown
# 4986                   unknown
# 4987                   unknown
# 4988                   unknown
# Name: packaging_tags, Length: 4989, dtype: str

# %%
df['packaging_tags'] = df['packaging_tags'].str.lower().str.split(',')

df['packaging_tags'] = [
    [item.strip() for item in row]
    for row in df['packaging_tags']
]

# %%
df.packaging_tags
# Out:
# 0                      [unknown]
# 1              [plastic, bottle]
# 2       [bottle-or-vial, bottle]
# 3                      [unknown]
# 4                      [unknown]
#                   ...
# 4984                   [unknown]
# 4985                   [unknown]
# 4986                   [unknown]
# 4987                   [unknown]
# 4988                   [unknown]
# Name: packaging_tags, Length: 4989, dtype: object

# %%
packaging_tags = df.packaging_tags.explode()

# %%
df.packaging_tags
# Out:
# 0                      [unknown]
# 1              [plastic, bottle]
# 2       [bottle-or-vial, bottle]
# 3                      [unknown]
# 4                      [unknown]
#                   ...
# 4984                   [unknown]
# 4985                   [unknown]
# 4986                   [unknown]
# 4987                   [unknown]
# 4988                   [unknown]
# Name: packaging_tags, Length: 4989, dtype: object

# %%
df['stores'] = df['stores'].str.lower().str.split(',')

df['stores'] = [
    [item.strip() for item in row]
    for row in df['stores']
]

# %%
df['purchase_places'] = df['purchase_places'].str.lower().str.split(',')

df['purchase_places'] = [
    [item.strip() for item in row]
    for row in df['purchase_places']
]

# %%
df['nutriscore_grade'] = df['nutriscore_grade'].str.lower().str.split(',')

df['nutriscore_grades'] = [
    [item.strip() for item in row]
    for row in df['nutriscore_grade']
]

# %%
df['ecoscore_grades'] = df['ecoscore_grade'].str.lower().str.split(',')

df['ecoscore_grades'] = [
    [item.strip() for item in row]
    for row in df['ecoscore_grade']
]

# %%
df['ingredients_text'] = df['ingredients_text'].str.lower().str.split(',')

df['ingredients_text'] = [
    [item.strip() for item in row]
    for row in df['ingredients_text']
]

# %%
df.head()
# Out:
#            code           product_name                      brands  \
# 0  2.222208e+10    [cocacola original]                   Coca-Cola
# 1  4.211156e+10       [coca cola zéro]  Coca-Cola-light, coca cola
# 2  4.900000e+10             [cocacola]                   Coca-Cola
# 3  4.900001e+10             [cocacola]                   Coca-Cola
# 4  4.900002e+10  [original taste soda]                   Coca-Cola
#
#                                      categories_tags         countries_tags  \
# 0         beverages, carbonated-drinks, sodas, colas                  spain
# 1  beverages, carbonated-drinks, artificially-swe...                 france
# 2  beverages-and-beverages-preparations, beverage...  france, united-states
# 3                                            unknown          united-states
# 4  beverages-and-beverages-preparations, beverage...  france, united-states
#
#              packaging_tags     stores purchase_places nutriscore_grade  \
# ...

# %%
df['product_name'].map(tuple).unique()
# Out:
# array([('cocacola original',), ('coca cola zéro',), ('cocacola',), ...,
#        ('cocacola zero sugar hương vani',),
#        ('coca cola  white peach flavor',), ('coca cola original tastew',)],
#       shape=(2581,), dtype=object)

# %%
df['product_name'].head(10)
# Out:
# 0               [cocacola original]
# 1                  [coca cola zéro]
# 2                        [cocacola]
# 3                        [cocacola]
# 4             [original taste soda]
# 5                         [unknown]
# 6    [cocacola original taste soda]
# 7                       [pibb xtra]
# 8             [cocacola zero sugar]
# 9             [cocacola zero sugar]
# Name: product_name, dtype: object

# %%
df.head()
# Out:
#            code           product_name                      brands  \
# 0  2.222208e+10    [cocacola original]                   Coca-Cola
# 1  4.211156e+10       [coca cola zéro]  Coca-Cola-light, coca cola
# 2  4.900000e+10             [cocacola]                   Coca-Cola
# 3  4.900001e+10             [cocacola]                   Coca-Cola
# 4  4.900002e+10  [original taste soda]                   Coca-Cola
#
#                                      categories_tags         countries_tags  \
# 0         beverages, carbonated-drinks, sodas, colas                  spain
# 1  beverages, carbonated-drinks, artificially-swe...                 france
# 2  beverages-and-beverages-preparations, beverage...  france, united-states
# 3                                            unknown          united-states
# 4  beverages-and-beverages-preparations, beverage...  france, united-states
#
#              packaging_tags     stores purchase_places nutriscore_grade  \
# ...

# %%
df.isnull().sum()
# Out:
# code                              0
# product_name                      0
# brands                            0
# categories_tags                   0
# countries_tags                    0
# packaging_tags                    0
# stores                            0
# purchase_places                   0
# nutriscore_grade                  0
# nova_group                     3084
# ecoscore_grade                    0
# ingredients_text                  0
# nutriments.sugars_100g         3990
# nutriments.energy-kcal_100g    3940
# nutriscore_grades                 0
# ecoscore_grades                   0
# dtype: int64

# %%
df.dtypes
# Out:
# code                           float64
# product_name                    object
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                  object
# stores                          object
# purchase_places                 object
# nutriscore_grade                object
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                object
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# nutriscore_grades               object
# ecoscore_grades                 object
# dtype: object

# %%
df['brands'] = df['brands'].str.lower().str.split(',')

df['brands'] = [
    [item.strip() for item in row]
    for row in df['brands']
]

# %%
df['ecoscore_grade'] = df['ecoscore_grade'].str.lower().str.split(',')

df['ecoscore_grade'] = [
    [item.strip() for item in row]
    for row in df['ecoscore_grade']
]

# %%
df.dtypes
# Out:
# code                           float64
# product_name                    object
# brands                          object
# categories_tags                    str
# countries_tags                     str
# packaging_tags                  object
# stores                          object
# purchase_places                 object
# nutriscore_grade                object
# nova_group                     float64
# ecoscore_grade                  object
# ingredients_text                object
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# nutriscore_grades               object
# ecoscore_grades                 object
# dtype: object

# %%
cat_cols = df.select_dtypes(include='object').columns

df[cat_cols] = df[cat_cols].astype('string')
# Out:
# /var/folders/bz/hvzhy0zx4mdcy6mrw7g2bcmh0000gn/T/ipykernel_16039/1094818609.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include='object').columns

# %%
df.dtypes
# Out:
# code                           float64
# product_name                    string
# brands                          string
# categories_tags                 string
# countries_tags                  string
# packaging_tags                  string
# stores                          string
# purchase_places                 string
# nutriscore_grade                string
# nova_group                     float64
# ecoscore_grade                  string
# ingredients_text                string
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# nutriscore_grades               string
# ecoscore_grades                 string
# dtype: object

# %%
df['product_name'].unique()
# Out:
# <ArrowStringArray>
# [               '['cocacola original']',
#                    '['coca cola zéro']',
#                          '['cocacola']',
#               '['original taste soda']',
#                           '['unknown']',
#      '['cocacola original taste soda']',
#                         '['pibb xtra']',
#               '['cocacola zero sugar']',
#          '['cocacola zero sugar cola']',
#        '['cherry cocacola zero sugar']',
#  ...
#                              '['アンバサ']',
#            '['sprite mint zero sugar']',
#                   '['cherry floaters']',
#  '['cocacola zero sugar cherry float']',
#                      '['orange fanta']',
#                  '['mezzo mix cherry']',
#            '['coca cola (zero sugar)']',
#    '['cocacola zero sugar hương vani']',
#     '['coca cola  white peach flavor']',
#         '['coca cola original tastew']']
# Length: 2581, dtype: string

# %%
df['brands'].unique()
# Out:
# <ArrowStringArray>
# [                                                        '['coca-cola']',
#                                       '['coca-cola-light', 'coca cola']',
#                                                  '['coca-cola company']',
#                              '['coca-cola', 'coca-cola original taste']',
#                                                  '['coca-cola', 'coke']',
#                                                               '['coke']',
#                                       '['coca-cola', 'coca-cola-light']',
#                                '["mcdonald's", 'the coca-cola company']',
#                                           '['minute maid', 'coca cola']',
#                                           '['minute maid', 'coca-cola']',
#  ...
#                                       '['quoted coca &quot;cola&quot;']',
#                                                 '['slice', 'coca-cola']',
# ...

# %%
df = df.explode('brands')

# %%
df['brands'].unique()
# Out:
# <ArrowStringArray>
# [                                                        '['coca-cola']',
#                                       '['coca-cola-light', 'coca cola']',
#                                                  '['coca-cola company']',
#                              '['coca-cola', 'coca-cola original taste']',
#                                                  '['coca-cola', 'coke']',
#                                                               '['coke']',
#                                       '['coca-cola', 'coca-cola-light']',
#                                '["mcdonald's", 'the coca-cola company']',
#                                           '['minute maid', 'coca cola']',
#                                           '['minute maid', 'coca-cola']',
#  ...
#                                       '['quoted coca &quot;cola&quot;']',
#                                                 '['slice', 'coca-cola']',
# ...

# %%
df = df.explode('product_name')

# %%
df['categories_tags'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                                                                                                                                               'beverages, carbonated-drinks, sodas, colas',
#                                                                                                                                             'beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, colas, diet-sodas, diet-cola-soft-drink',
#                                                                                                                                                                      'beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, colas, sweetened-beverages',
# ...

# %%
df = df.explode('categories_tags')

# %%
df.categories_tags
# Out:
# 0              beverages, carbonated-drinks, sodas, colas
# 1       beverages, carbonated-drinks, artificially-swe...
# 2       beverages-and-beverages-preparations, beverage...
# 3                                                 unknown
# 4       beverages-and-beverages-preparations, beverage...
#                               ...
# 4984    beverages-and-beverages-preparations, beverage...
# 4985                                          Dagligvarer
# 4986                                              unknown
# 4987                                              unknown
# 4988    beverages-and-beverages-preparations, beverage...
# Name: categories_tags, Length: 4989, dtype: string

# %%
df = df.explode('categories_tags')

# %%
df['product_name'].unique()
# Out:
# <ArrowStringArray>
# [               '['cocacola original']',
#                    '['coca cola zéro']',
#                          '['cocacola']',
#               '['original taste soda']',
#                           '['unknown']',
#      '['cocacola original taste soda']',
#                         '['pibb xtra']',
#               '['cocacola zero sugar']',
#          '['cocacola zero sugar cola']',
#        '['cherry cocacola zero sugar']',
#  ...
#                              '['アンバサ']',
#            '['sprite mint zero sugar']',
#                   '['cherry floaters']',
#  '['cocacola zero sugar cherry float']',
#                      '['orange fanta']',
#                  '['mezzo mix cherry']',
#            '['coca cola (zero sugar)']',
#    '['cocacola zero sugar hương vani']',
#     '['coca cola  white peach flavor']',
#         '['coca cola original tastew']']
# Length: 2581, dtype: string

# %%
type(df['product_name'].iloc[0])
# Out:
# str

# %%
df.product_name.head()
# Out:
# 0      ['cocacola original']
# 1         ['coca cola zéro']
# 2               ['cocacola']
# 3               ['cocacola']
# 4    ['original taste soda']
# Name: product_name, dtype: string

# %%
df['product_name'].unique()
# Out:
# <ArrowStringArray>
# [               '['cocacola original']',
#                    '['coca cola zéro']',
#                          '['cocacola']',
#               '['original taste soda']',
#                           '['unknown']',
#      '['cocacola original taste soda']',
#                         '['pibb xtra']',
#               '['cocacola zero sugar']',
#          '['cocacola zero sugar cola']',
#        '['cherry cocacola zero sugar']',
#  ...
#                              '['アンバサ']',
#            '['sprite mint zero sugar']',
#                   '['cherry floaters']',
#  '['cocacola zero sugar cherry float']',
#                      '['orange fanta']',
#                  '['mezzo mix cherry']',
#            '['coca cola (zero sugar)']',
#    '['cocacola zero sugar hương vani']',
#     '['coca cola  white peach flavor']',
#         '['coca cola original tastew']']
# Length: 2581, dtype: string

# %%
df['product_name'] = df['product_name'].str.replace('cocacola', 'coca-cola', regex=False)
df['product_name'] = df['product_name'].str.replace('coca cola', 'coca-cola', regex=False)

# %%
df['product_name'] = df['product_name'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
df['product_name'].unique()
# Out:
# <ArrowStringArray>
# [             '['coca-cola original']',                  '['coca-cola zéro']',
#                        '['coca-cola']',             '['original taste soda']',
#                          '['unknown']',   '['coca-cola original taste soda']',
#                        '['pibb xtra']',            '['coca-cola zero sugar']',
#        '['coca-cola zero sugar cola']',     '['cherry coca-cola zero sugar']',
#  ...
#             '['cepita manzana 900ml']',                            '['アンバサ']',
#           '['sprite mint zero sugar']',                 '['cherry floaters']',
#                     '['orange fanta']',                '['mezzo mix cherry']',
#           '['coca-cola (zero sugar)']', '['coca-cola zero sugar hương vani']',
#     '['coca-cola white peach flavor']',       '['coca-cola original tastew']']
# Length: 2482, dtype: string

# %%
df = df.explode('brands')

# %%
df['brands'].unique()
# Out:
# <ArrowStringArray>
# [                                                        '['coca-cola']',
#                                       '['coca-cola-light', 'coca cola']',
#                                                  '['coca-cola company']',
#                              '['coca-cola', 'coca-cola original taste']',
#                                                  '['coca-cola', 'coke']',
#                                                               '['coke']',
#                                       '['coca-cola', 'coca-cola-light']',
#                                '["mcdonald's", 'the coca-cola company']',
#                                           '['minute maid', 'coca cola']',
#                                           '['minute maid', 'coca-cola']',
#  ...
#                                       '['quoted coca &quot;cola&quot;']',
#                                                 '['slice', 'coca-cola']',
# ...

# %%
df['brands'] = df['brands'].str.replace('coca cola', 'coca-cola', regex=False)
df['brands'] = df['brands'].str.replace('cocacola', 'coca-cola', regex=False)
df['brands'] = df['brands'].str.replace('the coca-cola company', 'coca-cola company', regex=False)

# %%
df['brands'].unique()
# Out:
# <ArrowStringArray>
# [                                                        '['coca-cola']',
#                                       '['coca-cola-light', 'coca-cola']',
#                                                  '['coca-cola company']',
#                              '['coca-cola', 'coca-cola original taste']',
#                                                  '['coca-cola', 'coke']',
#                                                               '['coke']',
#                                       '['coca-cola', 'coca-cola-light']',
#                                    '["mcdonald's", 'coca-cola company']',
#                                           '['minute maid', 'coca-cola']',
#                           '['brasserie de tahiti', 'coca-cola company']',
#  ...
#                                         '['販売者/コカ•コーラ カスタマーマーケティング(株)']',
#                                       '['quoted coca &quot;cola&quot;']',
# ...

# %%
df[df['brands'].str.contains('original', case=False, na=False)]
# Out:
#               code                                       product_name  \
# 14    4.900005e+10                                      ['coca-cola']
# 3236  7.894900e+12  ['pack refrigerante coca-cola original lata 6 ...
# 4592  1.234066e+12                                      ['coca-cola']
# 4902  5.000113e+12                                      ['coca-cola']
#
#                                          brands  \
# 14    ['coca-cola', 'coca-cola original taste']
# 3236                     ['coca-cola original']
# 4592                         ['original taste']
# 4902                               ['original']
#
#                                         categories_tags  countries_tags  \
# 14    beverages-and-beverages-preparations, beverage...   united-states
# 3236                                            unknown          brazil
# 4592                                            unknown  united-kingdom
# 4902                                            unknown         austria
#
# ...

# %%
df[df['brands'].str.contains('jack', case=False, na=False)]
# Out:
#               code                                       product_name  \
# 3032  8.218401e+10           ["jack daniel's & coca-cola zero sugar"]
# 3498  5.449000e+12                             ["jack daniel's cola"]
# 3873  5.000113e+12                                   ['jd coca-cola']
# 4298  5.099873e+12                   ['gentleman jack mit coca-cola']
# 4576  5.449000e+12  ["jack daniel's tennessee whiskey mixed with c...
# 4702  9.300675e+12  ["jack daniel's tennessee whiskey mixed with c...
# 4738  9.300675e+12         ['tennessee whiskey mixed with coca-cola']
# 4889  5.449000e+12                         ['jack daniels coca-cola']
# 4940  5.449000e+12  ["jack daniel's tennessee whiskey mixed with c...
#
#                               brands  \
# 3032   ["jack daniel's & coca-cola"]
# 3498  ["jack daniel's", 'coca-cola']
# 3873                ['jack daniels']
# 4298                ['jack daniels']
# 4576                 ['jack & coke']
# ...

# %%
df[df['brands'].str.contains('mzy', case=False, na=False)]
# Out:
#               code               product_name  \
# 4946  6.975682e+12  ['mzy peach juice drink']
#
#                                    brands  \
# 4946  ['minute maid', 'coca-cola', 'mzy']
#
#                                         categories_tags  \
# 4946  beverages-and-beverages-preparations, plant-ba...
#
#              countries_tags packaging_tags       stores purchase_places  \
# 4946  china, united-kingdom    ['unknown']  ['unknown']     ['unknown']
#
#      nutriscore_grade  nova_group ecoscore_grade  \
# 4946            ['e']         4.0    ['unknown']
#
#                                        ingredients_text  \
# 4946  ['water', 'fructose syrup', 'sugar', 'concentr...
#
#       nutriments.sugars_100g  nutriments.energy-kcal_100g nutriscore_grades  \
# 4946                     NaN                          NaN             ['e']
#
#                           ecoscore_grades
# 4946  ['u', 'n', 'k', 'n', 'o', 'w', 'n']

# %%
df.brands.unique()
# Out:
# <ArrowStringArray>
# [                                                        '['coca-cola']',
#                                       '['coca-cola-light', 'coca-cola']',
#                                                  '['coca-cola company']',
#                              '['coca-cola', 'coca-cola original taste']',
#                                                  '['coca-cola', 'coke']',
#                                                               '['coke']',
#                                       '['coca-cola', 'coca-cola-light']',
#                                    '["mcdonald's", 'coca-cola company']',
#                                           '['minute maid', 'coca-cola']',
#                           '['brasserie de tahiti', 'coca-cola company']',
#  ...
#                                         '['販売者/コカ•コーラ カスタマーマーケティング(株)']',
#                                       '['quoted coca &quot;cola&quot;']',
# ...

# %%
import html

df['brands'] = df['brands'].apply(html.unescape)

# %%
print(df['brands'].nunique())
print(df['brands'].value_counts().head(20))
# Out:
# 444
# brands
# ['coca-cola']                                  3084
# ['unknown']                                     389
# ['coca-cola company']                           198
# ['coca-cola', 'coca-cola-light']                 89
# ['fanta', 'coca-cola']                           55
# ['coca-cola european partners norge a']          50
# ['coca-cola', 'coca-cola company']               44
# ['coke']                                         43
# ['coca-cola europacific partners norge as']      32
# ['coca-cola', 'coke']                            30
# ['coca-cola zero']                               24
# ["zaxby's"]                                      24
# ['coca-cola', 'coca-cola']                       23
# ['fanta', 'coca-cola company']                   23
# ['sonic']                                        20
# ['white castle']                                 16
# ['coca-cola company', 'coca-cola']               15
# ['coca']                                         15
# ...

# %%
df['categories_tags'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                                                                                                                                               'beverages, carbonated-drinks, sodas, colas',
#                                                                                                                                             'beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, colas, diet-sodas, diet-cola-soft-drink',
#                                                                                                                                                                      'beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, colas, sweetened-beverages',
# ...

# %%
df = df.explode('categories_tags')

# %%
df['categories_tags'] = df['categories_tags'].str.strip()

# %%
print(df['categories_tags'].unique())
# Out:
# <ArrowStringArray>
# [                                                                                                                                                                                                                               'beverages, carbonated-drinks, sodas, colas',
#                                                                                                                                             'beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, colas, diet-sodas, diet-cola-soft-drink',
#                                                                                                                                                                      'beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, colas, sweetened-beverages',
# ...

# %%
df['categories_tags'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                                                                                                                                               'beverages, carbonated-drinks, sodas, colas',
#                                                                                                                                             'beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, colas, diet-sodas, diet-cola-soft-drink',
#                                                                                                                                                                      'beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, colas, sweetened-beverages',
# ...

# %%
df.dtypes
# Out:
# code                           float64
# product_name                    string
# brands                             str
# categories_tags                 string
# countries_tags                  string
# packaging_tags                  string
# stores                          string
# purchase_places                 string
# nutriscore_grade                string
# nova_group                     float64
# ecoscore_grade                  string
# ingredients_text                string
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# nutriscore_grades               string
# ecoscore_grades                 string
# dtype: object

# %%
df['countries_tags'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                              'spain',
#                                                                                                               'france',
#                                                                                                'france, united-states',
#                                                                                                        'united-states',
#                                                                                        'canada, france, united-states',
#                                                                                            'saint-pierre-and-miquelon',
#                                                                                                               'canada',
#                                                                                                     'french-polynesia',
# ...

# %%
df.countries_tags.unique()
# Out:
# <ArrowStringArray>
# [                                                                                                              'spain',
#                                                                                                               'france',
#                                                                                                'france, united-states',
#                                                                                                        'united-states',
#                                                                                        'canada, france, united-states',
#                                                                                            'saint-pierre-and-miquelon',
#                                                                                                               'canada',
#                                                                                                     'french-polynesia',
# ...

# %%
print(df['countries_tags'].head())
# Out:
# 0                    spain
# 1                   france
# 2    france, united-states
# 3            united-states
# 4    france, united-states
# Name: countries_tags, dtype: string

# %%
print(df.columns.tolist())
# Out:
# ['code', 'product_name', 'brands', 'categories_tags', 'countries_tags', 'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade', 'nova_group', 'ecoscore_grade', 'ingredients_text', 'nutriments.sugars_100g', 'nutriments.energy-kcal_100g', 'nutriscore_grades', 'ecoscore_grades']

# %%
df['countries_tags'] = df['countries_tags'].apply(''.join)

# %%
df['countries_tags'] = df['countries_tags'].str.split(',')

# %%
print(type(df['countries_tags'].iloc[0]))
# Out:
# <class 'list'>

# %%
print(df['countries_tags'].head())
# Out:
# 0                     [spain]
# 1                    [france]
# 2    [france,  united-states]
# 3             [united-states]
# 4    [france,  united-states]
# Name: countries_tags, dtype: object

# %%
df = df.explode('countries_tags').reset_index(drop=True)

# %%
df['countries_tags'] = (
    df['countries_tags']
    .str.strip()
    .str.lower()
)

# %%
df['countries_tags'].unique()
# Out:
# <ArrowStringArray>
# [                              'spain',                              'france',
#                        'united-states',                              'canada',
#            'saint-pierre-and-miquelon',                    'french-polynesia',
#     'democratic-republic-of-the-congo',                      'united-kingdom',
#                                'india',                             'unknown',
#  ...
#  'virgin-islands-of-the-united-states',                               'egypt',
#                              'myanmar',                 'trinidad-and-tobago',
#                             'botswana',                            'maldives',
#                                'macau',                               'haiti',
#                        'latinoamérica',                             'mundial']
# Length: 148, dtype: str

# %%
df['packaging_tags'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                                                                     '['unknown']',
#                                                                                                                                             '['plastic', 'bottle']',
#                                                                                                                                      '['bottle-or-vial', 'bottle']',
#                                                                                                                                     '['aluminium-can', 'card-box']',
#                                                                                                                              '['can', 'aluminium-can', 'aluminum']',
# ...

# %%
df = df.explode('packaging_tags').reset_index(drop=True)

# %%
df['packaging_tags'] = (
    df['packaging_tags']
    .str.strip()
    .str.lower()
)

# %%
df['packaging_tags'].value_counts().head(30)
# Out:
# packaging_tags
# ['unknown']                                                                                                                                                                                                                   4026
# ['plastic']                                                                                                                                                                                                                    302
# ['plastic', 'bottle']                                                                                                                                                                                                          147
# ['bottle']                                                                                                                                                                                                                      81
# ...

# %%
import ast

df['packaging_tags'] = df['packaging_tags'].apply(ast.literal_eval)
df = df.explode('packaging_tags').reset_index(drop=True)
df['packaging_tags'] = df['packaging_tags'].str.strip().str.lower()

# %%
df['packaging_tags'].unique()
# Out:
# <ArrowStringArray>
# [                                                                   'unknown',
#                                                                     'plastic',
#                                                                      'bottle',
#                                                              'bottle-or-vial',
#                                                               'aluminium-can',
#                                                                    'card-box',
#                                                                         'can',
#                                                                    'aluminum',
#                                                                  'pet-bottle',
#                                                              'plastic-bottle',
#  ...
#                                                          'paper-based-carton',
#  'nl:161⁰-coke-com-2-pant-c-recycle-skal-resirkuleres-22-0066-gbnobe-t2ae10b',
# ...

# %%
noise_tags = [
    'unknown',
    'azul',
    'cun',
    'coca-cola',
    'nl:161⁰-coke-com-2-pant-c-recycle-skal-resirkuleres-22-0066-gbnobe-t2ae10b'
]

df = df[~df['packaging_tags'].isin(noise_tags)]

# %%
df['stores'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                 '['unknown']',
#                                                                                     '['walgreens', 'speedway']',
#                                                                                                 '['carrefour']',
#                                                                                                   '['hyper u']',
#                                                                  '['carrefour', 'hyper u', 'ls proxy', 'maxi']',
#  '['real canadian superstore', "shopper's drug mart", 'walmart', 'safeway', 'shell', 'circle k', 'on the run']',
#                                                                '['walmart', 'atlantic superstore', 'circle k']',
#                                                                                                     '['tesco']',
# ...

# %%
print(type(df['stores'].iloc[0]))
# Out:
# <class 'str'>

# %%
print(df['stores'].dtype)
# Out:
# string

# %%
df = df.explode('stores').reset_index(drop=True)

df['stores'] = df['stores'].str.strip().str.lower()

df['stores'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                 '['unknown']',
#                                                                                     '['walgreens', 'speedway']',
#                                                                                                 '['carrefour']',
#                                                                                                   '['hyper u']',
#                                                                  '['carrefour', 'hyper u', 'ls proxy', 'maxi']',
#  '['real canadian superstore', "shopper's drug mart", 'walmart', 'safeway', 'shell', 'circle k', 'on the run']',
#                                                                '['walmart', 'atlantic superstore', 'circle k']',
#                                                                                                     '['tesco']',
# ...

# %%
df.purchase_places.unique()
# Out:
# <ArrowStringArray>
# [                                                       '['unknown']',
#  '['san francisco', 'california', 'usa', 'grand rapids', 'michigan']',
#                                                          '['canada']',
#                                        '['saint pierre et miquelon']',
#                                     '['arue', 'polynésie francaise']',
#                          '['polynésie francaise', 'arue', 'papeete']',
#                                             '['polynésie francaise']',
#                        '['montréal', 'canada', 'calgary', 'alberta']',
#                                    '['toronto', 'ontario', 'canada']',
#                                                      '['california']',
#  ...
#                                                          '['brasil']',
#                                                           '['suomi']',
#                                                    '['magyarország']',
# ...

# %%
df = df.explode('purchase_places').reset_index(drop=True)

df['purchase_places'] = df['purchase_places'].str.strip().str.lower()

df['purchase_places'].unique()
# Out:
# <ArrowStringArray>
# [                                                       '['unknown']',
#  '['san francisco', 'california', 'usa', 'grand rapids', 'michigan']',
#                                                          '['canada']',
#                                        '['saint pierre et miquelon']',
#                                     '['arue', 'polynésie francaise']',
#                          '['polynésie francaise', 'arue', 'papeete']',
#                                             '['polynésie francaise']',
#                        '['montréal', 'canada', 'calgary', 'alberta']',
#                                    '['toronto', 'ontario', 'canada']',
#                                                      '['california']',
#  ...
#                                                          '['brasil']',
#                                                           '['suomi']',
#                                                    '['magyarország']',
# ...

# %%
df = df.explode('nutriscore_grade').reset_index(drop=True)

df['nutriscore_grade'] = df['nutriscore_grade'].str.strip().str.lower()

df['nutriscore_grade'].unique()
# Out:
# <ArrowStringArray>
# [       '['unknown']',              '['e']',              '['c']',
#               '['d']',              '['b']',              '['a']',
#  '['not-applicable']']
# Length: 7, dtype: string

# %%
df = df.explode('ecoscore_grade').reset_index(drop=True)

df['ecoscore_grade'] = df['ecoscore_grade'].str.strip().str.lower()

df['ecoscore_grade'].unique()
# Out:
# <ArrowStringArray>
# [       '['unknown']', '['not-applicable']',              '['c']',
#               '['e']',              '['a']',              '['d']',
#          '['a-plus']']
# Length: 7, dtype: string

# %%
df = df.explode('ingredients_text').reset_index(drop=True)

df['ingredients_text'] = df['ingredients_text'].str.strip().str.lower()

df['ingredients_text'].unique()
# Out:
# <ArrowStringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    '['unknown']',
# ...

# %%
df.ingredients_text.str.split(',')
# Out:
# 0                                           [['unknown']]
# 1                                           [['unknown']]
# 2       [['carbonated water',  'cane sugar',  'caramel...
# 3       [['carbonated water',  'cane sugar',  'caramel...
# 4       [['carbonated water',  'cane sugar',  'caramel...
#                               ...
# 4826    [['apă',  'sirop de fructoză',  'dioxid de car...
# 4827                                        [['unknown']]
# 4828    [['bautura racoritoare carbogazoasă cu gust de...
# 4829    [['apă',  'zahăr',  'suc de visine din concent...
# 4830                                        [['unknown']]
# Name: ingredients_text, Length: 4831, dtype: object

# %%
df['ingredients_text'] = df['ingredients_text'].apply(ast.literal_eval)

# %%
df = df.explode('ingredients_text').reset_index(drop=True)

# %%
df['ingredients_text'] = (
    df['ingredients_text']
    .str.strip()
    .str.lower()
)

# %%
print(df['ingredients_text'].unique())
# Out:
# <ArrowStringArray>
# [                                                                                                                                                                                                                                                                                                   'unknown',
#                                                                                                                                                                                                                                                                                            'carbonated water',
#                                                                                                                                                                                                                                                                                                  'cane sugar',
# ...

# %%
rare = df['ingredients_text'].value_counts()

rare[rare == 1]
# Out:
# ingredients_text
# filtered water                                                                                                                                         1
# concentrated orange juice                                                                                                                              1
# acidifiant : (e330                                                                                                                                     1
# conservateur : (e202)                                                                                                                                  1
# antioxydant : (e300)                                                                                                                                   1
#                                                                                                                                                       ..
# ...

# %%
df['countries_tags'].value_counts().head(10)
# Out:
# countries_tags
# france            6043
# germany           3385
# bolivia           2216
# spain             1981
# belgium           1803
# italy             1460
# switzerland       1312
# united-kingdom    1307
# romania           1037
# sweden            1027
# Name: count, dtype: int64

# %%
df['purchase_places'].value_counts().head(20)
# Out:
# purchase_places
# ['unknown']                                              21665
# ['cochabamba', 'bolivia']                                 1632
# ['bolivia']                                               1136
# ['france']                                                 749
# ['deutschland']                                            514
# ['netherlands', 'france', 'italy']                         432
# ['sverige', 'sweden']                                      387
# ['belgique', 'ireland', 'dublin']                          385
# ['españa']                                                 354
# ['switzerland']                                            342
# ['calgary', 'alberta', 'canada']                           306
# ['italia']                                                 271
# ['walmart']                                                243
# ['polska']                                                 236
# ['courrières', 'france']                                   211
# ...

# %%
df['stores'].value_counts().head(20)
# Out:
# stores
# ['unknown']                                                                                                                    23374
# ['farmacorp']                                                                                                                    503
# ['albert heijn', 'carrefour', 'decò', 'carrefour.fr']                                                                            432
# ['farmacorp', 'fidalga', 'amarket']                                                                                              399
# ['spar', 'centra', 'carrefour.fr']                                                                                               385
# ['city gross']                                                                                                                   379
# ['carrefour']                                                                                                                    367
# ...

# %%
print(len(df['countries_tags']))
print(len(df['nutriscore_grade']))
# Out:
# 34655
# 34655

# %%
print(df[['countries_tags', 'nutriscore_grade']].shape)
# Out:
# (34655, 2)

# %%
print(df['countries_tags'].dtype)
print(df['nutriscore_grade'].dtype)
# Out:
# str
# string

# %%
df.dtypes
# Out:
# code                           float64
# product_name                    string
# brands                             str
# categories_tags                 string
# countries_tags                     str
# packaging_tags                     str
# stores                          string
# purchase_places                 string
# nutriscore_grade                string
# nova_group                     float64
# ecoscore_grade                  string
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# nutriscore_grades               string
# ecoscore_grades                 string
# dtype: object

# %%
cat_cols = df.select_dtypes(include=['object', 'string']).columns
for col in cat_cols:
    df[col] = df[col].astype(str)

# %%
df.dtypes
# Out:
# code                           float64
# product_name                       str
# brands                             str
# categories_tags                    str
# countries_tags                     str
# packaging_tags                     str
# stores                             str
# purchase_places                    str
# nutriscore_grade                   str
# nova_group                     float64
# ecoscore_grade                     str
# ingredients_text                   str
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# nutriscore_grades                  str
# ecoscore_grades                    str
# dtype: object

# %%
df['nutriscore_grade'] = df['nutriscore_grade'].str.split(',')

# %%
df
# Out:
#                code                         product_name  \
# 0      4.211156e+10                   ['coca-cola zéro']
# 1      4.211156e+10                   ['coca-cola zéro']
# 2      4.900000e+10                        ['coca-cola']
# 3      4.900000e+10                        ['coca-cola']
# 4      4.900000e+10                        ['coca-cola']
# ...             ...                                  ...
# 34650  5.942321e+12  ['schweppes vișine și piper negru']
# 34651  5.942321e+12  ['schweppes vișine și piper negru']
# 34652  5.942321e+12  ['schweppes vișine și piper negru']
# 34653  5.942321e+12  ['schweppes vișine și piper negru']
# 34654  5.449000e+12                   ['original taste']
#
#                                  brands  \
# 0      ['coca-cola-light', 'coca-cola']
# 1      ['coca-cola-light', 'coca-cola']
# 2                         ['coca-cola']
# 3                         ['coca-cola']
# 4                         ['coca-cola']
# ...
