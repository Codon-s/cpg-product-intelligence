# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
df=pd.read_csv("datasets/schweppes_from_dump.csv")

# %%
df
# Out:
#                code                                       product_name  \
# 0     0016600000098                             Schweppes Soda tonique
# 1     0078000202465                            Sparkling seltzer water
# 2     0078000206401                                         GINGER ALE
# 3     0088009260724                                          Schweppes
# 4     0088009270617                                    SCHWEPPES LEMON
# ...             ...                                                ...
# 1609  5410221645716                        Schweppes pamplemousse rose
# 1610  9315596009919  Bounty Blast Raspberry & Orange Flavour Zero S...
# 1611  5697434709873                             Schweppes saveur pomme
# 1612  7617500199207                                   Schweppes Citrus
# 1613  7617500199160                                         Wild Berry
#
#          brands                                  categories_tags  \
# ...

# %%
df.dtypes
# Out:
# code                            object
# product_name                    object
# brands                          object
# categories_tags                 object
# countries_tags                  object
# packaging_tags                  object
# stores                          object
# purchase_places                 object
# nutriscore_grade                object
# nova_group                     float64
# ecoscore_grade                  object
# ingredients_text                object
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df.categories_tags=df.categories_tags.fillna('unknown')
df.countries_tags=df.countries_tags.fillna('unknown')
df.packaging_tags=df.packaging_tags.fillna('unknown')
df.stores=df.stores.fillna('unknown')
df.purchase_places=df.purchase_places.fillna('unknown')
df.nutriscore_grade=df.nutriscore_grade.fillna('unknown')
df.nova_group=df.nova_group.fillna('unknown')
df.ecoscore_grade=df.ecoscore_grade.fillna('unknown')
df.ingredients_text=df.ingredients_text.fillna('unknown')
df.product_name=df.product_name.fillna('unknown')
df.brands=df.brands.fillna('unknown')

# %%
df
# Out:
#                code                                       product_name  \
# 0     0016600000098                             Schweppes Soda tonique
# 1     0078000202465                            Sparkling seltzer water
# 2     0078000206401                                         GINGER ALE
# 3     0088009260724                                          Schweppes
# 4     0088009270617                                    SCHWEPPES LEMON
# ...             ...                                                ...
# 1609  5410221645716                        Schweppes pamplemousse rose
# 1610  9315596009919  Bounty Blast Raspberry & Orange Flavour Zero S...
# 1611  5697434709873                             Schweppes saveur pomme
# 1612  7617500199207                                   Schweppes Citrus
# 1613  7617500199160                                         Wild Berry
#
#          brands                                  categories_tags  \
# ...

# %%
df[df['product_name'].duplicated()]['product_name'].nunique()
# Out:
# 149

# %%
df['product_name'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1609     True
# 1610    False
# 1611    False
# 1612     True
# 1613     True
# Name: product_name, Length: 1614, dtype: bool

# %%
df['product_name'].value_counts()
[df['product_name'].value_counts()>1]
# Out:
# [product_name
#  Schweppes                            True
#  unknown                              True
#  Ginger Ale                           True
#  Schweppes Indian Tonic               True
#  Bitter Lemon                         True
#                                      ...
#  Schweppes Zero Citrus               False
#  Schweppes agrume                    False
#  Tonic et Matcha Schweppes           False
#  Gaseosa y un toque a hierbabuena    False
#  Schweppes saveur pomme              False
#  Name: count, Length: 975, dtype: bool]

# %%
df['product_name'].value_counts()
# Out:
# product_name
# Schweppes                           88
# unknown                             55
# Ginger Ale                          23
# Schweppes Indian Tonic              17
# Bitter Lemon                        17
#                                     ..
# Schweppes Zero Citrus                1
# Schweppes agrume                     1
# Tonic et Matcha Schweppes            1
# Gaseosa y un toque a hierbabuena     1
# Schweppes saveur pomme               1
# Name: count, Length: 975, dtype: int64

# %%
df.code[df.duplicated()]
# Out:
# Series([], Name: code, dtype: object)

# %%
df.brands.unique()
# Out:
# array(['unknown', 'Schweppes', 'schweppes', 'Fever-tree, Schweppes',
#        'Ricqles, Schweppes', 'Orangina, Schweppes',
#        'Orangina Schweppes, Pampryl', 'Orangina Schweppes, Schweppes',
#        'Indian Tonic, Schweppes', 'Orangina Schweppes France',
#        'Orangina, Orangina Schweppes', 'Scheppes, Schweppes',
#        'Orangina Schweppes, Pulco',
#        'Orangina Schweppes, Orangina Schweppes France, Pulco',
#        'Orangina Schweppes France, Pulco',
#        'Champomy, Orangina, Schweppes', 'Champomy, Orangina Schweppes',
#        'Schweppes, Zero, orangina schweppes',
#        'Orangina, Orangina Schweppes France, Schweppes International Limited',
#        'Orangina, Orangina Schweppes France',
#        'May Tea, Orangina Schweppes France',
#        'May tea, Orangine Schweppes France, Oscar mayer',
#        'May Tea, Orangina Schweppes',
#        'May Tea, Orangina Schweppes, Orangina Schweppes France',
# ...

# %%
df.brands.value_counts()
# Out:
# brands
# Schweppes                                     1201
# unknown                                        182
# schweppes                                       29
# Orangina, Schweppes                             13
# Papa John's                                     12
#                                               ...
# Schweppes, Zero, orangina schweppes              1
# Canada Dry                                       1
# San Benedetto, Schweppes                         1
# Schweppes Holdings                               1
# Schweppes, Schweppes International Limited       1
# Name: count, Length: 108, dtype: int64

# %%
brand1=df.brands.str.split(',')
brand1
# Out:
# 0         [unknown]
# 1       [Schweppes]
# 2       [Schweppes]
# 3         [unknown]
# 4       [Schweppes]
#            ...
# 1609      [unknown]
# 1610    [Schweppes]
# 1611      [unknown]
# 1612    [Schweppes]
# 1613    [Schweppes]
# Name: brands, Length: 1614, dtype: object

# %%
brand1=brand1.explode()
brand1
# Out:
# 0         unknown
# 1       Schweppes
# 2       Schweppes
# 3         unknown
# 4       Schweppes
#           ...
# 1609      unknown
# 1610    Schweppes
# 1611      unknown
# 1612    Schweppes
# 1613    Schweppes
# Name: brands, Length: 1755, dtype: object

# %%
brand1=brand1.str.strip()
brand1
# Out:
# 0         unknown
# 1       Schweppes
# 2       Schweppes
# 3         unknown
# 4       Schweppes
#           ...
# 1609      unknown
# 1610    Schweppes
# 1611      unknown
# 1612    Schweppes
# 1613    Schweppes
# Name: brands, Length: 1755, dtype: object

# %%
brand1.value_counts()
# Out:
# brands
# Schweppes                     1276
# unknown                        182
# schweppes                       38
# Orangina Schweppes              31
# Orangina                        30
#                               ...
# Schweppes Holdings               1
# San Benedetto                    1
# oasis                            1
# Karlovarské minerální vody       1
# schweppes.eu                     1
# Name: count, Length: 81, dtype: int64

# %%
brand1.unique()
# Out:
# array(['unknown', 'Schweppes', 'schweppes', 'Fever-tree', 'Ricqles',
#        'Orangina', 'Orangina Schweppes', 'Pampryl', 'Indian Tonic',
#        'Orangina Schweppes France', 'Scheppes', 'Pulco', 'Champomy',
#        'Zero', 'orangina schweppes', 'Schweppes International Limited',
#        'May Tea', 'May tea', 'Orangine Schweppes France', 'Oscar mayer',
#        "Schweppes Agrum'", 'SchweppesOrangina Schweppes',
#        'Schweppes International', 'Oasis', 'Oasis tropical', 'Coca-Cola',
#        'Canada Dry', 'Orangina schweppes', 'SCHWEPPES', 'Citron',
#        'Splash', 'Joi', 'La Casera', 'Trina', 'Sunny Delight', 'MayTea',
#        'ชเวปส์', 'Scheweppes', 'Schweppes Australia', 'Asahi Breweries',
#        'Spring Valley', 'Frantelle', 'Heineken', 'Schweppes Holdings',
#        'Dr Pepper', 'Suntory', 'San Benedetto', 'oasis',
#        'Karlovarské minerální vody', 'Orangina sunstory france',
#        'coca cola', 'coca-cola', 'Ginger Ale Schweppes',
# ...

# %%
brand1.tolist
# Out:
# <bound method IndexOpsMixin.tolist of 0         unknown
# 1       Schweppes
# 2       Schweppes
# 3         unknown
# 4       Schweppes
#           ...
# 1609      unknown
# 1610    Schweppes
# 1611      unknown
# 1612    Schweppes
# 1613    Schweppes
# Name: brands, Length: 1755, dtype: object>

# %%
brand1=brand1.str.lower()
brand1
# Out:
# 0         unknown
# 1       schweppes
# 2       schweppes
# 3         unknown
# 4       schweppes
#           ...
# 1609      unknown
# 1610    schweppes
# 1611      unknown
# 1612    schweppes
# 1613    schweppes
# Name: brands, Length: 1755, dtype: object

# %%
brand1.value_counts()
# Out:
# brands
# schweppes             1325
# unknown                182
# orangina schweppes      33
# orangina                30
# coca-cola               22
#                       ...
# frantelle                1
# heineken                 1
# schweppes holdings       1
# san benedetto            1
# schweppes.eu             1
# Name: count, Length: 70, dtype: int64

# %%
brand1.unique()
# Out:
# array(['unknown', 'schweppes', 'fever-tree', 'ricqles', 'orangina',
#        'orangina schweppes', 'pampryl', 'indian tonic',
#        'orangina schweppes france', 'scheppes', 'pulco', 'champomy',
#        'zero', 'schweppes international limited', 'may tea',
#        'orangine schweppes france', 'oscar mayer', "schweppes agrum'",
#        'schweppesorangina schweppes', 'schweppes international', 'oasis',
#        'oasis tropical', 'coca-cola', 'canada dry', 'citron', 'splash',
#        'joi', 'la casera', 'trina', 'sunny delight', 'maytea', 'ชเวปส์',
#        'scheweppes', 'schweppes australia', 'asahi breweries',
#        'spring valley', 'frantelle', 'heineken', 'schweppes holdings',
#        'dr pepper', 'suntory', 'san benedetto',
#        'karlovarské minerální vody', 'orangina sunstory france',
#        'coca cola', 'ginger ale schweppes', 'schweppes ginger ale',
#        'ringnes as', 'ringnes', 'coca-cola brasil', 'denzel smaak',
# ...

# %%
brand1=brand1.replace('scheppes','schweppes',regex=True)

# %%
brand1.nunique()
# Out:
# 69

# %%
brand1.value_counts()>1
# Out:
# brands
# schweppes                      True
# unknown                        True
# orangina schweppes             True
# orangina                       True
# coca-cola                      True
#                               ...
# heineken                      False
# schweppes holdings            False
# san benedetto                 False
# karlovarské minerální vody    False
# schweppes.eu                  False
# Name: count, Length: 69, dtype: bool

# %%
brand1.value_counts()
# Out:
# brands
# schweppes                     1326
# unknown                        182
# orangina schweppes              33
# orangina                        30
# coca-cola                       22
#                               ...
# heineken                         1
# schweppes holdings               1
# san benedetto                    1
# karlovarské minerální vody       1
# schweppes.eu                     1
# Name: count, Length: 69, dtype: int64

# %%
brand1.value_counts().head()
# Out:
# brands
# schweppes             1326
# unknown                182
# orangina schweppes      33
# orangina                30
# coca-cola               22
# Name: count, dtype: int64

# %%
brand1.nunique()
# Out:
# 69

# %%
df.categories_tags.value_counts().head()
# Out:
# categories_tags
# unknown                                                                                           792
# beverages-and-beverages-preparations, beverages                                                    59
# beverages, carbonated-drinks, sodas                                                                57
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas                          52
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages     42
# Name: count, dtype: int64

# %%
c1=df.categories_tags.str.split(',')
c1
# Out:
# 0                                               [unknown]
# 1                                               [unknown]
# 2                                             [beverages]
# 3                                               [unknown]
# 4                 [beverages,  carbonated-drinks,  sodas]
#                               ...
# 1609                                            [unknown]
# 1610                                            [unknown]
# 1611                                            [unknown]
# 1612    [beverages-and-beverages-preparations,  bevera...
# 1613    [beverages-and-beverages-preparations,  bevera...
# Name: categories_tags, Length: 1614, dtype: object

# %%
c1=c1.explode()
c1
# Out:
# 0                                    unknown
# 1                                    unknown
# 2                                  beverages
# 3                                    unknown
# 4                                  beverages
#                         ...
# 1611                                 unknown
# 1612    beverages-and-beverages-preparations
# 1612                               beverages
# 1613    beverages-and-beverages-preparations
# 1613                               beverages
# Name: categories_tags, Length: 5052, dtype: object

# %%
c1=c1.str.strip()
c1
# Out:
# 0                                    unknown
# 1                                    unknown
# 2                                  beverages
# 3                                    unknown
# 4                                  beverages
#                         ...
# 1611                                 unknown
# 1612    beverages-and-beverages-preparations
# 1612                               beverages
# 1613    beverages-and-beverages-preparations
# 1613                               beverages
# Name: categories_tags, Length: 5052, dtype: object

# %%
c1.unique()
# Out:
# array(['unknown', 'beverages', 'carbonated-drinks', 'sodas',
#        'plant-based-foods-and-beverages', 'plant-based-beverages',
#        'fruit-based-beverages', 'fruit-sodas', 'lemon-soft-drinks',
#        'sweetened-beverages', 'waters',
#        'beverages-and-beverages-preparations', 'plant-based-foods',
#        'fruits-and-vegetables-based-foods', 'vegetables-based-foods',
#        'vegetable-based-foods-and-beverages', 'juices-and-nectars',
#        'vegetable-based-beverages', 'tomatoes-and-their-products',
#        'vegetable-juices', 'tomato-juices', 'frozen-foods', 'tonic-water',
#        'artificially-sweetened-beverages', 'diet-beverages', 'diet-sodas',
#        'sodas-tonic', 'carbonated-soft-drinks-without-fruit-juice',
#        'carbonated-soft-drinks-without-fruit-juice-with-sugar',
#        'soda-aux-ecorces-de-quinquina',
#        'carbonated-soft-drinks-without-fruit-juice-with-sugar-and-artificial-sweeteners',
# ...

# %%
c1.value_counts().nsmallest(10)
# Out:
# categories_tags
# de:zero-sugar                             1
# răcoritoare-carbogazoasă                  1
# cervezas                                  1
# schweppes                                 1
# Soft Drinks                               1
# bebidas-alcoholicas                       1
# nb:bitter-lemon                           1
# carbonated-fruit-soft-drink-with-sugar    1
# soda-schweppes                            1
# grenadine                                 1
# Name: count, dtype: int64

# %%
c1.value_counts().nlargest(10)
# Out:
# categories_tags
# unknown                                 792
# beverages                               790
# carbonated-drinks                       590
# sodas                                   547
# beverages-and-beverages-preparations    413
# sweetened-beverages                     350
# artificially-sweetened-beverages        165
# plant-based-foods-and-beverages         154
# tonic-water                             151
# plant-based-beverages                   148
# Name: count, dtype: int64

# %%
c1=c1.replace('waters','water',regex=True)

# %%
plt.rcParams['font.size'] = 10
plt.figure(figsize=(16, 8))
ax = sb.countplot(data=None, x=c1)
ax.set_title('Category Tag Counts')
ax.set_xlabel('Category Tag')
ax.set_ylabel('Count')
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\7686605.py:8: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\7686605.py:8: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\7686605.py:8: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\7686605.py:8: UserWarning: Glyph 3650 (\N{THAI CHARACTER SARA O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\7686605.py:8: UserWarning: Glyph 3595 (\N{THAI CHARACTER SO SO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
c1_filtered = c1[c1 != 'unknown']

# %%
plt.rcParams['font.size'] = 10
plt.figure(figsize=(16, 8))
ax = sb.countplot(data=None, x=c1_filtered)
ax.set_title('Category Tag Counts (filtered)')
ax.set_xlabel('Category Tag')
ax.set_ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\3474729454.py:8: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\3474729454.py:8: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\3474729454.py:8: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\3474729454.py:8: UserWarning: Glyph 3650 (\N{THAI CHARACTER SARA O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\rudra yadav\AppData\Local\Temp\ipykernel_4184\3474729454.py:8: UserWarning: Glyph 3595 (\N{THAI CHARACTER SO SO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
ct1=df.countries_tags.str.split(',')

# %%
ct1=ct1.explode()

# %%
ct1=ct1.str.strip()

# %%
ct1.unique()
# Out:
# array(['canada', 'united-states', 'france', 'world', 'belgium',
#        'switzerland', 'luxembourg', 'netherlands', 'reunion', 'germany',
#        'morocco', 'martinique', 'austria', 'united-kingdom', 'romania',
#        'hong-kong', 'united-arab-emirates', 'serbia', 'bulgaria',
#        'senegal', 'croatia', 'portugal', 'denmark', 'sweden', 'norway',
#        'italy', 'spain', 'bolivia', 'bosnia-and-herzegovina',
#        'south-korea', 'cambodia', 'thailand', 'indonesia', 'australia',
#        'new-zealand', 'albania', 'ukraine', 'argentina',
#        'north-macedonia', 'south-africa', 'tunisia', 'algeria', 'hungary',
#        'poland', 'La Réunion', 'japan', 'greece', 'unknown', 'egypt',
#        'singapore', 'turkey', 'new-caledonia', 'brazil', 'mexico',
#        'cote-d-ivoire', 'cameroon', 'czech-republic', 'russia',
#        'trinidad-and-tobago', 'gabon', 'vietnam', 'cyprus', 'slovenia',
#        'saint-martin', 'moldova', 'ireland', 'israel', 'colombia',
# ...

# %%
ct1=ct1.replace('world','unknown',regex=True)

# %%
df.ecoscore_grade.unique()
# Out:
# array(['unknown', 'not-applicable', 'd', 'a'], dtype=object)

# %%
pt=df.packaging_tags.str.split(',')

# %%
pt=pt.explode()

# %%
pt=pt.str.strip()

# %%
pt=pt.replace('bg:1-бутилка-pet-за-рециклиране','bg:1-бутилка-pet-за-рециклиране(plastic)',regex=True)

# %%
df.stores.unique()
# Out:
# array(['unknown', 'Orangina sur la plage',
#        'Magasins U, Delhaize, carrefour.fr', 'Utile', 'Leclerc',
#        'Carrefour', 'Super U', 'Magasins U,leclerc,carrefour.fr',
#        'Intermarché,Magasins U, carrefour.fr', 'Magasins U, carrefour.fr',
#        'Cora,Magasins U, Delhaize, carrefour.fr', 'Carrefour Market',
#        'Intermarché', 'Auchan', 'Franprix', 'Monoprix',
#        'Carrefour,Super U', 'Casino', 'Franprix,Magasins U,carrefour.fr',
#        'Simply Market,Super U', 'Cora', 'Magasins U, carrefour.fr,Auchan',
#        'Auchan,Magasins U, carrefour.fr', 'Cora, Magasins U',
#        'delhaize, carrefour.fr',
#        'Leclerc, Magasins U, Delhaize, carrefour.fr',
#        'Cora,Leclerc,Magasins U,Delhaize, carrefour.fr',
#        'Leclerc,Magasins U,Delhaize, carrefour.fr',
#        'Carrefour Market,Leclerc', 'E.Leclerc,Auchan,Carefour',
#        'Magasins U', 'Delhaize', 'Leclercq, carrefour.fr',
# ...

# %%
df.purchase_places.unique()
# Out:
# array(['unknown', 'New York City,New York,USA', 'Leucate', 'France',
#        'Marseille,France', "Saint Martin d'Hères,France",
#        'Conflans-Sainte-Honorine', 'Marche en famenne', 'Paris,France',
#        'Niort,France', 'Courrières,France', 'Brest,France,Carvin',
#        'Lyon,France', 'neuilly sur Marne', 'Paris',
#        'France,Saint-Maur des Fossés', 'Veynes,France',
#        'Harnes,France,Marseille 5°', 'Nantes,France', 'temse,belgium',
#        'Orvault,France', 'Courrières,France,Orvault',
#        'France,Saint-Nazaire,Poitiers', 'Aix-en-Provence,France',
#        'Villers Bocage 80260,France', 'Marseille 5°', 'België',
#        'Deutschland', 'München,bayern,Deutschland',
#        'Liverpool,United Kingdom', 'Bucuresti,Romania', 'England',
#        'London', 'london,united kingdom', 'Belgique', 'Marche en Famenne',
#        "France,Dolus d'Oléron", 'Toulouse,France', 'Serbia', 'Morocco',
#        'Almada,Portugal', 'Crans,Suisse', 'Italie', 'Italia', 'Trieste',
# ...

# %%
pp=df.purchase_places.str.split(',')

# %%
pp=pp.explode()

# %%
pp=pp.str.strip()

# %%
pp.unique()
# Out:
# array(['unknown', 'New York City', 'New York', 'USA', 'Leucate', 'France',
#        'Marseille', "Saint Martin d'Hères", 'Conflans-Sainte-Honorine',
#        'Marche en famenne', 'Paris', 'Niort', 'Courrières', 'Brest',
#        'Carvin', 'Lyon', 'neuilly sur Marne', 'Saint-Maur des Fossés',
#        'Veynes', 'Harnes', 'Marseille 5°', 'Nantes', 'temse', 'belgium',
#        'Orvault', 'Saint-Nazaire', 'Poitiers', 'Aix-en-Provence',
#        'Villers Bocage 80260', 'België', 'Deutschland', 'München',
#        'bayern', 'Liverpool', 'United Kingdom', 'Bucuresti', 'Romania',
#        'England', 'London', 'london', 'united kingdom', 'Belgique',
#        'Marche en Famenne', "Dolus d'Oléron", 'Toulouse', 'Serbia',
#        'Morocco', 'Almada', 'Portugal', 'Crans', 'Suisse', 'Italie',
#        'Italia', 'Trieste', 'Madrid', 'España', 'Maroc', 'Bangkok',
#        'Thailand', 'NSW', 'Australia', 'Melbourne', 'Victoria',
#        'Afrique du Sud', 'Nürnberg', 'Bayern', 'Österreich', 'Tirol',
# ...

# %%
pp.value_counts()
# Out:
# purchase_places
# unknown        1458
# France           61
# España           12
# Madrid            7
# Deutschland       7
#                ...
# London            1
# England           1
# bayern            1
# München           1
# Bulgaria          1
# Name: count, Length: 93, dtype: int64

# %%
pp=pp.replace('New York City','New York',regex=True)

# %%
pp.unique()
# Out:
# array(['unknown', 'New York', 'USA', 'Leucate', 'France', 'Marseille',
#        "Saint Martin d'Hères", 'Conflans-Sainte-Honorine',
#        'Marche en famenne', 'Paris', 'Niort', 'Courrières', 'Brest',
#        'Carvin', 'Lyon', 'neuilly sur Marne', 'Saint-Maur des Fossés',
#        'Veynes', 'Harnes', 'Marseille 5°', 'Nantes', 'temse', 'belgium',
#        'Orvault', 'Saint-Nazaire', 'Poitiers', 'Aix-en-Provence',
#        'Villers Bocage 80260', 'België', 'Deutschland', 'München',
#        'bayern', 'Liverpool', 'United Kingdom', 'Bucuresti', 'Romania',
#        'England', 'London', 'london', 'united kingdom', 'Belgique',
#        'Marche en Famenne', "Dolus d'Oléron", 'Toulouse', 'Serbia',
#        'Morocco', 'Almada', 'Portugal', 'Crans', 'Suisse', 'Italie',
#        'Italia', 'Trieste', 'Madrid', 'España', 'Maroc', 'Bangkok',
#        'Thailand', 'NSW', 'Australia', 'Melbourne', 'Victoria',
#        'Afrique du Sud', 'Nürnberg', 'Bayern', 'Österreich', 'Tirol',
# ...

# %%
pp=pp.replace('Ελλάδα','greece',regex=True)

# %%
pp.value_counts()
# Out:
# purchase_places
# unknown        1458
# France           61
# España           12
# Deutschland       7
# Madrid            7
#                ...
# London            1
# England           1
# bayern            1
# München           1
# Bulgaria          1
# Name: count, Length: 92, dtype: int64

# %%
df.stores.unique()
# Out:
# array(['unknown', 'Orangina sur la plage',
#        'Magasins U, Delhaize, carrefour.fr', 'Utile', 'Leclerc',
#        'Carrefour', 'Super U', 'Magasins U,leclerc,carrefour.fr',
#        'Intermarché,Magasins U, carrefour.fr', 'Magasins U, carrefour.fr',
#        'Cora,Magasins U, Delhaize, carrefour.fr', 'Carrefour Market',
#        'Intermarché', 'Auchan', 'Franprix', 'Monoprix',
#        'Carrefour,Super U', 'Casino', 'Franprix,Magasins U,carrefour.fr',
#        'Simply Market,Super U', 'Cora', 'Magasins U, carrefour.fr,Auchan',
#        'Auchan,Magasins U, carrefour.fr', 'Cora, Magasins U',
#        'delhaize, carrefour.fr',
#        'Leclerc, Magasins U, Delhaize, carrefour.fr',
#        'Cora,Leclerc,Magasins U,Delhaize, carrefour.fr',
#        'Leclerc,Magasins U,Delhaize, carrefour.fr',
#        'Carrefour Market,Leclerc', 'E.Leclerc,Auchan,Carefour',
#        'Magasins U', 'Delhaize', 'Leclercq, carrefour.fr',
# ...

# %%
ss=df.stores.str.split(',')
ss
# Out:
# 0       [unknown]
# 1       [unknown]
# 2       [unknown]
# 3       [unknown]
# 4       [unknown]
#           ...
# 1609    [unknown]
# 1610    [unknown]
# 1611    [unknown]
# 1612    [unknown]
# 1613    [unknown]
# Name: stores, Length: 1614, dtype: object

# %%
ss=ss.explode()
ss
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 1609    unknown
# 1610    unknown
# 1611    unknown
# 1612    unknown
# 1613    unknown
# Name: stores, Length: 1694, dtype: object

# %%
ss.value_counts()
# Out:
# stores
# unknown             1472
# Magasins U            16
# Woolworths            16
# Carrefour             16
#  carrefour.fr         14
#                     ...
# Avion                  1
# British Airways        1
# U EXPRESS CECILE       1
# Spar                   1
# Tesco                  1
# Name: count, Length: 79, dtype: int64

# %%
ss_filtered = ss[ss != 'unknown']
ss
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 1609    unknown
# 1610    unknown
# 1611    unknown
# 1612    unknown
# 1613    unknown
# Name: stores, Length: 1694, dtype: object

# %%
top = df.groupby('brands')['product_name'].count().sort_values(ascending=False).head(15)
plt.figure(figsize=(12,6))
sb.barplot(x=top.index,y=top.values)
plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Number of Products")
plt.title("Top Brands by Product Count")
plt.show()
# Out:
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
top_products = df['product_name'].value_counts().head(15)
plt.figure(figsize=(12,6))
sb.barplot(y=top_products.index,x=top_products.values)
plt.xlabel("Count")
plt.ylabel("Product Name")
plt.title("Top Product Names")
plt.show()

# %%
unique = df.groupby('brands')['product_name'].nunique().sort_values(ascending=False).head(15)
plt.figure(figsize=(12,6))
sb.barplot(x=unique.index,y=unique.values)
plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Unique Products")
plt.title("Unique Products by Brand")
plt.show()
# Out:
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3594 (\N{THAI CHARACTER CHO CHANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\rudra yadav\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df.countries_tags.value_counts()
# Out:
# countries_tags
# france                    379
# united-states             114
# australia                 107
# spain                      98
# germany                    81
#                          ...
# greece, switzerland         1
# bolivia, spain              1
# france, morocco, spain      1
# saint-martin                1
# bulgaria, spain             1
# Name: count, Length: 174, dtype: int64

# %%
us_df = df[df['countries_tags'].str.contains('united-states', case=False, na=False)]
top_products = us_df['product_name'].value_counts().head(15)
plt.figure(figsize=(12,6))
sb.barplot(y=top_products.index, x=top_products.values)
plt.xlabel("Number of Products in United States")
plt.ylabel("Product Name")
plt.title("Top 15 Products in United States")
plt.show()

# %% [markdown]
# Observation :-
#
# Schweppes is the most common product name with about 5 occurrences. Ginger ale and GINGER ALE each appear around 4 times, showing that the same product may have different capitalization in the dataset.

# %%
us_df = df[df['countries_tags'].str.contains('united-states', case=False, na=False)]

top_brands = us_df['brands'].value_counts().head(15)

plt.figure(figsize=(12,6))
sb.barplot(x=top_brands.index, y=top_brands.values)

plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Number of Products")
plt.title("Top Brands in United States")
plt.show()

# %% [markdown]
# Observation :-
#
# Schweppes is clearly the dominant brand, with around 90+ products. Papa John's is a distant second with around 12 products, while the remaining brands have very few products.

# %%
print(df['countries_tags'].value_counts().head(20))
print(df['countries_tags'].unique()[:20])
# Out:
# countries_tags
# france             379
# united-states      114
# australia          107
# spain               98
# germany             81
# romania             56
# belgium, france     54
# belgium             50
# united-kingdom      40
# italy               29
# switzerland         22
# brazil              22
# poland              20
# algeria             20
# denmark             18
# ireland             16
# netherlands         16
# canada              15
# norway              15
# france, germany     13
# Name: count, dtype: int64
# ['canada' 'united-states' 'france, united-states' 'france'
#  'united-states, world' 'belgium, france' 'france, switzerland'
#  'belgium, france, luxembourg, netherlands' 'netherlands'
#  'france, reunion' 'belgium, france, germany, switzerland'
#  'france, germany, united-states' 'belgium, france, germany'
#  'belgium, france, morocco' 'france, luxembourg'
#  'belgium, france, switzerland, world' 'france, martinique' 'germany'
# ...

# %%
print(df[['countries_tags']].head(10))
# Out:
#           countries_tags
# 0                 canada
# 1          united-states
# 2  france, united-states
# 3                 france
# 4                 france
# 5                 france
# 6                 france
# 7   united-states, world
# 8                 france
# 9                 france

# %%
df['countries_tags'].value_counts()['united-states']
# Out:
# np.int64(114)

# %%
us_df = df[df['countries_tags'].str.contains('united-states', case=False, na=False)]

# %%
top_brands = us_df['brands'].value_counts().head(5)
plt.figure(figsize=(12,6))
sb.barplot(x=top_brands.index, y=top_brands.values)
plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Number of Products")
plt.title("Top  Brands in United States")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 top_brands = us_df['brands'].value_counts().head(5)
#       2 plt.figure(figsize=(12,6))
#       3 sb.barplot(x=top_brands.index, y=top_brands.values)
#
# NameError: name 'us_df' is not defined

# %%
us_df = df[df['countries_tags'].str.contains('united-states', case=False, na=False)]
top_products = us_df['product_name'].value_counts().head(15)
plt.figure(figsize=(12,6))
sb.barplot(y=top_products.index, x=top_products.values)
plt.xlabel("Count")
plt.ylabel("Product Name")
plt.title("Top 15 Product Names in United States")
plt.show()

# %%
us_data=df[df['countries_tags'].str.contains('united-states', case=False, na=False)]
# Out:
#                code                             product_name  \
# 1     0078000202465                  Sparkling seltzer water
# 2     0078000206401                               GINGER ALE
# 7     0898195001342                      Premium Tonic Water
# 95    3124480184337                                 Orangina
# 245   5449000046413                                Schweppes
# ...             ...                                      ...
# 1579  4260078621811                   Schweppes Zero Agrumes
# 1583       54023727  Bitter Lemon Limon Aromalı Gazlı İçecek
# 1596  5940628344061                                   Mojito
# 1605  9315596010403        PASSIONFRUIT FLAVOURED SOFT DRINK
# 1606  9315596009858                               Soda Water
#
#                                                  brands  \
# 1                                             Schweppes
# 2                                             Schweppes
# 7                                 Fever-tree, Schweppes
# ...

# %%
us_data['packaging_tags'].value_counts().head(15)
# Out:
# packaging_tags
# aluminium-cap, glass-bottle                               1
# 1-film-en-plastique-a-recycler-6-canettes-en-aluminium    1
# bottle                                                    1
# bottle-cap, pet-bottle                                    1
# unknown, aluminium-tin                                    1
# can, drink-can                                            1
# Name: count, dtype: int64

# %%
us_data['stores'].unique()
# Out:
# array([nan, 'Auchan,Magasins U, carrefour.fr', 'ShopRite'], dtype=object)

# %%
us_data['purchase_places'].value_counts()
# Out:
# purchase_places
# New York City,New York,USA    1
# Nantes,France                 1
# Name: count, dtype: int64

# %%
us_data['nutriscore_grade'].value_counts()
# Out:
# nutriscore_grade
# unknown           79
# e                 21
# b                 13
# c                  6
# d                  2
# not-applicable     1
# Name: count, dtype: int64

# %%
us_data['nova_group'].value_counts()
# Out:
# nova_group
# 4.0    30
# 1.0     4
# Name: count, dtype: int64

# %%
us_data['ecoscore_grade'].value_counts()
# Out:
# ecoscore_grade
# unknown           33
# not-applicable    19
# Name: count, dtype: int64

# %%
us_data['nutriments.sugars_100g'].value_counts()
# Out:
# nutriments.sugars_100g
# 0.000000      30
# 114.000000     2
# 26.250000      2
# 5.800000       2
# 3.800000       2
# 1.860000       2
# 209.000000     2
# 2.820000       2
# 186.000000     2
# 1.690000       2
# 9.010000       2
# 12.000000      1
# 2.400000       1
# 4.600000       1
# 4.400000       1
# 0.300000       1
# 9.406390       1
# 8.023649       1
# 90.497738      1
# 9.295775       1
# 10.405644      1
# 8.000000       1
# 14.500000      1
# 9.850746       1
# 9.705882       1
# 9.049774       1
# 9.523810       1
# 9.121622       1
# 10.704225      1
# 9.859155       1
# 9.120000       1
# 9.090000       1
# 11.270000      1
# 9.050000       1
# 40.000000      1
# 8.900000       1
# Name: count, dtype: int64

# %%
us_data['nutriments.energy-kcal_100g'].value_counts()
# Out:
# nutriments.energy-kcal_100g
# 0.000000      32
# 11.300000      2
# 100.000000     2
# 856.000000     2
# 7.440000       2
# 25.000000      2
# 464.000000     2
# 39.436620      2
# 37.000000      2
# 744.000000     2
# 42.000000      2
# 36.000000      2
# 200.000000     2
# 6.760000       2
# 34.000000      2
# 19.000000      2
# 29.560811      1
# 37.625558      1
# 1.690100       1
# 2.300000       1
# 16.000000      1
# 300.000000     1
# 361.990950     1
# 35.820896      1
# 40.564374      1
# 36.619718      1
# 58.000000      1
# 33.000000      1
# 35.294118      1
# 2.000000       1
# 36.199095      1
# 0.452489       1
# 35.273369      1
# 37.162162      1
# 35.900000      1
# 3.333333       1
# 49.500000      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sb.countplot(data=us_df, x='nova_group')

plt.xlabel("NOVA Group")
plt.ylabel("Count")
plt.title("NOVA Group Distribution in United States")
plt.show()

# %% [markdown]
# Observation :-
#
# NOVA Group 4 has the highest number of products, with around 30 products, while Group 1 has only around 4 products. This indicates that highly processed products dominate the available NOVA-classified U.S. data.

# %%
us_df = df[df['countries_tags'].str.contains('united-states', case=False, na=False)]

avg_sugar = (
    us_df.groupby('brands')['nutriments.sugars_100g']
    .mean()
    .sort_values(ascending=False)
    .head(15)
)

plt.figure(figsize=(12,6))
sb.barplot(x=avg_sugar.index, y=avg_sugar.values)

plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Average Sugar (g/100g)")
plt.title("Average Sugar by Brand in United States")
plt.show()

# %% [markdown]
# Observation :-
#
# Papa John's has the highest average sugar content, at around 86 g/100g, which is much higher than the other brands. Schweppes and other brands have considerably lower average sugar levels.

# %%
avg_calories = (
    us_df.groupby('brands')['nutriments.energy-kcal_100g']
    .mean()
    .sort_values(ascending=False)
    .head(15)
)

plt.figure(figsize=(12,6))
sb.barplot(x=avg_calories.index, y=avg_calories.values)

plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Average Energy (kcal/100g)")
plt.title("Average Calories by Brand in United States")
plt.show()

# %% [markdown]
# Observation :-
#
# Papa John's has the highest average energy value at approximately 350 kcal/100g. The other brands are much lower, mostly below about 40 kcal/100g

# %%
plt.figure(figsize=(12,6))
sb.barplot(x=avg_calories.index, y=avg_calories.values)

plt.xticks(rotation=90)
plt.xlabel("Brands")
plt.ylabel("Average Energy (kcal/100g)")
plt.title("Average Calories by Brand in United States")
plt.show()

# %%
us_data['ingredients_text'].value_counts()
# Out:
# ingredients_text
# undefined                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     12
# ...

# %%
ingredients = (us_df['ingredients_text'].dropna().str.split(',').explode().str.strip())
top_ingredients = ingredients.value_counts().head(20)
plt.figure(figsize=(12,8))
sb.barplot(y=top_ingredients.index, x=top_ingredients.values)
plt.xlabel("Count")
plt.ylabel("Ingredient")
plt.title("Top 20 Ingredients in United States Products")
plt.show()

# %%
ingredients = (
    us_df['ingredients_text']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
    .str.rstrip('.')
    .str.strip()
)

top_ingredients = ingredients.value_counts().head(20)

plt.figure(figsize=(12,8))
sb.barplot(y=top_ingredients.index, x=top_ingredients.values)

plt.xlabel("Count")
plt.ylabel("Ingredient")
plt.title("Top 20 Ingredients in United States Products")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Carbonated water is the most common ingredient, appearing about 28 times, followed by natural flavors with around 25 occurrences.
# Citric acid, high fructose corn syrup, sodium benzoate, and caramel color are also frequently used, showing a strong presence of sweeteners, preservatives, acids, and flavoring ingredients.
# The remaining ingredients such as quinine, aspartame, red 40, blue 1, sodium bicarbonate, and sodium chloride occur less frequently, generally around 2–4 times.

# %%
categories = (
    us_df['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
    .head(10)
)

plt.figure(figsize=(12,6))
sb.barplot(y=categories.index, x=categories.values)

plt.xlabel("Number of Products")
plt.ylabel("Category")
plt.title("Top Product Categories in United States")
plt.tight_layout()
plt.show()

# %%
nutriscore = us_df['nutriscore_grade'].value_counts()

plt.figure(figsize=(8,5))
sb.barplot(x=nutriscore.index, y=nutriscore.values)

plt.xlabel("Nutri-Score Grade")
plt.ylabel("Number of Products")
plt.title("Nutri-Score Grade Distribution in United States")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# as we can see that unknown values are more in that and e follow most in it and followed by b so this make the observation of this

# %%
top_stores = us_df['stores'].value_counts().head(15)
stores = (us_df['stores'].dropna().str.split(',').explode().str.strip())
plt.figure(figsize=(12,6))
sb.barplot(y=top_stores.index, x=top_stores.values)

plt.xlabel("Number of Products")
plt.ylabel("Store")
plt.title("Top  Stores in United States")
plt.show()

# %% [markdown]
# Observation :-
#
# ShopRite and Auchan, Magasins U, carrefour.fr each appear with only 1 product. Therefore, the store information is very limited in this U.S. subset, so strong conclusions about store popularity cannot be made.

# %%
us_data['product_name'].value_counts()
# Out:
# product_name
# Schweppes                                               5
# Ginger ale                                              4
# GINGER ALE                                              4
# Sparkling seltzer water                                 2
# Papa John's, Schweppes Ginger Ale Raspberry, 2 Liter    2
#                                                        ..
# Schweppes Original Sparkling Seltzer Water              1
# Caffeine free ginger ale                                1
# Schwepped original                                      1
# Scweppes                                                1
# PASSIONFRUIT FLAVOURED SOFT DRINK                       1
# Name: count, Length: 96, dtype: int64

# %%
aus_data=df[df['countries_tags'].str.contains('australia', case=False, na=False)]
aus_data
# Out:
#                code                                       product_name  \
# 350   9315596000435                               Lemon Lime & bitters
# 351   9315596000633                                                NaN
# 352   9315596002255                                              Agrum
# 353   9315596002439                                        Tonic Water
# 354   9315596002477                           Schweppes Dry Ginger Ale
# ...             ...                                                ...
# 1578  9315596010359                 Hyperspace Fizz Lime Flavour 250mL
# 1582  9315596010373                            Galactic Lemonade 250mL
# 1591  9315596009957  Thr mandalorian bounty blast, raspberry and or...
# 1597  9315596003580                                   Classic Lemonade
# 1610  9315596009919  Bounty Blast Raspberry & Orange Flavour Zero S...
#
#                                               brands  \
# 350                                        Schweppes
# ...

# %%
aus_data['packaging_tags'].value_counts()
# Out:
# packaging_tags
# glass-bottle                   3
# plastic-bottle                 3
# plastic                        2
# glass, bottle, glass-bottle    1
# pet-bottle                     1
# Name: count, dtype: int64

# %%
aus_data['product_name'].value_counts().head(15)
# Out:
# product_name
# Lemonade                                     5
# Indian Tonic Water                           3
# Classic Lemonade                             2
# schweppes raspberry                          2
# Pink Lemonade                                2
# Dry ginger ale                               2
# Passionfruit Lemonade                        2
# Natural mineral water                        2
# Soda Water                                   2
# Natural Mineral Water                        2
# Schweppes Ginger Beer 300ml                  1
# Zero sugar lime and lemon drink              1
# STRAWBERRY & WATERMELON FLAVOUR              1
# Schweppes Gelato Messina Pineapple & Lime    1
# Low Sugar Tonic                              1
# Name: count, dtype: int64

# %%
aus_data['brands'].value_counts()
# Out:
# brands
# Schweppes                                         107
# Schweppes Australia,Asahi Breweries, Schweppes      1
# Spring Valley,Schweppes Australia                   1
# Frantelle,Schweppes Australia                       1
# Belbake                                             1
# Schweppes X Messina                                 1
# Schweppes That’s alrightl                           1
# Name: count, dtype: int64

# %%
aus_data['stores'].value_counts()
# Out:
# stores
# Woolworths, Coles     9
# Woolworths            3
# Officeworks, Coles    2
# Woolworths,Coles      2
# Piedemonte's IGA      1
# Coles,Woolworths      1
# Woolworths,OTR        1
# Name: count, dtype: int64

# %%
aus_data['nutriscore_grade'].value_counts()
# Out:
# nutriscore_grade
# unknown    101
# c            5
# d            4
# e            2
# a            2
# b            1
# Name: count, dtype: int64

# %%
aus_data['nova_group'].value_counts()
# Out:
# nova_group
# 4.0    31
# 1.0     6
# 3.0     1
# Name: count, dtype: int64

# %%
aus_data['ecoscore_grade'].value_counts()
# Out:
# ecoscore_grade
# unknown           29
# not-applicable    12
# d                  1
# Name: count, dtype: int64

# %%
brands = (aus_data['brands'].dropna().str.split(',').explode().str.strip())
top_brands = brands.value_counts().head(15)
plt.figure(figsize=(12, 7))
sb.barplot(y=top_brands.index,x=top_brands.values)
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()
plt.show()

# %% [markdown]
# Observation :-
#
# Schweppes is the dominant brand, with far more products than all other brands.
# Other brands such as Schweppes Australia, Asahi Breweries, and Spring Valley have very few products in comparison.

# %%
top_products = aus_data['product_name'].value_counts().head(15)
plt.figure(figsize=(12,7))
sb.barplot(y=top_products.index, x=top_products.values)
plt.xlabel("Number of Products")
plt.ylabel("Product Name")
plt.title("Top Product Names in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Lemonade is the most common product, followed by Indian Tonic Water.
# Most other products appear only around 1–2 times, showing a wide variety of products.

# %%
categories_tags = (
    aus_data['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_categories = categories_tags.value_counts().head(15)

plt.figure(figsize=(12,7))
sb.barplot(y=top_categories.index, x=top_categories.values)

plt.xlabel("Number of Products")
plt.ylabel("Category")
plt.title("Top 15 Individual Product Categories in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Beverages is the largest category, followed by carbonated drinks and sodas.
# Water and tonic-water categories also have a noticeable presence.

# %%
stores = (aus_data['stores'].dropna().str.split(',').explode().str.strip())
top_stores = stores.value_counts()
plt.figure(figsize=(12,7))
sb.barplot(y=top_stores.index, x=top_stores.values)
plt.xlabel("Number of Products")
plt.ylabel("Store")
plt.title("Top Individual Stores in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Woolworths has the highest number of products, followed by Coles.
# Officeworks and other stores have very few products compared with the two major supermarkets

# %%
ingredients = (
    aus_data['ingredients_text']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_ingredients = ingredients.value_counts().head(20)

plt.figure(figsize=(12,8))
sb.barplot(y=top_ingredients.index, x=top_ingredients.values)

plt.xlabel("Number of Occurrences")
plt.ylabel("Ingredient")
plt.title("Top 20 Individual Ingredients in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Sugar is the most frequently occurring ingredient, followed closely by carbonated water.
# The data contains duplicates caused by different capitalization, such as Sugar, SUGAR, and sugar, as well as some unclear values like 331 and 2 beverage drive. These should ideally be standardized for more accurate analysis.

# %%
nutrition = aus_data['nutriscore_grade'].value_counts()

plt.figure(figsize=(8,5))
sb.barplot(x=nutrition.index, y=nutrition.values)

plt.xlabel("Nutrition Grade")
plt.ylabel("Number of Products")
plt.title("Nutrition Grade Distribution in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# 1. Nutrition Grade Distribution in Australia
# The “Unknown” nutrition grade has the highest number of products, with around 100 products.
# Grade C is the next most common, followed by D.
# Grades A, B, and E have comparatively very few products.
# This indicates that a large portion of the products do not have a recorded nutrition grade.

# %%
nova = aus_data['nova_group'].value_counts()

plt.figure(figsize=(8,5))
sb.barplot(x=nova.index, y=nova.values)

plt.xlabel("NOVA Group")
plt.ylabel("Number of Products")
plt.title("NOVA Group Distribution in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# 2. NOVA Group Distribution in Australia
# NOVA Group 4 has the highest number of products, with around 31 products.
# NOVA Group 1 has around 6 products.
# NOVA Group 3 has only about 1 product.
# No significant products are shown for NOVA Group 2.
# Therefore, the dataset is dominated by NOVA Group 4 products, which are generally classified as ultra-processed foods.

# %%
brand_sugar = (
    aus_data[['brands', 'nutriments.sugars_100g']]
    .dropna(subset=['brands'])
    .assign(brands=lambda x: x['brands'].str.split(','))
    .explode('brands')
)

brand_sugar['brands'] = brand_sugar['brands'].str.strip()

avg_sugar = (
    brand_sugar.groupby('brands')['nutriments.sugars_100g']
    .mean()
    .sort_values(ascending=False)
    .head(15)
)

plt.figure(figsize=(12,7))
sb.barplot(y=avg_sugar.index, x=avg_sugar.values)

plt.xlabel("Average Sugar (g/100g)")
plt.ylabel("Brand")
plt.title("Average Sugar by Individual Brand in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# 3. Average Sugar by Individual Brand
# Spring Valley has the highest average sugar content, at approximately 12 g/100g.
# Schweppes Australia and Schweppes X Messina follow, with around 9–10 g/100g.
# Asahi Breweries and Schweppes have lower averages, around 7–8 g/100g.
# Some brands show no visible bar, which may indicate missing/ unavailable sugar data rather than zero sugar.

# %%
brand_energy = (
    aus_data[['brands', 'nutriments.energy-kcal_100g']]
    .dropna(subset=['brands'])
    .assign(brands=lambda x: x['brands'].str.split(','))
    .explode('brands')
)

brand_energy['brands'] = brand_energy['brands'].str.strip()

avg_energy = (
    brand_energy.groupby('brands')['nutriments.energy-kcal_100g']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(12,7))
sb.barplot(y=avg_energy.index, x=avg_energy.values)

plt.xlabel("Average Energy (kcal/100g)")
plt.ylabel("Brand")
plt.title("Average Energy by Individual Brand in Australia")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Schweppes X Messina has the highest average energy content, at approximately 42 kcal/100g.
# Schweppes is second, at around 31 kcal/100g.
# The remaining brands have no visible values in the graph, likely because their energy data is missing or unavailable.
# Among the brands with available values, Schweppes X Messina has considerably higher average energy than Schweppes.

# %%
df.countries_tags.value_counts().head(20)
# Out:
# countries_tags
# france             379
# united-states      114
# australia          107
# spain               98
# germany             81
# romania             56
# belgium, france     54
# belgium             50
# united-kingdom      40
# italy               29
# brazil              22
# switzerland         22
# algeria             20
# poland              20
# denmark             18
# netherlands         16
# ireland             16
# norway              15
# canada              15
# france, germany     13
# Name: count, dtype: int64

# %%
countries= df['countries_tags'].str.split(',').explode().str.strip()

countries.value_counts().head(20)
# Out:
# countries_tags
# france            539
# germany           126
# spain             124
# united-states     122
# australia         115
# belgium           115
# romania            61
# switzerland        53
# united-kingdom     48
# italy              37
# morocco            31
# poland             24
# brazil             22
# algeria            22
# denmark            18
# canada             17
# netherlands        17
# ireland            16
# bulgaria           16
# norway             15
# Name: count, dtype: int64

# %%
germany_data=df[df['countries_tags'].str.contains('germany', case=False, na=False)]
germany_data
# Out:
#                code                                       product_name  \
# 86    3124480182746                                       Tonic Indian
# 95    3124480184337                                           Orangina
# 96    3124480184344                               Orangina et sa pulpe
# 169   4000140011498                                       Bitter Lemon
# 170   4000140011528                                 Indian Tonic Water
# ...             ...                                                ...
# 1540  5449000252357                                     schweppes pink
# 1570  9315596008073  Schweppes Zero Sugar Lemon Lime Bitters Soda S...
# 1571  9315596007939  Schweppes Zero Sugar Lemonade Soda Syrup Sugar...
# 1612  7617500199207                                   Schweppes Citrus
# 1613  7617500199160                                         Wild Berry
#
#                                                  brands  \
# 86                        Orangina Schweppes, Schweppes
# ...

# %%
germany_data
# Out:
#                code                                       product_name  \
# 86    3124480182746                                       Tonic Indian
# 95    3124480184337                                           Orangina
# 96    3124480184344                               Orangina et sa pulpe
# 169   4000140011498                                       Bitter Lemon
# 170   4000140011528                                 Indian Tonic Water
# ...             ...                                                ...
# 1540  5449000252357                                     schweppes pink
# 1570  9315596008073  Schweppes Zero Sugar Lemon Lime Bitters Soda S...
# 1571  9315596007939  Schweppes Zero Sugar Lemonade Soda Syrup Sugar...
# 1612  7617500199207                                   Schweppes Citrus
# 1613  7617500199160                                         Wild Berry
#
#                                                  brands  \
# 86                        Orangina Schweppes, Schweppes
# ...

# %%
germany_data['product_name'].value_counts().head(15)
# Out:
# product_name
# Bitter Lemon               7
# Wild Berry                 5
# Ginger Ale                 5
# Indian Tonic Water         5
# Dry Tonic Water            5
# Tonic Water                4
# American Ginger Ale        4
# Schweppes                  4
# White Peach                3
# Virgin Mojito              3
# Schweppes Zero             2
# Indian Tonic Water Zero    2
# Indian Tonic               2
# Schweppes Bitter Lemon     2
# Ginger Beer                2
# Name: count, dtype: int64

# %%
germany_data['brands'].value_counts()
# Out:
# brands
# Schweppes                                                               106
# schweppes                                                                 4
# Orangina, Orangina Schweppes France, Schweppes International Limited      2
# Orangina Schweppes, Schweppes                                             1
# schweppes, ชเวปส์                                                         1
# Orangina, Schweppes                                                       1
# Ginger Ale Schweppes, Schweppes, Schweppes Ginger Ale                     1
# Ringnes as                                                                1
# Schweppes Ginger Ale                                                      1
# Schweppes, schwepps                                                       1
# Schweppeses, Schweppes                                                    1
# Name: count, dtype: int64

# %%
brands = (
    germany_data['brands']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

brand_counts = brands.value_counts()

print(brand_counts)
# Out:
# brands
# Schweppes                          111
# schweppes                            5
# Orangina                             3
# Orangina Schweppes France            2
# Schweppes International Limited      2
# Schweppes Ginger Ale                 2
# Orangina Schweppes                   1
# ชเวปส์                               1
# Ginger Ale Schweppes                 1
# Ringnes as                           1
# schwepps                             1
# Schweppeses                          1
# Name: count, dtype: int64

# %%
germany_data['categories_tags'].value_counts().head(15)
# Out:
# categories_tags
# beverages-and-beverages-preparations, beverages                                                                                                                                                                  38
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages                                                                                                                   12
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, tonic-water, sweetened-beverages                                                                                                       8
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas                                                                                                                                         4
# ...

# %%
categories = (
    germany_data['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

category_counts = categories.value_counts().head(15)

print(category_counts)
# Out:
# categories_tags
# beverages                               97
# beverages-and-beverages-preparations    94
# carbonated-drinks                       56
# sodas                                   56
# sweetened-beverages                     39
# tonic-water                             20
# artificially-sweetened-beverages        11
# lemonade                                 8
# plant-based-foods-and-beverages          6
# plant-based-beverages                    6
# fruit-based-beverages                    6
# fruit-sodas                              6
# diet-beverages                           4
# non-alcoholic-beverages                  4
# orange-soft-drinks                       3
# Name: count, dtype: int64

# %%
germany_data['packaging_tags'].value_counts().head(15)
# Out:
# packaging_tags
# bottle                                                                                        10
# plastic                                                                                        6
# plastic, bottle, de:einwegpfand                                                                2
# plastic, bottle                                                                                2
# glass, bottle                                                                                  2
# plastic, de:einwegpfand                                                                        2
# pet-bottle                                                                                     1
# de:mehrwegflasche                                                                              1
# glass                                                                                          1
# ...

# %%
germany_data['stores'].value_counts()
# Out:
# stores
# REWE                                4
# Edeka                               2
# Lidl                                2
# Franprix,Magasins U,carrefour.fr    1
# Auchan,Magasins U, carrefour.fr     1
# Spar                                1
# tegut                               1
# Kaufland,Combi,Rewe,Famila          1
# carrefour.fr                        1
# Name: count, dtype: int64

# %%
stores = (
    germany_data['stores']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

store_counts = stores.value_counts()

print(store_counts)
# Out:
# stores
# REWE            4
# carrefour.fr    3
# Magasins U      2
# Edeka           2
# Lidl            2
# Franprix        1
# Auchan          1
# Spar            1
# tegut           1
# Kaufland        1
# Combi           1
# Rewe            1
# Famila          1
# Name: count, dtype: int64

# %%
germany_data['purchase_places'].value_counts()
# Out:
# purchase_places
# Deutschland                    4
# France                         1
# Nantes,France                  1
# München,bayern,Deutschland     1
# Serbia                         1
# Nürnberg,Bayern,Deutschland    1
# Österreich,Tirol               1
# Ginsheim,Deutschland           1
# Name: count, dtype: int64

# %%
purchase_places = (
    germany_data['purchase_places']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

purchase_place_counts = purchase_places.value_counts()

print(purchase_place_counts)
# Out:
# purchase_places
# Deutschland    7
# France         2
# Nantes         1
# München        1
# bayern         1
# Serbia         1
# Nürnberg       1
# Bayern         1
# Österreich     1
# Tirol          1
# Ginsheim       1
# Name: count, dtype: int64

# %%
germany_data['nutriscore_grade'].value_counts()
# Out:
# nutriscore_grade
# unknown    51
# e          33
# d          27
# c          14
# a           1
# Name: count, dtype: int64

# %%
germany_data['nova_group'].value_counts()
# Out:
# nova_group
# 4.0    52
# 3.0     1
# Name: count, dtype: int64

# %%
germany_data['ecoscore_grade'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
germany_data['ingredients_text'].value_counts()
# Out:
# ingredients_text
# ...

# %%
brands = (
    germany_data['brands']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_brands = brands.value_counts().head(5)

plt.figure(figsize=(12,7))
sb.barplot(y=top_brands.index, x=top_brands.values)

plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.title("Top Individual Brands in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# 1. Top Individual Brands in Germany
# Schweppes is the most represented brand, with more than 100 products.
# The other brands, such as schweppes, Orangina, Orangina Schweppes France, and Schweppes International Limited, have much fewer products.
# There is a very large difference between Schweppes and the remaining brands.

# %%
top_products = germany_data['product_name'].value_counts().head(10)

plt.figure(figsize=(12,7))
sb.barplot(y=top_products.index, x=top_products.values)

plt.xlabel("Number of Products")
plt.ylabel("Product Name")
plt.title("Top Product Names in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# 2. Top Product Names in Germany
# Bitter Lemon is the most common product, with around 7 products.
# Wild Berry, Ginger Ale, Indian Tonic Water, and Dry Tonic Water each have around 5 products.
# Tonic Water, American Ginger Ale, and Schweppes have around 4 products each.
# White Peach and Virgin Mojito have around 3 products each.
# Overall, the products are mainly beverage-related, particularly tonic water, ginger ale, and similar dri

# %%
categories = (
    germany_data['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_categories = categories.value_counts().head(10)

plt.figure(figsize=(12,7))
sb.barplot(y=top_categories.index, x=top_categories.values)

plt.xlabel("Number of Products")
plt.ylabel("Category")
plt.title("Top 10 Individual Categories in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# 3. Top 10 Individual Categories in Germany
# Beverages is the largest category, with nearly 100 products.
# Beverages-and-beverages-preparations is the second-largest, also with more than 90 products.
# Carbonated drinks and sodas each have around 55 products.
# Sweetened beverages have around 38 products.
# The remaining categories, such as tonic-water, artificially-sweetened beverages, lemonade, and plant-based beverages, have considerably fewer products.
# This shows that the German dataset is strongly dominated by beverage categories.

# %%
stores = (
    germany_data['stores']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_stores = stores.value_counts().head(15)

plt.figure(figsize=(12,7))
sb.barplot(y=top_stores.index, x=top_stores.values)

plt.xlabel("Number of Products")
plt.ylabel("Store")
plt.title("Top Individual Stores in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
#
# 4. Top Individual Stores in Germany
# REWE has the highest number of products, with about 4 products.
# Carrefour.fr follows with around 3 products.
# Magasins U, Edeka, and Lidl each have approximately 2 products.
# The remaining stores generally have around 1 product each.
# Therefore, REWE and Carrefour.fr contribute the largest number of products among the listed stores.

# %%
ingredients = (
    germany_data['ingredients_text']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_ingredients = ingredients.value_counts().head(8)

plt.figure(figsize=(12,8))
sb.barplot(y=top_ingredients.index, x=top_ingredients.values)

plt.xlabel("Number of Occurrences")
plt.ylabel("Ingredient")
plt.title("Top  Individual Ingredients in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
#
# 5. Top Individual Ingredients in Germany
# Kohlensäure (carbon dioxide) and Wasser (water) are the most frequently occurring ingredients, each appearing around 43 times.
# Zucker (sugar) appears around 32 times.
# Citric acid is also common, with approximately 23 occurrences.
# Natural flavors and other flavoring ingredients occur less frequently.
# This indicates that water, carbonation, sugar, and citric acid are the most common ingredients in the analyzed products.

# %%
nova = germany_data['nova_group'].value_counts()

plt.figure(figsize=(8,5))
sb.barplot(x=nova.index, y=nova.values)

plt.xlabel("NOVA Group")
plt.ylabel("Number of Products")
plt.title("NOVA Group Distribution in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
#
# NOVA Group 4 is overwhelmingly dominant, with approximately 50 products.
# NOVA Group 3 has only around 1–2 products.
# No significant products are visible for NOVA Groups 1 and 2.
# Therefore, the German dataset is heavily concentrated in NOVA Group 4 products.

# %%
print(germany_data.shape)
print(germany_data['nutriments.sugars_100g'].notna().sum())
print(germany_data['nutriments.sugars_100g'].head(20))
# Out:
# (126, 14)
# 0
# 86    NaN
# 95    NaN
# 96    NaN
# 169   NaN
# 170   NaN
# 171   NaN
# 173   NaN
# 174   NaN
# 175   NaN
# 176   NaN
# 177   NaN
# 178   NaN
# 179   NaN
# 180   NaN
# 181   NaN
# 182   NaN
# 183   NaN
# 184   NaN
# 206   NaN
# 207   NaN
# Name: nutriments.sugars_100g, dtype: float64

# %%
packaging = (
    germany_data['packaging_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

top_packaging = packaging.value_counts().head(5)

plt.figure(figsize=(12,7))
sb.barplot(y=top_packaging.index, x=top_packaging.values)

plt.xlabel("Number of Products")
plt.ylabel("Packaging")
plt.title("Top Individual Packaging Types in Germany")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
#
# Bottle is the most common packaging type, with approximately 22 products.
# Plastic is the second most common, with around 16 products.
# Disposable packaging (de:einwegpfand) appears around 5 times.
# Glass and PET (polyethylene terephthalate) each occur around 3 times.
# Thus, bottles and plastic packaging are the dominant packaging types in the dataset.

# %%
print([
    col for col in germany_data.columns
    if 'eco' in col.lower()
])
# Out:
# ['ecoscore_grade']

# %%
print(germany_data['ecoscore_grade'].notna().sum())
# Out:
# 0

# %%
nutri = germany_data['nutriscore_grade'].value_counts()

order = ['a', 'b', 'c', 'd', 'e']

plt.figure(figsize=(8,5))

sb.barplot(
    x=nutri.index,
    y=nutri.values,
    order=[x for x in order if x in nutri.index]
)

plt.xlabel("Nutri-Score Grade")
plt.ylabel("Number of Products")
plt.title("Nutri-Score Grade Distribution in Germany")

plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
#
# Grade E has the highest number of products, with approximately 34 products.
# Grade D follows with around 27 products.
# Grade C has around 14 products.
# Grade A is very rare, with only around 1 product.
# The distribution indicates that the analyzed products are concentrated more heavily in lower Nutri-Score grades (D and E).

# %%
countries= df['countries_tags'].str.split(',').explode().str.strip()

countries.value_counts().head(20)
# Out:
# countries_tags
# france            539
# germany           126
# spain             124
# united-states     122
# australia         115
# belgium           115
# romania            61
# switzerland        53
# united-kingdom     48
# italy              37
# morocco            31
# poland             24
# brazil             22
# algeria            22
# denmark            18
# canada             17
# netherlands        17
# ireland            16
# bulgaria           16
# norway             15
# Name: count, dtype: int64

# %%
belgium_data=df[df['countries_tags'].str.contains('belgium', case=False, na=False)]
belgium_data
# Out:
#                code                   product_name  \
# 14    3124480000576         Indian Tonic Schweppes
# 18    3124480001405         Schweppes indian tonic
# 20    3124480001702         Schweppes Indian Tonic
# 21    3124480002129  PET 1.5L SCHWEPPES ZERO LEMON
# 22    3124480002167                Schweppes lemon
# ...             ...                            ...
# 1157  3124488187033                Schweppes lemon
# 1162  3124488186944                schweppes appel
# 1207  8435185980069                Pink Grapefruit
# 1363  5410191305108                        agrumes
# 1577  8435185982766                            NaN
#
#                              brands  \
# 14                        Schweppes
# 18    Orangina Schweppes, Schweppes
# 20          Indian Tonic, Schweppes
# 21                        Schweppes
# 22                        Schweppes
# ...                             ...
# 1157                      Schweppes
# 1162                      Schweppes
# ...

# %%
belgium_data['brands'].value_counts()
# Out:
# brands
# Schweppes                                                               92
# Orangina Schweppes, Schweppes                                            3
# schweppes                                                                2
# Oasis, Orangina Schweppes France                                         2
# May Tea, Orangina Schweppes                                              2
# Orangina, Orangina Schweppes France, Schweppes International Limited     1
# Orangina, Orangina Schweppes France                                      1
# May Tea, Orangina Schweppes France                                       1
# May tea, Orangine Schweppes France, Oscar mayer                          1
# Orangina Schweppes France                                                1
# May Tea, Schweppes International Limited                                 1
# Indian Tonic, Schweppes                                                  1
# ...

# %%
brands = (
    belgium_data['brands']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

brand_counts = brands.value_counts()

print(brand_counts)
# Out:
# brands
# Schweppes                          96
# Orangina Schweppes                  8
# Orangina Schweppes France           7
# May Tea                             4
# Oasis                               3
# Orangina                            3
# May tea                             2
# Schweppes International Limited     2
# schweppes                           2
# Orangine Schweppes France           1
# Oscar mayer                         1
# Indian Tonic                        1
# Oasis tropical                      1
# SCHWEPPES                           1
# Orangina - Schweppes                1
# Canada Dry                          1
# s.a schweppes international         1
# Name: count, dtype: int64

# %%
belgium_data['product_name'].value_counts().head(15)
product_names = (
    germany_data['product_name']
    .dropna()
    .str.strip()
    .str.lower()
)

product_counts = product_names.value_counts().head(15)

print(product_counts)
# Out:
# product_name
# bitter lemon            7
# dry tonic water         7
# tonic water             6
# wild berry              5
# indian tonic water      5
# ginger ale              5
# virgin mojito           4
# schweppes               4
# american ginger ale     4
# soda water              3
# russian wild berry      3
# indian tonic            3
# schweppes ginger ale    3
# white peach             3
# ginger beer             2
# Name: count, dtype: int64

# %%
belgium_data['categories_tags'].value_counts()
# Out:
# categories_tags
# beverages, carbonated-drinks, sodas, sweetened-beverages                                                                                                                                                                                                 6
# beverages, carbonated-drinks, sodas                                                                                                                                                                                                                      5
# beverages, carbonated-drinks, sodas, tonic-water, sweetened-beverages                                                                                                                                                                                    4
# ...

# %%
categories = (
    belgium_data['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

category_counts = categories.value_counts().head(15)

print(category_counts)
# Out:
# categories_tags
# beverages                               85
# carbonated-drinks                       67
# sodas                                   64
# sweetened-beverages                     60
# artificially-sweetened-beverages        36
# plant-based-foods-and-beverages         32
# plant-based-beverages                   31
# beverages-and-beverages-preparations    28
# fruit-based-beverages                   26
# fruit-sodas                             21
# tonic-water                             19
# diet-beverages                          17
# diet-sodas                              14
# non-alcoholic-beverages                  9
# iced-teas                                6
# Name: count, dtype: int64

# %%
belgium_data['packaging_tags'].value_counts()
# Out:
# packaging_tags
# plastic, bottle                                                                                                                  9
# can, drink-can                                                                                                                   4
# bottle                                                                                                                           3
# bouteille-en-plastique                                                                                                           3
# plastic                                                                                                                          3
# boite-alu                                                                                                                        3
# bouteille-plastique                                                                                                              2
# ...

# %%
packaging = (
    belgium_data['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

packaging_counts = packaging.value_counts().head(15)

print(packaging_counts)
# Out:
# categories_tags
# beverages                               85
# carbonated-drinks                       67
# sodas                                   64
# sweetened-beverages                     60
# artificially-sweetened-beverages        36
# plant-based-foods-and-beverages         32
# plant-based-beverages                   31
# beverages-and-beverages-preparations    28
# fruit-based-beverages                   26
# fruit-sodas                             21
# tonic-water                             19
# diet-beverages                          17
# diet-sodas                              14
# non-alcoholic-beverages                  9
# iced-teas                                6
# Name: count, dtype: int64

# %%
belgium_data['stores'].value_counts()
# Out:
# stores
# Carrefour                                         7
# Delhaize                                          5
# Magasins U, Delhaize, carrefour.fr                2
# Cora,Leclerc,Magasins U,Delhaize, carrefour.fr    1
# carrefour.fr                                      1
# Magasins U,Delhaize                               1
# Magasins U,Delhaize,carrefour.fr                  1
# Magasins U,Delhaize,Intermarché,carrefour.fr      1
# Colruyt,Okay                                      1
# Banque alimentaire, Delhaize                      1
# Leclerc,Magasins U,Delhaize, carrefour.fr         1
# Leclerc, Magasins U, Delhaize, carrefour.fr       1
# Leclerc                                           1
# delhaize, carrefour.fr                            1
# Franprix,Magasins U,carrefour.fr                  1
# Casino                                            1
# Cora,Magasins U, Delhaize, carrefour.fr           1
# Magasins U, carrefour.fr                          1
# ...

# %%
stores = (
    belgium_data['stores']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

store_counts = stores.value_counts().head(8)

print(store_counts)
# Out:
# stores
# Delhaize        15
# carrefour.fr    14
# Magasins U      13
# Carrefour        7
# Leclerc          4
# Intermarché      2
# Cora             2
# leclerc          1
# Name: count, dtype: int64

# %%
belgium_data['purchase_places'].value_counts()
# Out:
# purchase_places
# France                         5
# Marche en Famenne              4
# Belgique                       3
# Aix-en-Provence,France         2
# Marche en famenne              2
# Conflans-Sainte-Honorine       1
# France,Dolus d'Oléron          1
# België                         1
# Villers Bocage 80260,France    1
# Orvault,France                 1
# Courrières,France,Orvault      1
# temse,belgium                  1
# Lyon,France                    1
# Courrières,France              1
# Niort,France                   1
# Paris,France                   1
# Toulouse,France                1
# Name: count, dtype: int64

# %%
purchase_places = (
    belgium_data['purchase_places']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

purchase_places_counts = purchase_places.value_counts().head(8)

print(purchase_places_counts)
# Out:
# purchase_places
# France                      16
# Marche en Famenne            4
# Belgique                     3
# Courrières                   2
# Marche en famenne            2
# Orvault                      2
# Aix-en-Provence              2
# Conflans-Sainte-Honorine     1
# Name: count, dtype: int64

# %%
belgium_data['nutriscore_grade'].value_counts()
# Out:
# nutriscore_grade
# unknown    47
# e          30
# c          20
# d          16
# b           1
# a           1
# Name: count, dtype: int64

# %%
belgium_data['nova_group'].value_counts()
# Out:
# nova_group
# 4.0    65
# 1.0     2
# Name: count, dtype: int64

# %%
belgium_data['ecoscore_grade'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.ecoscore_grade.value_counts()
# Out:
# ecoscore_grade
# unknown           154
# not-applicable     74
# d                   1
# a                   1
# Name: count, dtype: int64

# %%
belgium_data['ingredients_text'].value_counts()
# Out:
# ingredients_text
# eau gazéifiée, sucre, acidifiant : acide citrique, arôme naturels, arôme : quinine, édulcorants : acesulfame K et sucralose.                                                                                                                                                                                                                                    1
# infusion de thé vert 94% (eau, infusion intense de thé vert), sucre, acidifiants:acide malique et acide citrique, correcteur d'acidité : citrate de sodium, arôme naturel, antioxydant : acide ascorbique.                                                                                                                                                      1
# ...

# %%
brands = (
    belgium_data['brands']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

top_brands = brands.value_counts().head(5)

plt.figure(figsize=(12,7))
sb.barplot(y=top_brands.index, x=top_brands.values)

plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.title("Top Individual Brands in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:-
#
# Schweppes overwhelmingly dominates the dataset with close to 100 products.
# The next brands, such as Orangina Schweppes, Orangina Schweppes France, May Tea, and Orangina, have only a small number of products.
# Observation: There is a very strong brand concentration, with Schweppes representing the majority of products.

# %%
product_names = (
    belgium_data['product_name']
    .dropna()
    .str.strip()
    .str.lower()
)

top_products = product_names.value_counts().head(10)

# Display with proper capitalization
top_products.index = top_products.index.str.title()

plt.figure(figsize=(12,7))
sb.barplot(y=top_products.index, x=top_products.values)

plt.xlabel("Number of Products")
plt.ylabel("Product Name")
plt.title("Top Product Names in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Indian Tonic is the most frequently occurring product name.
# Schweppes Indian Tonic and Schweppes Agrumes follow.
# Other common products include Botanical Brew, Virgin Mojito, Indian Tonic Zero, Schweppes Pink Zero, and Soda Water.
# Observation: The product list is heavily focused on tonic waters, sodas, and other non-alcoholic beverages.

# %%
categories = (
    belgium_data['categories_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

top_categories = categories.value_counts().head(15)

plt.figure(figsize=(12,7))
sb.barplot(y=top_categories.index, x=top_categories.values)

plt.xlabel("Number of Products")
plt.ylabel("Category")
plt.title("Top Individual Categories in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Beverages are by far the largest product category, with around 80+ products.
# Carbonated drinks, sodas, and sweetened beverages are also highly represented.
# Plant-based beverages/foods and fruit-based beverages appear frequently.
# Observation: The Belgian dataset is strongly concentrated in the beverage sector, especially soft drinks and carbonated beverages.

# %%
stores = (
    belgium_data['stores']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

top_stores = stores.value_counts().head(15)

plt.figure(figsize=(12,7))
sb.barplot(y=top_stores.index, x=top_stores.values)

plt.xlabel("Number of Products")
plt.ylabel("Store")
plt.title("Top 15 Individual Stores in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# The results again show Delhaize as the leading store.
# Carrefour.fr and Magasins U are the next strongest contributors.
# Most of the remaining stores have only 1–7 products, indicating a steep drop after the top three.
# Observation: The Belgian dataset is dominated by a small number of store sources.

# %%
ingredients = (
    belgium_data['ingredients_text']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

top_ingredients = ingredients.value_counts().head(8)

plt.figure(figsize=(12,8))
sb.barplot(y=top_ingredients.index, x=top_ingredients.values)

plt.xlabel("Number of Occurrences")
plt.ylabel("Ingredient")
plt.title("Top Individual Ingredients in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Carbonated water (eau gazéifiée) is the most frequently occurring ingredient, with more than 40 occurrences.
# Sugar is the second most common ingredient.
# Citric acid and natural flavours also occur frequently.
# Other common ingredients include modified starch, potassium sorbate, ascorbic acid, and sweeteners.
# Observation: Many products are beverages and processed drinks containing sugar, flavourings, acidity regulators, preservatives, and sweeteners.

# %%
nutri = belgium_data['nutriscore_grade'].value_counts()

order = ['a', 'b', 'c', 'd', 'e']

plt.figure(figsize=(8,5))

sb.barplot(
    x=nutri.index,
    y=nutri.values,
    order=[x for x in order if x in nutri.index]
)

plt.xlabel("Nutri-Score Grade")
plt.ylabel("Number of Products")
plt.title("Nutri-Score Grade Distribution in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Nutri-Score E is the most common grade, with approximately 29 products.
# Nutri-Score C is the second most common, followed by D.
# Very few products have grades A or B.
# Observation: The overall nutritional profile of the products appears relatively poor, with a large proportion receiving lower Nutri-Score grades.

# %%
nova = belgium_data['nova_group'].value_counts()

plt.figure(figsize=(8,5))
sb.barplot(x=nova.index, y=nova.values)

plt.xlabel("NOVA Group")
plt.ylabel("Number of Products")
plt.title("NOVA Group Distribution in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# The dataset is overwhelmingly dominated by NOVA Group 4, with around 65 products.
# Only a very small number of products belong to NOVA Group 1.
# Observation: Most products in the Belgian dataset are ultra-processed foods, according to the NOVA classification.

# %%
packaging = (
    belgium_data['packaging_tags']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

top_packaging = packaging.value_counts().head(15)

plt.figure(figsize=(12,7))
sb.barplot(y=top_packaging.index, x=top_packaging.values)

plt.xlabel("Number of Products")
plt.ylabel("Packaging")
plt.title("Top 15 Individual Packaging Types in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observations :-
#
# Plastic is the most common packaging type, with approximately 21 products.
# Bottle is the second most common, followed by can and drink-can.
# Other frequent types include plastic bottles, metal, film, and glass.
# Observation: Plastic and bottle-based packaging dominate the product dataset, showing a strong dependence on conventional packaging materials.

# %%
store_product = (
    belgium_data[['stores', 'product_name']]
    .dropna(subset=['stores'])
    .copy()
)

store_product['stores'] = store_product['stores'].str.split(',')
store_product = store_product.explode('stores')

store_product['stores'] = store_product['stores'].str.strip().str.lower()

store_variety = (
    store_product.groupby('stores')['product_name']
    .nunique()
    .sort_values(ascending=False)
    .head(15)
)

plt.figure(figsize=(12,7))
sb.barplot(y=store_variety.index, x=store_variety.values)

plt.xlabel("Number of Unique Products")
plt.ylabel("Store")
plt.title("Stores with Highest Product Variety in Belgium")
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation :-
#
# Delhaize has the highest product variety, with about 17 unique products.
# Carrefour.fr and Magasins U follow with around 14 and 13 products.
# Carrefour and Leclerc show moderate variety.
# Stores such as Casino, Colruyt, Okay, Franprix, and E.Leclerc have comparatively fewer unique products.
# Observation: Product availability is concentrated mainly among a few large retail stores.

# %%
switzerland_data=df[df['countries_tags'].str.contains('switzerland', case=False, na=False)]
switzerland_data
# Out:
#                code                          product_name  \
# 19    3124480001429           Schweppes Zero INDIAN TONIC
# 27    3124480002570                             Schweppes
# 55    3124480170132                      Schweppes Agrum'
# 84    3124480182722                          Indian Tonic
# 86    3124480182746                          Tonic Indian
# 137   3124480235558                          Mon Tropical
# 177   4000140072178                           Tonic Water
# 229   5410221305085                      Schweppes Agrum'
# 242   5449000044730                   Schweppes Tangerine
# 271   7610238000203  The Original Indian Tonic (6 x 10cl)
# 272   7610238227136           Schweppes Grapefruit fusion
# 273   7610238230617                      Schweppes Citrus
# 274   7610238272303                    The Original Lemon
# 275   7610238272310                  Schweppes Ginger Ale
# 276   7610238300358                             Schweppes
# ...

# %%
switzerland_data['brands'].value_counts()
# Out:
# brands
# Schweppes                                     42
# schweppes                                      3
# SCHWEPPES                                      2
# unknown                                        2
# Orangina Schweppes, Schweppes                  1
# Oasis,Oasis tropical,Orangina Schweppes        1
# Oasis, Orangina Schweppes France               1
# Schweppes, Schweppes International Limited     1
# Name: count, dtype: int64

# %%
brands = (
    switzerland_data['brands']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
)

brand_counts = brands.value_counts()

print(brand_counts)
# Out:
# brands
# Schweppes                          44
# schweppes                           3
# Orangina Schweppes                  2
# Oasis                               2
# SCHWEPPES                           2
# unknown                             2
# Oasis tropical                      1
# Orangina Schweppes France           1
# Schweppes International Limited     1
# Name: count, dtype: int64

# %%
brands = (
    switzerland_data['brands']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

brand_counts = brands.value_counts()

print(brand_counts)
# Out:
# brands
# schweppes                          49
# orangina schweppes                  2
# oasis                               2
# unknown                             2
# oasis tropical                      1
# orangina schweppes france           1
# schweppes international limited     1
# Name: count, dtype: int64

# %%
switzerland_data['product_name'].value_counts().head(10)
# Out:
# product_name
# Schweppes                           3
# Schweppes Indian Tonic              3
# Bitter Lemon                        3
# Schweppes Ginger Ale                2
# Schweppes Agrum'                    2
# unknown                             2
# Limone                              2
# Schweppes Citrus                    2
# Schweppes selection Hibiscus        1
# Schweppes the original Russchian    1
# Name: count, dtype: int64

# %%
switzerland_data['categories_tags'].value_counts()
# Out:
# categories_tags
# unknown                                                                                                                                                                                                                                                                                                                      13
# beverages, carbonated-drinks, sodas, sweetened-beverages                                                                                                                                                                                                                                                                      4
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages                                                                                                                                                                                                                                3
# ...

# %%
switzerland_data['stores'].value_counts()
# Out:
# stores
# unknown                             48
# Carrefour                            1
# Franprix,Magasins U,carrefour.fr     1
# Colruyt,Okay                         1
# Le Marché des Corbeaux               1
# Coop                                 1
# Name: count, dtype: int64

# %%
stores = (
    switzerland_data['stores']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
)

store_counts = stores.value_counts()

print(store_counts)
# Out:
# stores
# unknown                   48
# carrefour                  1
# franprix                   1
# magasins u                 1
# carrefour.fr               1
# colruyt                    1
# okay                       1
# le marché des corbeaux     1
# coop                       1
# Name: count, dtype: int64

# %%
switzerland_data['ingredients_text'].value_counts()
# Out:
# ingredients_text
# unknown                                                                                                                                                                                                                                                                                                                                                                                             20
# Acqua, succhi di frutti da concentrato 12% (limone 11%, pompelmo 1%), zucchero, anidride carbonica, aroma naturale limone con altri aromi naturali, acidificante: acido citrico, correttore di acidità: sodio citrato, conservante: potassio sorbato.                                                                                                                                                2
# ...

# %%
switzerland_data['nutriscore_grade'].value_counts()
# Out:
# nutriscore_grade
# unknown    20
# e          18
# d           8
# c           6
# b           1
# Name: count, dtype: int64

# %%
switzerland_data['ecoscore_grade'].value_counts()
# Out:
# ecoscore_grade
# unknown           52
# not-applicable     1
# Name: count, dtype: int64

# %%
switzerland_data['nova_group'].value_counts()
# Out:
# nova_group
# 4.0        32
# unknown    21
# Name: count, dtype: int64

# %%
sugar = switzerland_data['nutriments.sugars_100g'].dropna()

print(sugar.describe())
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: nutriments.sugars_100g, dtype: float64
