# %%
# 0. IMPORT REQUIRED LIBRARIES


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

from IPython.display import display

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", 120)

sns.set_theme(style="whitegrid")

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
from pathlib import Path

filename = "fanta_5_countries_cleaned.csv"
data_path = None

for root in [Path.cwd(), *Path.cwd().parents]:
    for folder in [root / "DataSets", root / "Datasets", root / "data"]:
        candidate = folder / filename
        if candidate.exists():
            data_path = candidate
            break
    if data_path is not None:
        break

if data_path is None:
    raise FileNotFoundError(
        f"Could not find {filename}. Current working directory: {Path.cwd()}"
    )

df = pd.read_csv(data_path)

print("Dataset loaded successfully.")
print("Loaded from:", data_path.resolve())
print("Shape:", df.shape)

display(df.head())



print("Dataset loaded successfully.")
print("Shape:", df.shape)

display(df.head())
# Out:
# Dataset loaded successfully.
# Loaded from: C:\Users\Mokshda\OneDrive\Desktop\Codons_Project\project\datasets\fanta_5_countries_cleaned.csv
# Shape: (1059, 14)
#            code                                      product_name  \
# 0   24622511676                   Pepe's, Fantastico Chicharrones
# 1   35266007265              Tastee, White Pretzel Wonder Fantasy
# 2   41321016141                  Fantastico light cheese dressing
# 3   41497131815                              Oriental Fantasy Mix
# 4  481290024608  Truffle Fantaisie Cacao Powdered Truffles, Plain
#
#                         brands  \
# 0  Rudolph Foods Company  Inc.
# 1           Tastee Apple  Inc.
# 2                  Bernstein's
# 3    Weis,  Weis Markets  Inc.
# 4     Alaus Mathez Chocolatier
#
#                                                                          categories_tags  \
# 0                                                                                Unknown
# 1  plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods
# 2                                         condiments, sauces, salad-dressings, groceries
# 3                                                                              undefined
# 4                                                                                Unknown
#
#   countries_tags packaging_tags   stores purchase_places nutriscore_grade  \
# 0  united-states        Unknown  Unknown         Unknown          unknown
# 1  united-states        Unknown  Unknown         Unknown                d
# 2  united-states        Unknown  Unknown         Unknown                d
# 3  united-states        Unknown  Unknown         Unknown                d
# 4  united-states        Unknown  Unknown         Unknown          unknown
#
#   nova_group ecoscore_grade  \
# 0    Unknown        unknown
# 1        4.0        unknown
# 2        4.0        Unknown
# 3        3.0        Unknown
# 4        4.0        unknown
#
#                                                                                                           ingredients_text  \
# 0                                                                                       Pork fat with attached skin, salt.
# 1  Apple, caramel (corn syrup, sugar, condensed milk (milk, sucrose), hydrogenated palm oil, evaporated milk (disodium ...
# 2  Water, distilled vinegar, soybean oil, salt, maltodextrin, parmesan cheese (pasteurized part skim milk, cheese cultu...
# 3  ROASTED & SALTED (ALMONDS, SPANISH PEANUTS, CASHEWS, SOY NUTS), ROASTED NO SALT (PUMPKIN SEEDS SHELLED), CORN NUTS, ...
# 4  Vegetable fats (coconut, palm kernel), sugar, fat reduced cocoa powder, whey powder, cocoa powder, emulsifier: soya ...
#
#   nutriments.sugars_100g nutriments.energy-kcal_100g
# 0                Unknown                       571.0
# 1                  28.57                       232.0
# 2                   3.23                       80.65
# 3                   12.7                      1950.0
# 4                   42.5                       575.0
# Dataset loaded successfully.
# Shape: (1059, 14)
#            code                                      product_name  \
# 0   24622511676                   Pepe's, Fantastico Chicharrones
# 1   35266007265              Tastee, White Pretzel Wonder Fantasy
# 2   41321016141                  Fantastico light cheese dressing
# 3   41497131815                              Oriental Fantasy Mix
# 4  481290024608  Truffle Fantaisie Cacao Powdered Truffles, Plain
#
#                         brands  \
# 0  Rudolph Foods Company  Inc.
# 1           Tastee Apple  Inc.
# 2                  Bernstein's
# 3    Weis,  Weis Markets  Inc.
# 4     Alaus Mathez Chocolatier
#
#                                                                          categories_tags  \
# 0                                                                                Unknown
# 1  plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods
# 2                                         condiments, sauces, salad-dressings, groceries
# 3                                                                              undefined
# 4                                                                                Unknown
#
#   countries_tags packaging_tags   stores purchase_places nutriscore_grade  \
# 0  united-states        Unknown  Unknown         Unknown          unknown
# 1  united-states        Unknown  Unknown         Unknown                d
# 2  united-states        Unknown  Unknown         Unknown                d
# 3  united-states        Unknown  Unknown         Unknown                d
# 4  united-states        Unknown  Unknown         Unknown          unknown
#
#   nova_group ecoscore_grade  \
# 0    Unknown        unknown
# 1        4.0        unknown
# 2        4.0        Unknown
# 3        3.0        Unknown
# 4        4.0        unknown
#
#                                                                                                           ingredients_text  \
# 0                                                                                       Pork fat with attached skin, salt.
# 1  Apple, caramel (corn syrup, sugar, condensed milk (milk, sucrose), hydrogenated palm oil, evaporated milk (disodium ...
# 2  Water, distilled vinegar, soybean oil, salt, maltodextrin, parmesan cheese (pasteurized part skim milk, cheese cultu...
# 3  ROASTED & SALTED (ALMONDS, SPANISH PEANUTS, CASHEWS, SOY NUTS), ROASTED NO SALT (PUMPKIN SEEDS SHELLED), CORN NUTS, ...
# 4  Vegetable fats (coconut, palm kernel), sugar, fat reduced cocoa powder, whey powder, cocoa powder, emulsifier: soya ...
#
#   nutriments.sugars_100g nutriments.energy-kcal_100g
# 0                Unknown                       571.0
# 1                  28.57                       232.0
# 2                   3.23                       80.65
# 3                   12.7                      1950.0
# 4                   42.5                       575.0

# %%
# 2. INITIAL INSPECTION


print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Types:")
display(df.dtypes)

print("\nFirst 5 Records:")
display(df.head())

print("\nDuplicate Rows:", df.duplicated().sum())

print("\nMissing Values:")
display(df.isna().sum().sort_values(ascending=False).to_frame("Missing_Count"))
# Out:
# Dataset Shape: (1059, 14)
#
# Column Names:
# ['code', 'product_name', 'brands', 'categories_tags', 'countries_tags', 'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade', 'nova_group', 'ecoscore_grade', 'ingredients_text', 'nutriments.sugars_100g', 'nutriments.energy-kcal_100g']
#
# Data Types:
# code                           object
# product_name                      str
# brands                            str
# categories_tags                   str
# countries_tags                    str
# packaging_tags                    str
# stores                            str
# purchase_places                   str
# nutriscore_grade                  str
# nova_group                        str
# ecoscore_grade                    str
# ingredients_text                  str
# nutriments.sugars_100g            str
# nutriments.energy-kcal_100g       str
# dtype: object
# First 5 Records:
#            code                                      product_name  \
# 0   24622511676                   Pepe's, Fantastico Chicharrones
# 1   35266007265              Tastee, White Pretzel Wonder Fantasy
# 2   41321016141                  Fantastico light cheese dressing
# 3   41497131815                              Oriental Fantasy Mix
# 4  481290024608  Truffle Fantaisie Cacao Powdered Truffles, Plain
#
#                         brands  \
# 0  Rudolph Foods Company  Inc.
# 1           Tastee Apple  Inc.
# 2                  Bernstein's
# 3    Weis,  Weis Markets  Inc.
# 4     Alaus Mathez Chocolatier
#
#                                                                          categories_tags  \
# 0                                                                                Unknown
# 1  plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods
# 2                                         condiments, sauces, salad-dressings, groceries
# 3                                                                              undefined
# 4                                                                                Unknown
#
#   countries_tags packaging_tags   stores purchase_places nutriscore_grade  \
# 0  united-states        Unknown  Unknown         Unknown          unknown
# 1  united-states        Unknown  Unknown         Unknown                d
# 2  united-states        Unknown  Unknown         Unknown                d
# 3  united-states        Unknown  Unknown         Unknown                d
# 4  united-states        Unknown  Unknown         Unknown          unknown
#
#   nova_group ecoscore_grade  \
# 0    Unknown        unknown
# 1        4.0        unknown
# 2        4.0        Unknown
# 3        3.0        Unknown
# 4        4.0        unknown
#
#                                                                                                           ingredients_text  \
# 0                                                                                       Pork fat with attached skin, salt.
# 1  Apple, caramel (corn syrup, sugar, condensed milk (milk, sucrose), hydrogenated palm oil, evaporated milk (disodium ...
# 2  Water, distilled vinegar, soybean oil, salt, maltodextrin, parmesan cheese (pasteurized part skim milk, cheese cultu...
# 3  ROASTED & SALTED (ALMONDS, SPANISH PEANUTS, CASHEWS, SOY NUTS), ROASTED NO SALT (PUMPKIN SEEDS SHELLED), CORN NUTS, ...
# 4  Vegetable fats (coconut, palm kernel), sugar, fat reduced cocoa powder, whey powder, cocoa powder, emulsifier: soya ...
#
#   nutriments.sugars_100g nutriments.energy-kcal_100g
# 0                Unknown                       571.0
# 1                  28.57                       232.0
# 2                   3.23                       80.65
# 3                   12.7                      1950.0
# 4                   42.5                       575.0
# Duplicate Rows: 0
#
# Missing Values:
#                              Missing_Count
# code                                     0
# product_name                             0
# brands                                   0
# categories_tags                          0
# countries_tags                           0
# packaging_tags                           0
# stores                                   0
# purchase_places                          0
# nutriscore_grade                         0
# nova_group                               0
# ecoscore_grade                           0
# ingredients_text                         0
# nutriments.sugars_100g                   0
# nutriments.energy-kcal_100g              0

# %% [markdown]
# ## 3. STANDARDIZE MISSING VALUES

# %%
# Replace actual null values
df = df.fillna("Unknown")

# Replace empty and whitespace-only strings
for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].replace(
            r"^\s*$",
            "Unknown",
            regex=True
        )

print("Null/blank values have been replaced with 'Unknown'.")
print("Remaining NaN values:", df.isna().sum().sum())
# Out:
# Null/blank values have been replaced with 'Unknown'.
# Remaining NaN values: 0

# %%
# 4. COMPLETE ATTRIBUTE PROFILE
attribute_profile = pd.DataFrame({
    "Attribute": df.columns,
    "Data_Type": [df[c].dtype for c in df.columns],
    "Unique_Values": [df[c].nunique(dropna=False) for c in df.columns],
    "Unknown_Count": [
        df[c].astype(str).str.strip().str.lower().eq("unknown").sum()
        for c in df.columns
    ]
})

attribute_profile["Unknown_Percentage"] = (
    attribute_profile["Unknown_Count"] / len(df) * 100
).round(2)

display(attribute_profile)
# Out:
#                       Attribute Data_Type  Unique_Values  Unknown_Count  \
# 0                          code    object           1058              0
# 1                  product_name       str            823             10
# 2                        brands       str            243            179
# 3               categories_tags       str            167            533
# 4                countries_tags       str              5              0
# 5                packaging_tags       str             30            990
# 6                        stores       str             28           1015
# 7               purchase_places       str              9           1045
# 8              nutriscore_grade       str              8            624
# 9                    nova_group       str              4            888
# 10               ecoscore_grade       str              5           1036
# 11             ingredients_text       str            196            632
# 12       nutriments.sugars_100g       str            170            660
# 13  nutriments.energy-kcal_100g       str            194            652
#
#     Unknown_Percentage
# 0                 0.00
# 1                 0.94
# 2                16.90
# 3                50.33
# 4                 0.00
# 5                93.48
# 6                95.85
# 7                98.68
# 8                58.92
# 9                83.85
# 10               97.83
# 11               59.68
# 12               62.32
# 13               61.57

# %% [markdown]
# ## 5. PREPARE NUMERICAL ATTRIBUTES

# %%
numeric_source_columns = [
    "nutriments.sugars_100g",
    "nutriments.energy-kcal_100g",
    "nova_group"
]

for col in numeric_source_columns:
    if col in df.columns:
        df[col + "_num"] = pd.to_numeric(
            df[col],
            errors="coerce"
        )

# If numeric columns already existed from previous preprocessing,
# preserve/use them.
if "nutriments.sugars_100g_num" not in df.columns:
    if "nutriments.sugars_100g" in df.columns:
        df["nutriments.sugars_100g_num"] = pd.to_numeric(
            df["nutriments.sugars_100g"], errors="coerce"
        )

if "nutriments.energy-kcal_100g_num" not in df.columns:
    if "nutriments.energy-kcal_100g" in df.columns:
        df["nutriments.energy-kcal_100g_num"] = pd.to_numeric(
            df["nutriments.energy-kcal_100g"], errors="coerce"
        )

if "nova_group_num" not in df.columns:
    if "nova_group" in df.columns:
        df["nova_group_num"] = pd.to_numeric(
            df["nova_group"], errors="coerce"
        )

print("Numeric analysis columns prepared.")
# Out:
# Numeric analysis columns prepared.

# %% [markdown]
# #  PART 1 — UNITED STATES

# %%
us_df = df[
    df["countries_tags"].astype(str).str.lower() == "united-states"
].copy()

print("UNITED STATES DATASET")
print("=" * 60)
print("Records:", len(us_df))
print("Attributes:", len(us_df.columns))
display(us_df.head())
# Out:
# UNITED STATES DATASET
# ============================================================
# Records: 435
# Attributes: 17
#            code                                      product_name  \
# 0   24622511676                   Pepe's, Fantastico Chicharrones
# 1   35266007265              Tastee, White Pretzel Wonder Fantasy
# 2   41321016141                  Fantastico light cheese dressing
# 3   41497131815                              Oriental Fantasy Mix
# 4  481290024608  Truffle Fantaisie Cacao Powdered Truffles, Plain
#
#                         brands  \
# 0  Rudolph Foods Company  Inc.
# 1           Tastee Apple  Inc.
# 2                  Bernstein's
# 3    Weis,  Weis Markets  Inc.
# 4     Alaus Mathez Chocolatier
#
#                                                                          categories_tags  \
# 0                                                                                Unknown
# 1  plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods
# 2                                         condiments, sauces, salad-dressings, groceries
# 3                                                                              undefined
# 4                                                                                Unknown
#
#   countries_tags packaging_tags   stores purchase_places nutriscore_grade  \
# 0  united-states        Unknown  Unknown         Unknown          unknown
# 1  united-states        Unknown  Unknown         Unknown                d
# 2  united-states        Unknown  Unknown         Unknown                d
# 3  united-states        Unknown  Unknown         Unknown                d
# 4  united-states        Unknown  Unknown         Unknown          unknown
#
#   nova_group ecoscore_grade  \
# 0    Unknown        unknown
# 1        4.0        unknown
# 2        4.0        Unknown
# 3        3.0        Unknown
# 4        4.0        unknown
#
#                                                                                                           ingredients_text  \
# 0                                                                                       Pork fat with attached skin, salt.
# 1  Apple, caramel (corn syrup, sugar, condensed milk (milk, sucrose), hydrogenated palm oil, evaporated milk (disodium ...
# 2  Water, distilled vinegar, soybean oil, salt, maltodextrin, parmesan cheese (pasteurized part skim milk, cheese cultu...
# 3  ROASTED & SALTED (ALMONDS, SPANISH PEANUTS, CASHEWS, SOY NUTS), ROASTED NO SALT (PUMPKIN SEEDS SHELLED), CORN NUTS, ...
# 4  Vegetable fats (coconut, palm kernel), sugar, fat reduced cocoa powder, whey powder, cocoa powder, emulsifier: soya ...
#
#   nutriments.sugars_100g nutriments.energy-kcal_100g  \
# 0                Unknown                       571.0
# 1                  28.57                       232.0
# 2                   3.23                       80.65
# 3                   12.7                      1950.0
# 4                   42.5                       575.0
#
#    nutriments.sugars_100g_num  nutriments.energy-kcal_100g_num  nova_group_num
# 0                         NaN                           571.00             NaN
# 1                       28.57                           232.00             4.0
# 2                        3.23                            80.65             4.0
# 3                       12.70                          1950.00             3.0
# 4                       42.50                           575.00             4.0

# %% [markdown]
# ### United States — Detailed Attribute, Nutritional and Quality Analysis

# %%
# UNITED STATES — UNKNOWN VALUE ANALYSIS


us_unknown_summary = []

for col in us_df.columns:
    unknown_count = (
        us_df[col].astype(str)
        .str.strip()
        .str.lower()
        .eq("unknown")
        .sum()
    )

    us_unknown_summary.append({
        "Attribute": col,
        "Unknown_Count": unknown_count,
        "Total_Records": len(us_df),
        "Unknown_Percentage": round(
            unknown_count / len(us_df) * 100, 2
        )
    })

us_unknown_df = pd.DataFrame(us_unknown_summary).sort_values(
    "Unknown_Percentage", ascending=False
)

display(us_unknown_df)

plt.figure(figsize=(12, 6))
sns.barplot(data=us_unknown_df,
            x="Unknown_Percentage", y="Attribute")
plt.title("United States – Unknown Value Percentage by Attribute")
plt.xlabel("Unknown Values (%)")
plt.ylabel("Attribute")
plt.tight_layout()
plt.show()
# Out:
#                           Attribute  Unknown_Count  Total_Records  \
# 6                            stores            435            435
# 7                   purchase_places            434            435
# 5                    packaging_tags            429            435
# 10                   ecoscore_grade            428            435
# 9                        nova_group            381            435
# 8                  nutriscore_grade            174            435
# 3                   categories_tags            152            435
# 11                 ingredients_text            146            435
# 12           nutriments.sugars_100g            109            435
# 13      nutriments.energy-kcal_100g            103            435
# 2                            brands             49            435
# 1                      product_name              3            435
# 0                              code              0            435
# 4                    countries_tags              0            435
# 14       nutriments.sugars_100g_num              0            435
# 15  nutriments.energy-kcal_100g_num              0            435
# 16                   nova_group_num              0            435
#
#     Unknown_Percentage
# 6               100.00
# 7                99.77
# 5                98.62
# 10               98.39
# 9                87.59
# 8                40.00
# 3                34.94
# 11               33.56
# 12               25.06
# 13               23.68
# 2                11.26
# 1                 0.69
# 0                 0.00
# 4                 0.00
# 14                0.00
# 15                0.00
# 16                0.00

# %% [markdown]
# ###  Observation
#
# The chart shows that several fields have a lot of missing information. In the United States data, **stores, purchase places, packaging and Eco-Score** have very high numbers of `Unknown` values. Brand and product name information is more complete. This means the analysis of nutritional and retail attributes should be treated carefully because some fields have limited information.

# %%
# 
# UNITED STATES — PRODUCT ANALYSIS
# 

us_product_counts = (
    us_df["product_name"].value_counts().reset_index()
)
us_product_counts.columns = ["Product_Name", "Frequency"]

print("Top 20 Products:")
display(us_product_counts.head(20))

print("Total Product Records:", len(us_df))
print("Unique Products:", us_df["product_name"].nunique())
print(
    "Product Uniqueness Rate:",
    round(us_df["product_name"].nunique() / len(us_df) * 100, 2),
    "%"
)

plt.figure(figsize=(12, 7))
sns.barplot(data=us_product_counts.head(15),
            x="Frequency", y="Product_Name")
plt.title("United States – Top 15 Products")
plt.xlabel("Number of Records")
plt.ylabel("Product")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Products:
#                              Product_Name  Frequency
# 0                                   Fanta         11
# 1                            Fanta orange          5
# 2                             Orange soda          3
# 3                        Strawberry Fanta          3
# 4                                 Unknown          3
# 5                        Tropical Fantasy          3
# 6                        Tropical fantasy          3
# 7                             Fantasy Mix          3
# 8   Monster Energy Ultra Fantasy Ruby Red          3
# 9                      Fantasy Sour Belts          2
# 10            Fantastic Classic Lollipops          2
# 11                Fanta zero sugar orange          2
# 12                              Pineapple          2
# 13                            ORANGE SODA          2
# 14                        Pineapple Fanta          2
# 15                    Hi-Chew Fantasy Mix          2
# 16                     Truffles Fantaisie          2
# 17  McDonald's, Fanta Orange, Extra Small          2
# 18        McDonald's, Fanta Orange, Large          2
# 19       McDonald's, Fanta Orange, Medium          2
# Total Product Records: 435
# Unique Products: 338
# Product Uniqueness Rate: 77.7 %

# %% [markdown]
# ###  Observation
#
# The product chart shows that **Fanta is the most frequently recorded product** in the United States data. Most of the other products appear only a few times, so the product list is quite varied even though a few products occur repeatedly.

# %%
# UNITED STATES — BRAND ANALYSIS


us_brand_counts = (
    us_df["brands"].value_counts().reset_index()
)
us_brand_counts.columns = ["Brand", "Product_Count"]

print("Top 20 Brands:")
display(us_brand_counts.head(20))

print("Unique Brands:", us_df["brands"].nunique())

us_brand_diversity = (
    us_df["brands"].nunique() / len(us_df) * 100
)
print("Brand Diversity Ratio:", round(us_brand_diversity, 2), "%")

plt.figure(figsize=(12, 7))
sns.barplot(data=us_brand_counts.head(15),
            x="Product_Count", y="Brand")
plt.title("United States – Top 15 Brands")
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Brands:
#                Brand  Product_Count
# 0              Fanta             76
# 1     Firehouse Subs             72
# 2            Unknown             49
# 3            Zaxby's             32
# 4       White Castle             30
# 5        Whataburger             14
# 6   Church's Chicken             10
# 7              Sonic             10
# 8    Jack in the Box              8
# 9         McDonald's              8
# 10       Burger King              5
# 11        Applebee's              4
# 12          Del Taco              4
# 13           Popeyes              4
# 14         Red Robin              4
# 15      TGI Friday's              4
# 16           Wendy's              4
# 17         Fantastic              4
# 18             FANTA              3
# 19          Sunfeast              3
# Unique Brands: 88
# Brand Diversity Ratio: 20.23 %

# %% [markdown]
# ###  Observation
#
# The brand chart shows that **Fanta and Firehouse Subs** have the highest number of records in the United States data. There are also many products where the brand is recorded as `Unknown`, so the brand comparison does not cover every product equally.

# %%
# UNITED STATES — CATEGORY ANALYSIS


us_category_series = (
    us_df["categories_tags"].astype(str)
    .str.split(",").explode().str.strip()
)

us_category_series = us_category_series[
    us_category_series.str.lower() != "unknown"
]

us_category_counts = us_category_series.value_counts()

print("Top 25 Categories:")
display(us_category_counts.head(25))

us_top_categories = us_category_counts.head(15).reset_index()
us_top_categories.columns = ["Category", "Product_Count"]

plt.figure(figsize=(12, 8))
sns.barplot(data=us_top_categories,
            x="Product_Count", y="Category")
plt.title("United States – Top 15 Product Categories")
plt.xlabel("Product Count")
plt.ylabel("Category")
plt.tight_layout()
plt.show()
# Out:
# Top 25 Categories:
# categories_tags
# beverages                               257
# beverages-and-beverages-preparations    243
# carbonated-drinks                        19
# sodas                                    18
# plant-based-foods-and-beverages          13
# snacks                                   11
# sweet-snacks                             10
# confectioneries                           9
# plant-based-foods                         7
# plant-based-beverages                     6
# fruit-based-beverages                     5
# fruit-sodas                               5
# cereals-and-potatoes                      4
# cereals-and-their-products                4
# sweetened-beverages                       4
# cocoa-and-its-products                    3
# chocolate-candies                         3
# energy-drinks                             3
# fruits-and-vegetables-based-foods         2
# pastas                                    2
# artificially-sweetened-beverages          2
# entrees                                   2
# orange-soft-drinks                        2
# condiments                                1
# sauces                                    1
# Name: count, dtype: int64

# %% [markdown]
# ###  Observation
#
# The category chart is mainly made up of **beverages and beverage-related categories**. This makes sense for the dataset because many of the products are drinks. Smaller categories such as snacks, confectioneries and plant-based products are also present, but they occur much less often.

# %%
# UNITED STATES — PACKAGING, STORE AND PURCHASE PLACE


def analyze_multivalue_attribute(country_df, column, label):
    if column not in country_df.columns:
        print(f"Column not found: {column}")
        return pd.Series(dtype="int64")

    s = country_df[column].astype(str).str.split(",").explode().str.strip()
    s = s[s.str.lower() != "unknown"]
    counts = s.value_counts()

    print(f"Top {label}:")
    display(counts.head(20).to_frame("Count"))
    return counts

us_packaging_counts = analyze_multivalue_attribute(
    us_df, "packaging_tags", "Packaging Types"
)
us_store_counts = analyze_multivalue_attribute(
    us_df, "stores", "Stores"
)
us_purchase_counts = analyze_multivalue_attribute(
    us_df, "purchase_places", "Purchase Places"
)
# Out:
# Top Packaging Types:
#                 Count
# packaging_tags
# card-box            3
# plastic-bowl        1
# bottle              1
# hdpe-bottle         1
# paper-sleeve        1
# Top Stores:
# Empty DataFrame
# Columns: [Count]
# Index: []
# Top Purchase Places:
#                  Count
# purchase_places
# Maryland             1
# USA                  1

# %%
# UNITED STATES — NUTRI-SCORE, NOVA AND ECO-SCORE


for col, label in [
    ("nutriscore_grade", "Nutri-Score"),
    ("nova_group", "NOVA Group"),
    ("ecoscore_grade", "Eco-Score")
]:
    if col in us_df.columns:
        counts = us_df[col].value_counts()
        print(f"{label} Distribution:")
        display(counts)
        print(f"{label} Percentage:")
        display(us_df[col].value_counts(normalize=True).mul(100).round(2))

        plt.figure(figsize=(9, 5))
        sns.countplot(
            data=us_df,
            x=col,
            order=us_df[col].value_counts().index
        )
        plt.title(f"United States – {label} Distribution")
        plt.xlabel(label)
        plt.ylabel("Number of Products")
        plt.tight_layout()
        plt.show()
# Out:
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    174
# b          150
# e           54
# c           48
# d            8
# a            1
# Name: count, dtype: int64
# Nutri-Score Percentage:
# nutriscore_grade
# unknown    40.00
# b          34.48
# e          12.41
# c          11.03
# d           1.84
# a           0.23
# Name: proportion, dtype: float64
# NOVA Group Distribution:
# nova_group
# Unknown    381
# 4.0         51
# 3.0          2
# 1.0          1
# Name: count, dtype: int64
# NOVA Group Percentage:
# nova_group
# Unknown    87.59
# 4.0        11.72
# 3.0         0.46
# 1.0         0.23
# Name: proportion, dtype: float64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           346
# unknown            82
# not-applicable      3
# d                   2
# f                   2
# Name: count, dtype: int64
# Eco-Score Percentage:
# ecoscore_grade
# Unknown           79.54
# unknown           18.85
# not-applicable     0.69
# d                  0.46
# f                  0.46
# Name: proportion, dtype: float64

# %% [markdown]
# ###  Observation
#
# The Nutri-Score chart shows that **`Unknown` is a large part of the US data**, followed by grade **B**. Grade E is also noticeable, while grades A and D appear much less often. The high number of unknown scores means the Nutri-Score results should be interpreted with some caution.

# %%
# UNITED STATES — SUGAR AND ENERGY


us_sugar = us_df["nutriments.sugars_100g_num"].dropna()
us_energy = us_df["nutriments.energy-kcal_100g_num"].dropna()

print("Sugar Statistics:")
display(us_sugar.describe())

print("Energy Statistics:")
display(us_energy.describe())

plt.figure(figsize=(10, 6))
sns.histplot(us_sugar, bins=30, kde=True)
plt.title("United States – Sugar Distribution")
plt.xlabel("Sugar (g per 100g)")
plt.ylabel("Number of Products")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(us_energy, bins=30, kde=True)
plt.title("United States – Energy Distribution")
plt.xlabel("Energy (kcal per 100g)")
plt.ylabel("Number of Products")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
sns.boxplot(x=us_sugar)
plt.title("United States – Sugar Content Boxplot")
plt.xlabel("Sugar (g per 100g)")
plt.tight_layout()
plt.show()
# Out:
# Sugar Statistics:
# count    326.000000
# mean      14.707321
# std       29.361912
# min        0.000000
# 25%        1.050000
# 50%        2.000000
# 75%       12.675000
# max      254.000000
# Name: nutriments.sugars_100g_num, dtype: float64
# Energy Statistics:
# count      332.000000
# mean       182.620579
# std       1435.189239
# min          0.000000
# 25%          5.070000
# 50%          9.345000
# 75%        126.000000
# max      26000.000000
# Name: nutriments.energy-kcal_100g_num, dtype: float64

# %% [markdown]
# ###  Observation
#
# The sugar chart shows a wide spread in the United States data. The average sugar content is about **14.71 g per 100g**, while the median is only **2 g per 100g**. This large difference suggests that a few products with very high sugar values are pulling the average upward.

# %%
# UNITED STATES — SUGAR VS ENERGY


us_nutrition = us_df[
    ["nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"]
].dropna()

us_sugar_energy_corr = (
    us_nutrition["nutriments.sugars_100g_num"]
    .corr(us_nutrition["nutriments.energy-kcal_100g_num"])
)

print("Valid nutritional records:", len(us_nutrition))
print("Sugar–Energy Correlation:", round(us_sugar_energy_corr, 3))

plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=us_nutrition,
    x="nutriments.sugars_100g_num",
    y="nutriments.energy-kcal_100g_num",
    alpha=0.6
)
plt.title("United States – Sugar vs Energy")
plt.xlabel("Sugar (g per 100g)")
plt.ylabel("Energy (kcal per 100g)")
plt.tight_layout()
plt.show()
# Out:
# Valid nutritional records: 324
# Sugar–Energy Correlation: 0.062

# %% [markdown]
# ### 📝 Observation
#
# The scatter plot shows almost no clear linear relationship between sugar and energy in the United States data. The calculated correlation is only **0.062**, so higher sugar does not consistently mean higher energy in these records.

# %%
# UNITED STATES — OUTLIER ANALYSIS


def find_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return series[(series < lower) | (series > upper)]

us_sugar_outliers = find_outliers(us_sugar)
us_energy_outliers = find_outliers(us_energy)

print("Sugar Outliers:", len(us_sugar_outliers))
print("Energy Outliers:", len(us_energy_outliers))

print("\nHighest Sugar Products:")
display(
    us_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.sugars_100g_num"]
    ].dropna(subset=["nutriments.sugars_100g_num"])
     .sort_values("nutriments.sugars_100g_num", ascending=False)
     .head(20)
)

print("\nHighest Energy Products:")
display(
    us_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.energy-kcal_100g_num"]
    ].dropna(subset=["nutriments.energy-kcal_100g_num"])
     .sort_values("nutriments.energy-kcal_100g_num", ascending=False)
     .head(20)
)
# Out:
# Sugar Outliers: 62
# Energy Outliers: 52
#
# Highest Sugar Products:
#                                product_name        brands  \
# 808      Papa John's, Fanta Orange, 2 Liter   Papa John's
# 751      Papa John's, Fanta Orange, 2 Liter   Papa John's
# 764            Wendy's, Fanta Orange, Large       Wendy's
# 822            Wendy's, Fanta Orange, Large       Wendy's
# 817              Sonic, Fanta Orange, RT 44         Sonic
# 759              Sonic, Fanta Orange, RT 44         Sonic
# 333                        Tropical fantasy       Unknown
# 823           Wendy's, Fanta Orange, Medium       Wendy's
# 765           Wendy's, Fanta Orange, Medium       Wendy's
# 200                                16 Fl Oz         Fanta
# 462               Fantastic Classic Candies       Unknown
# 757              Sonic, Fanta Orange, Large         Sonic
# 815              Sonic, Fanta Orange, Large         Sonic
# 596             Fantastic Classic Lollipops     Hammond's
# 6               Fantastic Classic Lollipops     Hammond's
# 356                       Cranberry fantasy       Unknown
# 53   Hollow milk chocolate football fantasy       Unknown
# 762                     TGI Friday's, Fanta  TGI Friday's
# 820                     TGI Friday's, Fanta  TGI Friday's
# 973                             Fantasy Mix       Hi Chew
#
#                                                                       categories_tags  \
# 808                                   beverages-and-beverages-preparations, beverages
# 751                                   beverages-and-beverages-preparations, beverages
# 764                                   beverages-and-beverages-preparations, beverages
# 822                                   beverages-and-beverages-preparations, beverages
# 817                                   beverages-and-beverages-preparations, beverages
# 759                                   beverages-and-beverages-preparations, beverages
# 333                                                                           Unknown
# 823                                   beverages-and-beverages-preparations, beverages
# 765                                   beverages-and-beverages-preparations, beverages
# 200                                                                           Unknown
# 462                                    snacks, sweet-snacks, confectioneries, candies
# 757                                   beverages-and-beverages-preparations, beverages
# 815                                   beverages-and-beverages-preparations, beverages
# 596                                                                           Unknown
# 6                                               snacks, sweet-snacks, confectioneries
# 356                                                                           Unknown
# 53   snacks, sweet-snacks, cocoa-and-its-products, confectioneries, chocolate-candies
# 762                                   beverages-and-beverages-preparations, beverages
# 820                                   beverages-and-beverages-preparations, beverages
# 973                                                                           Unknown
#
#      nutriments.sugars_100g_num
# 808                  254.000000
# 751                  254.000000
# 764                  115.000000
# 822                  115.000000
# 817                  105.000000
# 759                  105.000000
# 333                  100.000000
# 823                   92.000000
# 765                   92.000000
# 200                   81.000000
# 462                   80.000000
# 757                   78.000000
# 815                   78.000000
# 596                   66.670000
# 6                     66.670000
# 356                   66.666667
# 53                    64.290000
# 762                   63.000000
# 820                   63.000000
# 973                   61.800000
# Highest Energy Products:
#                                                                            product_name  \
# 910                                                                      chucky's punch
# 3                                                                  Oriental Fantasy Mix
# 751                                                  Papa John's, Fanta Orange, 2 Liter
# 808                                                  Papa John's, Fanta Orange, 2 Liter
# 882                                                                  Truffles Fantaisie
# 51                                                 Arabica truffes cappuccino fantaisie
# 880                                                         Coeurs De Truffes Fantaisie
# 88                                                                      Fudge Fantasies
# 471                                                                   Truffes Fantaisie
# 4                                      Truffle Fantaisie Cacao Powdered Truffles, Plain
# 594                                                                  Truffles Fantaisie
# 0                                                       Pepe's, Fantastico Chicharrones
# 902                                                 Fantastik Vanilla Crème Water Rolls
# 222                                                    Dark Fantasy Choco Fills LUXURIA
# 55   Mini football fantasy hallow double crisp chocolaty'n smooth crisp'n crunchy candy
# 952                                                       Lightly Salted Plantain Chips
# 44                                     Fantasy cookie company, assorted holiday cookies
# 53                                               Hollow milk chocolate football fantasy
# 904                               Dark Fantasy Fantastik Choco Crème Filled Wafer Rolls
# 609                                                   Cheetos Fantastix! Ranch Flavored
#
#                           brands  \
# 910                        Fanta
# 3      Weis,  Weis Markets  Inc.
# 751                  Papa John's
# 808                  Papa John's
# 882                        Cémoi
# 51                       Unknown
# 880                       Guyaux
# 88                       Unknown
# 471                      Unknown
# 4       Alaus Mathez Chocolatier
# 594                      Unknown
# 0    Rudolph Foods Company  Inc.
# 902                 Dark Fantasy
# 222                     Sunfeast
# 55                       Unknown
# 952             Tropical Fantasy
# 44                       Unknown
# 53                       Unknown
# 904                     Sunfeast
# 609                      Cheetos
#
#                                                                       categories_tags  \
# 910                                                                           Unknown
# 3                                                                           undefined
# 751                                   beverages-and-beverages-preparations, beverages
# 808                                   beverages-and-beverages-preparations, beverages
# 882                                                                           Unknown
# 51   snacks, sweet-snacks, cocoa-and-its-products, confectioneries, chocolate-candies
# 880                                                                           Unknown
# 88                                                                            Unknown
# 471                                                                           Unknown
# 4                                                                             Unknown
# 594                                                                           Unknown
# 0                                                                             Unknown
# 902                                                                           Unknown
# 222                                                                           Unknown
# 55   snacks, sweet-snacks, cocoa-and-its-products, confectioneries, chocolate-candies
# 952                                                                           Unknown
# 44                                 snacks, sweet-snacks, biscuits-and-cakes, biscuits
# 53   snacks, sweet-snacks, cocoa-and-its-products, confectioneries, chocolate-candies
# 904                                                                           Unknown
# 609                                                                           Unknown
#
#      nutriments.energy-kcal_100g_num
# 910                     26000.000000
# 3                        1950.000000
# 751                      1020.000000
# 808                      1020.000000
# 882                       633.000000
# 51                        625.000000
# 880                       625.000000
# 88                        604.650000
# 471                       588.235294
# 4                         575.000000
# 594                       571.428571
# 0                         571.000000
# 902                       520.000000
# 222                       520.000000
# 55                        516.000000
# 952                       500.000000
# 44                        500.000000
# 53                        500.000000
# 904                       480.000000
# 609                       471.000000

# %%
# UNITED STATES — BRAND NUTRITION ANALYSIS


us_brand_nutrition = (
    us_df.groupby("brands")
    .agg(
        Product_Count=("product_name", "count"),
        Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
        Median_Sugar=("nutriments.sugars_100g_num", "median"),
        Avg_Energy=("nutriments.energy-kcal_100g_num", "mean"),
        Median_Energy=("nutriments.energy-kcal_100g_num", "median")
    )
    .reset_index()
)

us_brand_nutrition = (
    us_brand_nutrition[
        us_brand_nutrition["Product_Count"] >= 3
    ]
    .sort_values("Product_Count", ascending=False)
)

display(us_brand_nutrition.head(20))
# Out:
#               brands  Product_Count   Avg_Sugar  Median_Sugar  Avg_Energy  \
# 22             Fanta             76   14.847013     12.137419  986.784293
# 31    Firehouse Subs             72    0.987528      0.105500    4.022500
# 77           Unknown             49   24.464460     12.000000  242.430181
# 85           Zaxby's             32    2.016812      1.685000    8.080625
# 82      White Castle             30    2.181133      1.690000    8.712667
# 81       Whataburger             14    1.516000      1.690000    6.232857
# 10  Church's Chicken             10    1.862000      1.845000    7.504000
# 70             Sonic             10   57.000000     51.000000  228.000000
# 56        McDonald's              8   34.750000     32.000000  143.000000
# 45   Jack in the Box              8    0.940000      0.550000    3.756250
# 6        Burger King              5    1.896000      1.630000    7.740000
# 26         Fantastic              4    0.206000      0.206000         NaN
# 73      TGI Friday's              4   55.500000     55.500000  228.000000
# 1         Applebee's              4    0.997500      0.973000    4.200000
# 19          Del Taco              4    1.491250      1.350000    6.447500
# 80           Wendy's              4  103.500000    103.500000  422.000000
# 66         Red Robin              4   37.000000     37.000000  150.000000
# 63           Popeyes              4    2.000000      2.000000    7.990000
# 3      Auntie Anne's              3    1.593333      1.610000    6.373333
# 21             FANTA              3   12.600000     12.600000   45.000000
#
#     Median_Energy
# 22         46.500
# 31          2.000
# 77        212.000
# 85          6.740
# 82          6.760
# 81          6.760
# 10          7.375
# 70        204.000
# 56        132.000
# 45          2.200
# 6           6.530
# 26            NaN
# 73        228.000
# 1           4.315
# 19          5.635
# 80        422.000
# 66        150.000
# 63          7.990
# 3           6.440
# 21         45.000

# %%
# UNITED STATES — NUTRI-SCORE VS SUGAR / ENERGY


if "nutriscore_grade" in us_df.columns:

    us_nutri_sugar = us_df[
        ["nutriscore_grade", "nutriments.sugars_100g_num"]
    ].dropna()

    print("Sugar by Nutri-Score:")
    display(
        us_nutri_sugar.groupby("nutriscore_grade")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=us_nutri_sugar,
        x="nutriscore_grade",
        y="nutriments.sugars_100g_num"
    )
    plt.title("United States – Sugar Distribution by Nutri-Score")
    plt.xlabel("Nutri-Score")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()

    us_nutri_energy = us_df[
        ["nutriscore_grade", "nutriments.energy-kcal_100g_num"]
    ].dropna()

    print("Energy by Nutri-Score:")
    display(
        us_nutri_energy.groupby("nutriscore_grade")
        ["nutriments.energy-kcal_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=us_nutri_energy,
        x="nutriscore_grade",
        y="nutriments.energy-kcal_100g_num"
    )
    plt.title("United States – Energy by Nutri-Score")
    plt.xlabel("Nutri-Score")
    plt.ylabel("Energy (kcal per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
# Sugar by Nutri-Score:
#                   count   mean  median   min     max
# nutriscore_grade
# a                     1   2.38    2.38  2.38    2.38
# b                   150   1.08    1.27  0.00    5.83
# c                    46   3.34    3.66  0.00    5.85
# d                     7  21.24   12.70  3.23   50.00
# e                    50  56.78   43.00  5.50  254.00
# unknown              72  20.67   12.14  0.00  100.00
# Energy by Nutri-Score:
#                   count    mean  median    min       max
# nutriscore_grade
# a                     1  357.00  357.00  357.0    357.00
# b                   150    6.78    5.07    0.0    371.00
# c                    46   33.56   14.70    8.0    372.22
# d                     7  488.05  333.33   17.0   1950.00
# e                    50  275.03  196.00   38.0   1020.00
# unknown              78  519.81   53.46    0.0  26000.00

# %% [markdown]
# ###  Observation
#
# The Nutri-Score comparison shows a clear difference in sugar levels between the grades. Products with **E** have much higher average sugar than products with **B**, while the other grades fall between them or have fewer records. This suggests that sugar is one of the factors associated with the nutritional-score differences in this dataset.

# %%
# 
# UNITED STATES — NOVA VS SUGAR

if "nova_group" in us_df.columns:

    us_nova_sugar = us_df[
        ["nova_group", "nutriments.sugars_100g_num"]
    ].dropna()

    display(
        us_nova_sugar.groupby("nova_group")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=us_nova_sugar,
        x="nova_group",
        y="nutriments.sugars_100g_num"
    )
    plt.title("United States – Sugar by NOVA Processing Group")
    plt.xlabel("NOVA Group")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
#             count   mean  median   min     max
# nova_group
# 1.0             1   2.38    2.38  2.38    2.38
# 3.0             2   7.78    7.78  2.86   12.70
# 4.0            31  26.97   17.86  0.00   66.67
# Unknown       292  13.50    2.00  0.00  254.00

# %% [markdown]
# ### Observation
#
# The NOVA comparison shows that most records have an `Unknown` processing group. Among the records with a known group, **Group 4** has the highest average sugar. Because many NOVA values are missing, this result should be treated as a general pattern rather than a complete comparison.

# %%
# ============================================================
# UNITED STATES — CORRELATION
# ============================================================

corr_cols = [
    "nova_group_num",
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

available_corr_cols = [c for c in corr_cols if c in us_df.columns]

us_corr = us_df[available_corr_cols].corr()

display(us_corr.round(3))

plt.figure(figsize=(8, 6))
sns.heatmap(
    us_corr,
    annot=True,
    cmap="coolwarm",
    center=0,
    fmt=".2f"
)
plt.title("United States – Nutritional Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
#                                  nova_group_num  nutriments.sugars_100g_num  \
# nova_group_num                            1.000                       0.242
# nutriments.sugars_100g_num                0.242                       1.000
# nutriments.energy-kcal_100g_num           0.026                       0.062
#
#                                  nutriments.energy-kcal_100g_num
# nova_group_num                                             0.026
# nutriments.sugars_100g_num                                 0.062
# nutriments.energy-kcal_100g_num                            1.000

# %% [markdown]
# ###  Observation
#
# The correlation heatmap shows that the relationship between **sugar and energy is very weak** in the United States data. The relationship between NOVA group and sugar is somewhat stronger, but it is still not strong enough to say that one variable directly determines the other.

# %%
# ============================================================
# UNITED STATES — INGREDIENT ANALYSIS
# ============================================================

if "ingredients_text" in us_df.columns:

    ingredient_text = us_df["ingredients_text"].astype(str).str.lower()
    all_ingredients = []

    for text in ingredient_text:
        if text != "unknown":
            for ingredient in text.split(","):
                ingredient = ingredient.strip()
                if ingredient and ingredient != "unknown":
                    all_ingredients.append(ingredient)

    us_ingredient_counts = Counter(all_ingredients)

    us_ingredient_df = pd.DataFrame(
        us_ingredient_counts.most_common(30),
        columns=["Ingredient", "Frequency"]
    )

    display(us_ingredient_df)

    plt.figure(figsize=(12, 8))
    sns.barplot(
        data=us_ingredient_df.head(15),
        x="Frequency",
        y="Ingredient"
    )
    plt.title("United States – Most Frequently Reported Ingredients")
    plt.xlabel("Frequency")
    plt.ylabel("Ingredient")
    plt.tight_layout()
    plt.show()
# Out:
#                      Ingredient  Frequency
# 0                     undefined        230
# 1                   citric acid         26
# 2                          salt         24
# 3                         sugar         20
# 4              carbonated water         17
# 5               natural flavors         17
# 6                      yellow 6         13
# 7      high fructose corn syrup         13
# 8                        red 40         11
# 9          modified food starch         10
# 10                     enzymes)          9
# 11               sodium citrate          9
# 12              cheese cultures          8
# 13                  wheat flour          8
# 14      glycerol ester of rosin          8
# 15                        water          7
# 16              sodium benzoate          7
# 17               natural flavor          7
# 18                    sucralose          7
# 19                   malic acid          6
# 20  sucrose acetate isobutyrate          6
# 21                      red 40.          6
# 22                     yellow 5          6
# 23                   corn syrup          5
# 24   medium chain triglycerides          5
# 25                  niacinamide          5
# 26                  lactic acid          4
# 27                         whey          4
# 28                        red 3          4
# 29            potassium citrate          4

# %% [markdown]
# ###  Observation
#
# The ingredient chart shows that `undefined` appears very frequently, which means ingredient information is missing or not clearly recorded for many products. Among the actual ingredients, **citric acid, salt, sugar and carbonated water** are some of the more common entries.

# %%
# ============================================================
# UNITED STATES — CATEGORY VS NUTRITION
# ============================================================

if "categories_tags" in us_df.columns:

    us_category_nutrition = (
        us_df.groupby("categories_tags")
        .agg(
            Product_Count=("product_name", "count"),
            Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
            Avg_Energy=("nutriments.energy-kcal_100g_num", "mean")
        )
        .reset_index()
    )

    us_category_nutrition = (
        us_category_nutrition[
            us_category_nutrition["Product_Count"] >= 2
        ]
        .sort_values("Product_Count", ascending=False)
    )

    display(us_category_nutrition.head(20))
# Out:
#                                                                                          categories_tags  \
# 7                                                        beverages-and-beverages-preparations, beverages
# 1                                                                                                Unknown
# 35                                                                 snacks, sweet-snacks, confectioneries
# 9                              beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
# 2                                                                                              beverages
# 5                                                                    beverages, carbonated-drinks, sodas
# 34                      snacks, sweet-snacks, cocoa-and-its-products, confectioneries, chocolate-candies
# 13                                        beverages-and-beverages-preparations, beverages, energy-drinks
# 12        beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages
# 26  plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products
# 20                                                                                               entrees
#
#     Product_Count  Avg_Sugar  Avg_Energy
# 7             229  11.315943   45.799956
# 1             152  21.841241  570.464696
# 35              5  54.105000  337.416667
# 9               4   9.250000   66.500000
# 2               4   4.820915   19.750000
# 5               3   6.700000   28.000000
# 34              3  54.950000  547.000000
# 13              2        NaN         NaN
# 12              2        NaN         NaN
# 26              2  38.480000  385.000000
# 20              2   2.680000  180.000000

# %%
# ============================================================
# UNITED STATES — ATTRIBUTE-LEVEL ANALYSIS
# ============================================================

categorical_columns = [
    "brands",
    "categories_tags",
    "packaging_tags",
    "stores",
    "purchase_places",
    "nutriscore_grade",
    "nova_group",
    "ecoscore_grade"
]

for col in categorical_columns:
    if col in us_df.columns:
        print("\n" + "=" * 70)
        print(f"ATTRIBUTE: {col}")
        print("=" * 70)

        counts = (
            us_df[col]
            .astype(str)
            .value_counts()
            .head(15)
        )

        display(counts.to_frame("Count"))
# Out:
# ======================================================================
# ATTRIBUTE: brands
# ======================================================================
#                   Count
# brands
# Fanta                76
# Firehouse Subs       72
# Unknown              49
# Zaxby's              32
# White Castle         30
# Whataburger          14
# Church's Chicken     10
# Sonic                10
# Jack in the Box       8
# McDonald's            8
# Burger King           5
# Applebee's            4
# Del Taco              4
# Popeyes               4
# Red Robin             4
# ======================================================================
# ATTRIBUTE: categories_tags
# ======================================================================
#                                                                                                                           Count
# categories_tags
# beverages-and-beverages-preparations, beverages                                                                             229
# Unknown                                                                                                                     152
# snacks, sweet-snacks, confectioneries                                                                                         5
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas                                                     4
# beverages                                                                                                                     4
# beverages, carbonated-drinks, sodas                                                                                           3
# snacks, sweet-snacks, cocoa-and-its-products, confectioneries, chocolate-candies                                              3
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages                                2
# plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products                          2
# beverages-and-beverages-preparations, beverages, energy-drinks                                                                2
# entrees                                                                                                                       2
# plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods                                         1
# condiments, sauces, salad-dressings, groceries                                                                                1
# undefined                                                                                                                     1
# plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products, pastas, fresh-p...      1
# ======================================================================
# ATTRIBUTE: packaging_tags
# ======================================================================
#                         Count
# packaging_tags
# Unknown                   429
# card-box                    2
# plastic-bowl                1
# bottle                      1
# hdpe-bottle                 1
# card-box, paper-sleeve      1
# ======================================================================
# ATTRIBUTE: stores
# ======================================================================
#          Count
# stores
# Unknown    435
# ======================================================================
# ATTRIBUTE: purchase_places
# ======================================================================
#                  Count
# purchase_places
# Unknown            434
# Maryland,USA         1
# ======================================================================
# ATTRIBUTE: nutriscore_grade
# ======================================================================
#                   Count
# nutriscore_grade
# unknown             174
# b                   150
# e                    54
# c                    48
# d                     8
# a                     1
# ======================================================================
# ATTRIBUTE: nova_group
# ======================================================================
#             Count
# nova_group
# Unknown       381
# 4.0            51
# 3.0             2
# 1.0             1
# ======================================================================
# ATTRIBUTE: ecoscore_grade
# ======================================================================
#                 Count
# ecoscore_grade
# Unknown           346
# unknown            82
# not-applicable      3
# d                   2
# f                   2

# %%
# ============================================================
# UNITED STATES — NUMERICAL ATTRIBUTE ANALYSIS
# ============================================================

numerical_columns = [
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

us_numeric_summary = []

for col in numerical_columns:
    if col in us_df.columns:
        us_numeric_summary.append({
            "Attribute": col,
            "Count": us_df[col].count(),
            "Mean": us_df[col].mean(),
            "Median": us_df[col].median(),
            "Std": us_df[col].std(),
            "Minimum": us_df[col].min(),
            "Maximum": us_df[col].max()
        })

us_numeric_summary = pd.DataFrame(us_numeric_summary)
display(us_numeric_summary.round(2))
# Out:
#                          Attribute  Count    Mean  Median      Std  Minimum  \
# 0       nutriments.sugars_100g_num    326   14.71    2.00    29.36      0.0
# 1  nutriments.energy-kcal_100g_num    332  182.62    9.35  1435.19      0.0
#
#    Maximum
# 0    254.0
# 1  26000.0

# %%
# ============================================================
# UNITED STATES — DATA QUALITY CHECK
# ============================================================

print("UNITED STATES DATA QUALITY CHECK")
print("=" * 60)

print("Duplicate Rows:", us_df.duplicated().sum())
print("Duplicate Product Names:", us_df["product_name"].duplicated().sum())
print("Unique Products:", us_df["product_name"].nunique())
print("Unique Brands:", us_df["brands"].nunique())
print("Records:", len(us_df))
# Out:
# UNITED STATES DATA QUALITY CHECK
# ============================================================
# Duplicate Rows: 0
# Duplicate Product Names: 97
# Unique Products: 338
# Unique Brands: 88
# Records: 435

# %%
# ============================================================
# UNITED STATES — FINAL SUMMARY
# ============================================================

print("=" * 70)
print(" UNITED STATES – ADVANCED DATA ANALYSIS SUMMARY")
print("=" * 70)

print(f"\nTotal Records: {len(us_df):,}")
print(f"Unique Products: {us_df['product_name'].nunique():,}")
print(f"Unique Brands: {us_df['brands'].nunique():,}")

print("\nTop 5 Brands:")
display(us_brand_counts.head(5))

print("\nTop 5 Categories:")
display(us_category_counts.head(5))

print("\nTop Packaging Types:")
display(us_packaging_counts.head(5))

print("\nTop Stores:")
display(us_store_counts.head(5))

print("\nTop Purchase Places:")
display(us_purchase_counts.head(5))

if "nutriscore_grade" in us_df.columns:
    print("\nNutri-Score Distribution:")
    display(us_df["nutriscore_grade"].value_counts())

if "nova_group" in us_df.columns:
    print("\nNOVA Distribution:")
    display(us_df["nova_group"].value_counts())

if "ecoscore_grade" in us_df.columns:
    print("\nEco-Score Distribution:")
    display(us_df["ecoscore_grade"].value_counts())

print("\nNutritional Statistics:")
display(pd.DataFrame({
    "Metric": [
        "Average Sugar", "Median Sugar", "Maximum Sugar",
        "Average Energy", "Median Energy", "Maximum Energy"
    ],
    "Value": [
        us_sugar.mean(), us_sugar.median(), us_sugar.max(),
        us_energy.mean(), us_energy.median(), us_energy.max()
    ]
}).round(2))

print("\nSugar–Energy Correlation:", round(us_sugar_energy_corr, 3))
print("\nAnalysis completed for United States.")
# Out:
# ======================================================================
#  UNITED STATES – ADVANCED DATA ANALYSIS SUMMARY
# ======================================================================
#
# Total Records: 435
# Unique Products: 338
# Unique Brands: 88
#
# Top 5 Brands:
#             Brand  Product_Count
# 0           Fanta             76
# 1  Firehouse Subs             72
# 2         Unknown             49
# 3         Zaxby's             32
# 4    White Castle             30
# Top 5 Categories:
# categories_tags
# beverages                               257
# beverages-and-beverages-preparations    243
# carbonated-drinks                        19
# sodas                                    18
# plant-based-foods-and-beverages          13
# Name: count, dtype: int64
# Top Packaging Types:
# packaging_tags
# card-box        3
# plastic-bowl    1
# bottle          1
# hdpe-bottle     1
# paper-sleeve    1
# Name: count, dtype: int64
# Top Stores:
# Series([], Name: count, dtype: int64)
# Top Purchase Places:
# purchase_places
# Maryland    1
# USA         1
# Name: count, dtype: int64
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    174
# b          150
# e           54
# c           48
# d            8
# a            1
# Name: count, dtype: int64
# NOVA Distribution:
# nova_group
# Unknown    381
# 4.0         51
# 3.0          2
# 1.0          1
# Name: count, dtype: int64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           346
# unknown            82
# not-applicable      3
# d                   2
# f                   2
# Name: count, dtype: int64
# Nutritional Statistics:
#            Metric     Value
# 0   Average Sugar     14.71
# 1    Median Sugar      2.00
# 2   Maximum Sugar    254.00
# 3  Average Energy    182.62
# 4   Median Energy      9.35
# 5  Maximum Energy  26000.00
# Sugar–Energy Correlation: 0.062
#
# Analysis completed for United States.

# %% [markdown]
# ### United States — Observation and Insight
#
# The United States section contains **435 records**, representing **338 unique products** from **88 brands**. This is the broadest country-level catalog in the dataset, but the repeated product names show that record count is larger than distinct-product count. Among the nutrition values available for analysis, products average **14.71 g of sugar** and **182.62 kcal per 100 g**. The near-zero sugar-energy correlation (**0.062**) suggests that sugar alone does not explain energy variation; product type and other ingredients also matter.

# %% [markdown]
# # PART — ITALY
#
# The same complete analysis framework is applied to **Italy only**.

# %%
# ============================================================
# ITALY DATASET
# ============================================================

italy_df = df[
    df["countries_tags"].astype(str).str.lower() == "italy"
].copy()

print("ITALY DATASET")
print("=" * 60)
print("Records:", len(italy_df))
print("Attributes:", len(italy_df.columns))
display(italy_df.head())
# Out:
# ITALY DATASET
# ============================================================
# Records: 315
# Attributes: 17
#              code        product_name                  brands  \
# 9   5449000103789   Fanta zéro orange   The coca cola company
# 10  8001590947920  Fantasie alle Erbe  Philadelphia, mondelez
# 12  8028639000439            Fantasia              Barbagallo
# 14  5449000241375      Fanta original                   Fanta
# 19  8000571816224  Farfalle fantaisia  Brezzo, L'antico Forno
#
#                                                                                                             categories_tags  \
# 9                                         beverages-and-beverages-preparations, beverages, artificially-sweetened-beverages
# 10                                                                                                                  dairies
# 12                                                                                                                  Unknown
# 14  plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, sodas, ...
# 19                                                               plant-based-foods-and-beverages, plant-based-foods, pastas
#
#    countries_tags    packaging_tags   stores purchase_places nutriscore_grade  \
# 9           italy  it:bottiglia-pet  Unknown         Unknown                c
# 10          italy           Unknown  Unknown         Unknown                d
# 12          italy           Unknown  Unknown         Unknown          unknown
# 14          italy     bottiglia-pet  Unknown         Unknown          unknown
# 19          italy           Unknown  Unknown         Unknown                a
#
#    nova_group ecoscore_grade  \
# 9         4.0        Unknown
# 10        4.0        Unknown
# 12    Unknown        Unknown
# 14        4.0        Unknown
# 19    Unknown        Unknown
#
#                                                                                                            ingredients_text  \
# 9   Acqua, succo di arancia (12%), anidride carbonica, acidificante acido citrico, aromi naturali di agrumi, correttore ...
# 10  FORMAGGIO fresco [LATTE pastorizzato, crema di LATTE, sale, addensanti (alginato di sodio, farina di semi di carrube...
# 12                                                                                                                  Unknown
# 14  acqua, succo di arancia da concentrato (12%), zucchero, anidride carbonica, acidificante acido citrico, aromi natura...
# 19                                                                                                                  Unknown
#
#    nutriments.sugars_100g nutriments.energy-kcal_100g  \
# 9                 Unknown                     Unknown
# 10                Unknown                     Unknown
# 12                Unknown                     Unknown
# 14                Unknown                     Unknown
# 19                Unknown                     Unknown
#
#     nutriments.sugars_100g_num  nutriments.energy-kcal_100g_num  \
# 9                          NaN                              NaN
# 10                         NaN                              NaN
# 12                         NaN                              NaN
# 14                         NaN                              NaN
# 19                         NaN                              NaN
#
#     nova_group_num
# 9              4.0
# 10             4.0
# 12             NaN
# 14             4.0
# 19             NaN

# %%
# ============================================================
# ITALY — BASIC OVERVIEW
# ============================================================

print("Dataset Shape:", italy_df.shape)
print("\nColumn Names:")
print(italy_df.columns.tolist())

print("\nData Types:")
display(italy_df.dtypes)

print("\nStatistical Summary:")
display(italy_df.describe(include="all").T)
# Out:
# Dataset Shape: (315, 17)
#
# Column Names:
# ['code', 'product_name', 'brands', 'categories_tags', 'countries_tags', 'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade', 'nova_group', 'ecoscore_grade', 'ingredients_text', 'nutriments.sugars_100g', 'nutriments.energy-kcal_100g', 'nutriments.sugars_100g_num', 'nutriments.energy-kcal_100g_num', 'nova_group_num']
#
# Data Types:
# code                                object
# product_name                           str
# brands                                 str
# categories_tags                        str
# countries_tags                         str
# packaging_tags                         str
# stores                                 str
# purchase_places                        str
# nutriscore_grade                       str
# nova_group                             str
# ecoscore_grade                         str
# ingredients_text                       str
# nutriments.sugars_100g                 str
# nutriments.energy-kcal_100g            str
# nutriments.sugars_100g_num         float64
# nutriments.energy-kcal_100g_num    float64
# nova_group_num                     float64
# dtype: object
# Statistical Summary:
#                                  count unique              top freq      mean  \
# code                             315.0  314.0  8056149708361.0  2.0       NaN
# product_name                       315    263            Fanta   10       NaN
# brands                             315    126          Unknown   79       NaN
# categories_tags                    315     92          Unknown  174       NaN
# countries_tags                     315      1            italy  315       NaN
# packaging_tags                     315     12          Unknown  285       NaN
# stores                             315     15          Unknown  291       NaN
# purchase_places                    315      3          Unknown  309       NaN
# nutriscore_grade                   315      8          unknown  206       NaN
# nova_group                         315      4          Unknown  279       NaN
# ecoscore_grade                     315      2          Unknown  314       NaN
# ingredients_text                   315     41          Unknown  274       NaN
# nutriments.sugars_100g             315      1          Unknown  315       NaN
# nutriments.energy-kcal_100g        315      1          Unknown  315       NaN
# nutriments.sugars_100g_num         0.0    NaN              NaN  NaN       NaN
# nutriments.energy-kcal_100g_num    0.0    NaN              NaN  NaN       NaN
# nova_group_num                    36.0    NaN              NaN  NaN  3.305556
#
#                                       std  min  25%  50%  75%  max
# code                                  NaN  NaN  NaN  NaN  NaN  NaN
# product_name                          NaN  NaN  NaN  NaN  NaN  NaN
# brands                                NaN  NaN  NaN  NaN  NaN  NaN
# categories_tags                       NaN  NaN  NaN  NaN  NaN  NaN
# countries_tags                        NaN  NaN  NaN  NaN  NaN  NaN
# packaging_tags                        NaN  NaN  NaN  NaN  NaN  NaN
# stores                                NaN  NaN  NaN  NaN  NaN  NaN
# purchase_places                       NaN  NaN  NaN  NaN  NaN  NaN
# nutriscore_grade                      NaN  NaN  NaN  NaN  NaN  NaN
# nova_group                            NaN  NaN  NaN  NaN  NaN  NaN
# ecoscore_grade                        NaN  NaN  NaN  NaN  NaN  NaN
# ingredients_text                      NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.sugars_100g                NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.energy-kcal_100g           NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.sugars_100g_num            NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.energy-kcal_100g_num       NaN  NaN  NaN  NaN  NaN  NaN
# nova_group_num                   1.116613  1.0  3.0  4.0  4.0  4.0

# %%
# ============================================================
# ITALY — UNKNOWN VALUE ANALYSIS
# ============================================================

italy_unknown_summary = []

for col in italy_df.columns:
    unknown_count = (
        italy_df[col].astype(str)
        .str.strip()
        .str.lower()
        .eq("unknown")
        .sum()
    )

    italy_unknown_summary.append({
        "Attribute": col,
        "Unknown_Count": unknown_count,
        "Total_Records": len(italy_df),
        "Unknown_Percentage": round(
            unknown_count / len(italy_df) * 100, 2
        )
    })

italy_unknown_df = pd.DataFrame(italy_unknown_summary).sort_values(
    "Unknown_Percentage", ascending=False
)

display(italy_unknown_df)

plt.figure(figsize=(12, 6))
sns.barplot(data=italy_unknown_df,
            x="Unknown_Percentage", y="Attribute")
plt.title("Italy – Unknown Value Percentage by Attribute")
plt.xlabel("Unknown Values (%)")
plt.ylabel("Attribute")
plt.tight_layout()
plt.show()
# Out:
#                           Attribute  Unknown_Count  Total_Records  \
# 12           nutriments.sugars_100g            315            315
# 10                   ecoscore_grade            315            315
# 13      nutriments.energy-kcal_100g            315            315
# 7                   purchase_places            309            315
# 6                            stores            291            315
# 5                    packaging_tags            285            315
# 9                        nova_group            279            315
# 11                 ingredients_text            274            315
# 8                  nutriscore_grade            207            315
# 3                   categories_tags            174            315
# 2                            brands             79            315
# 0                              code              0            315
# 4                    countries_tags              0            315
# 1                      product_name              0            315
# 14       nutriments.sugars_100g_num              0            315
# 15  nutriments.energy-kcal_100g_num              0            315
# 16                   nova_group_num              0            315
#
#     Unknown_Percentage
# 12              100.00
# 10              100.00
# 13              100.00
# 7                98.10
# 6                92.38
# 5                90.48
# 9                88.57
# 11               86.98
# 8                65.71
# 3                55.24
# 2                25.08
# 0                 0.00
# 4                 0.00
# 1                 0.00
# 14                0.00
# 15                0.00
# 16                0.00

# %% [markdown]
# ###  Observation
#
# The Italy data has a large number of missing values in several attributes. In particular, **energy, sugar and Eco-Score information is missing for most records**. Brand and product names are more complete, so product and brand analysis can be used more confidently than nutritional analysis.

# %%
# ============================================================
# ITALY — PRODUCT ANALYSIS
# ============================================================

italy_product_counts = (
    italy_df["product_name"].value_counts().reset_index()
)
italy_product_counts.columns = ["Product_Name", "Frequency"]

print("Top 20 Products:")
display(italy_product_counts.head(20))

print("Total Product Records:", len(italy_df))
print("Unique Products:", italy_df["product_name"].nunique())
print(
    "Product Uniqueness Rate:",
    round(italy_df["product_name"].nunique() / len(italy_df) * 100, 2),
    "%"
)

plt.figure(figsize=(12, 7))
sns.barplot(data=italy_product_counts.head(15),
            x="Frequency", y="Product_Name")
plt.title("Italy – Top 15 Products")
plt.xlabel("Number of Records")
plt.ylabel("Product")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Products:
#                       Product_Name  Frequency
# 0                            Fanta         10
# 1              Fantasia di verdure          7
# 2                         Fantasia          4
# 3               Fantasie dell'orto          4
# 4                          Fantasy          4
# 5                        Aranciata          4
# 6                 Fantasia di mare          3
# 7                Insalata fantasia          3
# 8                      Peperoncino          3
# 9                 Fantasia di semi          2
# 10              Fantasia di Funghi          2
# 11                      Fantasmini          2
# 12                  Fanta limonata          2
# 13              Fantasia di legumi          2
# 14                        fantasie          2
# 15                  Misto fantasia          2
# 16               Contorno fantasia          2
# 17  Fantasia di funghi con porcini          2
# 18              Pirulo fantasmikos          2
# 19                       Pepe nero          2
# Total Product Records: 315
# Unique Products: 263
# Product Uniqueness Rate: 83.49 %

# %% [markdown]
# ###  Observation
#
# The product chart shows that **Fanta** is the most frequently recorded product in Italy. Other products such as *Fantasia di verdure* and *Aranciata* also appear several times, while most products occur only a small number of times.

# %%
# ============================================================
# ITALY — BRAND ANALYSIS
# ============================================================

italy_brand_counts = (
    italy_df["brands"].value_counts().reset_index()
)
italy_brand_counts.columns = ["Brand", "Product_Count"]

print("Top 20 Brands:")
display(italy_brand_counts.head(20))

print("Unique Brands:", italy_df["brands"].nunique())

italy_brand_diversity = (
    italy_df["brands"].nunique() / len(italy_df) * 100
)
print("Brand Diversity Ratio:", round(italy_brand_diversity, 2), "%")

plt.figure(figsize=(12, 7))
sns.barplot(data=italy_brand_counts.head(15),
            x="Product_Count", y="Brand")
plt.title("Italy – Top 15 Brands")
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Brands:
#                             Brand  Product_Count
# 0                         Unknown             79
# 1                           Fanta             29
# 2             Fantasie Aromatiche             27
# 3          Fantasy, Menz & Gasser              8
# 4                Gusto e fantasia              6
# 5   Euroverde, Fantasie dell'Orto              5
# 6                            Coop              5
# 7                           Gallo              4
# 8                           Selex              4
# 9                       Euroverde              3
# 10                          Conad              3
# 11                        Cerreto              3
# 12                       Consilia              3
# 13                    Ciro Amodio              3
# 14                         Bennet              3
# 15                         Sapori              3
# 16                      Esselunga              2
# 17            Dolciando, Eurospin              2
# 18                   Cereal terra              2
# 19            Pastificio Fantasia              2
# Unique Brands: 126
# Brand Diversity Ratio: 40.0 %

# %% [markdown]
# ###  Observation
#
# The brand chart shows that `Unknown` is the largest brand group in the Italy data. Among the named brands, **Fanta** and **Fantasie Aromatiche** have the highest representation. The dataset contains **126 unique brands**, so there is a good amount of brand variety.

# %%
# ============================================================
# ITALY — CATEGORY ANALYSIS
# ============================================================

italy_category_series = (
    italy_df["categories_tags"].astype(str)
    .str.split(",").explode().str.strip()
)

italy_category_series = italy_category_series[
    italy_category_series.str.lower() != "unknown"
]

italy_category_counts = italy_category_series.value_counts()

print("Top 25 Categories:")
display(italy_category_counts.head(25))

italy_top_categories = italy_category_counts.head(15).reset_index()
italy_top_categories.columns = ["Category", "Product_Count"]

plt.figure(figsize=(12, 8))
sns.barplot(data=italy_top_categories,
            x="Product_Count", y="Category")
plt.title("Italy – Top 15 Product Categories")
plt.xlabel("Product Count")
plt.ylabel("Category")
plt.tight_layout()
plt.show()
# Out:
# Top 25 Categories:
# categories_tags
# plant-based-foods-and-beverages         75
# plant-based-foods                       66
# beverages                               20
# frozen-foods                            17
# snacks                                  16
# fruits-and-vegetables-based-foods       15
# sweet-snacks                            14
# meals                                   13
# cereals-and-potatoes                    12
# seeds                                   12
# vegetables-based-foods                  12
# carbonated-drinks                       11
# cereals-and-their-products              11
# beverages-and-beverages-preparations    10
# sodas                                   10
# breakfasts                              10
# desserts                                10
# frozen-desserts                          9
# seafood                                  8
# spreads                                  8
# sweet-spreads                            8
# plant-based-beverages                    7
# fruit-based-beverages                    7
# soups                                    7
# legumes-and-their-products               7
# Name: count, dtype: int64

# %% [markdown]
# ###  Observation
#
# The category chart is led by **plant-based foods and beverages**, followed by plant-based foods and beverages in general. Frozen foods, snacks, fruits and vegetables and meals are also represented. This shows that the Italy data is more varied across food categories than just beverages.

# %%
# ============================================================
# ITALY — PACKAGING, STORE AND PURCHASE PLACE
# ============================================================

def analyze_multivalue_attribute(country_df, column, label):
    if column not in country_df.columns:
        print(f"Column not found: {column}")
        return pd.Series(dtype="int64")

    s = country_df[column].astype(str).str.split(",").explode().str.strip()
    s = s[s.str.lower() != "unknown"]
    counts = s.value_counts()

    print(f"Top {label}:")
    display(counts.head(20).to_frame("Count"))
    return counts

italy_packaging_counts = analyze_multivalue_attribute(
    italy_df, "packaging_tags", "Packaging Types"
)
italy_store_counts = analyze_multivalue_attribute(
    italy_df, "stores", "Stores"
)
italy_purchase_counts = analyze_multivalue_attribute(
    italy_df, "purchase_places", "Purchase Places"
)
# Out:
# Top Packaging Types:
#                                 Count
# packaging_tags
# it:bottiglia-pet                   13
# plastic                             7
# paper                               4
# metal                               4
# recyclable-metals                   4
# aluminium                           4
# glass                               3
# bottiglia-pet                       2
# composite-material                  2
# plastic-tinplate                    2
# clear-glass                         2
# hdpe-high-density-polyethylene      2
# bottle                              1
# envelope                            1
# it:c-pap-81                         1
# pe-polyethylene                     1
# ldpe-low-density-polyethylene       1
# pet-polyethylene-terephthalate      1
# Top Stores:
#               Count
# stores
# Coop              5
# Eurospin          3
# Bennet            3
# Esselunga         2
# Conad             2
# conad             1
# crai              1
# In's              1
# ARD Discount      1
# iperal            1
# Spar              1
# DPiù              1
# Crai              1
# MD                1
# Top Purchase Places:
#                   Count
# purchase_places
# Italia                6
# Mazara del Vallo      1
# Trapani               1

# %%
# ============================================================
# ITALY — NUTRI-SCORE, NOVA AND ECO-SCORE
# ============================================================

for col, label in [
    ("nutriscore_grade", "Nutri-Score"),
    ("nova_group", "NOVA Group"),
    ("ecoscore_grade", "Eco-Score")
]:
    if col in italy_df.columns:
        counts = italy_df[col].value_counts()
        print(f"{label} Distribution:")
        display(counts)
        print(f"{label} Percentage:")
        display(italy_df[col].value_counts(normalize=True).mul(100).round(2))

        plt.figure(figsize=(9, 5))
        sns.countplot(
            data=italy_df,
            x=col,
            order=italy_df[col].value_counts().index
        )
        plt.title(f"Italy – {label} Distribution")
        plt.xlabel(label)
        plt.ylabel("Number of Products")
        plt.tight_layout()
        plt.show()
# Out:
# Nutri-Score Distribution:
# nutriscore_grade
# unknown           206
# d                  26
# c                  25
# a                  18
# e                  16
# b                  14
# not-applicable      9
# Unknown             1
# Name: count, dtype: int64
# Nutri-Score Percentage:
# nutriscore_grade
# unknown           65.40
# d                  8.25
# c                  7.94
# a                  5.71
# e                  5.08
# b                  4.44
# not-applicable     2.86
# Unknown            0.32
# Name: proportion, dtype: float64
# NOVA Group Distribution:
# nova_group
# Unknown    279
# 4.0         23
# 3.0          7
# 1.0          6
# Name: count, dtype: int64
# NOVA Group Percentage:
# nova_group
# Unknown    88.57
# 4.0         7.30
# 3.0         2.22
# 1.0         1.90
# Name: proportion, dtype: float64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown    314
# unknown      1
# Name: count, dtype: int64
# Eco-Score Percentage:
# ecoscore_grade
# Unknown    99.68
# unknown     0.32
# Name: proportion, dtype: float64

# %% [markdown]
# ###  Observation
#
# The Nutri-Score chart shows that `unknown` is the largest group in Italy, covering most of the records. Among the known scores, **D, C and A** are the more visible groups. Because a large part of the data has no score, the chart gives only a partial view of the nutritional profile.

# %% [markdown]
# ###  Observation
#
# The scatter plot does not provide a meaningful sugar-versus-energy relationship for Italy because there are **no valid nutritional records** available for this calculation. This is mainly a data-availability issue rather than a finding about the products themselves.

# %%
# ============================================================
# ITALY — OUTLIER ANALYSIS
# ============================================================

def find_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return series[(series < lower) | (series > upper)]

if "nutriments.sugars_100g_num" in italy_df.columns:
    italy_sugar = italy_df["nutriments.sugars_100g_num"].dropna()
else:
    italy_sugar = pd.Series(dtype="float64")

if "nutriments.energy-kcal_100g_num" in italy_df.columns:
    italy_energy = italy_df["nutriments.energy-kcal_100g_num"].dropna()
else:
    italy_energy = pd.Series(dtype="float64")

italy_sugar_outliers = find_outliers(italy_sugar)
italy_energy_outliers = find_outliers(italy_energy)

print("Sugar Outliers:", len(italy_sugar_outliers))
print("Energy Outliers:", len(italy_energy_outliers))

print("\nHighest Sugar Products:")
display(
    italy_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.sugars_100g_num"]
    ].dropna(subset=["nutriments.sugars_100g_num"])
     .sort_values("nutriments.sugars_100g_num", ascending=False)
     .head(20)
)

print("\nHighest Energy Products:")
display(
    italy_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.energy-kcal_100g_num"]
    ].dropna(subset=["nutriments.energy-kcal_100g_num"])
     .sort_values("nutriments.energy-kcal_100g_num", ascending=False)
     .head(20)
)
# Out:
# Sugar Outliers: 0
# Energy Outliers: 0
#
# Highest Sugar Products:
# Empty DataFrame
# Columns: [product_name, brands, categories_tags, nutriments.sugars_100g_num]
# Index: []
# Highest Energy Products:
# Empty DataFrame
# Columns: [product_name, brands, categories_tags, nutriments.energy-kcal_100g_num]
# Index: []

# %%
# ============================================================
# ITALY — BRAND NUTRITION ANALYSIS
# ============================================================

italy_brand_nutrition = (
    italy_df.groupby("brands")
    .agg(
        Product_Count=("product_name", "count"),
        Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
        Median_Sugar=("nutriments.sugars_100g_num", "median"),
        Avg_Energy=("nutriments.energy-kcal_100g_num", "mean"),
        Median_Energy=("nutriments.energy-kcal_100g_num", "median")
    )
    .reset_index()
)

italy_brand_nutrition = (
    italy_brand_nutrition[
        italy_brand_nutrition["Product_Count"] >= 3
    ]
    .sort_values("Product_Count", ascending=False)
)

display(italy_brand_nutrition.head(20))
# Out:
#                             brands  Product_Count  Avg_Sugar  Median_Sugar  \
# 115                        Unknown             79        NaN           NaN
# 48                           Fanta             29        NaN           NaN
# 50             Fantasie Aromatiche             27        NaN           NaN
# 54          Fantasy, Menz & Gasser              8        NaN           NaN
# 65                Gusto e fantasia              6        NaN           NaN
# 45   Euroverde, Fantasie dell'Orto              5        NaN           NaN
# 31                            Coop              5        NaN           NaN
# 60                           Gallo              4        NaN           NaN
# 109                          Selex              4        NaN           NaN
# 30                        Consilia              3        NaN           NaN
# 44                       Euroverde              3        NaN           NaN
# 27                           Conad              3        NaN           NaN
# 17                         Cerreto              3        NaN           NaN
# 7                           Bennet              3        NaN           NaN
# 20                     Ciro Amodio              3        NaN           NaN
# 107                         Sapori              3        NaN           NaN
#
#      Avg_Energy  Median_Energy
# 115         NaN            NaN
# 48          NaN            NaN
# 50          NaN            NaN
# 54          NaN            NaN
# 65          NaN            NaN
# 45          NaN            NaN
# 31          NaN            NaN
# 60          NaN            NaN
# 109         NaN            NaN
# 30          NaN            NaN
# 44          NaN            NaN
# 27          NaN            NaN
# 17          NaN            NaN
# 7           NaN            NaN
# 20          NaN            NaN
# 107         NaN            NaN

# %% [markdown]
# ###  Observation
#
# The Nutri-Score versus sugar plot is empty for Italy because there are no valid sugar values available for the comparison. Therefore, no conclusion about the relationship between Nutri-Score and sugar can be made from this part of the dataset.

# %%
# ============================================================
# ITALY — NOVA VS SUGAR
# ============================================================

if "nova_group" in italy_df.columns:

    italy_nova_sugar = italy_df[
        ["nova_group", "nutriments.sugars_100g_num"]
    ].dropna()

    display(
        italy_nova_sugar.groupby("nova_group")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=italy_nova_sugar,
        x="nova_group",
        y="nutriments.sugars_100g_num"
    )
    plt.title("Italy – Sugar by NOVA Processing Group")
    plt.xlabel("NOVA Group")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
# Empty DataFrame
# Columns: [count, mean, median, min, max]
# Index: []

# %% [markdown]
# ###  Observation
#
# The chart compares sugar levels across NOVA processing groups in Italy. The groups show different sugar distributions, although missing NOVA information means the comparison does not cover every product.

# %%
# ============================================================
# ITALY — CORRELATION
# ============================================================

corr_cols = [
    "nova_group_num",
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

available_corr_cols = [c for c in corr_cols if c in italy_df.columns]

italy_corr = italy_df[available_corr_cols].corr()

display(italy_corr.round(3))

plt.figure(figsize=(8, 6))
sns.heatmap(
    italy_corr,
    annot=True,
    cmap="coolwarm",
    center=0,
    fmt=".2f"
)
plt.title("Italy – Nutritional Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
#                                  nova_group_num  nutriments.sugars_100g_num  \
# nova_group_num                              1.0                         NaN
# nutriments.sugars_100g_num                  NaN                         NaN
# nutriments.energy-kcal_100g_num             NaN                         NaN
#
#                                  nutriments.energy-kcal_100g_num
# nova_group_num                                               NaN
# nutriments.sugars_100g_num                                   NaN
# nutriments.energy-kcal_100g_num                              NaN

# %% [markdown]
# ###  Observation
#
# The heatmap gives a quick view of how the numerical attributes are related in Italy. The relationships are generally not strong enough to suggest that one attribute alone explains the others.

# %%
# ============================================================
# ITALY — INGREDIENT ANALYSIS
# ============================================================

if "ingredients_text" in italy_df.columns:

    ingredient_text = italy_df["ingredients_text"].astype(str).str.lower()
    all_ingredients = []

    for text in ingredient_text:
        if text != "unknown":
            for ingredient in text.split(","):
                ingredient = ingredient.strip()
                if ingredient and ingredient != "unknown":
                    all_ingredients.append(ingredient)

    italy_ingredient_counts = Counter(all_ingredients)

    italy_ingredient_df = pd.DataFrame(
        italy_ingredient_counts.most_common(30),
        columns=["Ingredient", "Frequency"]
    )

    display(italy_ingredient_df)

    plt.figure(figsize=(12, 8))
    sns.barplot(
        data=italy_ingredient_df.head(15),
        x="Frequency",
        y="Ingredient"
    )
    plt.title("Italy – Most Frequently Reported Ingredients")
    plt.xlabel("Frequency")
    plt.ylabel("Ingredient")
    plt.tight_layout()
    plt.show()
# Out:
#                                     Ingredient  Frequency
# 0                                        acqua         16
# 1                                     zucchero         11
# 2                           anidride carbonica          9
# 3                                         sale          8
# 4                   acidificante acido citrico          7
# 5                                        aromi          7
# 6                     aromi naturali di agrumi          6
# 7                 stabilizzante gomma d'acacia          5
# 8                    acesulfame k e sucralosio          4
# 9      correttore di acidità citrato trisodico          3
# 10             edulcoranti ciclammato di sodio          3
# 11               antiossidante acido ascorbico          3
# 12       succo di arancia da concentrato (12%)          3
# 13              antiossidante acido ascorbico.          3
# 14                                        uova          3
# 15                    olio di semi di girasole          3
# 16  farina di grano tenero tipo &quot;00&quot;          3
# 17                      succo di arancia (12%)          2
# 18                               semi di zucca          2
# 19                agenti lievitanti: difosfati          2
# 20                                    lattosio          2
# 21                      cacao magro in polvere          2
# 22                     latte intero in polvere          2
# 23                 uova da allevamento a terra          2
# 24                            fecola di patata          2
# 25            latte intero fresco pastorizzato          2
# 26                           amido di frumento          2
# 27                          carbonati di sodio          2
# 28              sciroppo di glucosio-fruttosio          2
# 29                               amido di riso          2

# %% [markdown]
# ###  Observation
#
# The ingredient chart shows the ingredients that appear most often in the Italy data. A few ingredients occur repeatedly, while many others appear less often. Missing or undefined ingredient entries should be kept in mind when interpreting the chart.

# %%
# ============================================================
# ITALY — CATEGORY VS NUTRITION
# ============================================================

if "categories_tags" in italy_df.columns:

    italy_category_nutrition = (
        italy_df.groupby("categories_tags")
        .agg(
            Product_Count=("product_name", "count"),
            Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
            Avg_Energy=("nutriments.energy-kcal_100g_num", "mean")
        )
        .reset_index()
    )

    italy_category_nutrition = (
        italy_category_nutrition[
            italy_category_nutrition["Product_Count"] >= 2
        ]
        .sort_values("Product_Count", ascending=False)
    )

    display(italy_category_nutrition.head(20))
# Out:
#                                                                                                             categories_tags  \
# 0                                                                                                                   Unknown
# 34                                                                       plant-based-foods-and-beverages, plant-based-foods
# 17                                                                                  desserts, frozen-foods, frozen-desserts
# 69                                                         plant-based-foods-and-beverages, plant-based-foods, meals, soups
# 2                                                                                            beverages, alcoholic-beverages
# 36  plant-based-foods-and-beverages, plant-based-foods, breakfasts, spreads, plant-based-spreads, sweet-spreads, fruit-a...
# 57            plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods, vegetables-based-foods
# 7                                                 beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
# 14                                                                                       breakfasts, spreads, sweet-spreads
# 77                                                                                    seafood, frozen-foods, frozen-seafood
# 88                                                                                    snacks, sweet-snacks, confectioneries
# 70                                                               plant-based-foods-and-beverages, plant-based-foods, pastas
# 18                                              desserts, frozen-foods, frozen-desserts, ice-creams-and-sorbets, ice-creams
# 28                                                                                                   meals, prepared-salads
# 27                                                                                      meals, pasta-dishes, stuffed-pastas
# 20                                                                                                      dietary-supplements
# 35                                                           plant-based-foods-and-beverages, plant-based-foods, breakfasts
# 61  plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods, vegetables-based-foods, mushr...
# 43  plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, seeds, cereals-and-their-products, cereal-...
# 30                                                                                          plant-based-foods-and-beverages
#
#     Product_Count  Avg_Sugar  Avg_Energy
# 0             174        NaN         NaN
# 34             14        NaN         NaN
# 17              6        NaN         NaN
# 69              4        NaN         NaN
# 2               3        NaN         NaN
# 36              3        NaN         NaN
# 57              3        NaN         NaN
# 7               3        NaN         NaN
# 14              3        NaN         NaN
# 77              3        NaN         NaN
# 88              3        NaN         NaN
# 70              3        NaN         NaN
# 18              2        NaN         NaN
# 28              2        NaN         NaN
# 27              2        NaN         NaN
# 20              2        NaN         NaN
# 35              2        NaN         NaN
# 61              2        NaN         NaN
# 43              2        NaN         NaN
# 30              2        NaN         NaN

# %%
# ============================================================
# ITALY — ATTRIBUTE-LEVEL ANALYSIS
# ============================================================

categorical_columns = [
    "brands",
    "categories_tags",
    "packaging_tags",
    "stores",
    "purchase_places",
    "nutriscore_grade",
    "nova_group",
    "ecoscore_grade"
]

for col in categorical_columns:
    if col in italy_df.columns:
        print("\n" + "=" * 70)
        print(f"ATTRIBUTE: {col}")
        print("=" * 70)

        counts = (
            italy_df[col]
            .astype(str)
            .value_counts()
            .head(15)
        )

        display(counts.to_frame("Count"))
# Out:
# ======================================================================
# ATTRIBUTE: brands
# ======================================================================
#                                Count
# brands
# Unknown                           79
# Fanta                             29
# Fantasie Aromatiche               27
# Fantasy, Menz & Gasser             8
# Gusto e fantasia                   6
# Euroverde, Fantasie dell'Orto      5
# Coop                               5
# Gallo                              4
# Selex                              4
# Euroverde                          3
# Conad                              3
# Cerreto                            3
# Consilia                           3
# Ciro Amodio                        3
# Bennet                             3
# ======================================================================
# ATTRIBUTE: categories_tags
# ======================================================================
#                                                                                                                           Count
# categories_tags
# Unknown                                                                                                                     174
# plant-based-foods-and-beverages, plant-based-foods                                                                           14
# desserts, frozen-foods, frozen-desserts                                                                                       6
# plant-based-foods-and-beverages, plant-based-foods, meals, soups                                                              4
# plant-based-foods-and-beverages, plant-based-foods, pastas                                                                    3
# plant-based-foods-and-beverages, plant-based-foods, breakfasts, spreads, plant-based-spreads, sweet-spreads, fruit-an...      3
# seafood, frozen-foods, frozen-seafood                                                                                         3
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas                                                     3
# breakfasts, spreads, sweet-spreads                                                                                            3
# plant-based-foods-and-beverages, plant-based-foods, fruits-and-vegetables-based-foods, vegetables-based-foods                 3
# beverages, alcoholic-beverages                                                                                                3
# snacks, sweet-snacks, confectioneries                                                                                         3
# plant-based-foods-and-beverages, plant-based-foods, seeds                                                                     2
# snacks, sweet-snacks, biscuits-and-cakes, biscuits                                                                            2
# meals, prepared-salads                                                                                                        2
# ======================================================================
# ATTRIBUTE: packaging_tags
# ======================================================================
#                                                                                                                          Count
# packaging_tags
# Unknown                                                                                                                    285
# it:bottiglia-pet                                                                                                            12
# metal, recyclable-metals, aluminium                                                                                          4
# plastic, paper                                                                                                               3
# bottiglia-pet                                                                                                                2
# plastic                                                                                                                      2
# composite-material, glass, plastic-tinplate, clear-glass                                                                     2
# paper                                                                                                                        1
# glass, bottle                                                                                                                1
# plastic, hdpe-high-density-polyethylene, it:bottiglia-pet                                                                    1
# envelope, it:c-pap-81                                                                                                        1
# plastic, pe-polyethylene, hdpe-high-density-polyethylene, ldpe-low-density-polyethylene, pet-polyethylene-terephthalate      1
# ======================================================================
# ATTRIBUTE: stores
# ======================================================================
#               Count
# stores
# Unknown         291
# Coop              5
# Eurospin          3
# Bennet            3
# Esselunga         2
# Conad             2
# conad             1
# crai              1
# In's              1
# ARD Discount      1
# iperal            1
# Spar              1
# DPiù              1
# Crai              1
# MD                1
# ======================================================================
# ATTRIBUTE: purchase_places
# ======================================================================
#                                  Count
# purchase_places
# Unknown                            309
# Italia                               5
# Mazara del Vallo,Trapani,Italia      1
# ======================================================================
# ATTRIBUTE: nutriscore_grade
# ======================================================================
#                   Count
# nutriscore_grade
# unknown             206
# d                    26
# c                    25
# a                    18
# e                    16
# b                    14
# not-applicable        9
# Unknown               1
# ======================================================================
# ATTRIBUTE: nova_group
# ======================================================================
#             Count
# nova_group
# Unknown       279
# 4.0            23
# 3.0             7
# 1.0             6
# ======================================================================
# ATTRIBUTE: ecoscore_grade
# ======================================================================
#                 Count
# ecoscore_grade
# Unknown           314
# unknown             1

# %%
# ============================================================
# ITALY — NUMERICAL ATTRIBUTE ANALYSIS
# ============================================================

numerical_columns = [
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

italy_numeric_summary = []

for col in numerical_columns:
    if col in italy_df.columns:
        italy_numeric_summary.append({
            "Attribute": col,
            "Count": italy_df[col].count(),
            "Mean": italy_df[col].mean(),
            "Median": italy_df[col].median(),
            "Std": italy_df[col].std(),
            "Minimum": italy_df[col].min(),
            "Maximum": italy_df[col].max()
        })

italy_numeric_summary = pd.DataFrame(italy_numeric_summary)
display(italy_numeric_summary.round(2))
# Out:
#                          Attribute  Count  Mean  Median  Std  Minimum  Maximum
# 0       nutriments.sugars_100g_num      0   NaN     NaN  NaN      NaN      NaN
# 1  nutriments.energy-kcal_100g_num      0   NaN     NaN  NaN      NaN      NaN

# %%
# ============================================================
# ITALY — DATA QUALITY CHECK
# ============================================================

print("ITALY DATA QUALITY CHECK")
print("=" * 60)

print("Duplicate Rows:", italy_df.duplicated().sum())
print("Duplicate Product Names:", italy_df["product_name"].duplicated().sum())
print("Unique Products:", italy_df["product_name"].nunique())
print("Unique Brands:", italy_df["brands"].nunique())
print("Records:", len(italy_df))
# Out:
# ITALY DATA QUALITY CHECK
# ============================================================
# Duplicate Rows: 0
# Duplicate Product Names: 52
# Unique Products: 263
# Unique Brands: 126
# Records: 315

# %%
# ============================================================
# ITALY — FINAL SUMMARY
# ============================================================

print("=" * 70)
print(" ITALY – ADVANCED DATA ANALYSIS SUMMARY")
print("=" * 70)

print(f"\nTotal Records: {len(italy_df):,}")
print(f"Unique Products: {italy_df['product_name'].nunique():,}")
print(f"Unique Brands: {italy_df['brands'].nunique():,}")

print("\nTop 5 Brands:")
display(italy_brand_counts.head(5))

print("\nTop 5 Categories:")
display(italy_category_counts.head(5))

print("\nTop Packaging Types:")
display(italy_packaging_counts.head(5))

print("\nTop Stores:")
display(italy_store_counts.head(5))

print("\nTop Purchase Places:")
display(italy_purchase_counts.head(5))

if "nutriscore_grade" in italy_df.columns:
    print("\nNutri-Score Distribution:")
    display(italy_df["nutriscore_grade"].value_counts())

if "nova_group" in italy_df.columns:
    print("\nNOVA Distribution:")
    display(italy_df["nova_group"].value_counts())

if "ecoscore_grade" in italy_df.columns:
    print("\nEco-Score Distribution:")
    display(italy_df["ecoscore_grade"].value_counts())

print("\nNutritional Statistics:")
display(pd.DataFrame({
    "Metric": [
        "Average Sugar", "Median Sugar", "Maximum Sugar",
        "Average Energy", "Median Energy", "Maximum Energy"
    ],
    "Value": [
        italy_sugar.mean(), italy_sugar.median(), italy_sugar.max(),
        italy_energy.mean(), italy_energy.median(), italy_energy.max()
    ]
}).round(2))

if {"nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"}.issubset(italy_df.columns):
    italy_nutrition = italy_df[
        ["nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"]
    ].dropna()

    if not italy_nutrition.empty:
        italy_sugar_energy_corr = (
            italy_nutrition["nutriments.sugars_100g_num"]
            .corr(italy_nutrition["nutriments.energy-kcal_100g_num"])
        )
        print("\nSugar–Energy Correlation:", round(float(italy_sugar_energy_corr), 3))
    else:
        italy_sugar_energy_corr = float("nan")
        print("\nSugar–Energy Correlation: not available (no valid nutritional records for Italy).")
else:
    italy_sugar_energy_corr = float("nan")
    print("\nSugar–Energy Correlation: not available (required nutrient columns are missing).")
print("\nAnalysis completed for Italy.")
# Out:
# ======================================================================
#  ITALY – ADVANCED DATA ANALYSIS SUMMARY
# ======================================================================
#
# Total Records: 315
# Unique Products: 263
# Unique Brands: 126
#
# Top 5 Brands:
#                     Brand  Product_Count
# 0                 Unknown             79
# 1                   Fanta             29
# 2     Fantasie Aromatiche             27
# 3  Fantasy, Menz & Gasser              8
# 4        Gusto e fantasia              6
# Top 5 Categories:
# categories_tags
# plant-based-foods-and-beverages    75
# plant-based-foods                  66
# beverages                          20
# frozen-foods                       17
# snacks                             16
# Name: count, dtype: int64
# Top Packaging Types:
# packaging_tags
# it:bottiglia-pet     13
# plastic               7
# paper                 4
# metal                 4
# recyclable-metals     4
# Name: count, dtype: int64
# Top Stores:
# stores
# Coop         5
# Eurospin     3
# Bennet       3
# Esselunga    2
# Conad        2
# Name: count, dtype: int64
# Top Purchase Places:
# purchase_places
# Italia              6
# Mazara del Vallo    1
# Trapani             1
# Name: count, dtype: int64
# Nutri-Score Distribution:
# nutriscore_grade
# unknown           206
# d                  26
# c                  25
# a                  18
# e                  16
# b                  14
# not-applicable      9
# Unknown             1
# Name: count, dtype: int64
# NOVA Distribution:
# nova_group
# Unknown    279
# 4.0         23
# 3.0          7
# 1.0          6
# Name: count, dtype: int64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown    314
# unknown      1
# Name: count, dtype: int64
# Nutritional Statistics:
#            Metric  Value
# 0   Average Sugar    NaN
# 1    Median Sugar    NaN
# 2   Maximum Sugar    NaN
# 3  Average Energy    NaN
# 4   Median Energy    NaN
# 5  Maximum Energy    NaN
# Sugar–Energy Correlation: not available (no valid nutritional records for Italy).
#
# Analysis completed for Italy.

# %% [markdown]
# ### Italy — Observation and Insight
#
# Italy contributes **315 records**, **263 unique products**, and **126 brands**, giving it the highest brand diversity among the five countries despite having fewer records than the United States. This indicates a relatively broad brand mix in the Italian portion of the catalog. Nutritional comparisons should be interpreted cautiously because many Italian nutrition fields are unavailable after numeric cleaning.

# %% [markdown]
# #  PART — UNITED KINGDOM
#
# The same complete analysis framework is applied to **United Kingdom only**.

# %%
# ============================================================
# UNITED KINGDOM DATASET
# ============================================================

uk_df = df[
    df["countries_tags"].astype(str).str.lower() == "united-kingdom"
].copy()

print("UNITED KINGDOM DATASET")
print("=" * 60)
print("Records:", len(uk_df))
print("Attributes:", len(uk_df.columns))
display(uk_df.head())
# Out:
# UNITED KINGDOM DATASET
# ============================================================
# Records: 143
# Attributes: 17
#              code       product_name            brands  \
# 7        20284299     Fantail Prawns    OceanSea,Tesco
# 15  5000112628944  Fanta Fruit Twist             Fanta
# 21  5000112631593  Fanta fruit twist             Fanta
# 22  5449000265197              Fanta  Fanta, Coco Coka
# 23  5000112639605        Fanta Grape             Fanta
#
#                                                                                                        categories_tags  \
# 7                                                                                seafood, crustaceans, shrimps, prawns
# 15                                                                                                             Unknown
# 21                                                                                                             Unknown
# 22                                                                                                             Unknown
# 23  plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, sodas
#
#     countries_tags                    packaging_tags      stores  \
# 7   united-kingdom  tray, plastic-tray, sleeve-board  Lidl,Tesco
# 15  united-kingdom                        pet-bottle     Unknown
# 21  united-kingdom                           Unknown     Unknown
# 22  united-kingdom                        pet-bottle     Unknown
# 23  united-kingdom                           Unknown     Unknown
#
#      purchase_places nutriscore_grade nova_group ecoscore_grade  \
# 7   Barnet,London,UK                c        3.0        Unknown
# 15           Unknown          unknown    Unknown        Unknown
# 21           Unknown          unknown    Unknown        Unknown
# 22           Unknown          unknown    Unknown        Unknown
# 23           Unknown                b    Unknown        Unknown
#
#                                               ingredients_text  \
# 7   Prawns 95% (_crustaceans_), salt, lactic acid, acetic acid
# 15                                                     Unknown
# 21                                                     Unknown
# 22                                                     Unknown
# 23                                                     Unknown
#
#    nutriments.sugars_100g nutriments.energy-kcal_100g  \
# 7                 Unknown                     Unknown
# 15                Unknown                     Unknown
# 21                Unknown                     Unknown
# 22                Unknown                     Unknown
# 23                Unknown                     Unknown
#
#     nutriments.sugars_100g_num  nutriments.energy-kcal_100g_num  \
# 7                          NaN                              NaN
# 15                         NaN                              NaN
# 21                         NaN                              NaN
# 22                         NaN                              NaN
# 23                         NaN                              NaN
#
#     nova_group_num
# 7              3.0
# 15             NaN
# 21             NaN
# 22             NaN
# 23             NaN

# %%
# ============================================================
# UNITED KINGDOM — BASIC OVERVIEW
# ============================================================

print("Dataset Shape:", uk_df.shape)
print("\nColumn Names:")
print(uk_df.columns.tolist())

print("\nData Types:")
display(uk_df.dtypes)

print("\nStatistical Summary:")
display(uk_df.describe(include="all").T)
# Out:
# Dataset Shape: (143, 17)
#
# Column Names:
# ['code', 'product_name', 'brands', 'categories_tags', 'countries_tags', 'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade', 'nova_group', 'ecoscore_grade', 'ingredients_text', 'nutriments.sugars_100g', 'nutriments.energy-kcal_100g', 'nutriments.sugars_100g_num', 'nutriments.energy-kcal_100g_num', 'nova_group_num']
#
# Data Types:
# code                                object
# product_name                           str
# brands                                 str
# categories_tags                        str
# countries_tags                         str
# packaging_tags                         str
# stores                                 str
# purchase_places                        str
# nutriscore_grade                       str
# nova_group                             str
# ecoscore_grade                         str
# ingredients_text                       str
# nutriments.sugars_100g                 str
# nutriments.energy-kcal_100g            str
# nutriments.sugars_100g_num         float64
# nutriments.energy-kcal_100g_num    float64
# nova_group_num                     float64
# dtype: object
# Statistical Summary:
#                                  count unique             top freq      mean  \
# code                             143.0  143.0      20284299.0  1.0       NaN
# product_name                       143    101           Fanta   14       NaN
# brands                             143     30           Fanta   96       NaN
# categories_tags                    143     35         Unknown   97       NaN
# countries_tags                     143      1  united-kingdom  143       NaN
# packaging_tags                     143      8         Unknown  128       NaN
# stores                             143      6         Unknown  138       NaN
# purchase_places                    143      2         Unknown  142       NaN
# nutriscore_grade                   143      6         unknown  106       NaN
# nova_group                         143      4         Unknown  109       NaN
# ecoscore_grade                     143      3         Unknown  134       NaN
# ingredients_text                   143     41         Unknown  103       NaN
# nutriments.sugars_100g             143      1         Unknown  143       NaN
# nutriments.energy-kcal_100g        143      1         Unknown  143       NaN
# nutriments.sugars_100g_num         0.0    NaN             NaN  NaN       NaN
# nutriments.energy-kcal_100g_num    0.0    NaN             NaN  NaN       NaN
# nova_group_num                    34.0    NaN             NaN  NaN  3.794118
#
#                                       std  min  25%  50%  75%  max
# code                                  NaN  NaN  NaN  NaN  NaN  NaN
# product_name                          NaN  NaN  NaN  NaN  NaN  NaN
# brands                                NaN  NaN  NaN  NaN  NaN  NaN
# categories_tags                       NaN  NaN  NaN  NaN  NaN  NaN
# countries_tags                        NaN  NaN  NaN  NaN  NaN  NaN
# packaging_tags                        NaN  NaN  NaN  NaN  NaN  NaN
# stores                                NaN  NaN  NaN  NaN  NaN  NaN
# purchase_places                       NaN  NaN  NaN  NaN  NaN  NaN
# nutriscore_grade                      NaN  NaN  NaN  NaN  NaN  NaN
# nova_group                            NaN  NaN  NaN  NaN  NaN  NaN
# ecoscore_grade                        NaN  NaN  NaN  NaN  NaN  NaN
# ingredients_text                      NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.sugars_100g                NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.energy-kcal_100g           NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.sugars_100g_num            NaN  NaN  NaN  NaN  NaN  NaN
# nutriments.energy-kcal_100g_num       NaN  NaN  NaN  NaN  NaN  NaN
# nova_group_num                   0.591834  1.0  4.0  4.0  4.0  4.0

# %%
# ============================================================
# UNITED KINGDOM — UNKNOWN VALUE ANALYSIS
# ============================================================

uk_unknown_summary = []

for col in uk_df.columns:
    unknown_count = (
        uk_df[col].astype(str)
        .str.strip()
        .str.lower()
        .eq("unknown")
        .sum()
    )

    uk_unknown_summary.append({
        "Attribute": col,
        "Unknown_Count": unknown_count,
        "Total_Records": len(uk_df),
        "Unknown_Percentage": round(
            unknown_count / len(uk_df) * 100, 2
        )
    })

uk_unknown_df = pd.DataFrame(uk_unknown_summary).sort_values(
    "Unknown_Percentage", ascending=False
)

display(uk_unknown_df)

plt.figure(figsize=(12, 6))
sns.barplot(data=uk_unknown_df,
            x="Unknown_Percentage", y="Attribute")
plt.title("United Kingdom – Unknown Value Percentage by Attribute")
plt.xlabel("Unknown Values (%)")
plt.ylabel("Attribute")
plt.tight_layout()
plt.show()
# Out:
#                           Attribute  Unknown_Count  Total_Records  \
# 13      nutriments.energy-kcal_100g            143            143
# 12           nutriments.sugars_100g            143            143
# 7                   purchase_places            142            143
# 10                   ecoscore_grade            142            143
# 6                            stores            138            143
# 5                    packaging_tags            128            143
# 9                        nova_group            109            143
# 8                  nutriscore_grade            106            143
# 11                 ingredients_text            103            143
# 3                   categories_tags             97            143
# 2                            brands             14            143
# 1                      product_name              4            143
# 0                              code              0            143
# 4                    countries_tags              0            143
# 14       nutriments.sugars_100g_num              0            143
# 15  nutriments.energy-kcal_100g_num              0            143
# 16                   nova_group_num              0            143
#
#     Unknown_Percentage
# 13              100.00
# 12              100.00
# 7                99.30
# 10               99.30
# 6                96.50
# 5                89.51
# 9                76.22
# 8                74.13
# 11               72.03
# 3                67.83
# 2                 9.79
# 1                 2.80
# 0                 0.00
# 4                 0.00
# 14                0.00
# 15                0.00
# 16                0.00

# %% [markdown]
# ###  Observation
#
# The chart shows how complete the available information is for different attributes in United Kingdom. Attributes with a higher percentage of `Unknown` values have less information available, so those fields should be used carefully when comparing products.

# %%
# ============================================================
# UNITED KINGDOM — PRODUCT ANALYSIS
# ============================================================

uk_product_counts = (
    uk_df["product_name"].value_counts().reset_index()
)
uk_product_counts.columns = ["Product_Name", "Frequency"]

print("Top 20 Products:")
display(uk_product_counts.head(20))

print("Total Product Records:", len(uk_df))
print("Unique Products:", uk_df["product_name"].nunique())
print(
    "Product Uniqueness Rate:",
    round(uk_df["product_name"].nunique() / len(uk_df) * 100, 2),
    "%"
)

plt.figure(figsize=(12, 7))
sns.barplot(data=uk_product_counts.head(15),
            x="Frequency", y="Product_Name")
plt.title("United Kingdom – Top 15 Products")
plt.xlabel("Number of Records")
plt.ylabel("Product")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Products:
#                    Product_Name  Frequency
# 0                         Fanta         14
# 1             Fanta fruit twist          6
# 2                  Fanta Orange          6
# 3                   Fanta Lemon          4
# 4                       Unknown          4
# 5                   Fanta Grape          3
# 6                   Fruit Twist          3
# 7             Fanta Fruit Twist          2
# 8                  Fanta exotic          2
# 9                  Fanta orange          2
# 10            fanta fruit twist          2
# 11                 Fanta Cherry          2
# 12             Fantasy brownies          2
# 13                        Lemon          2
# 14                       Orange          2
# 15                        fanta          2
# 16               Fantail Prawns          1
# 17           Fanta Orange 500ml          1
# 18  Fantastically fruity muesli          1
# 19                #WhatTheFanta          1
# Total Product Records: 143
# Unique Products: 101
# Product Uniqueness Rate: 70.63 %

# %% [markdown]
# ###  Observation
#
# The chart shows the products that appear most often in the United Kingdom data. A few products occur more frequently, while many others appear only a small number of times. This gives a quick idea of which products are most represented in this dataset.

# %%
# ============================================================
# UNITED KINGDOM — BRAND ANALYSIS
# ============================================================

uk_brand_counts = (
    uk_df["brands"].value_counts().reset_index()
)
uk_brand_counts.columns = ["Brand", "Product_Count"]

print("Top 20 Brands:")
display(uk_brand_counts.head(20))

print("Unique Brands:", uk_df["brands"].nunique())

uk_brand_diversity = (
    uk_df["brands"].nunique() / len(uk_df) * 100
)
print("Brand Diversity Ratio:", round(uk_brand_diversity, 2), "%")

plt.figure(figsize=(12, 7))
sns.barplot(data=uk_brand_counts.head(15),
            x="Product_Count", y="Brand")
plt.title("United Kingdom – Top 15 Brands")
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Brands:
#                Brand  Product_Count
# 0              Fanta             96
# 1            Unknown             14
# 2          Coca Cola              3
# 3     Brompton House              3
# 4           Sunfeast              2
# 5     OceanSea,Tesco              1
# 6   Fanta, Coco Coka              1
# 7      Sierra, Fanta              1
# 8     Dorset cereals              1
# 9          Gelatelli              1
# 10  Fanta, Coca-Cola              1
# 11         Coca cola              1
# 12    cryspy fantasy              1
# 13            Mentos              1
# 14    crispy Fantasy              1
# 15              Asda              1
# 16    Crispy Fantasy              1
# 17       Ice Fantasy              1
# 18       Santa Maria              1
# 19      Four Seasons              1
# Unique Brands: 30
# Brand Diversity Ratio: 20.98 %

# %% [markdown]
# ###  Observation
#
# The chart shows the brands that are most represented in the United Kingdom data. Some brands have noticeably more records than others, while `Unknown` also appears where brand information is missing. This means the brand distribution is not evenly spread.

# %%
# ============================================================
# UNITED KINGDOM — CATEGORY ANALYSIS
# ============================================================

uk_category_series = (
    uk_df["categories_tags"].astype(str)
    .str.split(",").explode().str.strip()
)

uk_category_series = uk_category_series[
    uk_category_series.str.lower() != "unknown"
]

uk_category_counts = uk_category_series.value_counts()

print("Top 25 Categories:")
display(uk_category_counts.head(25))

uk_top_categories = uk_category_counts.head(15).reset_index()
uk_top_categories.columns = ["Category", "Product_Count"]

plt.figure(figsize=(12, 8))
sns.barplot(data=uk_top_categories,
            x="Product_Count", y="Category")
plt.title("United Kingdom – Top 15 Product Categories")
plt.xlabel("Product Count")
plt.ylabel("Category")
plt.tight_layout()
plt.show()
# Out:
# Top 25 Categories:
# categories_tags
# beverages                               34
# carbonated-drinks                       25
# sodas                                   23
# beverages-and-beverages-preparations    22
# plant-based-foods-and-beverages         18
# plant-based-beverages                   15
# fruit-based-beverages                   15
# fruit-sodas                             14
# sweetened-beverages                     11
# artificially-sweetened-beverages         9
# orange-soft-drinks                       6
# snacks                                   5
# sweet-snacks                             5
# plant-based-foods                        3
# breakfasts                               3
# cereals-and-potatoes                     3
# cereals-and-their-products               3
# breakfast-cereals                        3
# biscuits-and-cakes                       3
# carbonated-fruit-soft-drink              3
# mueslis                                  2
# desserts                                 2
# frozen-foods                             2
# frozen-desserts                          2
# ice-creams-and-sorbets                   2
# Name: count, dtype: int64

# %% [markdown]
# ###  Observation
#
# The chart shows the main product categories in the United Kingdom data. The larger bars represent categories with more product records, while the smaller categories have fewer records. Overall, the chart gives a simple picture of the types of products represented in this country.

# %%
# ============================================================
# UNITED KINGDOM — PACKAGING, STORE AND PURCHASE PLACE
# ============================================================

def analyze_multivalue_attribute(country_df, column, label):
    if column not in country_df.columns:
        print(f"Column not found: {column}")
        return pd.Series(dtype="int64")

    s = country_df[column].astype(str).str.split(",").explode().str.strip()
    s = s[s.str.lower() != "unknown"]
    counts = s.value_counts()

    print(f"Top {label}:")
    display(counts.head(20).to_frame("Count"))
    return counts

uk_packaging_counts = analyze_multivalue_attribute(
    uk_df, "packaging_tags", "Packaging Types"
)
uk_store_counts = analyze_multivalue_attribute(
    uk_df, "stores", "Stores"
)
uk_purchase_counts = analyze_multivalue_attribute(
    uk_df, "purchase_places", "Purchase Places"
)
# Out:
# Top Packaging Types:
#                              Count
# packaging_tags
# pet-bottle                      10
# glass-bottle                     2
# tray                             1
# plastic-tray                     1
# sleeve-board                     1
# pet-cap                          1
# bottle-or-vial                   1
# bottle                           1
# ldpe-bag                         1
# 1-plastic-bottle-to-recycle      1
# 1-plastic-lid                    1
# Top Stores:
#         Count
# stores
# Tesco       2
# Lidl        1
# migros      1
# B&M         1
# ASDA        1
# Top Purchase Places:
#                  Count
# purchase_places
# Barnet               1
# London               1
# UK                   1

# %%
# ============================================================
# UNITED KINGDOM — NUTRI-SCORE, NOVA AND ECO-SCORE
# ============================================================

for col, label in [
    ("nutriscore_grade", "Nutri-Score"),
    ("nova_group", "NOVA Group"),
    ("ecoscore_grade", "Eco-Score")
]:
    if col in uk_df.columns:
        counts = uk_df[col].value_counts()
        print(f"{label} Distribution:")
        display(counts)
        print(f"{label} Percentage:")
        display(uk_df[col].value_counts(normalize=True).mul(100).round(2))

        plt.figure(figsize=(9, 5))
        sns.countplot(
            data=uk_df,
            x=col,
            order=uk_df[col].value_counts().index
        )
        plt.title(f"United Kingdom – {label} Distribution")
        plt.xlabel(label)
        plt.ylabel("Number of Products")
        plt.tight_layout()
        plt.show()
# Out:
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    106
# c           14
# d           11
# b            6
# e            5
# a            1
# Name: count, dtype: int64
# Nutri-Score Percentage:
# nutriscore_grade
# unknown    74.13
# c           9.79
# d           7.69
# b           4.20
# e           3.50
# a           0.70
# Name: proportion, dtype: float64
# NOVA Group Distribution:
# nova_group
# Unknown    109
# 4.0         29
# 3.0          4
# 1.0          1
# Name: count, dtype: int64
# NOVA Group Percentage:
# nova_group
# Unknown    76.22
# 4.0        20.28
# 3.0         2.80
# 1.0         0.70
# Name: proportion, dtype: float64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           134
# unknown             8
# not-applicable      1
# Name: count, dtype: int64
# Eco-Score Percentage:
# ecoscore_grade
# Unknown           93.71
# unknown            5.59
# not-applicable     0.70
# Name: proportion, dtype: float64

# %% [markdown]
# ###  Observation
#
# The charts show the distribution of Nutri-Score, NOVA Group and Eco-Score values in the United Kingdom data. Some categories have more records than others, but the number of `Unknown` values also needs to be considered when reading these results.

# %% [markdown]
# ###  Observation
#
# The charts show how sugar and energy values are spread across the products in United Kingdom. The distributions are not completely even, and some products are much higher than the rest. This suggests that a small number of products may have a strong effect on the average values.

# %%
# ============================================================
# UNITED KINGDOM — OUTLIER ANALYSIS
# ============================================================

def find_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return series[(series < lower) | (series > upper)]

uk_sugar_outliers = find_outliers(uk_sugar)
uk_energy_outliers = find_outliers(uk_energy)

print("Sugar Outliers:", len(uk_sugar_outliers))
print("Energy Outliers:", len(uk_energy_outliers))

print("\nHighest Sugar Products:")
display(
    uk_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.sugars_100g_num"]
    ].dropna(subset=["nutriments.sugars_100g_num"])
     .sort_values("nutriments.sugars_100g_num", ascending=False)
     .head(20)
)

print("\nHighest Energy Products:")
display(
    uk_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.energy-kcal_100g_num"]
    ].dropna(subset=["nutriments.energy-kcal_100g_num"])
     .sort_values("nutriments.energy-kcal_100g_num", ascending=False)
     .head(20)
)
# Out:
# Sugar Outliers: 0
# Energy Outliers: 0
#
# Highest Sugar Products:
# Empty DataFrame
# Columns: [product_name, brands, categories_tags, nutriments.sugars_100g_num]
# Index: []
# Highest Energy Products:
# Empty DataFrame
# Columns: [product_name, brands, categories_tags, nutriments.energy-kcal_100g_num]
# Index: []

# %%
# ============================================================
# UNITED KINGDOM — BRAND NUTRITION ANALYSIS
# ============================================================

uk_brand_nutrition = (
    uk_df.groupby("brands")
    .agg(
        Product_Count=("product_name", "count"),
        Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
        Median_Sugar=("nutriments.sugars_100g_num", "median"),
        Avg_Energy=("nutriments.energy-kcal_100g_num", "mean"),
        Median_Energy=("nutriments.energy-kcal_100g_num", "median")
    )
    .reset_index()
)

uk_brand_nutrition = (
    uk_brand_nutrition[
        uk_brand_nutrition["Product_Count"] >= 3
    ]
    .sort_values("Product_Count", ascending=False)
)

display(uk_brand_nutrition.head(20))
# Out:
#             brands  Product_Count  Avg_Sugar  Median_Sugar  Avg_Energy  \
# 12           Fanta             96        NaN           NaN         NaN
# 26         Unknown             14        NaN           NaN         NaN
# 3        Coca Cola              3        NaN           NaN         NaN
# 1   Brompton House              3        NaN           NaN         NaN
#
#     Median_Energy
# 12            NaN
# 26            NaN
# 3             NaN
# 1             NaN

# %% [markdown]
# ###  Observation
#
# The chart compares sugar levels across different Nutri-Score groups in United Kingdom. The groups do not have the same sugar distribution, which shows that products with different Nutri-Scores can have noticeably different sugar levels.

# %% [markdown]
# ###  Observation
#
# The chart compares sugar levels across NOVA processing groups in United Kingdom. The groups show different sugar distributions, although missing NOVA information means the comparison does not cover every product.

# %%
# ============================================================
# UNITED KINGDOM — CORRELATION
# ============================================================

corr_cols = [
    "nova_group_num",
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

available_corr_cols = [c for c in corr_cols if c in uk_df.columns]

uk_corr = uk_df[available_corr_cols].corr()

display(uk_corr.round(3))

plt.figure(figsize=(8, 6))
sns.heatmap(
    uk_corr,
    annot=True,
    cmap="coolwarm",
    center=0,
    fmt=".2f"
)
plt.title("United Kingdom – Nutritional Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
#                                  nova_group_num  nutriments.sugars_100g_num  \
# nova_group_num                              1.0                         NaN
# nutriments.sugars_100g_num                  NaN                         NaN
# nutriments.energy-kcal_100g_num             NaN                         NaN
#
#                                  nutriments.energy-kcal_100g_num
# nova_group_num                                               NaN
# nutriments.sugars_100g_num                                   NaN
# nutriments.energy-kcal_100g_num                              NaN

# %%
# ============================================================
# UNITED KINGDOM — INGREDIENT ANALYSIS
# ============================================================

if "ingredients_text" in uk_df.columns:

    ingredient_text = uk_df["ingredients_text"].astype(str).str.lower()
    all_ingredients = []

    for text in ingredient_text:
        if text != "unknown":
            for ingredient in text.split(","):
                ingredient = ingredient.strip()
                if ingredient and ingredient != "unknown":
                    all_ingredients.append(ingredient)

    uk_ingredient_counts = Counter(all_ingredients)

    uk_ingredient_df = pd.DataFrame(
        uk_ingredient_counts.most_common(30),
        columns=["Ingredient", "Frequency"]
    )

    display(uk_ingredient_df)

    plt.figure(figsize=(12, 8))
    sns.barplot(
        data=uk_ingredient_df.head(15),
        x="Frequency",
        y="Ingredient"
    )
    plt.title("United Kingdom – Most Frequently Reported Ingredients")
    plt.xlabel("Frequency")
    plt.ylabel("Ingredient")
    plt.tight_layout()
    plt.show()
# Out:
#                                                    Ingredient  Frequency
# 0                                            carbonated water         19
# 1                                                       sugar         13
# 2                                          acid (citric acid)          8
# 3                            preservative (potassium sorbate)          8
# 4                                         natural flavourings          6
# 5                                          acids (citric acid          6
# 6                                                        salt          5
# 7                                               glucose syrup          5
# 8                                                  sucralose)          4
# 9                                                 malic acid)          4
# 10                        acidity regulator (sodium citrates)          4
# 11                                   sweeteners (acesulfame k          4
# 12                            preservative (sulphur dioxide))          3
# 13                          lemon juice from concentrate (3%)          3
# 14                fruit juices from concentrate 5% (pineapple          3
# 15                            glycerol esters of wood rosins)          3
# 16                                antioxidant (ascorbic acid)          3
# 17                                    stabilisers (acacia gum          3
# 18                                                     zucker          3
# 19                            apple juice from concentrate (3          2
# 20                                                     lemon)          2
# 21                               sweeteners (sodium cyclamate          2
# 22                                               acesulfame-k          2
# 23                                colour (brilliant blue fcf)          2
# 24                       orange juice from concentrate (3.7%)          2
# 25                       citrus fruit from concentrate (1.3%)          2
# 26                                 vegetable extracts (carrot          2
# 27                                                   pumpkin)          2
# 28                                      stabiliser (guar gum)          2
# 29  natural orange flavourings with other natural flavourings          2

# %% [markdown]
# ###  Observation
#
# The ingredient chart shows the ingredients that appear most often in the United Kingdom data. A few ingredients occur repeatedly, while many others appear less often. Missing or undefined ingredient entries should be kept in mind when interpreting the chart.

# %%
# ============================================================
# UNITED KINGDOM — CATEGORY VS NUTRITION
# ============================================================

if "categories_tags" in uk_df.columns:

    uk_category_nutrition = (
        uk_df.groupby("categories_tags")
        .agg(
            Product_Count=("product_name", "count"),
            Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
            Avg_Energy=("nutriments.energy-kcal_100g_num", "mean")
        )
        .reset_index()
    )

    uk_category_nutrition = (
        uk_category_nutrition[
            uk_category_nutrition["Product_Count"] >= 2
        ]
        .sort_values("Product_Count", ascending=False)
    )

    display(uk_category_nutrition.head(20))
# Out:
#                                                                                                             categories_tags  \
# 1                                                                                                                   Unknown
# 5                                                                                       beverages, carbonated-drinks, sodas
# 20  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 12                                                           beverages-and-beverages-preparations, beverages, energy-drinks
# 2                                                                                                                 beverages
# 13                                                     beverages-and-beverages-preparations, beverages, sweetened-beverages
# 17  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 22  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 32                                               snacks, sweet-snacks, biscuits-and-cakes, cakes, chocolate-cakes, brownies
#
#     Product_Count  Avg_Sugar  Avg_Energy
# 1              97        NaN         NaN
# 5               5        NaN         NaN
# 20              3        NaN         NaN
# 12              2        NaN         NaN
# 2               2        NaN         NaN
# 13              2        NaN         NaN
# 17              2        NaN         NaN
# 22              2        NaN         NaN
# 32              2        NaN         NaN

# %%
# ============================================================
# UNITED KINGDOM — ATTRIBUTE-LEVEL ANALYSIS
# ============================================================

categorical_columns = [
    "brands",
    "categories_tags",
    "packaging_tags",
    "stores",
    "purchase_places",
    "nutriscore_grade",
    "nova_group",
    "ecoscore_grade"
]

for col in categorical_columns:
    if col in uk_df.columns:
        print("\n" + "=" * 70)
        print(f"ATTRIBUTE: {col}")
        print("=" * 70)

        counts = (
            uk_df[col]
            .astype(str)
            .value_counts()
            .head(15)
        )

        display(counts.to_frame("Count"))
# Out:
# ======================================================================
# ATTRIBUTE: brands
# ======================================================================
#                   Count
# brands
# Fanta                96
# Unknown              14
# Coca Cola             3
# Brompton House        3
# Sunfeast              2
# OceanSea,Tesco        1
# Fanta, Coco Coka      1
# Sierra, Fanta         1
# Dorset cereals        1
# Gelatelli             1
# Fanta, Coca-Cola      1
# Coca cola             1
# cryspy fantasy        1
# Mentos                1
# crispy Fantasy        1
# ======================================================================
# ATTRIBUTE: categories_tags
# ======================================================================
#                                                                                                                           Count
# categories_tags
# Unknown                                                                                                                      97
# beverages, carbonated-drinks, sodas                                                                                           5
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      3
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      2
# beverages                                                                                                                     2
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      2
# snacks, sweet-snacks, biscuits-and-cakes, cakes, chocolate-cakes, brownies                                                    2
# beverages-and-beverages-preparations, beverages, sweetened-beverages                                                          2
# beverages-and-beverages-preparations, beverages, energy-drinks                                                                2
# seafood, crustaceans, shrimps, prawns                                                                                         1
# plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, sodas            1
# plant-based-foods-and-beverages, plant-based-foods, breakfasts, cereals-and-potatoes, cereals-and-their-products, bre...      1
# Juice                                                                                                                         1
# beverages, artificially-sweetened-beverages                                                                                   1
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      1
# ======================================================================
# ATTRIBUTE: packaging_tags
# ======================================================================
#                                             Count
# packaging_tags
# Unknown                                       128
# pet-bottle                                      8
# glass-bottle                                    2
# tray, plastic-tray, sleeve-board                1
# pet-bottle, pet-cap                             1
# bottle-or-vial, bottle, pet-bottle              1
# ldpe-bag                                        1
# 1-plastic-bottle-to-recycle, 1-plastic-lid      1
# ======================================================================
# ATTRIBUTE: stores
# ======================================================================
#             Count
# stores
# Unknown       138
# Lidl,Tesco      1
# migros          1
# B&M             1
# ASDA            1
# Tesco           1
# ======================================================================
# ATTRIBUTE: purchase_places
# ======================================================================
#                   Count
# purchase_places
# Unknown             142
# Barnet,London,UK      1
# ======================================================================
# ATTRIBUTE: nutriscore_grade
# ======================================================================
#                   Count
# nutriscore_grade
# unknown             106
# c                    14
# d                    11
# b                     6
# e                     5
# a                     1
# ======================================================================
# ATTRIBUTE: nova_group
# ======================================================================
#             Count
# nova_group
# Unknown       109
# 4.0            29
# 3.0             4
# 1.0             1
# ======================================================================
# ATTRIBUTE: ecoscore_grade
# ======================================================================
#                 Count
# ecoscore_grade
# Unknown           134
# unknown             8
# not-applicable      1

# %%
# ============================================================
# UNITED KINGDOM — NUMERICAL ATTRIBUTE ANALYSIS
# ============================================================

numerical_columns = [
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

uk_numeric_summary = []

for col in numerical_columns:
    if col in uk_df.columns:
        uk_numeric_summary.append({
            "Attribute": col,
            "Count": uk_df[col].count(),
            "Mean": uk_df[col].mean(),
            "Median": uk_df[col].median(),
            "Std": uk_df[col].std(),
            "Minimum": uk_df[col].min(),
            "Maximum": uk_df[col].max()
        })

uk_numeric_summary = pd.DataFrame(uk_numeric_summary)
display(uk_numeric_summary.round(2))
# Out:
#                          Attribute  Count  Mean  Median  Std  Minimum  Maximum
# 0       nutriments.sugars_100g_num      0   NaN     NaN  NaN      NaN      NaN
# 1  nutriments.energy-kcal_100g_num      0   NaN     NaN  NaN      NaN      NaN

# %%
# ============================================================
# UNITED KINGDOM — DATA QUALITY CHECK
# ============================================================

print("UNITED KINGDOM DATA QUALITY CHECK")
print("=" * 60)

print("Duplicate Rows:", uk_df.duplicated().sum())
print("Duplicate Product Names:", uk_df["product_name"].duplicated().sum())
print("Unique Products:", uk_df["product_name"].nunique())
print("Unique Brands:", uk_df["brands"].nunique())
print("Records:", len(uk_df))
# Out:
# UNITED KINGDOM DATA QUALITY CHECK
# ============================================================
# Duplicate Rows: 0
# Duplicate Product Names: 42
# Unique Products: 101
# Unique Brands: 30
# Records: 143

# %%
# ============================================================
# UNITED KINGDOM — FINAL SUMMARY
# ============================================================

print("=" * 70)
print(" UNITED KINGDOM – ADVANCED DATA ANALYSIS SUMMARY")
print("=" * 70)

print(f"\nTotal Records: {len(uk_df):,}")
print(f"Unique Products: {uk_df['product_name'].nunique():,}")
print(f"Unique Brands: {uk_df['brands'].nunique():,}")

print("\nTop 5 Brands:")
display(uk_brand_counts.head(5))

print("\nTop 5 Categories:")
display(uk_category_counts.head(5))

print("\nTop Packaging Types:")
display(uk_packaging_counts.head(5))

print("\nTop Stores:")
display(uk_store_counts.head(5))

print("\nTop Purchase Places:")
display(uk_purchase_counts.head(5))

if "nutriscore_grade" in uk_df.columns:
    print("\nNutri-Score Distribution:")
    display(uk_df["nutriscore_grade"].value_counts())

if "nova_group" in uk_df.columns:
    print("\nNOVA Distribution:")
    display(uk_df["nova_group"].value_counts())

if "ecoscore_grade" in uk_df.columns:
    print("\nEco-Score Distribution:")
    display(uk_df["ecoscore_grade"].value_counts())

print("\nNutritional Statistics:")
display(pd.DataFrame({
    "Metric": [
        "Average Sugar", "Median Sugar", "Maximum Sugar",
        "Average Energy", "Median Energy", "Maximum Energy"
    ],
    "Value": [
        uk_sugar.mean(), uk_sugar.median(), uk_sugar.max(),
        uk_energy.mean(), uk_energy.median(), uk_energy.max()
    ]
}).round(2))

if {"nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"}.issubset(uk_df.columns):
    uk_nutrition = uk_df[
        ["nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"]
    ].dropna()

    if not uk_nutrition.empty:
        uk_sugar_energy_corr = (
            uk_nutrition["nutriments.sugars_100g_num"]
            .corr(uk_nutrition["nutriments.energy-kcal_100g_num"])
        )
        print("\nSugar–Energy Correlation:", round(float(uk_sugar_energy_corr), 3))
    else:
        uk_sugar_energy_corr = float("nan")
        print("\nSugar–Energy Correlation: not available (no valid nutritional records for United Kingdom).")
else:
    uk_sugar_energy_corr = float("nan")
    print("\nSugar–Energy Correlation: not available (required nutrient columns are missing).")
print("\nAnalysis completed for United Kingdom.")
# Out:
# ======================================================================
#  UNITED KINGDOM – ADVANCED DATA ANALYSIS SUMMARY
# ======================================================================
#
# Total Records: 143
# Unique Products: 101
# Unique Brands: 30
#
# Top 5 Brands:
#             Brand  Product_Count
# 0           Fanta             96
# 1         Unknown             14
# 2       Coca Cola              3
# 3  Brompton House              3
# 4        Sunfeast              2
# Top 5 Categories:
# categories_tags
# beverages                               34
# carbonated-drinks                       25
# sodas                                   23
# beverages-and-beverages-preparations    22
# plant-based-foods-and-beverages         18
# Name: count, dtype: int64
# Top Packaging Types:
# packaging_tags
# pet-bottle      10
# glass-bottle     2
# tray             1
# plastic-tray     1
# sleeve-board     1
# Name: count, dtype: int64
# Top Stores:
# stores
# Tesco     2
# Lidl      1
# migros    1
# B&M       1
# ASDA      1
# Name: count, dtype: int64
# Top Purchase Places:
# purchase_places
# Barnet    1
# London    1
# UK        1
# Name: count, dtype: int64
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    106
# c           14
# d           11
# b            6
# e            5
# a            1
# Name: count, dtype: int64
# NOVA Distribution:
# nova_group
# Unknown    109
# 4.0         29
# 3.0          4
# 1.0          1
# Name: count, dtype: int64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           134
# unknown             8
# not-applicable      1
# Name: count, dtype: int64
# Nutritional Statistics:
#            Metric  Value
# 0   Average Sugar    NaN
# 1    Median Sugar    NaN
# 2   Maximum Sugar    NaN
# 3  Average Energy    NaN
# 4   Median Energy    NaN
# 5  Maximum Energy    NaN
# Sugar–Energy Correlation: not available (no valid nutritional records for United Kingdom).
#
# Analysis completed for United Kingdom.

# %% [markdown]
# ### United Kingdom — Observation and Insight
#
# The United Kingdom section contains **143 records**, **101 unique products**, and **30 brands**. The smaller catalog means its distributions are more sensitive to individual products, so comparisons with larger country samples should be treated as directional rather than definitive. The same caution applies to nutrition-based conclusions because several United Kingdom nutrition values are not available for numeric analysis.

# %% [markdown]
# #  PART — AUSTRALIA
#
# The same complete analysis framework is applied to **Australia only**.

# %%
# ============================================================
# AUSTRALIA DATASET
# ============================================================

australia_df = df[
    df["countries_tags"].astype(str).str.lower() == "australia"
].copy()

print("AUSTRALIA DATASET")
print("=" * 60)
print("Records:", len(australia_df))
print("Attributes:", len(australia_df.columns))
display(australia_df.head())
# Out:
# AUSTRALIA DATASET
# ============================================================
# Records: 95
# Attributes: 17
#              code                                          product_name  \
# 17  9310155003223  Crinkle Cut Snacks Sweet Chilli & Sour Cream Flavour
# 31  9310155010221                      Gluten Free Rice Noodles Chicken
# 32  9310155711302                           Fantastic Noodles beef bowl
# 39  9310155010139                                       Honey Baked Ham
# 62  9300675013444                                                 Fanta
#
#        brands  \
# 17  Fantastic
# 31  Fantastic
# 32  Fantastic
# 39  Fantastic
# 62  Coca-Cola
#
#                                                                                                             categories_tags  \
# 17                                             snacks, salty-snacks, appetizers, biscuits-and-crackers, crackers-appetizers
# 31  plant-based-foods-and-beverages, plant-based-foods, dried-products, pastas, dried-products-to-be-rehydrated, noodles...
# 32  plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products, dried-products...
# 39                                                                                                                  Unknown
# 62                                                                                      beverages, carbonated-drinks, sodas
#
#    countries_tags  packaging_tags      stores purchase_places  \
# 17      australia         Unknown     Unknown         Unknown
# 31      australia         Unknown  Woolworths         Unknown
# 32      australia         Unknown     Unknown         Unknown
# 39      australia         Unknown     Unknown         Unknown
# 62      australia  plastic-bottle     Unknown         Unknown
#
#    nutriscore_grade nova_group  ecoscore_grade  \
# 17                d        4.0         Unknown
# 31          unknown        4.0         Unknown
# 32          unknown        4.0         Unknown
# 39          unknown    Unknown         unknown
# 62          unknown    Unknown  not-applicable
#
#                                                                                                            ingredients_text  \
# 17  rice flour (53%), maize starch, seasoning (sugar, maltodextrin, salt, flavour enhancers (e621, e635), flavour (soy, ...
# 31  ingredients noodles: rice noodles: rice flour (90%), tapioca starch, flavour sachet: salt, flavour,herbs and spices,...
# 32  wheat flour, vegetable oil (antioxidant (319)), modified starch (1420), salt, mineral salts (501, 500, 451), vegetab...
# 39                                                                                                                  Unknown
# 62                                                                                                                  Unknown
#
#    nutriments.sugars_100g nutriments.energy-kcal_100g  \
# 17                Unknown                     Unknown
# 31        2.7605633802817             45.175450704225
# 32                Unknown                     Unknown
# 39                    4.4                       413.0
# 62                    4.5                        19.0
#
#     nutriments.sugars_100g_num  nutriments.energy-kcal_100g_num  \
# 17                         NaN                              NaN
# 31                    2.760563                        45.175451
# 32                         NaN                              NaN
# 39                    4.400000                       413.000000
# 62                    4.500000                        19.000000
#
#     nova_group_num
# 17             4.0
# 31             4.0
# 32             4.0
# 39             NaN
# 62             NaN

# %%
# ============================================================
# AUSTRALIA — BASIC OVERVIEW
# ============================================================

print("Dataset Shape:", australia_df.shape)
print("\nColumn Names:")
print(australia_df.columns.tolist())

print("\nData Types:")
display(australia_df.dtypes)

print("\nStatistical Summary:")
display(australia_df.describe(include="all").T)
# Out:
# Dataset Shape: (95, 17)
#
# Column Names:
# ['code', 'product_name', 'brands', 'categories_tags', 'countries_tags', 'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade', 'nova_group', 'ecoscore_grade', 'ingredients_text', 'nutriments.sugars_100g', 'nutriments.energy-kcal_100g', 'nutriments.sugars_100g_num', 'nutriments.energy-kcal_100g_num', 'nova_group_num']
#
# Data Types:
# code                                object
# product_name                           str
# brands                                 str
# categories_tags                        str
# countries_tags                         str
# packaging_tags                         str
# stores                                 str
# purchase_places                        str
# nutriscore_grade                       str
# nova_group                             str
# ecoscore_grade                         str
# ingredients_text                       str
# nutriments.sugars_100g                 str
# nutriments.energy-kcal_100g            str
# nutriments.sugars_100g_num         float64
# nutriments.energy-kcal_100g_num    float64
# nova_group_num                     float64
# dtype: object
# Statistical Summary:
#                                 count unique              top freq  \
# code                             95.0   95.0  9310155003223.0  1.0
# product_name                       95     90            Fanta    2
# brands                             95     16        Fantastic   36
# categories_tags                    95     11          Unknown   76
# countries_tags                     95      1        australia   95
# packaging_tags                     95      3          Unknown   93
# stores                             95      8          Unknown   81
# purchase_places                    95      2          Unknown   94
# nutriscore_grade                   95      4          unknown   91
# nova_group                         95      2          Unknown   69
# ecoscore_grade                     95      3          Unknown   64
# ingredients_text                   95     33          Unknown   62
# nutriments.sugars_100g             95     38          Unknown   41
# nutriments.energy-kcal_100g        95     52          Unknown   38
# nutriments.sugars_100g_num       54.0    NaN              NaN  NaN
# nutriments.energy-kcal_100g_num  57.0    NaN              NaN  NaN
# nova_group_num                   26.0    NaN              NaN  NaN
#
#                                        mean         std  min       25%   50%  \
# code                                    NaN         NaN  NaN       NaN   NaN
# product_name                            NaN         NaN  NaN       NaN   NaN
# brands                                  NaN         NaN  NaN       NaN   NaN
# categories_tags                         NaN         NaN  NaN       NaN   NaN
# countries_tags                          NaN         NaN  NaN       NaN   NaN
# packaging_tags                          NaN         NaN  NaN       NaN   NaN
# stores                                  NaN         NaN  NaN       NaN   NaN
# purchase_places                         NaN         NaN  NaN       NaN   NaN
# nutriscore_grade                        NaN         NaN  NaN       NaN   NaN
# nova_group                              NaN         NaN  NaN       NaN   NaN
# ecoscore_grade                          NaN         NaN  NaN       NaN   NaN
# ingredients_text                        NaN         NaN  NaN       NaN   NaN
# nutriments.sugars_100g                  NaN         NaN  NaN       NaN   NaN
# nutriments.energy-kcal_100g             NaN         NaN  NaN       NaN   NaN
# nutriments.sugars_100g_num        13.615726   21.671643  0.0   0.05275   4.2
# nutriments.energy-kcal_100g_num  195.468002  199.624226  0.4  2.031549  93.1
# nova_group_num                          4.0         0.0  4.0       4.0   4.0
#
#                                    75%    max
# code                               NaN    NaN
# product_name                       NaN    NaN
# brands                             NaN    NaN
# categories_tags                    NaN    NaN
# countries_tags                     NaN    NaN
# packaging_tags                     NaN    NaN
# stores                             NaN    NaN
# purchase_places                    NaN    NaN
# nutriscore_grade                   NaN    NaN
# nova_group                         NaN    NaN
# ecoscore_grade                     NaN    NaN
# ingredients_text                   NaN    NaN
# nutriments.sugars_100g             NaN    NaN
# nutriments.energy-kcal_100g        NaN    NaN
# nutriments.sugars_100g_num         8.0   99.9
# nutriments.energy-kcal_100g_num  402.0  536.0
# nova_group_num                     4.0    4.0

# %%
# ============================================================
# AUSTRALIA — UNKNOWN VALUE ANALYSIS
# ============================================================

australia_unknown_summary = []

for col in australia_df.columns:
    unknown_count = (
        australia_df[col].astype(str)
        .str.strip()
        .str.lower()
        .eq("unknown")
        .sum()
    )

    australia_unknown_summary.append({
        "Attribute": col,
        "Unknown_Count": unknown_count,
        "Total_Records": len(australia_df),
        "Unknown_Percentage": round(
            unknown_count / len(australia_df) * 100, 2
        )
    })

australia_unknown_df = pd.DataFrame(australia_unknown_summary).sort_values(
    "Unknown_Percentage", ascending=False
)

display(australia_unknown_df)

plt.figure(figsize=(12, 6))
sns.barplot(data=australia_unknown_df,
            x="Unknown_Percentage", y="Attribute")
plt.title("Australia – Unknown Value Percentage by Attribute")
plt.xlabel("Unknown Values (%)")
plt.ylabel("Attribute")
plt.tight_layout()
plt.show()
# Out:
#                           Attribute  Unknown_Count  Total_Records  \
# 7                   purchase_places             94             95
# 10                   ecoscore_grade             93             95
# 5                    packaging_tags             93             95
# 8                  nutriscore_grade             91             95
# 6                            stores             81             95
# 3                   categories_tags             76             95
# 9                        nova_group             69             95
# 11                 ingredients_text             62             95
# 12           nutriments.sugars_100g             41             95
# 13      nutriments.energy-kcal_100g             38             95
# 2                            brands             12             95
# 0                              code              0             95
# 4                    countries_tags              0             95
# 1                      product_name              0             95
# 14       nutriments.sugars_100g_num              0             95
# 15  nutriments.energy-kcal_100g_num              0             95
# 16                   nova_group_num              0             95
#
#     Unknown_Percentage
# 7                98.95
# 10               97.89
# 5                97.89
# 8                95.79
# 6                85.26
# 3                80.00
# 9                72.63
# 11               65.26
# 12               43.16
# 13               40.00
# 2                12.63
# 0                 0.00
# 4                 0.00
# 1                 0.00
# 14                0.00
# 15                0.00
# 16                0.00

# %% [markdown]
# ###  Observation
#
# The chart shows how complete the available information is for different attributes in Australia. Attributes with a higher percentage of `Unknown` values have less information available, so those fields should be used carefully when comparing products.

# %%
# ============================================================
# AUSTRALIA — PRODUCT ANALYSIS
# ============================================================

australia_product_counts = (
    australia_df["product_name"].value_counts().reset_index()
)
australia_product_counts.columns = ["Product_Name", "Frequency"]

print("Top 20 Products:")
display(australia_product_counts.head(20))

print("Total Product Records:", len(australia_df))
print("Unique Products:", australia_df["product_name"].nunique())
print(
    "Product Uniqueness Rate:",
    round(australia_df["product_name"].nunique() / len(australia_df) * 100, 2),
    "%"
)

plt.figure(figsize=(12, 7))
sns.barplot(data=australia_product_counts.head(15),
            x="Frequency", y="Product_Name")
plt.title("Australia – Top 15 Products")
plt.xlabel("Number of Records")
plt.ylabel("Product")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Products:
#                                             Product_Name  Frequency
# 0                                                  Fanta          2
# 1                                           Fanta orange          2
# 2                                                Delites          2
# 3                                Fanta zero sugar orange          2
# 4                                                  Lemon          2
# 5   Crinkle Cut Snacks Sweet Chilli & Sour Cream Flavour          1
# 6                       Gluten Free Rice Noodles Chicken          1
# 7                            Fantastic Noodles beef bowl          1
# 8                                        Honey Baked Ham          1
# 9                                 fantastic rice squares          1
# 10                    Fantastic Chicken and Corn Noodles          1
# 11                                    FANTA ORANGE 1.25L          1
# 12                                  Cheese rice crackers          1
# 13                               Noodles Chicken Flavour          1
# 14                                        fantasy spread          1
# 15                                       Instant Noodles          1
# 16     Crinkle Cut Snacks Flame Grilled Barbeque Flavour          1
# 17                                               Noodles          1
# 18                                       Noodles chicken          1
# 19                                       Fantasy cupcjes          1
# Total Product Records: 95
# Unique Products: 90
# Product Uniqueness Rate: 94.74 %

# %% [markdown]
# ###  Observation
#
# The chart shows the products that appear most often in the Australia data. A few products occur more frequently, while many others appear only a small number of times. This gives a quick idea of which products are most represented in this dataset.

# %%
# ============================================================
# AUSTRALIA — BRAND ANALYSIS
# ============================================================

australia_brand_counts = (
    australia_df["brands"].value_counts().reset_index()
)
australia_brand_counts.columns = ["Brand", "Product_Count"]

print("Top 20 Brands:")
display(australia_brand_counts.head(20))

print("Unique Brands:", australia_df["brands"].nunique())

australia_brand_diversity = (
    australia_df["brands"].nunique() / len(australia_df) * 100
)
print("Brand Diversity Ratio:", round(australia_brand_diversity, 2), "%")

plt.figure(figsize=(12, 7))
sns.barplot(data=australia_brand_counts.head(15),
            x="Product_Count", y="Brand")
plt.title("Australia – Top 15 Brands")
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Brands:
#                        Brand  Product_Count
# 0                  Fantastic             36
# 1                      Fanta             28
# 2                    Unknown             12
# 3                      Coles              4
# 4                  Coca-Cola              2
# 5                Bare Bakers              2
# 6               Dark Fantasy              2
# 7   Coles Supermarket, Coles              1
# 8                     Nestlé              1
# 9                       Fini              1
# 10          Fantastic Snacks              1
# 11             The coca-cola              1
# 12         Fantastic Delites              1
# 13                  Fantasia              1
# 14                  Sunfeast              1
# 15                   Fantasy              1
# Unique Brands: 16
# Brand Diversity Ratio: 16.84 %

# %% [markdown]
# ###  Observation
#
# The chart shows the brands that are most represented in the Australia data. Some brands have noticeably more records than others, while `Unknown` also appears where brand information is missing. This means the brand distribution is not evenly spread.

# %%
# ============================================================
# AUSTRALIA — CATEGORY ANALYSIS
# ============================================================

australia_category_series = (
    australia_df["categories_tags"].astype(str)
    .str.split(",").explode().str.strip()
)

australia_category_series = australia_category_series[
    australia_category_series.str.lower() != "unknown"
]

australia_category_counts = australia_category_series.value_counts()

print("Top 25 Categories:")
display(australia_category_counts.head(25))

australia_top_categories = australia_category_counts.head(15).reset_index()
australia_top_categories.columns = ["Category", "Product_Count"]

plt.figure(figsize=(12, 8))
sns.barplot(data=australia_top_categories,
            x="Product_Count", y="Category")
plt.title("Australia – Top 15 Product Categories")
plt.xlabel("Product Count")
plt.ylabel("Category")
plt.tight_layout()
plt.show()
# Out:
# Top 25 Categories:
# categories_tags
# plant-based-foods-and-beverages       9
# plant-based-foods                     9
# pastas                                9
# noodles                               9
# dried-products                        8
# dried-products-to-be-rehydrated       8
# instant-noodles                       8
# snacks                                5
# salty-snacks                          5
# appetizers                            5
# biscuits-and-crackers                 5
# crackers-appetizers                   5
# cereals-and-potatoes                  4
# cereals-and-their-products            4
# beverages                             4
# carbonated-drinks                     3
# sodas                                 3
# breakfasts                            1
# spreads                               1
# sweet-spreads                         1
# cracker-biscuits-with-grains-seeds    1
# glut                                  1
# Name: count, dtype: int64

# %% [markdown]
# ###  Observation
#
# The chart shows the main product categories in the Australia data. The larger bars represent categories with more product records, while the smaller categories have fewer records. Overall, the chart gives a simple picture of the types of products represented in this country.

# %%
# ============================================================
# AUSTRALIA — PACKAGING, STORE AND PURCHASE PLACE
# ============================================================

def analyze_multivalue_attribute(country_df, column, label):
    if column not in country_df.columns:
        print(f"Column not found: {column}")
        return pd.Series(dtype="int64")

    s = country_df[column].astype(str).str.split(",").explode().str.strip()
    s = s[s.str.lower() != "unknown"]
    counts = s.value_counts()

    print(f"Top {label}:")
    display(counts.head(20).to_frame("Count"))
    return counts

australia_packaging_counts = analyze_multivalue_attribute(
    australia_df, "packaging_tags", "Packaging Types"
)
australia_store_counts = analyze_multivalue_attribute(
    australia_df, "stores", "Stores"
)
australia_purchase_counts = analyze_multivalue_attribute(
    australia_df, "purchase_places", "Purchase Places"
)
# Out:
# Top Packaging Types:
#                 Count
# packaging_tags
# plastic-bottle      1
# glass               1
# Top Stores:
#                    Count
# stores
# Woolworths            10
# Coles                  8
# Drakes                 2
# Coles Supermarket      1
# Kmart                  1
# IGA                    1
# Top Purchase Places:
#                  Count
# purchase_places
# Australia            1

# %%
# ============================================================
# AUSTRALIA — NUTRI-SCORE, NOVA AND ECO-SCORE
# ============================================================

for col, label in [
    ("nutriscore_grade", "Nutri-Score"),
    ("nova_group", "NOVA Group"),
    ("ecoscore_grade", "Eco-Score")
]:
    if col in australia_df.columns:
        counts = australia_df[col].value_counts()
        print(f"{label} Distribution:")
        display(counts)
        print(f"{label} Percentage:")
        display(australia_df[col].value_counts(normalize=True).mul(100).round(2))

        plt.figure(figsize=(9, 5))
        sns.countplot(
            data=australia_df,
            x=col,
            order=australia_df[col].value_counts().index
        )
        plt.title(f"Australia – {label} Distribution")
        plt.xlabel(label)
        plt.ylabel("Number of Products")
        plt.tight_layout()
        plt.show()
# Out:
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    91
# d           2
# b           1
# e           1
# Name: count, dtype: int64
# Nutri-Score Percentage:
# nutriscore_grade
# unknown    95.79
# d           2.11
# b           1.05
# e           1.05
# Name: proportion, dtype: float64
# NOVA Group Distribution:
# nova_group
# Unknown    69
# 4.0        26
# Name: count, dtype: int64
# NOVA Group Percentage:
# nova_group
# Unknown    72.63
# 4.0        27.37
# Name: proportion, dtype: float64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           64
# unknown           29
# not-applicable     2
# Name: count, dtype: int64
# Eco-Score Percentage:
# ecoscore_grade
# Unknown           67.37
# unknown           30.53
# not-applicable     2.11
# Name: proportion, dtype: float64

# %% [markdown]
# ###  Observation
#
# The charts show the distribution of Nutri-Score, NOVA Group and Eco-Score values in the Australia data. Some categories have more records than others, but the number of `Unknown` values also needs to be considered when reading these results.

# %%
# ============================================================
# AUSTRALIA — SUGAR AND ENERGY
# ============================================================

australia_sugar = australia_df["nutriments.sugars_100g_num"].dropna()
australia_energy = australia_df["nutriments.energy-kcal_100g_num"].dropna()

print("Sugar Statistics:")
display(australia_sugar.describe())

print("Energy Statistics:")
display(australia_energy.describe())

plt.figure(figsize=(10, 6))
sns.histplot(australia_sugar, bins=30, kde=True)
plt.title("Australia – Sugar Distribution")
plt.xlabel("Sugar (g per 100g)")
plt.ylabel("Number of Products")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(australia_energy, bins=30, kde=True)
plt.title("Australia – Energy Distribution")
plt.xlabel("Energy (kcal per 100g)")
plt.ylabel("Number of Products")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
sns.boxplot(x=australia_sugar)
plt.title("Australia – Sugar Content Boxplot")
plt.xlabel("Sugar (g per 100g)")
plt.tight_layout()
plt.show()
# Out:
# Sugar Statistics:
# count    54.000000
# mean     13.615726
# std      21.671643
# min       0.000000
# 25%       0.052750
# 50%       4.200000
# 75%       8.000000
# max      99.900000
# Name: nutriments.sugars_100g_num, dtype: float64
# Energy Statistics:
# count     57.000000
# mean     195.468002
# std      199.624226
# min        0.400000
# 25%        2.031549
# 50%       93.100000
# 75%      402.000000
# max      536.000000
# Name: nutriments.energy-kcal_100g_num, dtype: float64

# %% [markdown]
# ###  Observation
#
# The charts show how sugar and energy values are spread across the products in Australia. The distributions are not completely even, and some products are much higher than the rest. This suggests that a small number of products may have a strong effect on the average values.

# %%
# ============================================================
# AUSTRALIA — SUGAR VS ENERGY
# ============================================================

australia_nutrition = australia_df[
    ["nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"]
].dropna()

australia_sugar_energy_corr = (
    australia_nutrition["nutriments.sugars_100g_num"]
    .corr(australia_nutrition["nutriments.energy-kcal_100g_num"])
)

print("Valid nutritional records:", len(australia_nutrition))
print("Sugar–Energy Correlation:", round(australia_sugar_energy_corr, 3))

plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=australia_nutrition,
    x="nutriments.sugars_100g_num",
    y="nutriments.energy-kcal_100g_num",
    alpha=0.6
)
plt.title("Australia – Sugar vs Energy")
plt.xlabel("Sugar (g per 100g)")
plt.ylabel("Energy (kcal per 100g)")
plt.tight_layout()
plt.show()
# Out:
# Valid nutritional records: 50
# Sugar–Energy Correlation: 0.473

# %% [markdown]
# ###  Observation
#
# The scatter plot compares sugar and energy for the products in Australia. The points are spread across the chart rather than following one clear straight pattern, so the two values do not appear to move together in exactly the same way for every product.

# %%
# ============================================================
# AUSTRALIA — OUTLIER ANALYSIS
# ============================================================

def find_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return series[(series < lower) | (series > upper)]

australia_sugar_outliers = find_outliers(australia_sugar)
australia_energy_outliers = find_outliers(australia_energy)

print("Sugar Outliers:", len(australia_sugar_outliers))
print("Energy Outliers:", len(australia_energy_outliers))

print("\nHighest Sugar Products:")
display(
    australia_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.sugars_100g_num"]
    ].dropna(subset=["nutriments.sugars_100g_num"])
     .sort_values("nutriments.sugars_100g_num", ascending=False)
     .head(20)
)

print("\nHighest Energy Products:")
display(
    australia_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.energy-kcal_100g_num"]
    ].dropna(subset=["nutriments.energy-kcal_100g_num"])
     .sort_values("nutriments.energy-kcal_100g_num", ascending=False)
     .head(20)
)
# Out:
# Sugar Outliers: 12
# Energy Outliers: 0
#
# Highest Sugar Products:
#                              product_name                    brands  \
# 950                           Fairy Floss                   Fantasy
# 93                         fantasy spread  Coles Supermarket, Coles
# 477                              Fantales                   Unknown
# 353                         Fantasy belts                      Fini
# 885            Hazelnu5 Creme Wafer Rolls              Dark Fantasy
# 277                        Fanta Tropical                   Unknown
# 210                  Fantales Family Size                    Nestlé
# 608     Fantastically Fudgey Choc Brownie               Bare Bakers
# 597      Fantastically Fudgy Choc Brownie               Bare Bakers
# 909                       Chocolate Meltz              Dark Fantasy
# 919  Dark Fantasy (Choco-Style Nut Fills)                  Sunfeast
# 618     Fantasy cones vanilla & raspberry                     Coles
# 968                    Fantasy Finger Bun                     Coles
# 606                           Grape Fanta                     Fanta
# 600                                 Grape                     Fanta
# 911                                 Lemon                     Fanta
# 937                        Chucky’s Punch                     Fanta
# 308                          Fanta orange                     Fanta
# 72                     FANTA ORANGE 1.25L                     Fanta
# 361                               Delites                 Fantastic
#
#                         categories_tags  nutriments.sugars_100g_num
# 950                             Unknown                        99.9
# 93   breakfasts, spreads, sweet-spreads                        62.3
# 477                             Unknown                        58.0
# 353                             Unknown                        54.0
# 885                             Unknown                        52.8
# 277                             Unknown                        47.0
# 210                             Unknown                        44.4
# 608                             Unknown                        41.1
# 597                             Unknown                        41.0
# 909                             Unknown                        39.2
# 919                             Unknown                        35.2
# 618                             Unknown                        25.3
# 968                             Unknown                        18.2
# 606                             Unknown                         8.0
# 600                             Unknown                         8.0
# 911                             Unknown                         7.7
# 937                             Unknown                         7.6
# 308                           beverages                         7.2
# 72                              Unknown                         7.2
# 361                             Unknown                         6.8
# Highest Energy Products:
#                                     product_name             brands  \
# 909                              Chocolate Meltz       Dark Fantasy
# 919         Dark Fantasy (Choco-Style Nut Fills)           Sunfeast
# 431        Fantastic Flaxseed with Chia + Almond            Unknown
# 885                   Hazelnu5 Creme Wafer Rolls       Dark Fantasy
# 478                                 Delite curls          Fantastic
# 477                                     Fantales            Unknown
# 608            Fantastically Fudgey Choc Brownie        Bare Bakers
# 452              ThinnerBite black rice crackers          Fantastic
# 617  Tomatoe, Red Onion & Balsamic Rice Crackers          Fantastic
# 201                              Fantasy cupcjes              Coles
# 515                 Thinnerbite black rice cakes          Fantastic
# 39                               Honey Baked Ham          Fantastic
# 950                                  Fairy Floss            Fantasy
# 63                        fantastic rice squares          Fantastic
# 628             Sweet Chill & Sour Cream Delites          Fantastic
# 580                Delites Sour Cream And Chives          Fantastic
# 490                 Chesder cheese rice crackers          Fantastic
# 361                                      Delites          Fantastic
# 210                         Fantales Family Size             Nestlé
# 567                     Thai Chilli & Lemongrass  Fantastic Delites
#
#     categories_tags  nutriments.energy-kcal_100g_num
# 909         Unknown                        536.00000
# 919         Unknown                        536.00000
# 431         Unknown                        530.00000
# 885         Unknown                        488.00000
# 478         Unknown                        463.75000
# 477         Unknown                        454.11090
# 608         Unknown                        442.00000
# 452         Unknown                        437.40000
# 617         Unknown                        430.00000
# 201         Unknown                        426.00000
# 515         Unknown                        423.60000
# 39          Unknown                        413.00000
# 950         Unknown                        406.00000
# 63          Unknown                        404.00000
# 628         Unknown                        402.00000
# 580         Unknown                        397.00000
# 490         Unknown                        390.00000
# 361         Unknown                        382.40000
# 210         Unknown                        363.28872
# 567         Unknown                        363.00000

# %%
# ============================================================
# AUSTRALIA — BRAND NUTRITION ANALYSIS
# ============================================================

australia_brand_nutrition = (
    australia_df.groupby("brands")
    .agg(
        Product_Count=("product_name", "count"),
        Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
        Median_Sugar=("nutriments.sugars_100g_num", "median"),
        Avg_Energy=("nutriments.energy-kcal_100g_num", "mean"),
        Median_Energy=("nutriments.energy-kcal_100g_num", "median")
    )
    .reset_index()
)

australia_brand_nutrition = (
    australia_brand_nutrition[
        australia_brand_nutrition["Product_Count"] >= 3
    ]
    .sort_values("Product_Count", ascending=False)
)

display(australia_brand_nutrition.head(20))
# Out:
#        brands  Product_Count  Avg_Sugar  Median_Sugar  Avg_Energy  \
# 7   Fantastic             36   3.056977      2.800000  289.084747
# 5       Fanta             28   3.046667      0.000000   10.385927
# 15    Unknown             12  21.333333      1.666667  296.127725
# 2       Coles              4  15.333333     18.200000  261.422298
#
#     Median_Energy
# 7       386.20000
# 5         1.12000
# 15      327.05545
# 2       301.50000

# %%
# ============================================================
# AUSTRALIA — NUTRI-SCORE VS SUGAR / ENERGY
# ============================================================

if "nutriscore_grade" in australia_df.columns:

    australia_nutri_sugar = australia_df[
        ["nutriscore_grade", "nutriments.sugars_100g_num"]
    ].dropna()

    print("Sugar by Nutri-Score:")
    display(
        australia_nutri_sugar.groupby("nutriscore_grade")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=australia_nutri_sugar,
        x="nutriscore_grade",
        y="nutriments.sugars_100g_num"
    )
    plt.title("Australia – Sugar Distribution by Nutri-Score")
    plt.xlabel("Nutri-Score")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()

    australia_nutri_energy = australia_df[
        ["nutriscore_grade", "nutriments.energy-kcal_100g_num"]
    ].dropna()

    print("Energy by Nutri-Score:")
    display(
        australia_nutri_energy.groupby("nutriscore_grade")
        ["nutriments.energy-kcal_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=australia_nutri_energy,
        x="nutriscore_grade",
        y="nutriments.energy-kcal_100g_num"
    )
    plt.title("Australia – Energy by Nutri-Score")
    plt.xlabel("Nutri-Score")
    plt.ylabel("Energy (kcal per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
# Sugar by Nutri-Score:
#                   count   mean  median  min   max
# nutriscore_grade
# e                     1   6.20     6.2  6.2   6.2
# unknown              53  13.76     4.0  0.0  99.9
# Energy by Nutri-Score:
#                   count    mean  median  min    max
# nutriscore_grade
# unknown              57  195.47    93.1  0.4  536.0

# %% [markdown]
# ###  Observation
#
# The chart compares sugar levels across different Nutri-Score groups in Australia. The groups do not have the same sugar distribution, which shows that products with different Nutri-Scores can have noticeably different sugar levels.

# %%
# ============================================================
# AUSTRALIA — NOVA VS SUGAR
# ============================================================

if "nova_group" in australia_df.columns:

    australia_nova_sugar = australia_df[
        ["nova_group", "nutriments.sugars_100g_num"]
    ].dropna()

    display(
        australia_nova_sugar.groupby("nova_group")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=australia_nova_sugar,
        x="nova_group",
        y="nutriments.sugars_100g_num"
    )
    plt.title("Australia – Sugar by NOVA Processing Group")
    plt.xlabel("NOVA Group")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
#             count   mean  median   min   max
# nova_group
# 4.0             7  16.98     6.2  0.71  54.0
# Unknown        47  13.11     4.0  0.00  99.9

# %%
# ============================================================
# AUSTRALIA — CORRELATION
# ============================================================

corr_cols = [
    "nova_group_num",
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

available_corr_cols = [c for c in corr_cols if c in australia_df.columns]

australia_corr = australia_df[available_corr_cols].corr()

display(australia_corr.round(3))

plt.figure(figsize=(8, 6))
sns.heatmap(
    australia_corr,
    annot=True,
    cmap="coolwarm",
    center=0,
    fmt=".2f"
)
plt.title("Australia – Nutritional Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
#                                  nova_group_num  nutriments.sugars_100g_num  \
# nova_group_num                              NaN                         NaN
# nutriments.sugars_100g_num                  NaN                       1.000
# nutriments.energy-kcal_100g_num             NaN                       0.473
#
#                                  nutriments.energy-kcal_100g_num
# nova_group_num                                               NaN
# nutriments.sugars_100g_num                                 0.473
# nutriments.energy-kcal_100g_num                            1.000

# %% [markdown]
# ###  Observation
#
# The heatmap gives a quick view of how the numerical attributes are related in Australia. The relationships are generally not strong enough to suggest that one attribute alone explains the others.

# %%
# ============================================================
# AUSTRALIA — INGREDIENT ANALYSIS
# ============================================================

if "ingredients_text" in australia_df.columns:

    ingredient_text = australia_df["ingredients_text"].astype(str).str.lower()
    all_ingredients = []

    for text in ingredient_text:
        if text != "unknown":
            for ingredient in text.split(","):
                ingredient = ingredient.strip()
                if ingredient and ingredient != "unknown":
                    all_ingredients.append(ingredient)

    australia_ingredient_counts = Counter(all_ingredients)

    australia_ingredient_df = pd.DataFrame(
        australia_ingredient_counts.most_common(30),
        columns=["Ingredient", "Frequency"]
    )

    display(australia_ingredient_df)

    plt.figure(figsize=(12, 8))
    sns.barplot(
        data=australia_ingredient_df.head(15),
        x="Frequency",
        y="Ingredient"
    )
    plt.title("Australia – Most Frequently Reported Ingredients")
    plt.xlabel("Frequency")
    plt.ylabel("Ingredient")
    plt.tight_layout()
    plt.show()
# Out:
#                       Ingredient  Frequency
# 0                          sugar         21
# 1                           salt         20
# 2                   maltodextrin         11
# 3                        flavour         11
# 4                food acids (330          8
# 5                           331)          8
# 6             preservative (202)          7
# 7               carbonated water          6
# 8                  yeast extract          5
# 9                  vegetable oil          5
# 10        flavour enhancers (621          5
# 11                          950)          5
# 12                  maize starch          4
# 13  hydrolysed vegetable protein          4
# 14                 potato starch          4
# 15                tapioca starch          4
# 16                          635)          4
# 17              seasoning (sugar          3
# 18                           soy          3
# 19              herbs and spices          3
# 20                          631)          3
# 21                           500          3
# 22            antioxidant (307b)          3
# 23          noodles: wheat flour          3
# 24                          955)          3
# 25                          milk          3
# 26              soy sauce powder          3
# 27                  onion powder          3
# 28               102 briens road          3
# 29  northmead nsw 2152 australia          3

# %% [markdown]
# ###  Observation
#
# The ingredient chart shows the ingredients that appear most often in the Australia data. A few ingredients occur repeatedly, while many others appear less often. Missing or undefined ingredient entries should be kept in mind when interpreting the chart.

# %%
# ============================================================
# AUSTRALIA — CATEGORY VS NUTRITION
# ============================================================

if "categories_tags" in australia_df.columns:

    australia_category_nutrition = (
        australia_df.groupby("categories_tags")
        .agg(
            Product_Count=("product_name", "count"),
            Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
            Avg_Energy=("nutriments.energy-kcal_100g_num", "mean")
        )
        .reset_index()
    )

    australia_category_nutrition = (
        australia_category_nutrition[
            australia_category_nutrition["Product_Count"] >= 2
        ]
        .sort_values("Product_Count", ascending=False)
    )

    display(australia_category_nutrition.head(20))
# Out:
#                                                                                                            categories_tags  \
# 0                                                                                                                  Unknown
# 7  plant-based-foods-and-beverages, plant-based-foods, dried-products, pastas, dried-products-to-be-rehydrated, noodles...
# 2                                                                                      beverages, carbonated-drinks, sodas
# 8                                             snacks, salty-snacks, appetizers, biscuits-and-crackers, crackers-appetizers
# 4  plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products, dried-products...
#
#    Product_Count  Avg_Sugar  Avg_Energy
# 0             76  14.142754  211.294130
# 7              5   1.120641   79.068863
# 2              3   4.500000   19.000000
# 8              3        NaN         NaN
# 4              2        NaN         NaN

# %%
# ============================================================
# AUSTRALIA — ATTRIBUTE-LEVEL ANALYSIS
# ============================================================

categorical_columns = [
    "brands",
    "categories_tags",
    "packaging_tags",
    "stores",
    "purchase_places",
    "nutriscore_grade",
    "nova_group",
    "ecoscore_grade"
]

for col in categorical_columns:
    if col in australia_df.columns:
        print("\n" + "=" * 70)
        print(f"ATTRIBUTE: {col}")
        print("=" * 70)

        counts = (
            australia_df[col]
            .astype(str)
            .value_counts()
            .head(15)
        )

        display(counts.to_frame("Count"))
# Out:
# ======================================================================
# ATTRIBUTE: brands
# ======================================================================
#                           Count
# brands
# Fantastic                    36
# Fanta                        28
# Unknown                      12
# Coles                         4
# Coca-Cola                     2
# Bare Bakers                   2
# Dark Fantasy                  2
# Coles Supermarket, Coles      1
# Nestlé                        1
# Fini                          1
# Fantastic Snacks              1
# The coca-cola                 1
# Fantastic Delites             1
# Fantasia                      1
# Sunfeast                      1
# ======================================================================
# ATTRIBUTE: categories_tags
# ======================================================================
#                                                                                                                           Count
# categories_tags
# Unknown                                                                                                                      76
# plant-based-foods-and-beverages, plant-based-foods, dried-products, pastas, dried-products-to-be-rehydrated, noodles,...      5
# snacks, salty-snacks, appetizers, biscuits-and-crackers, crackers-appetizers                                                  3
# beverages, carbonated-drinks, sodas                                                                                           3
# plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products, dried-products,...      2
# breakfasts, spreads, sweet-spreads                                                                                            1
# plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products, dried-products,...      1
# plant-based-foods-and-beverages, plant-based-foods, cereals-and-potatoes, cereals-and-their-products, pastas, noodles         1
# beverages                                                                                                                     1
# snacks, salty-snacks, appetizers, biscuits-and-crackers, crackers-appetizers, cracker-biscuits-with-grains-seeds              1
# snacks, salty-snacks, appetizers, biscuits-and-crackers, crackers-appetizers, glut                                            1
# ======================================================================
# ATTRIBUTE: packaging_tags
# ======================================================================
#                 Count
# packaging_tags
# Unknown            93
# plastic-bottle      1
# glass               1
# ======================================================================
# ATTRIBUTE: stores
# ======================================================================
#                              Count
# stores
# Unknown                         81
# Woolworths                       5
# Woolworths, Coles                3
# Coles                            2
# Coles Supermarket, Coles         1
# Kmart                            1
# Coles,Woolworths,Drakes          1
# Coles,Woolworths,Drakes,IGA      1
# ======================================================================
# ATTRIBUTE: purchase_places
# ======================================================================
#                  Count
# purchase_places
# Unknown             94
# Australia            1
# ======================================================================
# ATTRIBUTE: nutriscore_grade
# ======================================================================
#                   Count
# nutriscore_grade
# unknown              91
# d                     2
# b                     1
# e                     1
# ======================================================================
# ATTRIBUTE: nova_group
# ======================================================================
#             Count
# nova_group
# Unknown        69
# 4.0            26
# ======================================================================
# ATTRIBUTE: ecoscore_grade
# ======================================================================
#                 Count
# ecoscore_grade
# Unknown            64
# unknown            29
# not-applicable      2

# %%
# ============================================================
# AUSTRALIA — NUMERICAL ATTRIBUTE ANALYSIS
# ============================================================

numerical_columns = [
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

australia_numeric_summary = []

for col in numerical_columns:
    if col in australia_df.columns:
        australia_numeric_summary.append({
            "Attribute": col,
            "Count": australia_df[col].count(),
            "Mean": australia_df[col].mean(),
            "Median": australia_df[col].median(),
            "Std": australia_df[col].std(),
            "Minimum": australia_df[col].min(),
            "Maximum": australia_df[col].max()
        })

australia_numeric_summary = pd.DataFrame(australia_numeric_summary)
display(australia_numeric_summary.round(2))
# Out:
#                          Attribute  Count    Mean  Median     Std  Minimum  \
# 0       nutriments.sugars_100g_num     54   13.62     4.2   21.67      0.0
# 1  nutriments.energy-kcal_100g_num     57  195.47    93.1  199.62      0.4
#
#    Maximum
# 0     99.9
# 1    536.0

# %%
# ============================================================
# AUSTRALIA — DATA QUALITY CHECK
# ============================================================

print("AUSTRALIA DATA QUALITY CHECK")
print("=" * 60)

print("Duplicate Rows:", australia_df.duplicated().sum())
print("Duplicate Product Names:", australia_df["product_name"].duplicated().sum())
print("Unique Products:", australia_df["product_name"].nunique())
print("Unique Brands:", australia_df["brands"].nunique())
print("Records:", len(australia_df))
# Out:
# AUSTRALIA DATA QUALITY CHECK
# ============================================================
# Duplicate Rows: 0
# Duplicate Product Names: 5
# Unique Products: 90
# Unique Brands: 16
# Records: 95

# %%
# ============================================================
# AUSTRALIA — FINAL SUMMARY
# ============================================================

print("=" * 70)
print("🌍 AUSTRALIA – ADVANCED DATA ANALYSIS SUMMARY")
print("=" * 70)

print(f"\nTotal Records: {len(australia_df):,}")
print(f"Unique Products: {australia_df['product_name'].nunique():,}")
print(f"Unique Brands: {australia_df['brands'].nunique():,}")

print("\nTop 5 Brands:")
display(australia_brand_counts.head(5))

print("\nTop 5 Categories:")
display(australia_category_counts.head(5))

print("\nTop Packaging Types:")
display(australia_packaging_counts.head(5))

print("\nTop Stores:")
display(australia_store_counts.head(5))

print("\nTop Purchase Places:")
display(australia_purchase_counts.head(5))

if "nutriscore_grade" in australia_df.columns:
    print("\nNutri-Score Distribution:")
    display(australia_df["nutriscore_grade"].value_counts())

if "nova_group" in australia_df.columns:
    print("\nNOVA Distribution:")
    display(australia_df["nova_group"].value_counts())

if "ecoscore_grade" in australia_df.columns:
    print("\nEco-Score Distribution:")
    display(australia_df["ecoscore_grade"].value_counts())

print("\nNutritional Statistics:")
display(pd.DataFrame({
    "Metric": [
        "Average Sugar", "Median Sugar", "Maximum Sugar",
        "Average Energy", "Median Energy", "Maximum Energy"
    ],
    "Value": [
        australia_sugar.mean(), australia_sugar.median(), australia_sugar.max(),
        australia_energy.mean(), australia_energy.median(), australia_energy.max()
    ]
}).round(2))

print("\nSugar–Energy Correlation:", round(australia_sugar_energy_corr, 3))
print("\nAnalysis completed for Australia.")
# Out:
# ======================================================================
# 🌍 AUSTRALIA – ADVANCED DATA ANALYSIS SUMMARY
# ======================================================================
#
# Total Records: 95
# Unique Products: 90
# Unique Brands: 16
#
# Top 5 Brands:
#        Brand  Product_Count
# 0  Fantastic             36
# 1      Fanta             28
# 2    Unknown             12
# 3      Coles              4
# 4  Coca-Cola              2
# Top 5 Categories:
# categories_tags
# plant-based-foods-and-beverages    9
# plant-based-foods                  9
# pastas                             9
# noodles                            9
# dried-products                     8
# Name: count, dtype: int64
# Top Packaging Types:
# packaging_tags
# plastic-bottle    1
# glass             1
# Name: count, dtype: int64
# Top Stores:
# stores
# Woolworths           10
# Coles                 8
# Drakes                2
# Coles Supermarket     1
# Kmart                 1
# Name: count, dtype: int64
# Top Purchase Places:
# purchase_places
# Australia    1
# Name: count, dtype: int64
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    91
# d           2
# b           1
# e           1
# Name: count, dtype: int64
# NOVA Distribution:
# nova_group
# Unknown    69
# 4.0        26
# Name: count, dtype: int64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           64
# unknown           29
# not-applicable     2
# Name: count, dtype: int64
# Nutritional Statistics:
#            Metric   Value
# 0   Average Sugar   13.62
# 1    Median Sugar    4.20
# 2   Maximum Sugar   99.90
# 3  Average Energy  195.47
# 4   Median Energy   93.10
# 5  Maximum Energy  536.00
# Sugar–Energy Correlation: 0.473
#
# Analysis completed for Australia.

# %% [markdown]
# ### Australia — Observation and Insight
#
# Australia contributes **95 records**, **90 unique products**, and **16 brands**, so its catalog has relatively little product-name repetition. Its products average **13.62 g of sugar** and **195.47 kcal per 100 g**, the highest average energy level in the comparison. The positive sugar-energy correlation (**0.473**) indicates a moderate relationship, although the smaller sample size means this pattern should be read as an observed association rather than a causal effect.

# %% [markdown]
# # PART — ROMANIA
#
# The same complete analysis framework is applied to **Romania only**.

# %%
# ============================================================
# ROMANIA DATASET
# ============================================================

romania_df = df[
    df["countries_tags"].astype(str).str.lower() == "romania"
].copy()

print("ROMANIA DATASET")
print("=" * 60)
print("Records:", len(romania_df))
print("Attributes:", len(romania_df.columns))
display(romania_df.head())
# Out:
# ROMANIA DATASET
# ============================================================
# Records: 71
# Attributes: 17
#              code                                        product_name  \
# 8   5449000029973                                        Fanta lămâie
# 16  5449000665829                 Fanta Portocale și fructul pasiunii
# 28  5449000280282                                   Fanta Dark Orange
# 40  5449000021670                          Fanta zero zahăr portocale
# 41  5449000270320  Fanta zero zahăr cu zmeură, lămâie verde și baobab
#
#                                  brands  \
# 8                                 Fanta
# 16                                Fanta
# 28                                Fanta
# 40  Fanta, Coca-Cola, Coca-Cola Company
# 41  Fanta, Coca-Cola, Coca-Cola Company
#
#                                                                                                             categories_tags  \
# 8   plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, sodas, ...
# 16  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 28  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 40  plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, artific...
# 41                               beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, sweetened-beverages
#
#    countries_tags                           packaging_tags   stores  \
# 8         romania                                  Unknown  Unknown
# 16        romania  plastic, pet-polyethylene-terephthalate  Unknown
# 28        romania  plastic, pet-polyethylene-terephthalate  Unknown
# 40        romania  plastic, pet-polyethylene-terephthalate  Unknown
# 41        romania  plastic, pet-polyethylene-terephthalate  Unknown
#
#       purchase_places nutriscore_grade nova_group  ecoscore_grade  \
# 8             Unknown          unknown        4.0  not-applicable
# 16  Constanta,Romania                d        4.0  not-applicable
# 28            Romania                d        4.0  not-applicable
# 40            Romania                c        4.0  not-applicable
# 41            Romania                c        4.0  not-applicable
#
#                                                                                                            ingredients_text  \
# 8   apă, zahăr, dioxid de carbon, suc de lămâie din concentrat (2%), acidifiant acid citric, stabilizatori: gumă arabică...
# 16  Apa, sirop de fructoza-glucoza, dioxid de carbon, suc de fructe concentrat (portocale 2,8%, fructul pasiunii 0,1%, l...
# 28  apă, zahăr, suc de fructe din concentrat (portocale 2%, portocale roșii 1%), dioxid de carbon, acidifianți: acid cit...
# 40  Apă, suc de portocale din concentrat 3%, dioxid de carbon, acidifianți: acid citric și acid malic, îndulcitori: cicl...
# 41  Apă, dioxid de carbon, suc de fructe din concentrat: suc de portocale (2,9%), suc de lămâie verde (0,1%), suc de zme...
#
#    nutriments.sugars_100g nutriments.energy-kcal_100g  \
# 8                    11.1                     Unknown
# 16                    6.5                     Unknown
# 28                    4.3                        19.0
# 40                    0.3                         2.0
# 41                    0.4                         3.0
#
#     nutriments.sugars_100g_num  nutriments.energy-kcal_100g_num  \
# 8                         11.1                              NaN
# 16                         6.5                              NaN
# 28                         4.3                             19.0
# 40                         0.3                              2.0
# 41                         0.4                              3.0
#
#     nova_group_num
# 8              4.0
# 16             4.0
# 28             4.0
# 40             4.0
# 41             4.0

# %%
# ============================================================
# ROMANIA — BASIC OVERVIEW
# ============================================================

print("Dataset Shape:", romania_df.shape)
print("\nColumn Names:")
print(romania_df.columns.tolist())

print("\nData Types:")
display(romania_df.dtypes)

print("\nStatistical Summary:")
display(romania_df.describe(include="all").T)
# Out:
# Dataset Shape: (71, 17)
#
# Column Names:
# ['code', 'product_name', 'brands', 'categories_tags', 'countries_tags', 'packaging_tags', 'stores', 'purchase_places', 'nutriscore_grade', 'nova_group', 'ecoscore_grade', 'ingredients_text', 'nutriments.sugars_100g', 'nutriments.energy-kcal_100g', 'nutriments.sugars_100g_num', 'nutriments.energy-kcal_100g_num', 'nova_group_num']
#
# Data Types:
# code                                object
# product_name                           str
# brands                                 str
# categories_tags                        str
# countries_tags                         str
# packaging_tags                         str
# stores                                 str
# purchase_places                        str
# nutriscore_grade                       str
# nova_group                             str
# ecoscore_grade                         str
# ingredients_text                       str
# nutriments.sugars_100g                 str
# nutriments.energy-kcal_100g            str
# nutriments.sugars_100g_num         float64
# nutriments.energy-kcal_100g_num    float64
# nova_group_num                     float64
# dtype: object
# Statistical Summary:
#                                 count unique              top freq       mean  \
# code                             71.0   71.0  5449000029973.0  1.0        NaN
# product_name                       71     65            fanta    3        NaN
# brands                             71     11            Fanta   25        NaN
# categories_tags                    71     27          Unknown   34        NaN
# countries_tags                     71      1          romania   71        NaN
# packaging_tags                     71      6          Unknown   55        NaN
# stores                             71      2          Unknown   70        NaN
# purchase_places                    71      4          Unknown   66        NaN
# nutriscore_grade                   71      5          unknown   46        NaN
# nova_group                         71      2          Unknown   50        NaN
# ecoscore_grade                     71      3          Unknown   53        NaN
# ingredients_text                   71     25          Unknown   47        NaN
# nutriments.sugars_100g             71     13          Unknown   52        NaN
# nutriments.energy-kcal_100g        71     11          Unknown   53        NaN
# nutriments.sugars_100g_num       19.0    NaN              NaN  NaN   6.268421
# nutriments.energy-kcal_100g_num  18.0    NaN              NaN  NaN  35.555556
# nova_group_num                   21.0    NaN              NaN  NaN        4.0
#
#                                        std  min  25%  50%   75%    max
# code                                   NaN  NaN  NaN  NaN   NaN    NaN
# product_name                           NaN  NaN  NaN  NaN   NaN    NaN
# brands                                 NaN  NaN  NaN  NaN   NaN    NaN
# categories_tags                        NaN  NaN  NaN  NaN   NaN    NaN
# countries_tags                         NaN  NaN  NaN  NaN   NaN    NaN
# packaging_tags                         NaN  NaN  NaN  NaN   NaN    NaN
# stores                                 NaN  NaN  NaN  NaN   NaN    NaN
# purchase_places                        NaN  NaN  NaN  NaN   NaN    NaN
# nutriscore_grade                       NaN  NaN  NaN  NaN   NaN    NaN
# nova_group                             NaN  NaN  NaN  NaN   NaN    NaN
# ecoscore_grade                         NaN  NaN  NaN  NaN   NaN    NaN
# ingredients_text                       NaN  NaN  NaN  NaN   NaN    NaN
# nutriments.sugars_100g                 NaN  NaN  NaN  NaN   NaN    NaN
# nutriments.energy-kcal_100g            NaN  NaN  NaN  NaN   NaN    NaN
# nutriments.sugars_100g_num       13.517316  0.0  0.1  0.3  7.45   59.0
# nutriments.energy-kcal_100g_num  77.678994  1.0  2.0  9.0  40.0  337.0
# nova_group_num                         0.0  4.0  4.0  4.0   4.0    4.0

# %%
# ============================================================
# ROMANIA — UNKNOWN VALUE ANALYSIS
# ============================================================

romania_unknown_summary = []

for col in romania_df.columns:
    unknown_count = (
        romania_df[col].astype(str)
        .str.strip()
        .str.lower()
        .eq("unknown")
        .sum()
    )

    romania_unknown_summary.append({
        "Attribute": col,
        "Unknown_Count": unknown_count,
        "Total_Records": len(romania_df),
        "Unknown_Percentage": round(
            unknown_count / len(romania_df) * 100, 2
        )
    })

romania_unknown_df = pd.DataFrame(romania_unknown_summary).sort_values(
    "Unknown_Percentage", ascending=False
)

display(romania_unknown_df)

plt.figure(figsize=(12, 6))
sns.barplot(data=romania_unknown_df,
            x="Unknown_Percentage", y="Attribute")
plt.title("Romania – Unknown Value Percentage by Attribute")
plt.xlabel("Unknown Values (%)")
plt.ylabel("Attribute")
plt.tight_layout()
plt.show()
# Out:
#                           Attribute  Unknown_Count  Total_Records  \
# 6                            stores             70             71
# 7                   purchase_places             66             71
# 10                   ecoscore_grade             58             71
# 5                    packaging_tags             55             71
# 13      nutriments.energy-kcal_100g             53             71
# 12           nutriments.sugars_100g             52             71
# 9                        nova_group             50             71
# 11                 ingredients_text             47             71
# 8                  nutriscore_grade             46             71
# 3                   categories_tags             34             71
# 2                            brands             25             71
# 1                      product_name              3             71
# 0                              code              0             71
# 4                    countries_tags              0             71
# 14       nutriments.sugars_100g_num              0             71
# 15  nutriments.energy-kcal_100g_num              0             71
# 16                   nova_group_num              0             71
#
#     Unknown_Percentage
# 6                98.59
# 7                92.96
# 10               81.69
# 5                77.46
# 13               74.65
# 12               73.24
# 9                70.42
# 11               66.20
# 8                64.79
# 3                47.89
# 2                35.21
# 1                 4.23
# 0                 0.00
# 4                 0.00
# 14                0.00
# 15                0.00
# 16                0.00

# %% [markdown]
# ###  Observation
#
# The chart shows how complete the available information is for different attributes in Romania. Attributes with a higher percentage of `Unknown` values have less information available, so those fields should be used carefully when comparing products.

# %%
# ============================================================
# ROMANIA — PRODUCT ANALYSIS
# ============================================================

romania_product_counts = (
    romania_df["product_name"].value_counts().reset_index()
)
romania_product_counts.columns = ["Product_Name", "Frequency"]

print("Top 20 Products:")
display(romania_product_counts.head(20))

print("Total Product Records:", len(romania_df))
print("Unique Products:", romania_df["product_name"].nunique())
print(
    "Product Uniqueness Rate:",
    round(romania_df["product_name"].nunique() / len(romania_df) * 100, 2),
    "%"
)

plt.figure(figsize=(12, 7))
sns.barplot(data=romania_product_counts.head(15),
            x="Frequency", y="Product_Name")
plt.title("Romania – Top 15 Products")
plt.xlabel("Number of Records")
plt.ylabel("Product")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Products:
#                                           Product_Name  Frequency
# 0                                                fanta          3
# 1                                              Unknown          3
# 2                                        Fanta Madness          2
# 3                                             fanta 1l          2
# 4                                         Fanta lămâie          1
# 5                  Fanta Portocale și fructul pasiunii          1
# 6                                    Fanta Dark Orange          1
# 7                           Fanta zero zahăr portocale          1
# 8   Fanta zero zahăr cu zmeură, lămâie verde și baobab          1
# 9                                               Raison          1
# 10                                        Fanta citron          1
# 11                                   Fanta Orange Zero          1
# 12                                Fanta struguri 2,5 L          1
# 13                       Fanta Zero Zahăr Portocale 2L          1
# 14  Fanta What the Fanta Zero Zahăr Ananas și Hibiscus          1
# 15                                          la fantana          1
# 16                                         Fanta mango          1
# 17                                    Marcelo caramelo          1
# 18                                       Fanta mystère          1
# 19                                       #whatthefanta          1
# Total Product Records: 71
# Unique Products: 65
# Product Uniqueness Rate: 91.55 %

# %% [markdown]
# ###  Observation
#
# The chart shows the products that appear most often in the Romania data. A few products occur more frequently, while many others appear only a small number of times. This gives a quick idea of which products are most represented in this dataset.

# %%
# ============================================================
# ROMANIA — BRAND ANALYSIS
# ============================================================

romania_brand_counts = (
    romania_df["brands"].value_counts().reset_index()
)
romania_brand_counts.columns = ["Brand", "Product_Count"]

print("Top 20 Brands:")
display(romania_brand_counts.head(20))

print("Unique Brands:", romania_df["brands"].nunique())

romania_brand_diversity = (
    romania_df["brands"].nunique() / len(romania_df) * 100
)
print("Brand Diversity Ratio:", round(romania_brand_diversity, 2), "%")

plt.figure(figsize=(12, 7))
sns.barplot(data=romania_brand_counts.head(15),
            x="Product_Count", y="Brand")
plt.title("Romania – Top 15 Brands")
plt.xlabel("Number of Products")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()
# Out:
# Top 20 Brands:
#                                          Brand  Product_Count
# 0                                        Fanta             25
# 1                                      Unknown             25
# 2                                    Coca Cola             10
# 3          Fanta, Coca-Cola, Coca-Cola Company              2
# 4                                    Coca-Cola              2
# 5                                    coca cola              2
# 6                              día de fantasía              1
# 7                                      fantail              1
# 8   Fanta, Cadia, Coca-Cola, Coca-Cola Company              1
# 9                             Fanta, Coca-Cola              1
# 10                                       fanta              1
# Unique Brands: 11
# Brand Diversity Ratio: 15.49 %

# %% [markdown]
# ###  Observation
#
# The chart shows the brands that are most represented in the Romania data. Some brands have noticeably more records than others, while `Unknown` also appears where brand information is missing. This means the brand distribution is not evenly spread.

# %%
# ============================================================
# ROMANIA — CATEGORY ANALYSIS
# ============================================================

romania_category_series = (
    romania_df["categories_tags"].astype(str)
    .str.split(",").explode().str.strip()
)

romania_category_series = romania_category_series[
    romania_category_series.str.lower() != "unknown"
]

romania_category_counts = romania_category_series.value_counts()

print("Top 25 Categories:")
display(romania_category_counts.head(25))

romania_top_categories = romania_category_counts.head(15).reset_index()
romania_top_categories.columns = ["Category", "Product_Count"]

plt.figure(figsize=(12, 8))
sns.barplot(data=romania_top_categories,
            x="Product_Count", y="Category")
plt.title("Romania – Top 15 Product Categories")
plt.xlabel("Product Count")
plt.ylabel("Category")
plt.tight_layout()
plt.show()
# Out:
# Top 25 Categories:
# categories_tags
# beverages                               34
# carbonated-drinks                       30
# sodas                                   28
# beverages-and-beverages-preparations    23
# plant-based-foods-and-beverages         12
# plant-based-beverages                   12
# fruit-based-beverages                   11
# sweetened-beverages                     11
# fruit-sodas                              9
# artificially-sweetened-beverages         9
# diet-beverages                           2
# diet-sodas                               2
# orange-soft-drinks                       2
# Soft Drinks                              2
# ro:suc                                   1
# ro:fanta-mango                           1
# snacks                                   1
# sweet-snacks                             1
# confectioneries                          1
# candies                                  1
# gummi-candies                            1
# ro:Suc-de-portocale                      1
# ro:suc de portocale                      1
# ro:bautura                               1
# carbonated-fruit-soft-drink              1
# Name: count, dtype: int64

# %% [markdown]
# ###  Observation
#
# The chart shows the main product categories in the Romania data. The larger bars represent categories with more product records, while the smaller categories have fewer records. Overall, the chart gives a simple picture of the types of products represented in this country.

# %%
# ============================================================
# ROMANIA — PACKAGING, STORE AND PURCHASE PLACE
# ============================================================

def analyze_multivalue_attribute(country_df, column, label):
    if column not in country_df.columns:
        print(f"Column not found: {column}")
        return pd.Series(dtype="int64")

    s = country_df[column].astype(str).str.split(",").explode().str.strip()
    s = s[s.str.lower() != "unknown"]
    counts = s.value_counts()

    print(f"Top {label}:")
    display(counts.head(20).to_frame("Count"))
    return counts

romania_packaging_counts = analyze_multivalue_attribute(
    romania_df, "packaging_tags", "Packaging Types"
)
romania_store_counts = analyze_multivalue_attribute(
    romania_df, "stores", "Stores"
)
romania_purchase_counts = analyze_multivalue_attribute(
    romania_df, "purchase_places", "Purchase Places"
)
# Out:
# Top Packaging Types:
#                                 Count
# packaging_tags
# plastic                            13
# pet-polyethylene-terephthalate      4
# ro:sticlă                           1
# 10                                  1
# can                                 1
# Top Stores:
#            Count
# stores
# Carrefour      1
# Top Purchase Places:
#                  Count
# purchase_places
# Romania              4
# Constanta            1
# România              1

# %%
# ============================================================
# ROMANIA — NUTRI-SCORE, NOVA AND ECO-SCORE
# ============================================================

for col, label in [
    ("nutriscore_grade", "Nutri-Score"),
    ("nova_group", "NOVA Group"),
    ("ecoscore_grade", "Eco-Score")
]:
    if col in romania_df.columns:
        counts = romania_df[col].value_counts()
        print(f"{label} Distribution:")
        display(counts)
        print(f"{label} Percentage:")
        display(romania_df[col].value_counts(normalize=True).mul(100).round(2))

        plt.figure(figsize=(9, 5))
        sns.countplot(
            data=romania_df,
            x=col,
            order=romania_df[col].value_counts().index
        )
        plt.title(f"Romania – {label} Distribution")
        plt.xlabel(label)
        plt.ylabel("Number of Products")
        plt.tight_layout()
        plt.show()
# Out:
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    46
# c           7
# e           7
# b           6
# d           5
# Name: count, dtype: int64
# Nutri-Score Percentage:
# nutriscore_grade
# unknown    64.79
# c           9.86
# e           9.86
# b           8.45
# d           7.04
# Name: proportion, dtype: float64
# NOVA Group Distribution:
# nova_group
# Unknown    50
# 4.0        21
# Name: count, dtype: int64
# NOVA Group Percentage:
# nova_group
# Unknown    70.42
# 4.0        29.58
# Name: proportion, dtype: float64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           53
# not-applicable    13
# unknown            5
# Name: count, dtype: int64
# Eco-Score Percentage:
# ecoscore_grade
# Unknown           74.65
# not-applicable    18.31
# unknown            7.04
# Name: proportion, dtype: float64

# %% [markdown]
# ###  Observation
#
# The charts show the distribution of Nutri-Score, NOVA Group and Eco-Score values in the Romania data. Some categories have more records than others, but the number of `Unknown` values also needs to be considered when reading these results.

# %%
# ============================================================
# ROMANIA — SUGAR AND ENERGY
# ============================================================

romania_sugar = romania_df["nutriments.sugars_100g_num"].dropna()
romania_energy = romania_df["nutriments.energy-kcal_100g_num"].dropna()

print("Sugar Statistics:")
display(romania_sugar.describe())

print("Energy Statistics:")
display(romania_energy.describe())

plt.figure(figsize=(10, 6))
sns.histplot(romania_sugar, bins=30, kde=True)
plt.title("Romania – Sugar Distribution")
plt.xlabel("Sugar (g per 100g)")
plt.ylabel("Number of Products")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(romania_energy, bins=30, kde=True)
plt.title("Romania – Energy Distribution")
plt.xlabel("Energy (kcal per 100g)")
plt.ylabel("Number of Products")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
sns.boxplot(x=romania_sugar)
plt.title("Romania – Sugar Content Boxplot")
plt.xlabel("Sugar (g per 100g)")
plt.tight_layout()
plt.show()
# Out:
# Sugar Statistics:
# count    19.000000
# mean      6.268421
# std      13.517316
# min       0.000000
# 25%       0.100000
# 50%       0.300000
# 75%       7.450000
# max      59.000000
# Name: nutriments.sugars_100g_num, dtype: float64
# Energy Statistics:
# count     18.000000
# mean      35.555556
# std       77.678994
# min        1.000000
# 25%        2.000000
# 50%        9.000000
# 75%       40.000000
# max      337.000000
# Name: nutriments.energy-kcal_100g_num, dtype: float64

# %% [markdown]
# ###  Observation
#
# The charts show how sugar and energy values are spread across the products in Romania. The distributions are not completely even, and some products are much higher than the rest. This suggests that a small number of products may have a strong effect on the average values.

# %%
# ============================================================
# ROMANIA — SUGAR VS ENERGY
# ============================================================

romania_nutrition = romania_df[
    ["nutriments.sugars_100g_num", "nutriments.energy-kcal_100g_num"]
].dropna()

romania_sugar_energy_corr = (
    romania_nutrition["nutriments.sugars_100g_num"]
    .corr(romania_nutrition["nutriments.energy-kcal_100g_num"])
)

print("Valid nutritional records:", len(romania_nutrition))
print("Sugar–Energy Correlation:", round(romania_sugar_energy_corr, 3))

plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=romania_nutrition,
    x="nutriments.sugars_100g_num",
    y="nutriments.energy-kcal_100g_num",
    alpha=0.6
)
plt.title("Romania – Sugar vs Energy")
plt.xlabel("Sugar (g per 100g)")
plt.ylabel("Energy (kcal per 100g)")
plt.tight_layout()
plt.show()
# Out:
# Valid nutritional records: 16
# Sugar–Energy Correlation: 0.995

# %% [markdown]
# ###  Observation
#
# The scatter plot compares sugar and energy for the products in Romania. The points are spread across the chart rather than following one clear straight pattern, so the two values do not appear to move together in exactly the same way for every product.

# %%
# ============================================================
# ROMANIA — OUTLIER ANALYSIS
# ============================================================

def find_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return series[(series < lower) | (series > upper)]

romania_sugar_outliers = find_outliers(romania_sugar)
romania_energy_outliers = find_outliers(romania_energy)

print("Sugar Outliers:", len(romania_sugar_outliers))
print("Energy Outliers:", len(romania_energy_outliers))

print("\nHighest Sugar Products:")
display(
    romania_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.sugars_100g_num"]
    ].dropna(subset=["nutriments.sugars_100g_num"])
     .sort_values("nutriments.sugars_100g_num", ascending=False)
     .head(20)
)

print("\nHighest Energy Products:")
display(
    romania_df[
        ["product_name", "brands", "categories_tags",
         "nutriments.energy-kcal_100g_num"]
    ].dropna(subset=["nutriments.energy-kcal_100g_num"])
     .sort_values("nutriments.energy-kcal_100g_num", ascending=False)
     .head(20)
)
# Out:
# Sugar Outliers: 1
# Energy Outliers: 1
#
# Highest Sugar Products:
#                                            product_name  \
# 493                                    Marcelo caramelo
# 565                                  Fanta Tropical 0.5
# 8                                          Fanta lămâie
# 604                               Fanta Strawberry kiwi
# 149                                              Raison
# 16                  Fanta Portocale și fructul pasiunii
# 948                                   Peach And Jasmine
# 28                                    Fanta Dark Orange
# 41   Fanta zero zahăr cu zmeură, lămâie verde și baobab
# 40                           Fanta zero zahăr portocale
# 198                                   Fanta Orange Zero
# 323                       Fanta Zero Zahăr Portocale 2L
# 402                                         Fanta mango
# 331  Fanta What the Fanta Zero Zahăr Ananas și Hibiscus
# 197                                        Fanta citron
# 511      Fanta Zero Zahăr #WhatTheFanta Bezea de Lămâie
# 504                                       #whatthefanta
# 498                                       Fanta mystère
# 512      Fanta Zero Zahăr #WhatTheFanta Vanilie și Lime
#
#                                   brands  \
# 493                      día de fantasía
# 565                            Coca Cola
# 8                                  Fanta
# 604                                Fanta
# 149                                Fanta
# 16                                 Fanta
# 948                                Fanta
# 28                                 Fanta
# 41   Fanta, Coca-Cola, Coca-Cola Company
# 40   Fanta, Coca-Cola, Coca-Cola Company
# 198                                Fanta
# 323                            Coca Cola
# 402                            Coca-Cola
# 331                            Coca Cola
# 197                                Fanta
# 511                            Coca Cola
# 504                                Fanta
# 498                                Fanta
# 512                            Coca Cola
#
#                                                                                                              categories_tags  \
# 493                                                            snacks, sweet-snacks, confectioneries, candies, gummi-candies
# 565                           beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages
# 8    plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, sodas, ...
# 604                                                beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
# 149                                                                                                                   ro:suc
# 16   beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 948                                                                                                                  Unknown
# 28   beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 41                                beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, sweetened-beverages
# 40   plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, artific...
# 198  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 323              beverages-and-beverages-preparations, beverages, carbonated-drinks, artificially-sweetened-beverages, sodas
# 402                                                                      beverages, carbonated-drinks, sodas, ro:fanta-mango
# 331                                                                              beverages, artificially-sweetened-beverages
# 197  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 511                                                                              beverages, artificially-sweetened-beverages
# 504                        beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, diet-sodas
# 498                        beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, diet-sodas
# 512                                                beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
#
#      nutriments.sugars_100g_num
# 493                        59.0
# 565                        13.2
# 8                          11.1
# 604                        10.2
# 149                         8.4
# 16                          6.5
# 948                         4.6
# 28                          4.3
# 41                          0.4
# 40                          0.3
# 198                         0.3
# 323                         0.3
# 402                         0.3
# 331                         0.1
# 197                         0.1
# 511                         0.0
# 504                         0.0
# 498                         0.0
# 512                         0.0
# Highest Energy Products:
#                                            product_name  \
# 493                                    Marcelo caramelo
# 565                                  Fanta Tropical 0.5
# 566                                   Fanta Tropical 2l
# 946                                        Fanta Lamaie
# 604                               Fanta Strawberry kiwi
# 149                                              Raison
# 948                                   Peach And Jasmine
# 28                                    Fanta Dark Orange
# 197                                        Fanta citron
# 198                                   Fanta Orange Zero
# 402                                         Fanta mango
# 41   Fanta zero zahăr cu zmeură, lămâie verde și baobab
# 40                           Fanta zero zahăr portocale
# 323                       Fanta Zero Zahăr Portocale 2L
# 498                                       Fanta mystère
# 511      Fanta Zero Zahăr #WhatTheFanta Bezea de Lămâie
# 504                                       #whatthefanta
# 331  Fanta What the Fanta Zero Zahăr Ananas și Hibiscus
#
#                                   brands  \
# 493                      día de fantasía
# 565                            Coca Cola
# 566                            Coca Cola
# 946                                Fanta
# 604                                Fanta
# 149                                Fanta
# 948                                Fanta
# 28                                 Fanta
# 197                                Fanta
# 198                                Fanta
# 402                            Coca-Cola
# 41   Fanta, Coca-Cola, Coca-Cola Company
# 40   Fanta, Coca-Cola, Coca-Cola Company
# 323                            Coca Cola
# 498                                Fanta
# 511                            Coca Cola
# 504                                Fanta
# 331                            Coca Cola
#
#                                                                                                              categories_tags  \
# 493                                                            snacks, sweet-snacks, confectioneries, candies, gummi-candies
# 565                           beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages
# 566                                                beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
# 946                                                                                                                  Unknown
# 604                                                beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
# 149                                                                                                                   ro:suc
# 948                                                                                                                  Unknown
# 28   beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 197  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 198  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 402                                                                      beverages, carbonated-drinks, sodas, ro:fanta-mango
# 41                                beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, sweetened-beverages
# 40   plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, artific...
# 323              beverages-and-beverages-preparations, beverages, carbonated-drinks, artificially-sweetened-beverages, sodas
# 498                        beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, diet-sodas
# 511                                                                              beverages, artificially-sweetened-beverages
# 504                        beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, diet-sodas
# 331                                                                              beverages, artificially-sweetened-beverages
#
#      nutriments.energy-kcal_100g_num
# 493                            337.0
# 565                             53.0
# 566                             53.0
# 946                             48.0
# 604                             42.0
# 149                             34.0
# 948                             19.0
# 28                              19.0
# 197                              9.0
# 198                              9.0
# 402                              3.0
# 41                               3.0
# 40                               2.0
# 323                              2.0
# 498                              2.0
# 511                              2.0
# 504                              2.0
# 331                              1.0

# %%
# ============================================================
# ROMANIA — BRAND NUTRITION ANALYSIS
# ============================================================

romania_brand_nutrition = (
    romania_df.groupby("brands")
    .agg(
        Product_Count=("product_name", "count"),
        Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
        Median_Sugar=("nutriments.sugars_100g_num", "median"),
        Avg_Energy=("nutriments.energy-kcal_100g_num", "mean"),
        Median_Energy=("nutriments.energy-kcal_100g_num", "median")
    )
    .reset_index()
)

romania_brand_nutrition = (
    romania_brand_nutrition[
        romania_brand_nutrition["Product_Count"] >= 3
    ]
    .sort_values("Product_Count", ascending=False)
)

display(romania_brand_nutrition.head(20))
# Out:
#       brands  Product_Count  Avg_Sugar  Median_Sugar  Avg_Energy  \
# 2      Fanta             25       4.55          4.45   20.444444
# 6    Unknown             25        NaN           NaN         NaN
# 0  Coca Cola             10       2.72          0.10   22.200000
#
#    Median_Energy
# 2           19.0
# 6            NaN
# 0            2.0

# %%
# ============================================================
# ROMANIA — NUTRI-SCORE VS SUGAR / ENERGY
# ============================================================

if "nutriscore_grade" in romania_df.columns:

    romania_nutri_sugar = romania_df[
        ["nutriscore_grade", "nutriments.sugars_100g_num"]
    ].dropna()

    print("Sugar by Nutri-Score:")
    display(
        romania_nutri_sugar.groupby("nutriscore_grade")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=romania_nutri_sugar,
        x="nutriscore_grade",
        y="nutriments.sugars_100g_num"
    )
    plt.title("Romania – Sugar Distribution by Nutri-Score")
    plt.xlabel("Nutri-Score")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()

    romania_nutri_energy = romania_df[
        ["nutriscore_grade", "nutriments.energy-kcal_100g_num"]
    ].dropna()

    print("Energy by Nutri-Score:")
    display(
        romania_nutri_energy.groupby("nutriscore_grade")
        ["nutriments.energy-kcal_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=romania_nutri_energy,
        x="nutriscore_grade",
        y="nutriments.energy-kcal_100g_num"
    )
    plt.title("Romania – Energy by Nutri-Score")
    plt.xlabel("Nutri-Score")
    plt.ylabel("Energy (kcal per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
# Sugar by Nutri-Score:
#                   count   mean  median   min   max
# nutriscore_grade
# b                     5   0.14     0.1   0.0   0.3
# c                     4   0.20     0.2   0.0   0.4
# d                     2   5.40     5.4   4.3   6.5
# e                     2  34.60    34.6  10.2  59.0
# unknown               6   6.27     6.5   0.0  13.2
# Energy by Nutri-Score:
#                   count   mean  median   min    max
# nutriscore_grade
# b                     5    4.8     2.0   2.0    9.0
# c                     4    2.0     2.0   1.0    3.0
# d                     1   19.0    19.0  19.0   19.0
# e                     2  189.5   189.5  42.0  337.0
# unknown               6   35.0    41.0   3.0   53.0

# %% [markdown]
# ###  Observation
#
# The chart compares sugar levels across different Nutri-Score groups in Romania. The groups do not have the same sugar distribution, which shows that products with different Nutri-Scores can have noticeably different sugar levels.

# %%
# ============================================================
# ROMANIA — NOVA VS SUGAR
# ============================================================

if "nova_group" in romania_df.columns:

    romania_nova_sugar = romania_df[
        ["nova_group", "nutriments.sugars_100g_num"]
    ].dropna()

    display(
        romania_nova_sugar.groupby("nova_group")
        ["nutriments.sugars_100g_num"]
        .agg(["count", "mean", "median", "min", "max"])
        .round(2)
    )

    plt.figure(figsize=(10, 6))
    sns.boxplot(
        data=romania_nova_sugar,
        x="nova_group",
        y="nutriments.sugars_100g_num"
    )
    plt.title("Romania – Sugar by NOVA Processing Group")
    plt.xlabel("NOVA Group")
    plt.ylabel("Sugar (g per 100g)")
    plt.tight_layout()
    plt.show()
# Out:
#             count  mean  median  min   max
# nova_group
# 4.0            10  4.61    2.35  0.0  13.2
# Unknown         9  8.11    0.30  0.0  59.0

# %% [markdown]
# ### Observation
#
# The chart compares sugar levels across NOVA processing groups in Romania. The groups show different sugar distributions, although missing NOVA information means the comparison does not cover every product.

# %%
# ============================================================
# ROMANIA — CORRELATION
# ============================================================

corr_cols = [
    "nova_group_num",
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

available_corr_cols = [c for c in corr_cols if c in romania_df.columns]

romania_corr = romania_df[available_corr_cols].corr()

display(romania_corr.round(3))

plt.figure(figsize=(8, 6))
sns.heatmap(
    romania_corr,
    annot=True,
    cmap="coolwarm",
    center=0,
    fmt=".2f"
)
plt.title("Romania – Nutritional Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
#                                  nova_group_num  nutriments.sugars_100g_num  \
# nova_group_num                              NaN                         NaN
# nutriments.sugars_100g_num                  NaN                       1.000
# nutriments.energy-kcal_100g_num             NaN                       0.995
#
#                                  nutriments.energy-kcal_100g_num
# nova_group_num                                               NaN
# nutriments.sugars_100g_num                                 0.995
# nutriments.energy-kcal_100g_num                            1.000

# %% [markdown]
# ###  Observation
#
# The heatmap gives a quick view of how the numerical attributes are related in Romania. The relationships are generally not strong enough to suggest that one attribute alone explains the others.

# %%
# ============================================================
# ROMANIA — INGREDIENT ANALYSIS
# ============================================================

if "ingredients_text" in romania_df.columns:

    ingredient_text = romania_df["ingredients_text"].astype(str).str.lower()
    all_ingredients = []

    for text in ingredient_text:
        if text != "unknown":
            for ingredient in text.split(","):
                ingredient = ingredient.strip()
                if ingredient and ingredient != "unknown":
                    all_ingredients.append(ingredient)

    romania_ingredient_counts = Counter(all_ingredients)

    romania_ingredient_df = pd.DataFrame(
        romania_ingredient_counts.most_common(30),
        columns=["Ingredient", "Frequency"]
    )

    display(romania_ingredient_df)

    plt.figure(figsize=(12, 8))
    sns.barplot(
        data=romania_ingredient_df.head(15),
        x="Frequency",
        y="Ingredient"
    )
    plt.title("Romania – Most Frequently Reported Ingredients")
    plt.xlabel("Frequency")
    plt.ylabel("Ingredient")
    plt.tight_layout()
    plt.show()
# Out:
#                                             Ingredient  Frequency
# 0                                     dioxid de carbon         15
# 1                                                  apă         12
# 2                                                zahăr          6
# 3                                          acesulfam-k          6
# 4                                       arome naturale          5
# 5                            antioxidant acid ascorbic          4
# 6                                                  apa          4
# 7                                                  1%)          4
# 8   arome naturale de portocale cu alte arome naturale          4
# 9                        conservant: sorbat de potasiu          4
# 10                                        acid citric)          4
# 11                              acidifiant acid citric          3
# 12                                               arome          3
# 13                        conservant sorbat de potasiu          3
# 14                                          sucraloză)          3
# 15                           sirop de fructoză-glucoză          3
# 16                                               zahar          3
# 17                           sirop de fructoza-glucoza          2
# 18              acidifianți: acid citric și acid malic          2
# 19                       stabilizatori: gumă de acacia          2
# 20                          antioxidant: acid ascorbic          2
# 21                      îndulcitori: ciclamat de sodiu          2
# 22                                           sucraloză          2
# 23                             acidifianţi (acid malic          2
# 24                   suc de lămâie din concentrat (1%)          2
# 25                       stabilizatori (gumă de acacia          2
# 26                                         polifosfati          2
# 27              esteri glicerici ai răşinilor din lemn          2
# 28                      acetat izobutirat de zaharoză)          2
# 29                              îndulcitori (ciclamați          2

# %% [markdown]
# ###  Observation
#
# The ingredient chart shows the ingredients that appear most often in the Romania data. A few ingredients occur repeatedly, while many others appear less often. Missing or undefined ingredient entries should be kept in mind when interpreting the chart.

# %%
# ============================================================
# ROMANIA — CATEGORY VS NUTRITION
# ============================================================

if "categories_tags" in romania_df.columns:

    romania_category_nutrition = (
        romania_df.groupby("categories_tags")
        .agg(
            Product_Count=("product_name", "count"),
            Avg_Sugar=("nutriments.sugars_100g_num", "mean"),
            Avg_Energy=("nutriments.energy-kcal_100g_num", "mean")
        )
        .reset_index()
    )

    romania_category_nutrition = (
        romania_category_nutrition[
            romania_category_nutrition["Product_Count"] >= 2
        ]
        .sort_values("Product_Count", ascending=False)
    )

    display(romania_category_nutrition.head(20))
# Out:
#                                                                                                             categories_tags  \
# 0                                                                                                                   Unknown
# 9                                                 beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas
# 16  beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-...
# 1                                                                               beverages, artificially-sweetened-beverages
# 2                         beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, diet-sodas
# 12                           beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages
#
#     Product_Count  Avg_Sugar  Avg_Energy
# 0              34   4.600000   33.500000
# 9               7   5.100000   47.500000
# 16              3   1.566667   12.333333
# 1               2   0.050000    1.500000
# 2               2   0.000000    2.000000
# 12              2  13.200000   53.000000

# %%
# ============================================================
# ROMANIA — ATTRIBUTE-LEVEL ANALYSIS
# ============================================================

categorical_columns = [
    "brands",
    "categories_tags",
    "packaging_tags",
    "stores",
    "purchase_places",
    "nutriscore_grade",
    "nova_group",
    "ecoscore_grade"
]

for col in categorical_columns:
    if col in romania_df.columns:
        print("\n" + "=" * 70)
        print(f"ATTRIBUTE: {col}")
        print("=" * 70)

        counts = (
            romania_df[col]
            .astype(str)
            .value_counts()
            .head(15)
        )

        display(counts.to_frame("Count"))
# Out:
# ======================================================================
# ATTRIBUTE: brands
# ======================================================================
#                                             Count
# brands
# Fanta                                          25
# Unknown                                        25
# Coca Cola                                      10
# Fanta, Coca-Cola, Coca-Cola Company             2
# Coca-Cola                                       2
# coca cola                                       2
# día de fantasía                                 1
# fantail                                         1
# Fanta, Cadia, Coca-Cola, Coca-Cola Company      1
# Fanta, Coca-Cola                                1
# fanta                                           1
# ======================================================================
# ATTRIBUTE: categories_tags
# ======================================================================
#                                                                                                                           Count
# categories_tags
# Unknown                                                                                                                      34
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas                                                     7
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      3
# beverages, artificially-sweetened-beverages                                                                                   2
# beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, diet-beverages, diet-sodas                             2
# beverages-and-beverages-preparations, beverages, carbonated-drinks, sodas, sweetened-beverages                                2
# plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, sodas, f...      1
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      1
# plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-drinks, fruit-based-beverages, artifici...      1
# beverages, carbonated-drinks, artificially-sweetened-beverages, sodas, sweetened-beverages                                    1
# ro:suc                                                                                                                        1
# beverages-and-beverages-preparations, beverages, carbonated-drinks, artificially-sweetened-beverages, sodas                   1
# beverages, carbonated-drinks, sodas, ro:fanta-mango                                                                           1
# snacks, sweet-snacks, confectioneries, candies, gummi-candies                                                                 1
# beverages-and-beverages-preparations, plant-based-foods-and-beverages, beverages, plant-based-beverages, carbonated-d...      1
# ======================================================================
# ATTRIBUTE: packaging_tags
# ======================================================================
#                                          Count
# packaging_tags
# Unknown                                     55
# plastic                                      9
# plastic, pet-polyethylene-terephthalate      4
# ro:sticlă                                    1
# 10                                           1
# can                                          1
# ======================================================================
# ATTRIBUTE: stores
# ======================================================================
#            Count
# stores
# Unknown       70
# Carrefour      1
# ======================================================================
# ATTRIBUTE: purchase_places
# ======================================================================
#                    Count
# purchase_places
# Unknown               66
# Romania                3
# Constanta,Romania      1
# România                1
# ======================================================================
# ATTRIBUTE: nutriscore_grade
# ======================================================================
#                   Count
# nutriscore_grade
# unknown              46
# c                     7
# e                     7
# b                     6
# d                     5
# ======================================================================
# ATTRIBUTE: nova_group
# ======================================================================
#             Count
# nova_group
# Unknown        50
# 4.0            21
# ======================================================================
# ATTRIBUTE: ecoscore_grade
# ======================================================================
#                 Count
# ecoscore_grade
# Unknown            53
# not-applicable     13
# unknown             5

# %%
# ============================================================
# ROMANIA — NUMERICAL ATTRIBUTE ANALYSIS
# ============================================================

numerical_columns = [
    "nutriments.sugars_100g_num",
    "nutriments.energy-kcal_100g_num"
]

romania_numeric_summary = []

for col in numerical_columns:
    if col in romania_df.columns:
        romania_numeric_summary.append({
            "Attribute": col,
            "Count": romania_df[col].count(),
            "Mean": romania_df[col].mean(),
            "Median": romania_df[col].median(),
            "Std": romania_df[col].std(),
            "Minimum": romania_df[col].min(),
            "Maximum": romania_df[col].max()
        })

romania_numeric_summary = pd.DataFrame(romania_numeric_summary)
display(romania_numeric_summary.round(2))
# Out:
#                          Attribute  Count   Mean  Median    Std  Minimum  \
# 0       nutriments.sugars_100g_num     19   6.27     0.3  13.52      0.0
# 1  nutriments.energy-kcal_100g_num     18  35.56     9.0  77.68      1.0
#
#    Maximum
# 0     59.0
# 1    337.0

# %%
# ============================================================
# ROMANIA — DATA QUALITY CHECK
# ============================================================

print("ROMANIA DATA QUALITY CHECK")
print("=" * 60)

print("Duplicate Rows:", romania_df.duplicated().sum())
print("Duplicate Product Names:", romania_df["product_name"].duplicated().sum())
print("Unique Products:", romania_df["product_name"].nunique())
print("Unique Brands:", romania_df["brands"].nunique())
print("Records:", len(romania_df))
# Out:
# ROMANIA DATA QUALITY CHECK
# ============================================================
# Duplicate Rows: 0
# Duplicate Product Names: 6
# Unique Products: 65
# Unique Brands: 11
# Records: 71

# %%
# ============================================================
# ROMANIA — FINAL SUMMARY
# ============================================================

print("=" * 70)
print(" ROMANIA – ADVANCED DATA ANALYSIS SUMMARY")
print("=" * 70)

print(f"\nTotal Records: {len(romania_df):,}")
print(f"Unique Products: {romania_df['product_name'].nunique():,}")
print(f"Unique Brands: {romania_df['brands'].nunique():,}")

print("\nTop 5 Brands:")
display(romania_brand_counts.head(5))

print("\nTop 5 Categories:")
display(romania_category_counts.head(5))

print("\nTop Packaging Types:")
display(romania_packaging_counts.head(5))

print("\nTop Stores:")
display(romania_store_counts.head(5))

print("\nTop Purchase Places:")
display(romania_purchase_counts.head(5))

if "nutriscore_grade" in romania_df.columns:
    print("\nNutri-Score Distribution:")
    display(romania_df["nutriscore_grade"].value_counts())

if "nova_group" in romania_df.columns:
    print("\nNOVA Distribution:")
    display(romania_df["nova_group"].value_counts())

if "ecoscore_grade" in romania_df.columns:
    print("\nEco-Score Distribution:")
    display(romania_df["ecoscore_grade"].value_counts())

print("\nNutritional Statistics:")
display(pd.DataFrame({
    "Metric": [
        "Average Sugar", "Median Sugar", "Maximum Sugar",
        "Average Energy", "Median Energy", "Maximum Energy"
    ],
    "Value": [
        romania_sugar.mean(), romania_sugar.median(), romania_sugar.max(),
        romania_energy.mean(), romania_energy.median(), romania_energy.max()
    ]
}).round(2))

print("\nSugar–Energy Correlation:", round(romania_sugar_energy_corr, 3))
print("\nAnalysis completed for Romania.")
# Out:
# ======================================================================
#  ROMANIA – ADVANCED DATA ANALYSIS SUMMARY
# ======================================================================
#
# Total Records: 71
# Unique Products: 65
# Unique Brands: 11
#
# Top 5 Brands:
#                                  Brand  Product_Count
# 0                                Fanta             25
# 1                              Unknown             25
# 2                            Coca Cola             10
# 3  Fanta, Coca-Cola, Coca-Cola Company              2
# 4                            Coca-Cola              2
# Top 5 Categories:
# categories_tags
# beverages                               34
# carbonated-drinks                       30
# sodas                                   28
# beverages-and-beverages-preparations    23
# plant-based-foods-and-beverages         12
# Name: count, dtype: int64
# Top Packaging Types:
# packaging_tags
# plastic                           13
# pet-polyethylene-terephthalate     4
# ro:sticlă                          1
# 10                                 1
# can                                1
# Name: count, dtype: int64
# Top Stores:
# stores
# Carrefour    1
# Name: count, dtype: int64
# Top Purchase Places:
# purchase_places
# Romania      4
# Constanta    1
# România      1
# Name: count, dtype: int64
# Nutri-Score Distribution:
# nutriscore_grade
# unknown    46
# c           7
# e           7
# b           6
# d           5
# Name: count, dtype: int64
# NOVA Distribution:
# nova_group
# Unknown    50
# 4.0        21
# Name: count, dtype: int64
# Eco-Score Distribution:
# ecoscore_grade
# Unknown           53
# not-applicable    13
# unknown            5
# Name: count, dtype: int64
# Nutritional Statistics:
#            Metric   Value
# 0   Average Sugar    6.27
# 1    Median Sugar    0.30
# 2   Maximum Sugar   59.00
# 3  Average Energy   35.56
# 4   Median Energy    9.00
# 5  Maximum Energy  337.00
# Sugar–Energy Correlation: 0.995
#
# Analysis completed for Romania.

# %% [markdown]
# ### Romania — Observation and Insight
#
# Romania has the smallest catalog at **71 records**, covering **65 unique products** and **11 brands**. It also has the lowest average sugar (**6.27 g per 100 g**) and lowest average energy (**35.56 kcal per 100 g**) among the countries with usable nutrition values. Its sugar-energy correlation is very strong (**0.995**), but this result is based on a small sample and should be validated with more complete product coverage before being generalized.

# %% [markdown]
# #  PART 6 — FIVE-COUNTRY COMPARATIVE ADVANCED ANALYSIS
#
# All five individual analyses are now complete. This section compares the countries using the **same single dataframe `df`**.

# %%
# ============================================================
# 31. VERIFY FIVE COUNTRIES
# ============================================================

countries_to_check = [
    "united-states",
    "italy",
    "united-kingdom",
    "australia",
    "romania"
]

country_summary = (
    df[
        df["countries_tags"].astype(str).str.lower().isin(countries_to_check)
    ]
    .assign(Country=lambda x: x["countries_tags"].astype(str).str.lower())
    .groupby("Country")
    .size()
    .reindex(countries_to_check)
    .reset_index(name="Record_Count")
)

display(country_summary)
# Out:
#           Country  Record_Count
# 0   united-states           435
# 1           italy           315
# 2  united-kingdom           143
# 3       australia            95
# 4         romania            71

# %%
# ============================================================
# 32. RECORD / PRODUCT / BRAND COMPARISON
# ============================================================

comparison_df = (
    df[
        df["countries_tags"].astype(str).str.lower().isin(countries_to_check)
    ]
    .assign(Country=lambda x: x["countries_tags"].astype(str).str.lower())
    .groupby("Country")
    .agg(
        Records=("product_name", "count"),
        Unique_Products=("product_name", "nunique"),
        Unique_Brands=("brands", "nunique")
    )
    .reindex(countries_to_check)
    .reset_index()
)

comparison_df["Brand_Diversity_Percentage"] = (
    comparison_df["Unique_Brands"] /
    comparison_df["Records"] * 100
).round(2)

display(comparison_df)
# Out:
#           Country  Records  Unique_Products  Unique_Brands  \
# 0   united-states      435              338             88
# 1           italy      315              263            126
# 2  united-kingdom      143              101             30
# 3       australia       95               90             16
# 4         romania       71               65             11
#
#    Brand_Diversity_Percentage
# 0                       20.23
# 1                       40.00
# 2                       20.98
# 3                       16.84
# 4                       15.49

# %% [markdown]
# ### Catalog Size — Observation and Insight
#
# Catalog size varies substantially by country. The United States leads with **435 records**, while Romania has **71**, so raw counts should not be treated as market-size estimates. Italy stands out for brand breadth with **126 brands across 315 records**, whereas Romania has **11 brands across 71 records**, showing a much narrower observed brand mix.

# %%
# ============================================================
# 33. NUTRITIONAL COMPARISON
# ============================================================

nutrition_comparison = (
    df[
        df["countries_tags"].astype(str).str.lower().isin(countries_to_check)
    ]
    .assign(Country=lambda x: x["countries_tags"].astype(str).str.lower())
    .groupby("Country")
    .agg(
        Average_Sugar=("nutriments.sugars_100g_num", "mean"),
        Median_Sugar=("nutriments.sugars_100g_num", "median"),
        Maximum_Sugar=("nutriments.sugars_100g_num", "max"),
        Average_Energy=("nutriments.energy-kcal_100g_num", "mean"),
        Median_Energy=("nutriments.energy-kcal_100g_num", "median"),
        Maximum_Energy=("nutriments.energy-kcal_100g_num", "max")
    )
    .reindex(countries_to_check)
    .reset_index()
)

display(nutrition_comparison.round(2))
# Out:
#           Country  Average_Sugar  Median_Sugar  Maximum_Sugar  Average_Energy  \
# 0   united-states          14.71           2.0          254.0          182.62
# 1           italy            NaN           NaN            NaN             NaN
# 2  united-kingdom            NaN           NaN            NaN             NaN
# 3       australia          13.62           4.2           99.9          195.47
# 4         romania           6.27           0.3           59.0           35.56
#
#    Median_Energy  Maximum_Energy
# 0           9.35         26000.0
# 1            NaN             NaN
# 2            NaN             NaN
# 3          93.10           536.0
# 4           9.00           337.0

# %%
# ============================================================
# 34. AVERAGE SUGAR BY COUNTRY
# ============================================================

plt.figure(figsize=(11, 6))
sns.barplot(
    data=nutrition_comparison,
    x="Country",
    y="Average_Sugar"
)
plt.title("Average Sugar Content Across Five Countries")
plt.xlabel("Country")
plt.ylabel("Average Sugar (g per 100g)")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Observation
#
# The chart compares the average sugar content across the five countries. The bars are different in height, showing that the average sugar level is not the same in every country. The country with the tallest bar has the highest average sugar in this dataset.

# %% [markdown]
# ### Comparative Nutrition — Observation and Insight
#
# The nutrition comparison shows a clear spread across the countries with usable values: the United States has the highest average sugar (**14.71 g/100 g**), Romania the lowest (**6.27 g/100 g**), and Australia the highest average energy (**195.47 kcal/100 g**). These averages should be compared alongside the valid-record counts and missing-value patterns, because incomplete nutrition fields limit direct comparisons for Italy and the United Kingdom.

# %%
# ============================================================
# 35. AVERAGE ENERGY BY COUNTRY
# ============================================================

plt.figure(figsize=(11, 6))
sns.barplot(
    data=nutrition_comparison,
    x="Country",
    y="Average_Energy"
)
plt.title("Average Energy Content Across Five Countries")
plt.xlabel("Country")
plt.ylabel("Average Energy (kcal per 100g)")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Observation
#
# The chart compares the average energy content across the five countries. The differences between the bars show that the products recorded in each country do not have the same average energy level.

# %% [markdown]
# ### Average Energy Visualization — Analysis Result
#
# The average-energy chart shows that **Australia has the highest average energy content at 195.47 kcal per 100 g**, followed by the United States at 182.62 kcal per 100 g. Romania is the lowest at 35.56 kcal per 100 g. Italy and the United Kingdom do not have sufficient numeric energy values for a reliable comparison, so their missing values should not be interpreted as zero.

# %%
# ============================================================
# 36. NUTRI-SCORE COMPARISON
# ============================================================

nutri_comparison = pd.crosstab(
    df["countries_tags"].astype(str).str.lower(),
    df["nutriscore_grade"]
).reindex(countries_to_check).fillna(0)

display(nutri_comparison)

nutri_percentage = (
    nutri_comparison
    .div(nutri_comparison.sum(axis=1), axis=0)
    * 100
).round(2)

print("Nutri-Score Percentage by Country:")
display(nutri_percentage)
# Out:
# nutriscore_grade  Unknown   a    b   c   d   e  not-applicable  unknown
# countries_tags
# united-states           0   1  150  48   8  54               0      174
# italy                   1  18   14  25  26  16               9      206
# united-kingdom          0   1    6  14  11   5               0      106
# australia               0   0    1   0   2   1               0       91
# romania                 0   0    6   7   5   7               0       46
# Nutri-Score Percentage by Country:
# nutriscore_grade  Unknown     a      b      c     d      e  not-applicable  \
# countries_tags
# united-states        0.00  0.23  34.48  11.03  1.84  12.41            0.00
# italy                0.32  5.71   4.44   7.94  8.25   5.08            2.86
# united-kingdom       0.00  0.70   4.20   9.79  7.69   3.50            0.00
# australia            0.00  0.00   1.05   0.00  2.11   1.05            0.00
# romania              0.00  0.00   8.45   9.86  7.04   9.86            0.00
#
# nutriscore_grade  unknown
# countries_tags
# united-states       40.00
# italy               65.40
# united-kingdom      74.13
# australia           95.79
# romania             64.79

# %% [markdown]
# ### Nutri-Score Comparison — Analysis Result
#
# The Nutri-Score crosstab compares the observed grade counts for each country. The comparison should be read as a distribution of **recorded classifications**, not a complete health profile of each market, because unreported grades remain represented as `Unknown` and country sample sizes are different.

# %%
# ============================================================
# 37. NOVA GROUP COMPARISON
# ============================================================

nova_comparison = pd.crosstab(
    df["countries_tags"].astype(str).str.lower(),
    df["nova_group"]
).reindex(countries_to_check).fillna(0)

display(nova_comparison)

nova_percentage = (
    nova_comparison
    .div(nova_comparison.sum(axis=1), axis=0)
    * 100
).round(2)

print("NOVA Percentage by Country:")
display(nova_percentage)
# Out:
# nova_group      1.0  3.0  4.0  Unknown
# countries_tags
# united-states     1    2   51      381
# italy             6    7   23      279
# united-kingdom    1    4   29      109
# australia         0    0   26       69
# romania           0    0   21       50
# NOVA Percentage by Country:
# nova_group       1.0   3.0    4.0  Unknown
# countries_tags
# united-states   0.23  0.46  11.72    87.59
# italy           1.90  2.22   7.30    88.57
# united-kingdom  0.70  2.80  20.28    76.22
# australia       0.00  0.00  27.37    72.63
# romania         0.00  0.00  29.58    70.42

# %% [markdown]
# ### NOVA Group Comparison — Analysis Result
#
# The NOVA table shows the distribution of food-processing groups across the five observed country catalogs. Differences should be evaluated using the percentage table rather than raw counts, because the United States contributes many more records than Romania and the percentage calculation excludes neither missing classifications nor uneven catalog coverage.

# %%
# ============================================================
# 38. ECO-SCORE COMPARISON
# ============================================================

eco_comparison = pd.crosstab(
    df["countries_tags"].astype(str).str.lower(),
    df["ecoscore_grade"]
).reindex(countries_to_check).fillna(0)

display(eco_comparison)

eco_percentage = (
    eco_comparison
    .div(eco_comparison.sum(axis=1), axis=0)
    * 100
).round(2)

print("Eco-Score Percentage by Country:")
display(eco_percentage)
# Out:
# ecoscore_grade  Unknown  d  f  not-applicable  unknown
# countries_tags
# united-states       346  2  2               3       82
# italy               314  0  0               0        1
# united-kingdom      134  0  0               1        8
# australia            64  0  0               2       29
# romania              53  0  0              13        5
# Eco-Score Percentage by Country:
# ecoscore_grade  Unknown     d     f  not-applicable  unknown
# countries_tags
# united-states     79.54  0.46  0.46            0.69    18.85
# italy             99.68  0.00  0.00            0.00     0.32
# united-kingdom    93.71  0.00  0.00            0.70     5.59
# australia         67.37  0.00  0.00            2.11    30.53
# romania           74.65  0.00  0.00           18.31     7.04

# %% [markdown]
# ### Eco-Score Comparison — Analysis Result
#
# The Eco-Score table compares the environmental classification recorded for products in each country. The percentages make country profiles easier to compare than raw totals, but the result remains limited to products with a documented Eco-Score; `Unknown` values indicate missing source information rather than poor environmental performance.

# %% [markdown]
# ### Score Distributions — Observation and Insight
#
# The Nutri-Score, NOVA, and Eco-Score tables describe how product classifications are distributed within each country. The main analytical point is that the country profiles are not directly interchangeable: record volumes differ and missing values were standardized as `Unknown`. Therefore, the percentage tables are more useful for comparing the observed classified products than for claiming differences in the full national markets.

# %%
# ============================================================
# 39. SUGAR–ENERGY CORRELATION BY COUNTRY
# ============================================================

country_correlations = []

for country in countries_to_check:
    temp = df[
        df["countries_tags"].astype(str).str.lower() == country
    ][
        [
            "nutriments.sugars_100g_num",
            "nutriments.energy-kcal_100g_num"
        ]
    ].dropna()

    country_correlations.append({
        "Country": country,
        "Valid_Records": len(temp),
        "Sugar_Energy_Correlation": (
            temp["nutriments.sugars_100g_num"]
            .corr(temp["nutriments.energy-kcal_100g_num"])
            if len(temp) > 1 else np.nan
        )
    })

country_correlations = pd.DataFrame(country_correlations)

display(country_correlations.round(3))
# Out:
#           Country  Valid_Records  Sugar_Energy_Correlation
# 0   united-states            324                     0.062
# 1           italy              0                       NaN
# 2  united-kingdom              0                       NaN
# 3       australia             50                     0.473
# 4         romania             16                     0.995

# %% [markdown]
# ### Sugar–Energy Relationship — Observation and Insight
#
# The country correlations are uneven: the United States shows almost no linear relationship (**0.062**), Australia a moderate positive relationship (**0.473**), and Romania a very strong positive relationship (**0.995**). Italy and the United Kingdom do not have enough usable paired nutrition values for a meaningful correlation. The result is descriptive, not causal, and the Romania estimate is especially sensitive to its small sample.

# %%
# ============================================================
# 40. TOP BRANDS BY COUNTRY
# ============================================================

for country in countries_to_check:
    print("\n" + "=" * 70)
    print(country.upper())
    print("=" * 70)

    temp = df[
        df["countries_tags"].astype(str).str.lower() == country
    ]

    display(
        temp["brands"]
        .value_counts()
        .head(10)
        .to_frame("Product_Count")
    )
# Out:
# ======================================================================
# UNITED-STATES
# ======================================================================
#                   Product_Count
# brands
# Fanta                        76
# Firehouse Subs               72
# Unknown                      49
# Zaxby's                      32
# White Castle                 30
# Whataburger                  14
# Church's Chicken             10
# Sonic                        10
# Jack in the Box               8
# McDonald's                    8
# ======================================================================
# ITALY
# ======================================================================
#                                Product_Count
# brands
# Unknown                                   79
# Fanta                                     29
# Fantasie Aromatiche                       27
# Fantasy, Menz & Gasser                     8
# Gusto e fantasia                           6
# Euroverde, Fantasie dell'Orto              5
# Coop                                       5
# Gallo                                      4
# Selex                                      4
# Euroverde                                  3
# ======================================================================
# UNITED-KINGDOM
# ======================================================================
#                   Product_Count
# brands
# Fanta                        96
# Unknown                      14
# Coca Cola                     3
# Brompton House                3
# Sunfeast                      2
# OceanSea,Tesco                1
# Fanta, Coco Coka              1
# Sierra, Fanta                 1
# Dorset cereals                1
# Gelatelli                     1
# ======================================================================
# AUSTRALIA
# ======================================================================
#                           Product_Count
# brands
# Fantastic                            36
# Fanta                                28
# Unknown                              12
# Coles                                 4
# Coca-Cola                             2
# Bare Bakers                           2
# Dark Fantasy                          2
# Coles Supermarket, Coles              1
# Nestlé                                1
# Fini                                  1
# ======================================================================
# ROMANIA
# ======================================================================
#                                             Product_Count
# brands
# Fanta                                                  25
# Unknown                                                25
# Coca Cola                                              10
# Fanta, Coca-Cola, Coca-Cola Company                     2
# Coca-Cola                                               2
# coca cola                                               2
# día de fantasía                                         1
# fantail                                                 1
# Fanta, Cadia, Coca-Cola, Coca-Cola Company              1
# Fanta, Coca-Cola                                        1

# %%
# ============================================================
# 41. TOP CATEGORIES BY COUNTRY
# ============================================================

for country in countries_to_check:
    print("\n" + "=" * 70)
    print(country.upper())
    print("=" * 70)

    temp = df[
        df["countries_tags"].astype(str).str.lower() == country
    ]

    categories = (
        temp["categories_tags"]
        .astype(str)
        .str.split(",")
        .explode()
        .str.strip()
    )

    categories = categories[
        categories.str.lower() != "unknown"
    ]

    display(
        categories.value_counts()
        .head(10)
        .to_frame("Product_Count")
    )
# Out:
# ======================================================================
# UNITED-STATES
# ======================================================================
#                                       Product_Count
# categories_tags
# beverages                                       257
# beverages-and-beverages-preparations            243
# carbonated-drinks                                19
# sodas                                            18
# plant-based-foods-and-beverages                  13
# snacks                                           11
# sweet-snacks                                     10
# confectioneries                                   9
# plant-based-foods                                 7
# plant-based-beverages                             6
# ======================================================================
# ITALY
# ======================================================================
#                                    Product_Count
# categories_tags
# plant-based-foods-and-beverages               75
# plant-based-foods                             66
# beverages                                     20
# frozen-foods                                  17
# snacks                                        16
# fruits-and-vegetables-based-foods             15
# sweet-snacks                                  14
# meals                                         13
# cereals-and-potatoes                          12
# seeds                                         12
# ======================================================================
# UNITED-KINGDOM
# ======================================================================
#                                       Product_Count
# categories_tags
# beverages                                        34
# carbonated-drinks                                25
# sodas                                            23
# beverages-and-beverages-preparations             22
# plant-based-foods-and-beverages                  18
# plant-based-beverages                            15
# fruit-based-beverages                            15
# fruit-sodas                                      14
# sweetened-beverages                              11
# artificially-sweetened-beverages                  9
# ======================================================================
# AUSTRALIA
# ======================================================================
#                                  Product_Count
# categories_tags
# plant-based-foods-and-beverages              9
# plant-based-foods                            9
# pastas                                       9
# noodles                                      9
# dried-products                               8
# dried-products-to-be-rehydrated              8
# instant-noodles                              8
# snacks                                       5
# salty-snacks                                 5
# appetizers                                   5
# ======================================================================
# ROMANIA
# ======================================================================
#                                       Product_Count
# categories_tags
# beverages                                        34
# carbonated-drinks                                30
# sodas                                            28
# beverages-and-beverages-preparations             23
# plant-based-foods-and-beverages                  12
# plant-based-beverages                            12
# fruit-based-beverages                            11
# sweetened-beverages                              11
# fruit-sodas                                       9
# artificially-sweetened-beverages                  9

# %%
# ============================================================
# 42. DATA QUALITY COMPARISON
# ============================================================

quality_rows = []

for country in countries_to_check:

    temp = df[
        df["countries_tags"].astype(str).str.lower() == country
    ]

    unknown_total = sum(
        temp[col].astype(str)
        .str.strip()
        .str.lower()
        .eq("unknown")
        .sum()
        for col in temp.columns
    )

    quality_rows.append({
        "Country": country,
        "Records": len(temp),
        "Duplicate_Rows": temp.duplicated().sum(),
        "Unknown_Cells": unknown_total,
        "Unique_Products": temp["product_name"].nunique(),
        "Unique_Brands": temp["brands"].nunique()
    })

quality_comparison = pd.DataFrame(quality_rows)

display(quality_comparison)
# Out:
#           Country  Records  Duplicate_Rows  Unknown_Cells  Unique_Products  \
# 0   united-states      435               0           2843              338
# 1           italy      315               0           2843              263
# 2  united-kingdom      143               0           1269              101
# 3       australia       95               0            750               90
# 4         romania       71               0            559               65
#
#    Unique_Brands
# 0             88
# 1            126
# 2             30
# 3             16
# 4             11

# %% [markdown]
# ### Data Quality — Observation and Insight
#
# The quality comparison should be read together with the country counts: the United States has the largest absolute number of records and Italy has the widest brand coverage, while smaller country samples can make missing cells or repeated products more influential. Treating missing values as `Unknown` preserves the source records, but it also means that score and nutrition comparisons describe the documented subset rather than every product in each market.

# %% [markdown]
# #  PART 7 — AUTOMATED FINAL INSIGHTS
#
# The following cell creates data-driven summary statements from the actual results in the notebook.

# %%
# ============================================================
# 43. AUTOMATED FINAL INSIGHTS
# ============================================================

print("=" * 80)
print("FINAL FIVE-COUNTRY DATA ANALYSIS INSIGHTS")
print("=" * 80)

highest_records = comparison_df.loc[
    comparison_df["Records"].idxmax()
]

highest_brands = comparison_df.loc[
    comparison_df["Unique_Brands"].idxmax()
]

highest_avg_sugar = nutrition_comparison.loc[
    nutrition_comparison["Average_Sugar"].idxmax()
]

lowest_avg_sugar = nutrition_comparison.loc[
    nutrition_comparison["Average_Sugar"].idxmin()
]

highest_avg_energy = nutrition_comparison.loc[
    nutrition_comparison["Average_Energy"].idxmax()
]

lowest_avg_energy = nutrition_comparison.loc[
    nutrition_comparison["Average_Energy"].idxmin()
]

print(
    f"\n• Highest number of records: "
    f"{highest_records['Country']} "
    f"({int(highest_records['Records']):,})"
)

print(
    f"• Highest number of unique brands: "
    f"{highest_brands['Country']} "
    f"({int(highest_brands['Unique_Brands']):,})"
)

print(
    f"• Highest average sugar: "
    f"{highest_avg_sugar['Country']} "
    f"({highest_avg_sugar['Average_Sugar']:.2f} g/100g)"
)

print(
    f"• Lowest average sugar: "
    f"{lowest_avg_sugar['Country']} "
    f"({lowest_avg_sugar['Average_Sugar']:.2f} g/100g)"
)

print(
    f"• Highest average energy: "
    f"{highest_avg_energy['Country']} "
    f"({highest_avg_energy['Average_Energy']:.2f} kcal/100g)"
)

print(
    f"• Lowest average energy: "
    f"{lowest_avg_energy['Country']} "
    f"({lowest_avg_energy['Average_Energy']:.2f} kcal/100g)"
)
# Out:
# ================================================================================
# FINAL FIVE-COUNTRY DATA ANALYSIS INSIGHTS
# ================================================================================
#
# • Highest number of records: united-states (435)
# • Highest number of unique brands: italy (126)
# • Highest average sugar: united-states (14.71 g/100g)
# • Lowest average sugar: romania (6.27 g/100g)
# • Highest average energy: australia (195.47 kcal/100g)
# • Lowest average energy: romania (35.56 kcal/100g)

# %% [markdown]
# ## Concise Five-Country Summary
#
# The analysis shows five distinct catalog profiles: the **United States** has the largest observed catalog (**435 records, 338 products, 88 brands**) and the highest average sugar (**14.71 g/100 g**); **Italy** has the greatest brand diversity (**126 brands across 315 records**); the **United Kingdom** contributes a smaller catalog (**143 records, 101 products, 30 brands**); **Australia** has the highest average energy (**195.47 kcal/100 g**) with **95 records**; and **Romania** has the smallest catalog (**71 records, 65 products, 11 brands**) plus the lowest average sugar (**6.27 g/100 g**) and energy (**35.56 kcal/100 g**). The sugar-energy relationship is weak in the United States, moderate in Australia, and very strong in Romania, while Italy and the United Kingdom lack sufficient paired nutrition data. Because coverage, sample size, and completeness vary by country, these findings describe the collected product records and should not be interpreted as estimates of entire national markets.

# %% [markdown]
# # Final Observations and Conclusion
#
# ## Executive Summary
#
# This analysis compares product records from the United States, Italy, the United Kingdom, Australia, and Romania using one combined dataset. The five country catalogs differ in size, product variety, brand representation, nutritional profile, classification coverage, and data completeness. The tables below summarize the main results, followed by detailed observations and interpretation guidance.
#
# ## 1. Country Catalog Comparison
#
# | Country | Records | Unique Products | Unique Brands | Main Observation |
# |---|---:|---:|---:|---|
# | United States | 435 | 338 | 88 | Largest observed catalog |
# | Italy | 315 | 263 | 126 | Highest brand diversity |
# | United Kingdom | 143 | 101 | 30 | Smaller catalog with limited nutrition coverage |
# | Australia | 95 | 90 | 16 | High product uniqueness and highest average energy |
# | Romania | 71 | 65 | 11 | Smallest catalog and narrowest brand mix |
#
# ### Catalog Interpretation
#
# The United States has the largest number of records, while Italy has the greatest number of unique brands. Romania has the smallest observed catalog. Record counts should not be treated as market-size estimates because the dataset may contain different collection levels, repeated product names, and unequal coverage across countries. The difference between records and unique products also shows that a record is not always a distinct product.
#
# ## 2. Nutritional Comparison
#
# | Country | Average Sugar (g/100 g) | Median Sugar (g/100 g) | Average Energy (kcal/100 g) | Median Energy (kcal/100 g) | Interpretation |
# |---|---:|---:|---:|---:|---|
# | United States | 14.71 | 2.00 | 182.62 | 9.35 | Highest average sugar |
# | Italy | Not available | Not available | Not available | Not available | Insufficient numeric nutrition coverage |
# | United Kingdom | Not available | Not available | Not available | Not available | Insufficient numeric nutrition coverage |
# | Australia | 13.62 | 4.20 | 195.47 | 93.10 | Highest average energy |
# | Romania | 6.27 | 0.30 | 35.56 | 9.00 | Lowest average sugar and energy |
#
# ### Nutritional Interpretation
#
# Among the countries with usable numeric values, the United States has the highest average sugar content at **14.71 g per 100 g**. Romania has the lowest average sugar content at **6.27 g per 100 g** and the lowest average energy content at **35.56 kcal per 100 g**. Australia has the highest average energy value at **195.47 kcal per 100 g**. Italy and the United Kingdom should not be interpreted as having zero sugar or energy; their values are unavailable or insufficient for a reliable comparison.
#
# ## 3. Sugar and Energy Relationship
#
# | Country | Sugar-Energy Correlation | Strength in Observed Data | Interpretation |
# |---|---:|---|---|
# | United States | 0.062 | Very weak | Sugar alone does not explain energy variation |
# | Italy | Not available | Not calculable | Insufficient paired nutrition values |
# | United Kingdom | Not available | Not calculable | Insufficient paired nutrition values |
# | Australia | 0.473 | Moderate positive | Higher sugar tends to occur with higher energy in this sample |
# | Romania | 0.995 | Very strong positive | Strong observed association, sensitive to small sample size |
#
# ### Correlation Interpretation
#
# The United States shows almost no linear relationship between sugar and energy, which means that other ingredients and product types likely contribute substantially to energy differences. Australia shows a moderate positive relationship. Romania shows a very strong positive relationship, but the small number of records makes this estimate sensitive to individual products. Correlation describes association only and does not demonstrate causation.
#
# ## 4. Country-Level Observations
#
# ### United States
#
# The United States section contains **435 records**, representing **338 unique products** from **88 brands**. It is the broadest country-level catalog, but repeated product names show that the record count is larger than the distinct-product count. Products average **14.71 g of sugar** and **182.62 kcal per 100 g** among the available nutrition values. The near-zero sugar-energy correlation of **0.062** suggests that sugar alone does not explain the energy variation in this catalog.
#
# ### Italy
#
# Italy contains **315 records**, **263 unique products**, and **126 brands**. Although it has fewer records than the United States, it has the highest number of unique brands in the comparison. This indicates the broadest observed brand mix. Many Italian nutrition values are unavailable after numeric cleaning, so Italy's nutritional profile cannot be compared reliably with countries that have more complete nutrition records.
#
# ### United Kingdom
#
# The United Kingdom contributes **143 records**, **101 unique products**, and **30 brands**. Its smaller catalog means that individual products can have a greater effect on observed distributions. The available data does not provide enough complete paired sugar and energy values for a meaningful correlation, so the United Kingdom is better interpreted through its documented products, brands, categories, and classifications.
#
# ### Australia
#
# Australia contributes **95 records**, **90 unique products**, and **16 brands**, indicating relatively little product-name repetition. Its products average **13.62 g of sugar** and **195.47 kcal per 100 g**, the highest average energy level in the comparison. The positive correlation of **0.473** indicates a moderate relationship between sugar and energy in this sample, but it should not be treated as causal.
#
# ### Romania
#
# Romania has the smallest catalog, with **71 records**, **65 unique products**, and **11 brands**. It has the lowest average sugar content at **6.27 g per 100 g** and the lowest average energy content at **35.56 kcal per 100 g** among the countries with usable nutrition values. Its **0.995** sugar-energy correlation is very strong, but the small sample means the result should be validated with more complete product coverage.
#
# ## 5. Product Classification and Data Quality
#
# | Analysis Area | Main Result | Important Limitation |
# |---|---|---|
# | Nutri-Score | Country-level grade distributions are available for comparison | Unknown grades represent missing source information |
# | NOVA Group | Processing-group distributions can be compared using percentages | Raw counts are affected by unequal country catalog sizes |
# | Eco-Score | Environmental classification patterns are visible in the recorded data | Unknown scores do not indicate poor environmental performance |
# | Nutrition | United States, Australia, and Romania show usable averages | Italy and the United Kingdom have insufficient numeric coverage |
# | Data quality | Missing values were standardized as `Unknown` to preserve records | Classification and nutrition comparisons describe documented subsets |
#
# The Nutri-Score, NOVA Group, and Eco-Score tables describe the classifications recorded for products in each country. Percentage tables are more meaningful than raw counts because the country sample sizes differ substantially. An `Unknown` value means that the source did not provide the field; it should not be interpreted as a negative score or a product characteristic.
#
# ## 6. Final Conclusion
#
# The analysis identifies five distinct product intelligence profiles:
#
# - **United States:** the largest observed catalog, the highest average sugar, and a very weak sugar-energy relationship.
# - **Italy:** the highest brand diversity, but limited nutritional coverage.
# - **United Kingdom:** a smaller catalog with insufficient paired nutrition values for strong nutritional conclusions.
# - **Australia:** the highest average energy and a moderate positive sugar-energy relationship.
# - **Romania:** the smallest catalog, the lowest observed sugar and energy averages, and a strong but sample-sensitive sugar-energy relationship.
#
# Overall, the analysis is useful for describing the collected product records, identifying country-level differences, and highlighting areas for further investigation. The results should not be generalized to entire national markets because coverage, sample size, duplicate-product patterns, and field completeness vary by country. Future analysis would be stronger with more complete nutrition and classification fields, consistent country coverage, explicit duplicate-product handling, and a larger sample from each market.
