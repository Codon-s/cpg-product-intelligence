# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('datasets/fanta_from_dump.csv')

# %%
df
# Out:
#                code                          product_name  \
# 0     0024622511676       Pepe's, Fantastico Chicharrones
# 1     0035266007265  Tastee, White Pretzel Wonder Fantasy
# 2     0041321016141      Fantastico light cheese dressing
# 3     0041497131815                  Oriental Fantasy Mix
# 4     0049000014235                           Orange Soda
# ...             ...                                   ...
# 4466  7316110001947                      Fantastic fläder
# 4467  5449000322203              Fanta orange low calorie
# 4468  5000112686043                         Fanta Laranja
# 4469  4897148040045          Fanta - Banana and Chocolate
# 4470  9310155012393        fantastic rice crackers chilli
#
#                            brands  \
# 0     Rudolph Foods Company  Inc.
# 1              Tastee Apple  Inc.
# 2                     Bernstein's
# 3       Weis,  Weis Markets  Inc.
# 4                           Fanta
# ...                           ...
# ...

# %%
df.dtypes
# Out:
# code                            object
# product_name                    object
# brands                          object
# categories_tags                 object
# countries_tags                  object
# packaging_tags                  object
# stores                          object
# purchase_places                 object
# nutriscore_grade                object
# nova_group                     float64
# ecoscore_grade                  object
# ingredients_text                object
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# code                              0
# product_name                    108
# brands                         1044
# categories_tags                2368
# countries_tags                   19
# packaging_tags                 4004
# stores                         4190
# purchase_places                4248
# nutriscore_grade                  2
# nova_group                     3326
# ecoscore_grade                 4040
# ingredients_text               2984
# nutriments.sugars_100g         3750
# nutriments.energy-kcal_100g    3719
# dtype: int64

# %%
df.product_name=df['product_name'].fillna('unknown')

# %%
df.brands=df['brands'].fillna('unknown')

# %%
df.categories_tags=df['categories_tags'].fillna('unknown')

# %%
df.countries_tags=df['countries_tags'].fillna('unknown')

# %%
df.stores=df.stores.fillna('unknown')

# %%
df.purchase_places=df.purchase_places.fillna('unknown')

# %%
df.nutriscore_grade=df.nutriscore_grade.fillna('unknown')

# %%
df.eco_grade=df.ecoscore_grade.fillna('unknown')
# Out:
# C:\Users\Sahil bopche\AppData\Local\Temp\ipykernel_19796\26283359.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.eco_grade=df.ecoscore_grade.fillna('unknown')

# %%
df.product_name.unique()
# Out:
# array(["Pepe's, Fantastico Chicharrones",
#        'Tastee, White Pretzel Wonder Fantasy',
#        'Fantastico light cheese dressing', ..., 'Fantastic fläder',
#        'Fanta - Banana and Chocolate', 'fantastic rice crackers chilli'],
#       shape=(2880,), dtype=object)

# %%
df.brands.unique()
# Out:
# array(['Rudolph Foods Company  Inc.', 'Tastee Apple  Inc.', "Bernstein's",
#        'Weis,  Weis Markets  Inc.', 'Fanta', 'Grandma', 'M&S',
#        'BRASSERIE DE TAHITI (sous license), COCA COLA INTERNATIONAL',
#        'Alaus Mathez Chocolatier', 'D.S.D. Merchandisers  Inc.',
#        "Hammond's", "Fanta, Mcdonald's, The Coca Cola Company", 'Casino',
#        'Vahiné', 'Lidl', 'OceanSea,Tesco', 'Favorina', 'unknown',
#        'Disneyland', 'Disneyland Paris', 'favorina', 'Grand Frais',
#        'Cricks', 'Epiceries d’ici et d’ailleurs', 'Petit Furet',
#        'Confiserie Gida, Gida', 'ISAURA', 'Moreno',
#        'Mama Mancini, Roncadin', 'Jacquot', 'Panzani', 'Le Roy René',
#        'Confiserie du Roy René', 'Haribo', 'Cémoi, DIPA, Jacquot',
#        'Cemoi', 'Cémoi', 'DIPA', 'McCormick, Vahiné', 'Arnaud Soubeyran',
#        'Nougat Soubeyran', 'Carrefour, Esprit de fete', 'Serebis', 'U',
#        'Auteuil', 'Cora', 'Belle france', 'Dardenne', 'Franprix',
# ...

# %%
df.countries_tags.unique()
# Out:
# array(['united-states', 'france, spain, united-states',
#        'france, germany, spain', 'france, germany, switzerland',
#        'france, spain', 'france',
#        'bolivia, france, norway, spain, united-states', 'canada',
#        'france, united-kingdom', 'unknown', 'united-kingdom',
#        'belgium, france', 'germany', 'france, saint-pierre-and-miquelon',
#        'france, morocco', 'france, italy, spain', 'france, reunion',
#        'switzerland', 'china', 'france, martinique', 'french-polynesia',
#        'france, world', 'france, switzerland', 'bulgaria, france',
#        'austria, belgium, bulgaria, france, georgia, germany, hungary, italy, nigeria, romania, spain, switzerland, tunisia, united-kingdom',
#        'denmark', 'hong-kong', 'france, japan', 'japan',
#        'belgium, denmark, france', 'france, germany',
#        'france, italy, spain, switzerland', 'france, italy, switzerland',
#        'sweden', 'norway', 'france, serbia', 'serbia', 'belgium',
# ...

# %%
df.ingredients_text.unique()
# Out:
# array(['Pork fat with attached skin, salt.',
#        'Apple, caramel (corn syrup, sugar, condensed milk (milk, sucrose), hydrogenated palm oil, evaporated milk (disodium phosphate, carrageenan), soy flour, lecithin, monodiglyceride, vanillin and salt), chocolate coating (sugar, partially hydrogenated vegetable oil [palm kernel and or palm and/or cottonseed], skim milk powder, cocoa, vanilla, sorbitan tristearate [an emulsifier], soy lecithin [an emulsifier] and salt), pretzels (wheat flour, vital wheat gluten, salt, corn syrup, vegetable oil [may contain one or more of the following: corn, canola, cottonseed, soybean), sodium bicarbonate, yeast).',
# ...

# %%
df.dtypes
# Out:
# code                            object
# product_name                    object
# brands                          object
# categories_tags                 object
# countries_tags                  object
# packaging_tags                  object
# stores                          object
# purchase_places                 object
# nutriscore_grade                object
# nova_group                     float64
# ecoscore_grade                  object
# ingredients_text                object
# nutriments.sugars_100g         float64
# nutriments.energy-kcal_100g    float64
# dtype: object

# %%
df.nova_group.unique()
# Out:
# array([nan,  4.,  3.,  2.,  1.])

# %%
df.nova_group.value_counts()
# Out:
# nova_group
# 4.0    1065
# 3.0      48
# 1.0      28
# 2.0       4
# Name: count, dtype: int64

# %% [markdown]
# WE DROP UNKNOWN COLUMN(IT CONTAINS 316 COUNTS)

# %%
df.nutriscore_grade.value_counts().drop('unknown',errors='ignore').plot(
 kind ='bar',
 figsize =(10, 5),
 title ='Nutri-score Grade Distribution'
)
plt.xticks(rotation=0)
plt.show()

# %%
raw_countries = df.countries_tags.str.split(',')
raw_countries
# Out:
# 0                        [united-states]
# 1                        [united-states]
# 2                        [united-states]
# 3                        [united-states]
# 4       [france,  spain,  united-states]
#                       ...
# 4466                            [sweden]
# 4467                     [united-states]
# 4468                          [portugal]
# 4469                    [united-kingdom]
# 4470                           [bahrain]
# Name: countries_tags, Length: 4471, dtype: object

# %%
exploded_countries = raw_countries.explode()
exploded_countries
# Out:
# 0        united-states
# 1        united-states
# 2        united-states
# 3        united-states
# 4               france
#              ...
# 4466            sweden
# 4467     united-states
# 4468          portugal
# 4469    united-kingdom
# 4470           bahrain
# Name: countries_tags, Length: 4905, dtype: object

# %%
exploded_countries.value_counts()
# Out:
# countries_tags
# france           1455
# united-states     449
# germany           332
# italy             319
# spain             183
#                  ...
# estonia             1
# colombia            1
# ghana               1
# guatemala           1
# honduras            1
# Name: count, Length: 191, dtype: int64

# %%
df.nutriscore_grade[df.nutriscore_grade != 'unknown'].value_counts()
# Out:
# nutriscore_grade
# e                 805
# c                 266
# b                 250
# d                 198
# a                  47
# not-applicable     18
# Name: count, dtype: int64

# %%
df_clean=df['countries_tags'].str.split(',').explode()
df_clean=df_clean.str.strip()
df_clean=df_clean[df_clean!= 'unknown']
df_clean.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Countries with Fanta Products')
plt.xlabel('Countries')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
df.clean=df['categories_tags'].str.split(',').explode()
df.clean=df.clean.str.strip()
df.clean=df.clean[df.clean!= 'unknown']
df.clean.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Categories with Fanta Products')
plt.xlabel('Categories')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Sahil bopche\AppData\Local\Temp\ipykernel_19796\1662676737.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.clean=df['categories_tags'].str.split(',').explode()

# %%
df.clean=df['packaging_tags'].str.split(',').explode()
df.clean=df.clean.str.strip()
df.clean=df.clean[df.clean!= 'unknown']
df.clean.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Packaging Types with Fanta Products')
plt.xlabel('Packaging Types')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
df_clean=df['ecoscore_grade'].str.split(',').explode()
df_clean=df_clean.str.strip()
df_clean=df_clean[df_clean!= 'unknown']
df_clean.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Ecoscore Grades with Fanta Products')
plt.xlabel('Ecoscore Grades')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
df_clean=df['brands'].str.split(',').explode()
df_clean=df_clean.str.strip()
df_clean=df_clean[df_clean!= 'unknown']
df_clean.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Brands with Fanta Products')
plt.xlabel('Brands')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
df_clean=df['purchase_places'].str.split(',').explode()
df_clean=df_clean.str.strip()
df_clean=df_clean[df_clean!= 'unknown']
df_clean.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Purchase Places with Fanta Products')
plt.xlabel('Purchase Places')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
countries = df.countries_tags.str.split(',')
exploded_countries =  raw_countries.explode()
exploded_countries = exploded_countries.str.strip()
exploded_countries.value_counts()['india']
# Out:
# np.int64(76)

# %%
df.packaging_tags.value_counts()
# Out:
# packaging_tags
# plastic                                                                                                                                                               46
# plastic, bag                                                                                                                                                          28
# plastic, bottle                                                                                                                                                       26
# bottle                                                                                                                                                                17
# metal, recyclable-metals, aluminium                                                                                                                                   16
# ...

# %%
raw_countries = df.countries_tags.str.split(',')
exploded_countries = raw_countries.explode()
exploded_countries = exploded_countries.str.strip()
exploded_countries.value_counts()['india']
# Out:
# np.int64(76)

# %%
b_clean = df['stores'].str.split(',').explode()
b_clean = b_clean.str.strip()

# %%
united_states_data = df[df['countries_tags'].str.contains('united-states',case=False, na=False)
                   ][[
                       'product_name',
                       'nutriscore_grade',
                       'nutriments.sugars_100g',
                       'nutriments.energy-kcal_100g',
                       'purchase_places',
                       'categories_tags',
                       'nova_group',
                       'countries_tags',

                   ]]
united_states_data
# Out:
#                                product_name nutriscore_grade  \
# 0           Pepe's, Fantastico Chicharrones          unknown
# 1      Tastee, White Pretzel Wonder Fantasy                d
# 2          Fantastico light cheese dressing                d
# 3                      Oriental Fantasy Mix                d
# 4                               Orange Soda                e
# ...                                     ...              ...
# 4447  Monster Energy Ultra Fantasy Ruby Red          unknown
# 4450                   Fantasy passionfruit          unknown
# 4452                            Fanta lemon          unknown
# 4464                       Orange Flavoured          unknown
# 4467               Fanta orange low calorie          unknown
#
#       nutriments.sugars_100g  nutriments.energy-kcal_100g purchase_places  \
# 0                        NaN                       571.00         unknown
# 1                      28.57                       232.00         unknown
# ...

# %%
countries = united_states_data['nutriscore_grade'].str.split(',')
exploded_countries = countries.explode()
exploded_countries.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='nutriscore_grade'>

# %%
places = united_states_data['purchase_places'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Purchase Places in United States with Fanta Products')
plt.xlabel('Purchase Place')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
categories = united_states_data.copy()
categories = categories['categories_tags'].str.split(',')
categories = categories.explode('categories_tags')
categories = categories[(categories != 'unknown')]

countries = categories.value_counts().head(10).plot(kind='bar')
countries = united_states_data['categories_tags'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Categories in United States with Fanta Products')
plt.xlabel('Categories') 
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
nova_groups = united_states_data['nova_group'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Nova Groups in United States with Fanta Products')
plt.xlabel('Nova Groups')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# ============================================================
# PART 1 — EXTRACT FIVE COUNTRIES INTO ONE DATASET
# ============================================================

# Work on a copy so the original dataframe remains unchanged
fanta_five_countries = df.copy()

# Keep only products belonging to the five selected countries
country_pattern = '|'.join(TARGET_COUNTRIES)

fanta_five_countries = fanta_five_countries[
    fanta_five_countries['countries_tags']
    .str.contains(
        country_pattern,
        case=False,
        na=False
    )
].copy()

# Create a clean Country column
def identify_country(country_string):

    country_string = str(country_string).lower()

    for country in TARGET_COUNTRIES:

        if country in country_string:

            return COUNTRY_LABELS[country]

    return 'Other'


fanta_five_countries['Country'] = (
    fanta_five_countries['countries_tags']
    .apply(identify_country)
)

# Keep only our five countries
fanta_five_countries = fanta_five_countries[
    fanta_five_countries['Country'].isin(
        COUNTRY_ORDER
    )
].copy()

print(
    "Total records:",
    len(fanta_five_countries)
)

print("\nCountry distribution:")

print(
    fanta_five_countries['Country']
    .value_counts()
)

display(
    fanta_five_countries.head()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 9
#       5 # Work on a copy so the original dataframe remains unchanged
#       6 fanta_five_countries = df.copy()
#       7
#       8 # Keep only products belonging to the five selected countries
# ----> 9 country_pattern = '|'.join(TARGET_COUNTRIES)
#      10
#      11 fanta_five_countries = fanta_five_countries[
#      12     fanta_five_countries['countries_tags']
#
# NameError: name 'TARGET_COUNTRIES' is not defined
